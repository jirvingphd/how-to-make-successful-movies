# %% [markdown]
# # Part 2 - Quick EDA Overview of Extracted TMDB Data

# %% [markdown]
# > Quick EDA for checking overview of movie data extracted from TMDB api.

# %% [markdown]
# - How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# - How many movies are there in each of the certification categories (G/PG/PG-13/R)?
# - What is the average revenue per certification category?
# - What is the average budget per certification category

# %%
## Importing custom function for project
# %load_ext autoreload
# %autoreload 2
import project_functions as pf

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

plt.style.use('fivethirtyeight')
sns.set_context('talk')

pd.set_option('display.max_columns',100)

# %%
# plt.rcParams['figure.facecolor']

# %%
# FOLDER = "Data-Previous/tmdb/"
FOLDER = "Data/"
# sorted(os.listdir(FOLDER))

# %%
## Should show students glob
import glob
q  = f"{FOLDER}*combined*"#final*.csv.gz"
files = sorted(glob.glob(q))
files
# Out:
# ['Data/combined_tmdb_api_data.csv.gz']

# %% [markdown]
# ## Concatenating DataFrames

# %%
# df = pd.read_csv(files[0])
# df

# %%
# # df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in files] )
# df_list =  []
# files_error = []
# for f in files:
#     try:
#         temp_df = pd.read_csv(f,lineterminator='\n')
#         df_list.append(temp_df)
#     except Exception as e:
#         print(f"[!] Error for {f}")
#         display(e)
#         files_error.append(f)
        
# # df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in files] )
# df = pd.concat(df_list)
# df
# # df

# %%
# ## drop placeholder imdb ids of 0
# df = df.loc[ df['imdb_id']!='0']
# df

# %% [markdown]
# ### Adding Release Year

# %%
# df['Release Year'] = df['release_date'].apply(lambda x: float(str(x).split('-')[0]))
# df

# %%
## Saving combined data 
fname =FOLDER+'combined_tmdb_api_data.csv.gz'
# Code for making combined file moved to notebook 2A
# df.to_csv(fname,compression='gzip',index=False)
df = pd.read_csv(fname, lineterminator='\n')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93059 entries, 0 to 93058
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  93059 non-null  bool
#  1   backdrop_path          57215 non-null  object
#  2   belongs_to_collection  5218 non-null   object
#  3   budget                 93059 non-null  int64
#  4   genres                 93059 non-null  object
#  5   homepage               25567 non-null  object
#  6   id                     93059 non-null  int64
#  7   imdb_id                93059 non-null  object
#  8   original_language      93059 non-null  object
#  9   original_title         93059 non-null  object
#  10  overview               91122 non-null  object
#  11  popularity             93059 non-null  float64
#  12  poster_path            84711 non-null  object
#  13  production_companies   93059 non-null  object
#  14  production_countries   93059 non-null  object
#  15  release_date           90778 non-null  object
#  16  revenue                93059 non-null  int64
#  17  runtime                93059 non-null  int64
#  18  spoken_languages       93059 non-null  object
#  19  status                 93059 non-null  object
#  20  tagline                33222 non-null  object
#  21  title                  93059 non-null  object
#  22  video                  93059 non-null  bool
#  23  vote_average           93059 non-null  float64
#  24  vote_count             93059 non-null  int64
#  25  certification          18733 non-null  object
#  26  Release Year           90778 non-null  float64
# dtypes: bool(2), float64(3), int64(5), object(17)
# memory usage: 17.9+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1  False                               NaN                   NaN         0
# 2  False   /krEZg9tb6blhc7sV6Us2ZGQ0gA.jpg                   NaN         0
# 3  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4  False  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN         0
#
#                                               genres homepage      id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127
# 1           [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843
# 4                      [{'id': 18, 'name': 'Drama'}]      NaN   49511
#
#      imdb_id original_language   original_title  \
# 0  tt0113026                en  The Fantasticks
# 1  tt0113092                en    For the Cause
# 2  tt0116391                hi             Gang
# 3  tt0118694                cn             花樣年華
# 4  tt0118852                en   Chinese Coffee
#
#                                             overview  popularity  \
# 0  Two rural teens sing and dance their way throu...       2.559
# 1  Earth is in a state of constant war and two co...       3.393
# 2  After falling prey to underworld, four friends...       2.748
# 3  Two neighbors become intimate after discoverin...      27.940
# 4  When Harry Levine, an aging, unsuccessful Gree...       5.495
#
#                         poster_path  \
# 0  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2  /dYcuiiBDpPUvCcPbiWdH4REjGn3.jpg
# 3  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 4  [{'id': 67930, 'logo_path': None, 'name': 'Cha...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0
# 3  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29  14204632
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0
#
#    runtime                                   spoken_languages    status  \
# 0       86  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      100  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      165  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4       99  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification  Release Year
# 0  False         5.500          22           NaN        2000.0
# 1  False         4.958          12           NaN        2000.0
# 2  False         5.000           2           NaN        2000.0
# 3  False         8.109        2433            PG        2000.0
# 4  False         6.600          56             R        2000.0

# %% [markdown]
# # Q1: How many movies had at least some valid financial information (values > 0 for budget OR revenue)?

# %%
## save separeate filters for movie with budget/revenue >0 
filter_budget = df['budget'] > 0
filter_revenue = df['revenue']>0


## print value counts of filters
print('- Movies with >0 for budget:')
display(filter_budget.value_counts())

print('- Movies with >0 for revenue:')
display(filter_revenue.value_counts())
# Out:
# - Movies with >0 for budget:
# False    78739
# True     14320
# Name: budget, dtype: int64
# - Movies with >0 for revenue:
# False    83092
# True      9967
# Name: revenue, dtype: int64

# %%
## compare using and vs or for filtering financials 
filter_and = filter_budget & filter_revenue
print('- If use AND for final filter:')
display(filter_and.value_counts())

filter_or = filter_budget | filter_revenue
print('- If use OR for final filter:')
display(filter_or.value_counts())
# Out:
# - If use AND for final filter:
# False    86906
# True      6153
# dtype: int64
# - If use OR for final filter:
# False    74925
# True     18134
# dtype: int64

# %%
## Using filter_or
filter_financial = filter_and
filter_financial.value_counts()
# Out:
# False    86906
# True      6153
# dtype: int64

# %%
ax = sns.countplot(x=filter_financial)
ax.set_title('# of Movies with SOME Valid Financial Data');

# %%
ax = sns.countplot(x=filter_financial)
ax.set_title('# of Movies with SOME Valid Financial Data');

# %% [markdown]
# >- There are 13,404 movies with financial data (either >0 for revenue OR budget)

# %%
ax = sns.countplot(x=filter_and)
ax.set_title('# of Movies with Both Revenue and Budget',y=1.1);
pf.annotate_bars(ax,fmt=",")
# Out:
# <Axes: title={'center': '# of Movies with Both Revenue and Budget'}, ylabel='count'>

# %%
## Using only filtered financial movies for remaining EDA
plot_df = df[filter_financial].copy()
plot_df
# Out:
#        adult                     backdrop_path  \
# 3      False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 12     False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 14     False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 17     False  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 18     False  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# ...      ...                               ...
# 92808  False  /u9x18arVbh9VRY05aeJ43eaiI3t.jpg
# 92833  False  /pRb9zpNXH1u6Fd4Da9H8PaIDwoY.jpg
# 92961  False                               NaN
# 93025  False                               NaN
# 93058  False  /klb3yODwKMRle19EcvdeSatEZL7.jpg
#
#                                    belongs_to_collection     budget  \
# 3                                                    NaN     150000
# 12                                                   NaN     120000
# 14     {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 17                                                   NaN    8000000
# 18     {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
# ...                                                  ...        ...
# 92808                                                NaN   36000000
# 92833                                                NaN   24066000
# 92961                                                NaN       1000
# 93025                                                NaN          5
# 93058                                                NaN   15000000
#
#                                                   genres  \
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 12     [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 14     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 17     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 18     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                  ...
# 92808                     [{'id': 35, 'name': 'Comedy'}]
# 92833  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 92961  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...
# 93025  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 93058  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                 homepage       id     imdb_id  \
# 3                                                    NaN      843   tt0118694
# 12                                                   NaN    19085   tt0120467
# 14                                                   NaN     7443   tt0120630
# 17                                                   NaN      318   tt0120753
# 18                                                   NaN      955   tt0120755
# ...                                                  ...      ...         ...
# 92808                          https://www.meangirls.com   673593  tt11762114
# 92833                                                NaN   868660  tt14564000
# 92961           https://app.filmhub.com/titles/28d7-302a  1185432  tt28630947
# 93025  https://www.master-hughes.com/thebigfootprophe...  1230046  tt30828956
# 93058                        https://www.nightswim.movie  1072342   tt9682428
#
#       original_language                 original_title  \
# 3                    cn                           花樣年華
# 12                   en                         Vulgar
# 14                   en                    Chicken Run
# 17                   en       The Million Dollar Hotel
# 18                   en         Mission: Impossible II
# ...                 ...                            ...
# 92808                en                     Mean Girls
# 92833                te                   గుంటూరు కారం
# 92961                en  The haunting in rosemary lane
# 93025                en           The bigfoot prophecy
# 93058                en                     Night Swim
#
#                                                 overview  popularity  \
# 3      Two neighbors become intimate after discoverin...      27.940
# 12     Vulgar is about a man who is a children's clow...       7.887
# 14     The creators of Wallace & Gromit bring you an ...      91.080
# 17     The Million Dollar Hotel starts with a jump fr...      11.473
# 18     With computer genius Luther Stickell at his si...      43.305
# ...                                                  ...         ...
# 92808  New student Cady Heron is welcomed into the to...     276.559
# 92833  In 1998, Marx and Lenin in Guntur, both decide...      40.886
# 92961  A story of two men doing a documentary of a ne...       1.004
# 93025      Bigfoot is said to have the power of prophecy       2.127
# 93058  Forced into early retirement by a degenerative...     168.637
#
#                             poster_path  \
# 3      /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 12     /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# 14     /oYbVT9e0k2ZSrRhDSCw2Yqshe1n.jpg
# 17     /iGRyPsZF0lfIL3IadmBdoAsYzyn.jpg
# 18     /1VMWLpk9VXyYcEZ8w3uUhp0OF1v.jpg
# ...                                 ...
# 92808  /fbbj3viSUDEGT1fFFMNpHP1iUjw.jpg
# 92833  /rKzkysQNX9gQIONlMcmz4QvW0Nv.jpg
# 92961  /naiFu3fbD3cNHRrx3ExOv4KNK9I.jpg
# 93025  /3yM1qHKxWhMvDya5d3QHIsBI6pV.jpg
# 93058  /gSkfBGdxdialBMM7P02V4hcI6Ij.jpg
#
#                                     production_companies  \
# 3      [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 12     [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 14     [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...
# 17     [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 18     [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...                                                  ...
# 92808  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...
# 92833  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...
# 92961  [{'id': 209845, 'logo_path': None, 'name': 'Cr...
# 93025  [{'id': 157524, 'logo_path': None, 'name': 'Ma...
# 93058  [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
#
#                                     production_countries release_date  \
# 3      [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29
# 12     [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26
# 14     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-23
# 17     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2000-02-09
# 18     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-05-24
# ...                                                  ...          ...
# 92808  [{'iso_3166_1': 'US', 'name': 'United States o...   2024-01-10
# 92833            [{'iso_3166_1': 'IN', 'name': 'India'}]   2024-01-11
# 92961   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2023-01-10
# 93025                                                 []   2024-01-31
# 93058  [{'iso_3166_1': 'US', 'name': 'United States o...   2024-01-03
#
#          revenue  runtime                                   spoken_languages  \
# 3       14204632       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 12         14904       87  [{'english_name': 'English', 'iso_639_1': 'en'...
# 14     224834564       84  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17        105983      122  [{'english_name': 'English', 'iso_639_1': 'en'...
# 18     546400000      123  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 92808   33200000      113  [{'english_name': 'English', 'iso_639_1': 'en'...
# 92833   15323439      159  [{'english_name': 'Telugu', 'iso_639_1': 'te',...
# 92961        100       58  [{'english_name': 'English', 'iso_639_1': 'en'...
# 93025          4      117                                                 []
# 93058   30600000       98  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#               status                                            tagline  \
# 3           Released  Feel the heat, keep the feeling burning, let t...
# 12          Released   Everyone loves a clown... some more than others.
# 14          Released  There's nothing more determined than poultry w...
# 17          Released                    Everyone has something to hide.
# 18          Released                       Expect the impossible again.
# ...              ...                                                ...
# 92808       Released                                Plastic is forever.
# 92833       Released                                 Highly Inflammable
# 92961       Released                      The haunting in rosemary lane
# 93025  In Production    Bigfoot brings a prophecy to those who seek him
# 93058       Released          Everything you fear is under the surface.
#
#                                title  video  vote_average  vote_count  \
# 3               In the Mood for Love  False         8.109        2433
# 12                            Vulgar  False         5.444          45
# 14                       Chicken Run  False         6.800        4704
# 17          The Million Dollar Hotel  False         5.893         303
# 18            Mission: Impossible II  False         6.123        6299
# ...                              ...    ...           ...         ...
# 92808                     Mean Girls  False         6.800          53
# 92833                  Guntur Kaaram  False         6.000           3
# 92961  The haunting in rosemary lane  False         0.000           0
# 93025           The bigfoot prophecy  False         0.000           0
# 93058                     Night Swim  False         5.095          41
#
#       certification  Release Year
# 3                PG        2000.0
# 12                R        2002.0
# 14                G        2000.0
# 17                R        2000.0
# 18              NaN        2000.0
# ...             ...           ...
# 92808         PG-13        2024.0
# 92833           NaN        2024.0
# 92961           NaN        2023.0
# 93025            NR        2024.0
# 93058         PG-13        2024.0
#
# [6153 rows x 27 columns]

# %% [markdown]
# # Q2: What Years are represented?

# %%
years =sorted( plot_df['Release Year'].dropna().astype(int).unique())
# years

# %%
plt.figure(figsize=(12,5))
ax = sns.countplot(data=plot_df, x='Release Year', order =years );
ax.set_title('Number of Movies in Each Year',y=1.05)
pf.annotate_bars(ax, fmt=',',size=12,convert_millions=False,despine=True,
                 spines=['left','right','bottom'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax
pf.savefig('Images/EDA_year_counts.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/EDA_year_counts.png

# %% [markdown]
# ### Average Revenue By Year

# %%
mill_fmt = pf.get_funcformatter(kind='m',prefix="$",float_fmt=',.0f')
mill_fmt

# %%
plt.figure(figsize=(12,5))
ax = sns.lineplot(data=plot_df, x='Release Year', y='revenue',)#,order =years );
ax.set_title('Average Revenue by Year',y=1.05)
pf.annotate_bars(ax, fmt=',',size=12,convert_millions=False,despine=True,
                 spines=['left','right','bottom'])
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(mill_fmt)
ax.set_xlim(right=2023)
pf.savefig('Images/EDA_avg_revenue_per_year.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/EDA_avg_revenue_per_year.png

# %% [markdown]
# ## Q3: How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
df['certification'].value_counts()
# Out:
# R          6820
# NR         5309
# PG-13      3775
# PG         1963
# G           666
# NC-17       196
# PG-13         2
# TV-PG         1
# Unrated       1
# Name: certification, dtype: int64

# %%
## fixing inconsitent certifications


# fix extra space certs
df['certification'] = df['certification'].str.strip()

## fix certification col
repl_cert = {'UR':'NR',
             'Not Rated':'NR',
             'Unrated':'NR',
             '-':'NR',
             '10':np.nan,
             'ScreamFest Horror Film Festival':'NR'}

df['certification'] = df['certification'].replace(repl_cert)
df['certification'].value_counts(dropna=False)
# Out:
# NaN      74326
# R         6820
# NR        5310
# PG-13     3777
# PG        1963
# G          666
# NC-17      196
# TV-PG        1
# Name: certification, dtype: int64

# %%
## to order them (optional)
cert_order = ['G','PG','PG-13','R','NC-17','NR']

# %%
ax = sns.countplot(data=plot_df, x='certification',order=cert_order);
ax.set_title('Number of Movies in Each Certification',y=1.05)
pf.annotate_bars(ax,fmt=',',size=12,convert_millions=False,despine=True,
                 spines=['left','right','bottom'])
# sns.despine(ax.get_figure(),left=True)
pf.savefig('Images/EDA_certification_counts.png',ax=ax,
           facecolor='white')
# Out:
# - Figure saved as Images/EDA_certification_counts.png

# %% [markdown]
# ## Q4: What is the average revenue per certification category?

# %%
ax= sns.barplot(data=plot_df, x='certification',y='revenue', 
                order=cert_order,errorbar=('ci',68));
pf.annotate_bars(ax, convert_millions=True,fmt='.1f',use_errorbars=True,xytext=(0,10))
ax.set_title('Average Revenue Per MPAA Rating',y=1.15);
ax.yaxis.set_major_formatter(mill_fmt)
pf.savefig('Images/EDA_avg_revenue_by_certification.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/EDA_avg_revenue_by_certification.png

# %% [markdown]
# ## Q5: What is the average budget per certification category?

# %%
ax= sns.barplot(data=plot_df, x='certification',y='budget', 
                order=cert_order,errorbar=("ci",68));
pf.annotate_bars(ax, convert_millions=True,fmt='.1f',xytext= (0,10),use_errorbars=True)
ax.set_title('Average Budget Per MPAA Rating',y=1.15);
ax.yaxis.set_major_formatter(mill_fmt)
pf.savefig('Images/EDA_avg_budget_by_certification.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/EDA_avg_budget_by_certification.png

# %% [markdown]
# ## Q6: What is the average ROI (%) for Movies with All Financial Data?

# %%
## Save plot_df with movies that had buget AND revnue
plot_df = df[filter_and].copy()
## calculate ROI
plot_df['ROI (%)'] = (df['revenue']- df['budget'])/df['budget'] *100

plot_df.info()
plot_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6153 entries, 3 to 93058
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  6153 non-null   bool
#  1   backdrop_path          5922 non-null   object
#  2   belongs_to_collection  1366 non-null   object
#  3   budget                 6153 non-null   int64
#  4   genres                 6153 non-null   object
#  5   homepage               2972 non-null   object
#  6   id                     6153 non-null   int64
#  7   imdb_id                6153 non-null   object
#  8   original_language      6153 non-null   object
#  9   original_title         6153 non-null   object
#  10  overview               6146 non-null   object
#  11  popularity             6153 non-null   float64
#  12  poster_path            6113 non-null   object
#  13  production_companies   6153 non-null   object
#  14  production_countries   6153 non-null   object
#  15  release_date           6138 non-null   object
#  16  revenue                6153 non-null   int64
#  17  runtime                6153 non-null   int64
#  18  spoken_languages       6153 non-null   object
#  19  status                 6153 non-null   object
#  20  tagline                4930 non-null   object
#  21  title                  6153 non-null   object
#  22  video                  6153 non-null   bool
#  23  vote_average           6153 non-null   float64
#  24  vote_count             6153 non-null   int64
#  25  certification          4142 non-null   object
#  26  Release Year           6138 non-null   float64
#  27  ROI (%)                6153 non-null   float64
# dtypes: bool(2), float64(4), int64(5), object(17)
# memory usage: 1.3+ MB
#     adult                     backdrop_path  \
# 3   False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 12  False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 14  False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 17  False  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 18  False  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
#
#                                 belongs_to_collection     budget  \
# 3                                                 NaN     150000
# 12                                                NaN     120000
# 14  {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 17                                                NaN    8000000
# 18  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
#
#                                                genres homepage     id  \
# 3   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843
# 12  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN  19085
# 14  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN   7443
# 17  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN    318
# 18  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      NaN    955
#
#       imdb_id original_language            original_title  \
# 3   tt0118694                cn                      花樣年華
# 12  tt0120467                en                    Vulgar
# 14  tt0120630                en               Chicken Run
# 17  tt0120753                en  The Million Dollar Hotel
# 18  tt0120755                en    Mission: Impossible II
#
#                                              overview  popularity  \
# 3   Two neighbors become intimate after discoverin...      27.940
# 12  Vulgar is about a man who is a children's clow...       7.887
# 14  The creators of Wallace & Gromit bring you an ...      91.080
# 17  The Million Dollar Hotel starts with a jump fr...      11.473
# 18  With computer genius Luther Stickell at his si...      43.305
#
#                          poster_path  \
# 3   /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 12  /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# 14  /oYbVT9e0k2ZSrRhDSCw2Yqshe1n.jpg
# 17  /iGRyPsZF0lfIL3IadmBdoAsYzyn.jpg
# 18  /1VMWLpk9VXyYcEZ8w3uUhp0OF1v.jpg
#
#                                  production_companies  \
# 3   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 12  [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 14  [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...
# 17  [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 18  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                  production_countries release_date    revenue  \
# 3   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29   14204632
# 12  [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26      14904
# 14  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-23  224834564
# 17  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2000-02-09     105983
# 18  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-05-24  546400000
#
#     runtime                                   spoken_languages    status  \
# 3        99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 12       87  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 14       84  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 17      122  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 18      123  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                               tagline  \
# 3   Feel the heat, keep the feeling burning, let t...
# 12   Everyone loves a clown... some more than others.
# 14  There's nothing more determined than poultry w...
# 17                    Everyone has something to hide.
# 18                       Expect the impossible again.
#
#                        title  video  vote_average  vote_count certification  \
# 3       In the Mood for Love  False         8.109        2433            PG
# 12                    Vulgar  False         5.444          45             R
# 14               Chicken Run  False         6.800        4704             G
# 17  The Million Dollar Hotel  False         5.893         303             R
# 18    Mission: Impossible II  False         6.123        6299           NaN
#
#     Release Year      ROI (%)
# 3         2000.0  9369.754667
# 12        2002.0   -87.580000
# 14        2000.0   399.632364
# 17        2000.0   -98.675213
# 18        2000.0   337.120000

# %%
## remove NR from cert-order for ROI
cert_order_roi = cert_order[:-1]
cert_order_roi
# Out:
# ['G', 'PG', 'PG-13', 'R', 'NC-17']

# %%
ax= sns.barplot(data=plot_df, x='certification',y='ROI (%)', 
                order=cert_order_roi,ci=None);
pf.annotate_bars(ax, convert_millions=False,ha='center',xytext=(5,10),fmt=',.1f')
ax.set_title('Average ROI (%) Per MPAA Rating',y=1.1);
ax.yaxis.set_major_formatter('{x:,.0f}%')
pf.savefig('Images/EDA_avg_roi_by_certification.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/EDA_avg_roi_by_certification.png
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_88269/1893341288.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax= sns.barplot(data=plot_df, x='certification',y='ROI (%)',

# %% [markdown]
# # Summary

# %% [markdown]
# - According to initial EDA, R movies are more common, but generate less revenue. However, in terms of ROI, they are almost as successful as PG-13 movies.

# %% [markdown]
# # APPENDIX

# %%
# ## Testing new vers with dynamic number format
# from matplotlib.ticker import FuncFormatter
# def millions(x,pos,prefix='$', suffix=None,float_fmt=","):
#     """function for use wth matplotlib FuncFormatter -  formats money in millions"""
#     x = x*1e-6
#     if suffix is None:
#         suffix="M"
#     string = "{prefix}{x:"+float_fmt+"}{suffix}"
#     return string.format(prefix=prefix,x=x, suffix=suffix)

# fmt = FuncFormatter(lambda x,pos: millions(x,pos, float_fmt=',.0f'))

# # prefix='$'
# # suffix='M'
# # float_fmt = ".0f"

# # fmt = "{prefix}{x*1e-6:,"+float_fmt + "}{suffix}"
# # fmt.format(prefix=prefix, x=1e9,float_fmt=float_fmt, sff )

# %%
ax.lines
# Out:
# <Axes.ArtistList of 0 lines>

# %% [markdown]
# ### BOOKMARK: Geting height of error bars for annotaitons
# - https://stackoverflow.com/questions/46270643/extracting-error-bars-and-point-positions-from-a-python-matplotlib-figure

# %%
# ax.lines

# %%
# def get_line_data(ax,just_error_heights=False):
#     """Adapted From Source: https://stackoverflow.com/a/46271417"""
#     x_list = []
#     lower_list = []
#     upper_list = []
#     for line in ax.lines:
#         x_list.append(line.get_xdata()[0])
#         lower_list.append(line.get_ydata()[0])
#         upper_list.append(line.get_ydata()[1])
        
#     y = 0.5 * (np.asarray(lower_list) + np.asarray(upper_list))
#     y_error = np.asarray(upper_list) - y
#     x = np.asarray(x_list)
    
#     if just_error_heights==False:
#         return x, y, y_error
#     else: 
#         return upper_list

# %%
# x_pos,y_pos,y_error = get_line_data(ax)
# y_error

# %%
# err_height= get_line_data(ax,just_error_heights=True)
# err_height

# %%
# ax.get_figure()
