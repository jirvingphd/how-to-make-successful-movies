# %% [markdown]
# # Part 3 - ETL & MySQL Database

# %% [markdown]
# Your stakeholder wants you to take the data you have been cleaning and collecting in Parts 1 &amp; 2 of the project, and wants you to create a MySQL database for them.
# <p>You should normalize the tables as best you can before adding them to your new database.</p>
# <ul>
# <li>Note: an important exception to their request is that they would like you to keep all of the data from the TMDB API in 1 table together (even though it will not be perfectly normalized).&nbsp;&nbsp;</li><li>You only need to keep the imdb_id, revenue, budget, and certification columns</li>
# </ul>
# </li>
# </ul>
# <h4>Required Transformation steps:</h4>
# <ul>
# <li>
# <p><strong>Normalize Genre:</strong></p>
# <ul>
# <li>Convert the single string of genres from title basics into 2 new tables.
# <ol>
# <li>
# <p><code>title_genres</code>:  with the columns:</p>
# <ul>
# <li>tconst</li>
# <li>genre_id</li>
# </ul>
# </li>
# <li>
# <p><code>genres</code>:</p>
# <ul>
# <li>genre_id</li>
# <li>genre_name</li>
# </ul>
# </li>
# </ol>
# </li>
# </ul>
# </li>
# <li>
# <p><strong>Discard unnecessary information:</strong></p>
# <ul>
# <li>For the <code>title basics</code> table, drop the following columns:
# <ul>
# <li>"original_title" (we will use the primary title column instead)</li>
# <li>"isAdult" ("Adult" will show up in the genres so this is redundant information).</li>
# <li>"titleType" (every row will be a movie).</li>
# <li>"genres" and other variants of genre (genre is now represented in the 2 new tables described above.</li>
# </ul>
# </li>
# <li>Do not include the <code>title_akas</code> table in your SQL database.
# <ul>
# <li>You have already filtered out the desired movies using this table and the remaining data is mostly nulls and not of-interest to the stakeholder.</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# <h4>MySQL Database Requirements</h4>
# <ul>
# <li>
# <p>Use sqlalchemy with pandas to execute your SQL queries inside your notebook.</p>
# </li>
# <li>
# <p>Create a new database on your MySQL server and  call it "movies".</p>
# </li>
# <li>
# <p>Make sure to have the following tables in your "movies" database:</p>
# <ul>
# <li><code>title_basics</code></li>
# <li><code>title_ratings</code></li>
# <li><code>title_genres</code></li>
# <li><code>genres</code></li>
# <li><code>tmdb_data</code></li>
# </ul>
# </li>
# <li>
# <p>Make sure to set a Primary Key for each table.</p>
# </li>
# <li>
# <p>After creating each table, show the first 5 rows of that table using a SQL query.</p>
# </li>
# <li>
# <p>Make sure to run the "SHOW TABLES" SQL query at the end of your notebook to show that all required tables have been created.</p></li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json
import missingno as ms

plt.rcParams['figure.facecolor'] = 'white'

pd.set_option('display.max_columns',100)

# %%
## Folder to save IMDB files
FOLDER = "Data/"
# os.makedirs(FOLDER,exist_ok=True)
sorted(os.listdir(FOLDER))
# Out:
# ['combined_tmdb_api_data.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'final_tmdb_data_2022.csv.gz',
#  'names_basics.csv.gz',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_crew_cleaned.csv.gz',
#  'title_principals.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json']

# %% [markdown]
# ## Extract: Loading Previous Data

# %% [markdown]
# ### Title Basics

# %%
## title basics
basics = pd.read_csv(f'{FOLDER}title_basics_cleaned.csv.gz',low_memory=False)
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112958 entries, 0 to 112957
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          112958 non-null  object
#  1   titleType       112958 non-null  object
#  2   primaryTitle    112958 non-null  object
#  3   originalTitle   112958 non-null  object
#  4   isAdult         112958 non-null  int64
#  5   startYear       112958 non-null  float64
#  6   runtimeMinutes  112958 non-null  int64
#  7   genres          112958 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.9+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0     2001.0
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                 The Other Side of the Wind        0     2018.0
# 3                          The Naked Monster        0     2005.0
# 4                   Grizzly II: The Predator        0     2020.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74   Horror,Music,Thriller

# %% [markdown]
# ### Title Ratings

# %%
## title ratings
ratings = pd.read_csv(f"{FOLDER}/title_ratings_cleaned.csv.gz",low_memory=False)
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85096 entries, 0 to 85095
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         85096 non-null  object
#  1   averageRating  85096 non-null  float64
#  2   numVotes       85096 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.9+ MB
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     83831
# 1  tt0062336            6.4       161
# 2  tt0069049            6.7      7236
# 3  tt0088751            5.2       320
# 4  tt0093119            2.9      1186

# %% [markdown]
# ### TMDB API Results

# %% [markdown]
# - Students should have combined the years 2000 and 2001 as part of Part 2. I forgot to do so so I am doing here

# %%
## INSTRUCTOR CODE (not taught to students)
import glob
q = f"{FOLDER}final*.csv.gz"
files = glob.glob(q)
files
# Out:
# ['Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2018.csv.gz',
#  'Data/final_tmdb_data_2014.csv.gz',
#  'Data/final_tmdb_data_2022.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2016.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2020.csv.gz',
#  'Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2012.csv.gz',
#  'Data/final_tmdb_data_2010.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2019.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2015.csv.gz',
#  'Data/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2017.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2013.csv.gz',
#  'Data/final_tmdb_data_2011.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz']

# %%
## INSTRUCTOR CODE (not taught to students)
df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in files])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78397 entries, 0 to 1516
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  78397 non-null  bool
#  1   backdrop_path          43654 non-null  object
#  2   belongs_to_collection  3943 non-null   object
#  3   budget                 78397 non-null  int64
#  4   genres                 78397 non-null  object
#  5   homepage               21370 non-null  object
#  6   id                     78397 non-null  int64
#  7   imdb_id                78397 non-null  object
#  8   original_language      78397 non-null  object
#  9   original_title         78397 non-null  object
#  10  overview               76518 non-null  object
#  11  popularity             78397 non-null  float64
#  12  poster_path            68663 non-null  object
#  13  production_companies   78397 non-null  object
#  14  production_countries   78397 non-null  object
#  15  release_date           76442 non-null  object
#  16  revenue                78397 non-null  int64
#  17  runtime                76952 non-null  float64
#  18  spoken_languages       78397 non-null  object
#  19  status                 78397 non-null  object
#  20  tagline                26818 non-null  object
#  21  title                  78397 non-null  object
#  22  video                  78397 non-null  bool
#  23  vote_average           78397 non-null  float64
#  24  vote_count             78397 non-null  int64
#  25  certification          16961 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(17)
# memory usage: 15.1+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False                               NaN                   NaN    100000
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
#
#                                               genres  \
# 0                                                 []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                                                NaN   30356  tt0144280
# 1                                                NaN   58520  tt0197633
# 2                                                NaN  459563  tt0204250
# 3  http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                NaN    9925  tt0244521
#
#   original_language                 original_title  \
# 0                en  Whispers from a Shallow Grave
# 1                en         Live Freaky Die Freaky
# 2                en          Death of a Saleswoman
# 3                en                Children of Men
# 4                en                    Funny Money
#
#                                             overview  popularity  \
# 0  When a beautiful photo model disappears, polic...       0.714
# 1  It is the year 3069 and the Earth has been rob...       1.957
# 2  Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3  In 2027, in a chaotic world in which humans ca...      18.314
# 4  Henry Perkins, a mild-mannered accountant, acc...       4.218
#
#                         poster_path  \
# 0  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                 production_companies  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FW...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31         0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18         0
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22  70595464
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01         0
#
#    runtime                                   spoken_languages    status  \
# 0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  6 housewives. 1 dead body. A trunk full of pla...
# 3                  The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases w...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R

# %%
## Dropping Placeholder rows with id=0
df = df.loc[ df['imdb_id']!='0']
df
# Out:
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False                               NaN                   NaN    100000
# 1     False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2     False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3     False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4     False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
# ...     ...                               ...                   ...       ...
# 1512  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN         0
# 1513  False                               NaN                   NaN         0
# 1514  False                               NaN                   NaN         0
# 1515  False                               NaN                   NaN         0
# 1516  False                               NaN                   NaN       400
#
#                                                  genres  \
# 0                                                    []
# 1     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                 ...
# 1512                [{'id': 99, 'name': 'Documentary'}]
# 1513  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1514                [{'id': 99, 'name': 'Documentary'}]
# 1515                [{'id': 99, 'name': 'Documentary'}]
# 1516  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage      id    imdb_id  \
# 0                                                   NaN   30356  tt0144280
# 1                                                   NaN   58520  tt0197633
# 2                                                   NaN  459563  tt0204250
# 3     http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                   NaN    9925  tt0244521
# ...                                                 ...     ...        ...
# 1512                      http://icarusfilms.com/if-cli  387250  tt7098636
# 1513                                                NaN  640680  tt7246872
# 1514  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 1515                                                NaN  713681  tt9414698
# 1516                                                NaN  253999  tt9641790
#
#      original_language                 original_title  \
# 0                   en  Whispers from a Shallow Grave
# 1                   en         Live Freaky Die Freaky
# 2                   en          Death of a Saleswoman
# 3                   en                Children of Men
# 4                   en                    Funny Money
# ...                ...                            ...
# 1512                fr   Le Clitoris, ce cher inconnu
# 1513                en         Tokyo Bedoone Tavaghof
# 1514                en             Zimbabwe Countdown
# 1515                en                   The Hot Shoe
# 1516                en                     Clearwater
#
#                                                overview  popularity  \
# 0     When a beautiful photo model disappears, polic...       0.714
# 1     It is the year 3069 and the Earth has been rob...       1.957
# 2     Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3     In 2027, in a chaotic world in which humans ca...      18.314
# 4     Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                 ...         ...
# 1512  Topics about female sexuality are growing in p...       1.400
# 1513                                                NaN       0.600
# 1514  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 1515  A Documentary Movie About Card Counting In The...       0.600
# 1516  A woman has been abducted by the Clearwater ki...       2.744
#
#                            poster_path  \
# 0     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1     /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4     /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                ...
# 1512  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 1513  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 1514  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 1515                               NaN
# 1516  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                    production_companies  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4     [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                 ...
# 1512  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 1513                                                 []
# 1514  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 1515                                                 []
# 1516  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                 ...          ...
# 1512           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 1513             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 1514  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 1515                                                 []   2003-01-01
# 1516                                                 []   2003-06-10
#
#        revenue  runtime                                   spoken_languages  \
# 0            0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3     70595464    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...        ...      ...                                                ...
# 1512         0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1513         0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 1514         0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1515         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1516         0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 0     Released                                                NaN
# 1     Released                                                NaN
# 2     Released  6 housewives. 1 dead body. A trunk full of pla...
# 3     Released                  The future's a thing of the past.
# 4     Released  Henry Perkins accidentally trades briefcases w...
# ...        ...                                                ...
# 1512  Released                                                NaN
# 1513  Released                                                NaN
# 1514  Released                                                NaN
# 1515  Released                                                NaN
# 1516  Released                                                NaN
#
#                                  title  video  vote_average  vote_count  \
# 0        Whispers from a Shallow Grave  False           2.0           2
# 1               Live Freaky Die Freaky  False           3.8           8
# 2                Death of a Saleswoman  False           3.0           1
# 3                      Children of Men  False           7.6        5794
# 4                          Funny Money  False           5.4          39
# ...                                ...    ...           ...         ...
# 1512  The Clitoris: Forbidden Pleasure  False           8.0           2
# 1513                   Tokyo, Non-Stop  False           0.0           0
# 1514                Zimbabwe Countdown  False           5.0           4
# 1515                      The Hot Shoe  False           0.0           0
# 1516                        Clearwater  False           0.0           0
#
#      certification
# 0              NaN
# 1               NR
# 2              NaN
# 3                R
# 4                R
# ...            ...
# 1512           NaN
# 1513           NaN
# 1514           NaN
# 1515           NaN
# 1516           NaN
#
# [78397 rows x 26 columns]

# %% [markdown]
# # Transform

# %% [markdown]
# ## basics

# %% [markdown]
# - normalize and separate genre
# - "original_title" (we will use the primary title column instead)
# - "isAdult" ("Adult" will show up in the genres so this is redundant information).
# - "titleType" (every row will be a movie).
# - "genres" and other variants of genre (genre is now represented in the 2 new tables described above.

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112958 entries, 0 to 112957
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          112958 non-null  object
#  1   titleType       112958 non-null  object
#  2   primaryTitle    112958 non-null  object
#  3   originalTitle   112958 non-null  object
#  4   isAdult         112958 non-null  int64
#  5   startYear       112958 non-null  float64
#  6   runtimeMinutes  112958 non-null  int64
#  7   genres          112958 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.9+ MB

# %%
cols_to_drop = ['originalTitle','isAdult','titleType'] #endYear not req'd
basics = basics.drop(columns=cols_to_drop)
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0088751                                  The Naked Monster
# 4       tt0093119                                Grizzly II: Revenge
# ...           ...                                                ...
# 112953  tt9915436                                  Vida em Movimento
# 112954  tt9915872                               The Last White Witch
# 112955  tt9916170                                      The Rehearsal
# 112956  tt9916190                                          Safeguard
# 112957  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2018.0             122                      Drama
# 3          2005.0             100       Comedy,Horror,Sci-Fi
# 4          2020.0              74      Horror,Music,Thriller
# ...           ...             ...                        ...
# 112953     2019.0              70                Documentary
# 112954     2019.0              97       Comedy,Drama,Fantasy
# 112955     2019.0              51                      Drama
# 112956     2020.0              90  Action,Adventure,Thriller
# 112957     2020.0              92              Drama,History
#
# [112958 rows x 5 columns]

# %% [markdown]
# ### Normalizing Genre

# %%
## Fill Missing Genres 
## Create a new column with the single-string genres as a list of strings
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0088751                                  The Naked Monster
# 4       tt0093119                                Grizzly II: Revenge
# ...           ...                                                ...
# 112953  tt9915436                                  Vida em Movimento
# 112954  tt9915872                               The Last White Witch
# 112955  tt9916170                                      The Rehearsal
# 112956  tt9916190                                          Safeguard
# 112957  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres  \
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2018.0             122                      Drama
# 3          2005.0             100       Comedy,Horror,Sci-Fi
# 4          2020.0              74      Horror,Music,Thriller
# ...           ...             ...                        ...
# 112953     2019.0              70                Documentary
# 112954     2019.0              97       Comedy,Drama,Fantasy
# 112955     2019.0              51                      Drama
# 112956     2020.0              90  Action,Adventure,Thriller
# 112957     2020.0              92              Drama,History
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3            [Comedy, Horror, Sci-Fi]
# 4           [Horror, Music, Thriller]
# ...                               ...
# 112953                  [Documentary]
# 112954       [Comedy, Drama, Fantasy]
# 112955                        [Drama]
# 112956  [Action, Adventure, Thriller]
# 112957               [Drama, History]
#
# [112958 rows x 6 columns]

# %%
## Explode the dataframe to make each genre into a separate row
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# ...           ...                                                ...
# 112956  tt9916190                                          Safeguard
# 112956  tt9916190                                          Safeguard
# 112956  tt9916190                                          Safeguard
# 112957  tt9916362                                              Coven
# 112957  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres genres_split
# 0          2001.0             118     Comedy,Fantasy,Romance       Comedy
# 0          2001.0             118     Comedy,Fantasy,Romance      Fantasy
# 0          2001.0             118     Comedy,Fantasy,Romance      Romance
# 1          2020.0              70                      Drama        Drama
# 2          2018.0             122                      Drama        Drama
# ...           ...             ...                        ...          ...
# 112956     2020.0              90  Action,Adventure,Thriller       Action
# 112956     2020.0              90  Action,Adventure,Thriller    Adventure
# 112956     2020.0              90  Action,Adventure,Thriller     Thriller
# 112957     2020.0              92              Drama,History        Drama
# 112957     2020.0              92              Drama,History      History
#
# [201185 rows x 6 columns]

# %% [markdown]
# #### Create title_genres Table - title_genres
# tconst: GenreID

# %%
## Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %% [markdown]
# #### Replacing Text Genres with Integer IDs

# %%
## Getting unique list of genres
unique_genres = sorted(title_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
## Make a dictionary with list of unique genres as the key and the new iteger id as vlaues
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Documentary': 7,
#  'Drama': 8,
#  'Family': 9,
#  'Fantasy': 10,
#  'Game-Show': 11,
#  'History': 12,
#  'Horror': 13,
#  'Music': 14,
#  'Musical': 15,
#  'Mystery': 16,
#  'News': 17,
#  'Reality-TV': 18,
#  'Romance': 19,
#  'Sci-Fi': 20,
#  'Short': 21,
#  'Sport': 22,
#  'Talk-Show': 23,
#  'Thriller': 24,
#  'War': 25,
#  'Western': 26}

# %% [markdown]
# #### Replacing Values in title_genres Table with Genre ID

# %%
## Use .map or .replace with our genre_id_map dictionary
title_genres['Genre_ID'] = title_genres['genres_split'].replace(genre_id_map)

## Drop the original genre column
title_genres.drop(columns=['genres_split'],inplace=True)
title_genres
# Out:
#            tconst  Genre_ID
# 0       tt0035423         5
# 0       tt0035423        10
# 0       tt0035423        19
# 1       tt0062336         8
# 2       tt0069049         8
# ...           ...       ...
# 112956  tt9916190         0
# 112956  tt9916190         2
# 112956  tt9916190        24
# 112957  tt9916362         8
# 112957  tt9916362        12
#
# [201185 rows x 2 columns]

# %% [markdown]
# #### Create `genres` table
# - Genre : Genre_ID

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Dropping original genre columns 
basics = basics.drop(columns=['genres','genres_split'])
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0088751                                  The Naked Monster
# 4       tt0093119                                Grizzly II: Revenge
# ...           ...                                                ...
# 112953  tt9915436                                  Vida em Movimento
# 112954  tt9915872                               The Last White Witch
# 112955  tt9916170                                      The Rehearsal
# 112956  tt9916190                                          Safeguard
# 112957  tt9916362                                              Coven
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2018.0             122
# 3          2005.0             100
# 4          2020.0              74
# ...           ...             ...
# 112953     2019.0              70
# 112954     2019.0              97
# 112955     2019.0              51
# 112956     2020.0              90
# 112957     2020.0              92
#
# [112958 rows x 4 columns]

# %% [markdown]
# # LOAD

# %% [markdown]
# ## Connect to MySQL

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *

# %%
## Getting mysql server password
import json
with open('/Users/codingdojo/.secret/mysql.json') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['user', 'password'])

# %%
## create a new movies database
connect_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies"

# %%
## Check if database exists, if not, create it
if database_exists(connect_str) == False:
    print("Creating the database.")
    create_database(connect_str)
else:
    print('The database already exists.')
# Out:
# The database already exists.

# %%
## create engine
engine = create_engine(connect_str)

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
tables = pd.read_sql(q, engine)
tables
# Out:
#    Tables_in_movies
# 0            genres
# 1  name_professions
# 2       professions
# 3      title_basics
# 4      title_genres
# 5     title_ratings
# 6     tmdb_data_aab
# 7     tmdb_data_mvp

# %% [markdown]
# ### Saving`title_basics` to db

# %%
## saving text length
key_len = basics['tconst'].map(len).max()
title_len = basics['primaryTitle'].map(len).max()
key_len, title_len
# Out:
# (10, 242)

# %%
basics_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'runtimeMinutes':Integer()
    }
basics_schema
# Out:
# {'tconst': String(length=11),
#  'primaryTitle': Text(length=243),
#  'startYear': Float(),
#  'runtimeMinutes': Integer()}

# %%
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0088751                                  The Naked Monster
# 4       tt0093119                                Grizzly II: Revenge
# ...           ...                                                ...
# 112953  tt9915436                                  Vida em Movimento
# 112954  tt9915872                               The Last White Witch
# 112955  tt9916170                                      The Rehearsal
# 112956  tt9916190                                          Safeguard
# 112957  tt9916362                                              Coven
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2018.0             122
# 3          2005.0             100
# 4          2020.0              74
# ...           ...             ...
# 112953     2019.0              70
# 112954     2019.0              97
# 112955     2019.0              51
# 112956     2020.0              90
# 112957     2020.0              92
#
# [112958 rows x 4 columns]

# %%
## Saving basics as table with schema,
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)

## setting title basics as the primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
## query first rows 
q = """SELECT * FROM title_basics LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0093119                                Grizzly II: Revenge     2020.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             100
# 4              74

# %% [markdown]
# ### Saving Genre Tables

# %% [markdown]
# #### Saving genre_lookup

# %%
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Primary key is Genre_ID
genre_lookup.to_sql('genres',engine,index=False, if_exists='replace')

engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`Genre_ID`);')

# %%
q = """SELECT * FROM genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Saving `title_genres` table

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
title_genres.to_sql('title_genres',engine,index=False,
                    if_exists='replace' )

# engine.execute('ALTER TABLE title_genres ADD PRIMARY KEY (`tconst`);')
# Out:
# 201185

# %%
q = """SELECT * FROM title_genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  Genre_ID
# 0  tt0035423         5
# 1  tt0035423        10
# 2  tt0035423        19
# 3  tt0062336         8
# 4  tt0069049         8

# %% [markdown]
# ### Saving `title_ratings`

# %%
ratings_schema = {'tconst':String(key_len+1), 
                 'averageRating':Float(),
                 'numVotes':Integer()}#get_schema(ratings)
ratings_schema
# Out:
# {'tconst': String(length=11), 'averageRating': Float(), 'numVotes': Integer()}

# %%
ratings.to_sql('title_ratings',engine,if_exists='replace',index=False,
              dtype=ratings_schema)
engine.execute("ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`)")

# %%
q = """SELECT * FROM title_ratings LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     83831
# 1  tt0062336            6.4       161
# 2  tt0069049            6.7      7236
# 3  tt0088751            5.2       320
# 4  tt0093119            2.9      1186

# %% [markdown]
# ### Saving TMDB API Data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78397 entries, 0 to 1516
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  78397 non-null  bool
#  1   backdrop_path          43654 non-null  object
#  2   belongs_to_collection  3943 non-null   object
#  3   budget                 78397 non-null  int64
#  4   genres                 78397 non-null  object
#  5   homepage               21370 non-null  object
#  6   id                     78397 non-null  int64
#  7   imdb_id                78397 non-null  object
#  8   original_language      78397 non-null  object
#  9   original_title         78397 non-null  object
#  10  overview               76518 non-null  object
#  11  popularity             78397 non-null  float64
#  12  poster_path            68663 non-null  object
#  13  production_companies   78397 non-null  object
#  14  production_countries   78397 non-null  object
#  15  release_date           76442 non-null  object
#  16  revenue                78397 non-null  int64
#  17  runtime                76952 non-null  float64
#  18  spoken_languages       78397 non-null  object
#  19  status                 78397 non-null  object
#  20  tagline                26818 non-null  object
#  21  title                  78397 non-null  object
#  22  video                  78397 non-null  bool
#  23  vote_average           78397 non-null  float64
#  24  vote_count             78397 non-null  int64
#  25  certification          16961 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(17)
# memory usage: 15.1+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False                               NaN                   NaN    100000
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
#
#                                               genres  \
# 0                                                 []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                                                NaN   30356  tt0144280
# 1                                                NaN   58520  tt0197633
# 2                                                NaN  459563  tt0204250
# 3  http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                NaN    9925  tt0244521
#
#   original_language                 original_title  \
# 0                en  Whispers from a Shallow Grave
# 1                en         Live Freaky Die Freaky
# 2                en          Death of a Saleswoman
# 3                en                Children of Men
# 4                en                    Funny Money
#
#                                             overview  popularity  \
# 0  When a beautiful photo model disappears, polic...       0.714
# 1  It is the year 3069 and the Earth has been rob...       1.957
# 2  Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3  In 2027, in a chaotic world in which humans ca...      18.314
# 4  Henry Perkins, a mild-mannered accountant, acc...       4.218
#
#                         poster_path  \
# 0  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                 production_companies  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FW...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31         0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18         0
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22  70595464
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01         0
#
#    runtime                                   spoken_languages    status  \
# 0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  6 housewives. 1 dead body. A trunk full of pla...
# 3                  The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases w...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R

# %% [markdown]
# ### Instructor Note: Saving 2 versions of API data: MVP and AAB

# %%
## Keeping some columns
cols_to_keep = ['imdb_id','budget','revenue','certification',
                'original_language']
mvp = df[cols_to_keep]
mvp
# Out:
#         imdb_id    budget   revenue certification original_language
# 0     tt0144280    100000         0           NaN                en
# 1     tt0197633         0         0            NR                en
# 2     tt0204250         0         0           NaN                en
# 3     tt0206634  76000000  70595464             R                en
# 4     tt0244521         0         0             R                en
# ...         ...       ...       ...           ...               ...
# 1512  tt7098636         0         0           NaN                fr
# 1513  tt7246872         0         0           NaN                en
# 1514  tt7637550         0         0           NaN                en
# 1515  tt9414698         0         0           NaN                en
# 1516  tt9641790       400         0           NaN                en
#
# [78397 rows x 5 columns]

# %%
mvp.isna().sum()
# Out:
# imdb_id                  0
# budget                   0
# revenue                  0
# certification        61436
# original_language        0
# dtype: int64

# %%
mvp
# Out:
#         imdb_id    budget   revenue certification original_language
# 0     tt0144280    100000         0           NaN                en
# 1     tt0197633         0         0            NR                en
# 2     tt0204250         0         0           NaN                en
# 3     tt0206634  76000000  70595464             R                en
# 4     tt0244521         0         0             R                en
# ...         ...       ...       ...           ...               ...
# 1512  tt7098636         0         0           NaN                fr
# 1513  tt7246872         0         0           NaN                en
# 1514  tt7637550         0         0           NaN                en
# 1515  tt9414698         0         0           NaN                en
# 1516  tt9641790       400         0           NaN                en
#
# [78397 rows x 5 columns]

# %%
## saving text length
key_len = mvp['imdb_id'].map(len).max()
cert_len = mvp['certification'].fillna('').map(len).max()
lang_len = mvp['original_language'].map(len).max()

key_len, cert_len,lang_len
# Out:
# (10, 31, 2)

# %%
## saving schema
api_data_schema = {'imdb_id':String(key_len+1), 
                 'budget':Float(),
                   'revenue':Float(),
                 'certification':Text(cert_len+1),
                  'original_language':Text(lang_len+1)}
api_data_schema
# Out:
# {'imdb_id': String(length=11),
#  'budget': Float(),
#  'revenue': Float(),
#  'certification': Text(length=32),
#  'original_language': Text(length=3)}

# %%
# saving mvp version
## Primary key is Genre_ID
mvp.to_sql('tmdb_data_mvp',engine, index=False,dtype=api_data_schema, if_exists='replace')

engine.execute('ALTER TABLE tmdb_data_mvp ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb_data_mvp LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#      imdb_id      budget     revenue certification original_language
# 0  tt0035423  48000000.0  76019000.0         PG-13                en
# 1  tt0062336         0.0         0.0          None                es
# 2  tt0069049  12000000.0         0.0             R                en
# 3  tt0088751    350000.0         0.0          None                en
# 4  tt0093119   7500000.0         0.0          None                en

# %%
df.head()
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False                               NaN                   NaN    100000
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
#
#                                               genres  \
# 0                                                 []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                                                NaN   30356  tt0144280
# 1                                                NaN   58520  tt0197633
# 2                                                NaN  459563  tt0204250
# 3  http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                NaN    9925  tt0244521
#
#   original_language                 original_title  \
# 0                en  Whispers from a Shallow Grave
# 1                en         Live Freaky Die Freaky
# 2                en          Death of a Saleswoman
# 3                en                Children of Men
# 4                en                    Funny Money
#
#                                             overview  popularity  \
# 0  When a beautiful photo model disappears, polic...       0.714
# 1  It is the year 3069 and the Earth has been rob...       1.957
# 2  Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3  In 2027, in a chaotic world in which humans ca...      18.314
# 4  Henry Perkins, a mild-mannered accountant, acc...       4.218
#
#                         poster_path  \
# 0  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                 production_companies  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FW...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31         0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18         0
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22  70595464
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01         0
#
#    runtime                                   spoken_languages    status  \
# 0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  6 housewives. 1 dead body. A trunk full of pla...
# 3                  The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases w...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R

# %%
# # saving AAB version
# ## Primary key is Genre_ID
# df.to_sql('tmdb_data_aab',engine, index=False,dtype=api_data_schema, if_exists='replace')
# engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %% [markdown]
# ### Troubleshoot: Error with AAB Version

# %% [markdown]
# - Error when trying to save AAB version.
# - Built a recursive feature addition loop to try adding more and more columns before running command that error'd.
# - Used function to programmatically make new schema each time (thinking the schema was part of the issue - but it may have been fine).

# %%
def get_schema(table,debug=False):
    ## save pandas dtypes in list, make empty dict
    dtypes = table.dtypes
    schema = {}
    
    # for each column
    for col in dtypes.index:
        ## print info if in debug mode
        if debug:
            print(f"{col} = {dtypes.loc[col]}")

        ## if its a string column (object)
        if dtypes.loc[col]=='object':
            
            ## Fill null values and make sure whole column is str
            data = table[col].fillna('').astype(str)
            
            ## get len first
            len_str = data.map(len).max()
            
            ## if the string is shorter than 21845 use String
            # (forget how i knew it was max size)
            if len_str < 21845:
                schema[col] = String( len_str + 1)
                
            ## If longer use Text
            else:
                schema[col] = Text(len_str+1)
        
        # if float make Float
        elif dtypes.loc[col] == 'float':
            schema[col] = Float()

        ## if int make Integer
        elif dtypes.loc[col] == 'int':
            schema[col] = Integer()
            
        ## if bool make Boolean
        elif dtypes.loc[col] == 'bool':
            schema[col] = Boolean()
            
    return schema

# %% [markdown]
# ## Bookmark: Need to Fix Title/Original Title

# %% [markdown]
# - Asian characters seem to be the issue. Need to identify and remove rows with incompatible characters.

# %%
len(df)
# Out:
# 78397

# %%
# identifying incomaptible rows
bad_titles = (df['original_title']!=df['title']) &\
                (df['original_language']!='en') &\
               ~df['spoken_languages'].str.contains('english',case=False)
df[bad_titles]
# Out:
#       adult                     backdrop_path belongs_to_collection  budget  \
# 565   False  /fU0dGkCASuB4CJ9ZHNnFYLAecuu.jpg                   NaN       0
# 596   False                               NaN                   NaN       0
# 817   False  /ryqbSDlFxLsdRZD52OHCJCUCMKq.jpg                   NaN       0
# 932   False  /gm5WpO1MD91Jd9MyIzKz2ztlgpS.jpg                   NaN       0
# 1251  False                               NaN                   NaN       0
# ...     ...                               ...                   ...     ...
# 1427  False                               NaN                   NaN       0
# 1428  False  /trBTaWhFmjfJWxbNQAoV8QQ4i7c.jpg                   NaN       0
# 1462  False  /e566QSXmxtn08Tsk4kBCfaCztln.jpg                   NaN       0
# 1464  False                               NaN                   NaN       0
# 1486  False                               NaN                   NaN       0
#
#                                                  genres  \
# 565   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 596                       [{'id': 18, 'name': 'Drama'}]
# 817                 [{'id': 99, 'name': 'Documentary'}]
# 932                       [{'id': 18, 'name': 'Drama'}]
# 1251                                                 []
# ...                                                 ...
# 1427                                                 []
# 1428  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1462  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1464                      [{'id': 18, 'name': 'Drama'}]
# 1486                                                 []
#
#                      homepage      id     imdb_id original_language  \
# 565                       NaN   59267   tt0456481                hi
# 596   http://www.nachbeben.ch  121742   tt0459116                de
# 817                       NaN   50543   tt0474297                fr
# 932                       NaN  115093   tt0482178                es
# 1251                      NaN  193449   tt0762124                ar
# ...                       ...     ...         ...               ...
# 1427                      NaN  645446  tt12224088                cn
# 1428                      NaN  801752  tt12229484                cn
# 1462                      NaN   65198   tt2137417                cn
# 1464                      NaN  193267   tt2162737                ko
# 1486                      NaN  519725   tt3075984                si
#
#           original_title                                           overview  \
# 565             जान ए मन  Agastya a NASA scientist comes in search of hi...
# 596            Nachbeben  Investment banker HP has allegedly ridden out ...
# 817   La planète blanche  The White Planet or in French, La Planète Blan...
# 932      Cabeza de perro  A drama about a boy who lives in a bubble beca...
# 1251                ويجا  Two strangers try to solve a mystery that revo...
# ...                  ...                                                ...
# 1427                  痛愛  When women love to be crazy, their consequence...
# 1428          偷窺樂無窮之紋身怪客  The story of the tattoo artist Ching and the p...
# 1462                極樂酷刑  Young Ngai planned to castrate himself to ente...
# 1464              우리의 향기  Although an initial match-making attempt betwe...
# 1486       Sakman Maluwa  The calm, dull marriage of a young woman and h...
#
#       popularity                       poster_path  \
# 565        2.212  /qBCQOQOZyeJKljODcGZbzr80REn.jpg
# 596        0.622  /55favwTon8oqtVezPN8SAALDvLf.jpg
# 817        1.441  /6ca68j8E3whkfAFhxEetaAVtaDa.jpg
# 932        1.512  /9uMk8VPBGOPGqkYZtaS5R8LDziY.jpg
# 1251       1.048  /p6XQM4HmJuxpRreiXOWACG5iUVU.jpg
# ...          ...                               ...
# 1427       0.600  /nbfuswLedQWYMjCJh632MA67Hew.jpg
# 1428       0.600  /uadBupfZdYYoMmALMvYHhtbk40C.jpg
# 1462       1.868  /246pVlZO5z5kVw4IGXL5Po73FNe.jpg
# 1464       0.600                               NaN
# 1486       0.600  /nUmVdMtmIRsiEsvKGOlp2harhkI.jpg
#
#                                    production_companies  \
# 565   [{'id': 60536, 'logo_path': '/chMIfiURhqvr6eWC...
# 596   [{'id': 28950, 'logo_path': '/8RuUUKhPiJbICV03...
# 817                                                  []
# 932                                                  []
# 1251                                                 []
# ...                                                 ...
# 1427                                                 []
# 1428                                                 []
# 1462                                                 []
# 1464  [{'id': 45494, 'logo_path': None, 'name': 'Kor...
# 1486                                                 []
#
#                                    production_countries release_date  revenue  \
# 565             [{'iso_3166_1': 'IN', 'name': 'India'}]   2006-10-20  5100000
# 596       [{'iso_3166_1': 'CH', 'name': 'Switzerland'}]   2006-03-02        0
# 817   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2006-03-22        0
# 932             [{'iso_3166_1': 'ES', 'name': 'Spain'}]   2006-08-25        0
# 1251                                                 []   2006-01-06        0
# ...                                                 ...          ...      ...
# 1427                                                 []   2003-01-01        0
# 1428                                                 []   2003-01-01        0
# 1462        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2003-01-01        0
# 1464      [{'iso_3166_1': 'KP', 'name': 'North Korea'}]   2003-01-30        0
# 1486                                                 []   2003-11-30        0
#
#       runtime spoken_languages    status  \
# 565     171.0               []  Released
# 596      96.0               []  Released
# 817      86.0               []  Released
# 932      91.0               []  Released
# 1251      0.0               []  Released
# ...       ...              ...       ...
# 1427     92.0               []  Released
# 1428    102.0               []  Released
# 1462     94.0               []  Released
# 1464     81.0               []  Released
# 1486    110.0               []  Released
#
#                                         tagline  \
# 565   Are you ready to fall in love..... again?
# 596                                         NaN
# 817                                         NaN
# 932                                         NaN
# 1251                                        NaN
# ...                                         ...
# 1427                                        NaN
# 1428                                        NaN
# 1462                                        NaN
# 1464                              Our Fragrance
# 1486                                        NaN
#
#                                       title  video  vote_average  vote_count  \
# 565                             Jaan-E-Mann  False           5.3          26
# 596                           Going Private  False           6.0           1
# 817                        The White Planet  False           6.0          12
# 932                                 Doghead  False           5.5          10
# 1251                                  Ouija  False           4.7           6
# ...                                     ...    ...           ...         ...
# 1427                                   Hurt  False           0.0           0
# 1428  The Peeper's Story: The Tattoo Master  False           0.0           0
# 1462   Tortured Sex Goddess of Ming Dynasty  False           2.0           1
# 1464                          Our Fragrance  False           5.5           4
# 1486                             The Garden  False           0.0           0
#
#      certification
# 565            NaN
# 596            NaN
# 817            NaN
# 932            NaN
# 1251           NaN
# ...            ...
# 1427           NaN
# 1428           NaN
# 1462           NaN
# 1464           NaN
# 1486           NaN
#
# [617 rows x 26 columns]

# %%
df = df[~bad_titles]
df
# Out:
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False                               NaN                   NaN    100000
# 1     False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2     False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3     False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4     False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
# ...     ...                               ...                   ...       ...
# 1512  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN         0
# 1513  False                               NaN                   NaN         0
# 1514  False                               NaN                   NaN         0
# 1515  False                               NaN                   NaN         0
# 1516  False                               NaN                   NaN       400
#
#                                                  genres  \
# 0                                                    []
# 1     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                 ...
# 1512                [{'id': 99, 'name': 'Documentary'}]
# 1513  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1514                [{'id': 99, 'name': 'Documentary'}]
# 1515                [{'id': 99, 'name': 'Documentary'}]
# 1516  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage      id    imdb_id  \
# 0                                                   NaN   30356  tt0144280
# 1                                                   NaN   58520  tt0197633
# 2                                                   NaN  459563  tt0204250
# 3     http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                   NaN    9925  tt0244521
# ...                                                 ...     ...        ...
# 1512                      http://icarusfilms.com/if-cli  387250  tt7098636
# 1513                                                NaN  640680  tt7246872
# 1514  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 1515                                                NaN  713681  tt9414698
# 1516                                                NaN  253999  tt9641790
#
#      original_language                 original_title  \
# 0                   en  Whispers from a Shallow Grave
# 1                   en         Live Freaky Die Freaky
# 2                   en          Death of a Saleswoman
# 3                   en                Children of Men
# 4                   en                    Funny Money
# ...                ...                            ...
# 1512                fr   Le Clitoris, ce cher inconnu
# 1513                en         Tokyo Bedoone Tavaghof
# 1514                en             Zimbabwe Countdown
# 1515                en                   The Hot Shoe
# 1516                en                     Clearwater
#
#                                                overview  popularity  \
# 0     When a beautiful photo model disappears, polic...       0.714
# 1     It is the year 3069 and the Earth has been rob...       1.957
# 2     Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3     In 2027, in a chaotic world in which humans ca...      18.314
# 4     Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                 ...         ...
# 1512  Topics about female sexuality are growing in p...       1.400
# 1513                                                NaN       0.600
# 1514  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 1515  A Documentary Movie About Card Counting In The...       0.600
# 1516  A woman has been abducted by the Clearwater ki...       2.744
#
#                            poster_path  \
# 0     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1     /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4     /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                ...
# 1512  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 1513  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 1514  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 1515                               NaN
# 1516  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                    production_companies  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4     [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                 ...
# 1512  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 1513                                                 []
# 1514  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 1515                                                 []
# 1516  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                 ...          ...
# 1512           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 1513             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 1514  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 1515                                                 []   2003-01-01
# 1516                                                 []   2003-06-10
#
#        revenue  runtime                                   spoken_languages  \
# 0            0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3     70595464    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...        ...      ...                                                ...
# 1512         0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1513         0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 1514         0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1515         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1516         0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 0     Released                                                NaN
# 1     Released                                                NaN
# 2     Released  6 housewives. 1 dead body. A trunk full of pla...
# 3     Released                  The future's a thing of the past.
# 4     Released  Henry Perkins accidentally trades briefcases w...
# ...        ...                                                ...
# 1512  Released                                                NaN
# 1513  Released                                                NaN
# 1514  Released                                                NaN
# 1515  Released                                                NaN
# 1516  Released                                                NaN
#
#                                  title  video  vote_average  vote_count  \
# 0        Whispers from a Shallow Grave  False           2.0           2
# 1               Live Freaky Die Freaky  False           3.8           8
# 2                Death of a Saleswoman  False           3.0           1
# 3                      Children of Men  False           7.6        5794
# 4                          Funny Money  False           5.4          39
# ...                                ...    ...           ...         ...
# 1512  The Clitoris: Forbidden Pleasure  False           8.0           2
# 1513                   Tokyo, Non-Stop  False           0.0           0
# 1514                Zimbabwe Countdown  False           5.0           4
# 1515                      The Hot Shoe  False           0.0           0
# 1516                        Clearwater  False           0.0           0
#
#      certification
# 0              NaN
# 1               NR
# 2              NaN
# 3                R
# 4                R
# ...            ...
# 1512           NaN
# 1513           NaN
# 1514           NaN
# 1515           NaN
# 1516           NaN
#
# [77780 rows x 26 columns]

# %%
df['revenue'] = df['revenue'].astype(float)
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_71524/2047350285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revenue'] = df['revenue'].astype(float)

# %%
df = df.reset_index(drop=True)
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 77775  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 77776  False                               NaN                   NaN
# 77777  False                               NaN                   NaN
# 77778  False                               NaN                   NaN
# 77779  False                               NaN                   NaN
#
#          budget                                             genres  \
# 0        100000                                                 []
# 1             0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2             0  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3      76000000  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4             0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...         ...                                                ...
# 77775         0                [{'id': 99, 'name': 'Documentary'}]
# 77776         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 77777         0                [{'id': 99, 'name': 'Documentary'}]
# 77778         0                [{'id': 99, 'name': 'Documentary'}]
# 77779       400  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 0                                                    NaN   30356  tt0144280
# 1                                                    NaN   58520  tt0197633
# 2                                                    NaN  459563  tt0204250
# 3      http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                    NaN    9925  tt0244521
# ...                                                  ...     ...        ...
# 77775                      http://icarusfilms.com/if-cli  387250  tt7098636
# 77776                                                NaN  640680  tt7246872
# 77777  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 77778                                                NaN  713681  tt9414698
# 77779                                                NaN  253999  tt9641790
#
#       original_language                 original_title  \
# 0                    en  Whispers from a Shallow Grave
# 1                    en         Live Freaky Die Freaky
# 2                    en          Death of a Saleswoman
# 3                    en                Children of Men
# 4                    en                    Funny Money
# ...                 ...                            ...
# 77775                fr   Le Clitoris, ce cher inconnu
# 77776                en         Tokyo Bedoone Tavaghof
# 77777                en             Zimbabwe Countdown
# 77778                en                   The Hot Shoe
# 77779                en                     Clearwater
#
#                                                 overview  popularity  \
# 0      When a beautiful photo model disappears, polic...       0.714
# 1      It is the year 3069 and the Earth has been rob...       1.957
# 2      Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3      In 2027, in a chaotic world in which humans ca...      18.314
# 4      Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                  ...         ...
# 77775  Topics about female sexuality are growing in p...       1.400
# 77776                                                NaN       0.600
# 77777  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 77778  A Documentary Movie About Card Counting In The...       0.600
# 77779  A woman has been abducted by the Clearwater ki...       2.744
#
#                             poster_path  \
# 0      /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1      /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2      /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3      /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4      /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                 ...
# 77775  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 77776  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 77777  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 77778                               NaN
# 77779  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                     production_companies  \
# 0                                                     []
# 1                                                     []
# 2      [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                  ...
# 77775  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 77776                                                 []
# 77777  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 77778                                                 []
# 77779  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                  ...          ...
# 77775           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 77776             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 77777  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 77778                                                 []   2003-01-01
# 77779                                                 []   2003-06-10
#
#           revenue  runtime                                   spoken_languages  \
# 0             0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0.0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      70595464.0    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4             0.0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 77775         0.0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 77776         0.0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 77777         0.0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 77778         0.0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 77779         0.0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released                                                NaN
# 2      Released  6 housewives. 1 dead body. A trunk full of pla...
# 3      Released                  The future's a thing of the past.
# 4      Released  Henry Perkins accidentally trades briefcases w...
# ...         ...                                                ...
# 77775  Released                                                NaN
# 77776  Released                                                NaN
# 77777  Released                                                NaN
# 77778  Released                                                NaN
# 77779  Released                                                NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 77775  The Clitoris: Forbidden Pleasure  False           8.0           2
# 77776                   Tokyo, Non-Stop  False           0.0           0
# 77777                Zimbabwe Countdown  False           5.0           4
# 77778                      The Hot Shoe  False           0.0           0
# 77779                        Clearwater  False           0.0           0
#
#       certification
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 77775           NaN
# 77776           NaN
# 77777           NaN
# 77778           NaN
# 77779           NaN
#
# [77780 rows x 26 columns]

# %%
schema = get_schema(df)
schema['title'] = Text()
schema['original_title'] = Text()

# %%
schema
# Out:
# {'adult': Boolean(),
#  'backdrop_path': String(length=33),
#  'belongs_to_collection': String(length=185),
#  'budget': Integer(),
#  'genres': String(length=257),
#  'homepage': String(length=487),
#  'id': Integer(),
#  'imdb_id': String(length=11),
#  'original_language': String(length=3),
#  'original_title': Text(),
#  'overview': String(length=1001),
#  'popularity': Float(),
#  'poster_path': String(length=33),
#  'production_companies': String(length=2942),
#  'production_countries': String(length=1129),
#  'release_date': String(length=11),
#  'revenue': Float(),
#  'runtime': Float(),
#  'spoken_languages': String(length=943),
#  'status': String(length=16),
#  'tagline': String(length=268),
#  'title': Text(),
#  'video': Boolean(),
#  'vote_average': Float(),
#  'vote_count': Integer(),
#  'certification': String(length=32)}

# %% [markdown]
# ### Dropping Titles, since these should be joinable with title basics table anyway

# %%
df_for_db = df.drop(columns=['title','original_title'])
df_for_db
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 77775  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 77776  False                               NaN                   NaN
# 77777  False                               NaN                   NaN
# 77778  False                               NaN                   NaN
# 77779  False                               NaN                   NaN
#
#          budget                                             genres  \
# 0        100000                                                 []
# 1             0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2             0  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3      76000000  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4             0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...         ...                                                ...
# 77775         0                [{'id': 99, 'name': 'Documentary'}]
# 77776         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 77777         0                [{'id': 99, 'name': 'Documentary'}]
# 77778         0                [{'id': 99, 'name': 'Documentary'}]
# 77779       400  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 0                                                    NaN   30356  tt0144280
# 1                                                    NaN   58520  tt0197633
# 2                                                    NaN  459563  tt0204250
# 3      http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                    NaN    9925  tt0244521
# ...                                                  ...     ...        ...
# 77775                      http://icarusfilms.com/if-cli  387250  tt7098636
# 77776                                                NaN  640680  tt7246872
# 77777  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 77778                                                NaN  713681  tt9414698
# 77779                                                NaN  253999  tt9641790
#
#       original_language                                           overview  \
# 0                    en  When a beautiful photo model disappears, polic...
# 1                    en  It is the year 3069 and the Earth has been rob...
# 2                    en  Top-ranking RubberTubber saleswoman Agatha J. ...
# 3                    en  In 2027, in a chaotic world in which humans ca...
# 4                    en  Henry Perkins, a mild-mannered accountant, acc...
# ...                 ...                                                ...
# 77775                fr  Topics about female sexuality are growing in p...
# 77776                en                                                NaN
# 77777                en  Once touted as Zimbabwe's saviour, Robert Muga...
# 77778                en  A Documentary Movie About Card Counting In The...
# 77779                en  A woman has been abducted by the Clearwater ki...
#
#        popularity                       poster_path  \
# 0           0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1           1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2           0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4           4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...           ...                               ...
# 77775       1.400  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 77776       0.600  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 77777       0.711  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 77778       0.600                               NaN
# 77779       2.744  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                     production_companies  \
# 0                                                     []
# 1                                                     []
# 2      [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                  ...
# 77775  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 77776                                                 []
# 77777  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 77778                                                 []
# 77779  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                  ...          ...
# 77775           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 77776             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 77777  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 77778                                                 []   2003-01-01
# 77779                                                 []   2003-06-10
#
#           revenue  runtime                                   spoken_languages  \
# 0             0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0.0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      70595464.0    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4             0.0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 77775         0.0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 77776         0.0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 77777         0.0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 77778         0.0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 77779         0.0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  video  \
# 0      Released                                                NaN  False
# 1      Released                                                NaN  False
# 2      Released  6 housewives. 1 dead body. A trunk full of pla...  False
# 3      Released                  The future's a thing of the past.  False
# 4      Released  Henry Perkins accidentally trades briefcases w...  False
# ...         ...                                                ...    ...
# 77775  Released                                                NaN  False
# 77776  Released                                                NaN  False
# 77777  Released                                                NaN  False
# 77778  Released                                                NaN  False
# 77779  Released                                                NaN  False
#
#        vote_average  vote_count certification
# 0               2.0           2           NaN
# 1               3.8           8            NR
# 2               3.0           1           NaN
# 3               7.6        5794             R
# 4               5.4          39             R
# ...             ...         ...           ...
# 77775           8.0           2           NaN
# 77776           0.0           0           NaN
# 77777           5.0           4           NaN
# 77778           0.0           0           NaN
# 77779           0.0           0           NaN
#
# [77780 rows x 24 columns]

# %%
df_for_db.to_sql('tmdb_data_aab',engine, index=False, 
                            if_exists='replace',dtype=get_schema(df_for_db))
#                           method='multi')
# Out:
# 77780

# %%
# ## loop through adding more columns and remove what errors
# good_cols = [*cols_to_keep]
# bad_cols = []
# all_cols = df.drop(columns=cols_to_keep).columns

# for col in all_cols:
#     print(f"- Adding {col}")
#     try: 
#         cols_to_try = [*good_cols, col]
#         df_filtered = df[ cols_to_try]
#         schema= get_schema(df_filtered)
#         ## Primary key is Genre_ID
#         df_filtered.to_sql('tmdb_data_aab',engine, index=False,
#                             if_exists='replace',#dtype=schema,
#                           method='multi')
        
#         # append col name to good_cols if no error
#         good_cols.append(col)
#     except Exception as e:
#         print("   - ERROR")
#         bad_cols.append({col:e})
# bad_cols

# %%
engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb_data_aab LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#    adult                     backdrop_path  \
# 0      0  /ab5yL8zgRotrICzGbEl10z24N71.jpg
# 1      0  /fw5tsNib4QZBEw18xmebpVe3WZ8.jpg
# 2      0  /zjG95oDnBcFKMPgBEmmuNVOMC90.jpg
# 3      0                              None
# 4      0  /2rGYlO0x9HFHyDmTlICGUj51AIJ.jpg
#
#                                belongs_to_collection    budget  \
# 0                                               None  48000000
# 1                                               None         0
# 2                                               None  12000000
# 3                                               None    350000
# 4  {'id': 528034, 'name': 'Grizzly Collection', '...   7500000
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 4  [{'id': 27, 'name': 'Horror'}, {'id': 10402, '...
#
#                                     homepage      id    imdb_id  \
# 0                                       None   11232  tt0035423
# 1  http://poetastros.com/el-tango-del-viudo/  602986  tt0062336
# 2     https://www.netflix.com/title/80085566  299782  tt0069049
# 3                                       None   29163  tt0088751
# 4                                       None   38258  tt0093119
#
#   original_language                                           overview  \
# 0                en  When her scientist ex-boyfriend discovers a po...
# 1                es  A man whose wife has committed suicide,  appea...
# 2                en  Surrounded by fans and skeptics, grizzled dire...
# 3                en  Using soundtracks and extensive footage from m...
# 4                en  All hell breaks loose when a giant grizzly, re...
#
#    popularity                       poster_path  \
# 0       9.183  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg
# 1       1.400  /yzbqP9woGq2wGUJh0DzVXlr3Th7.jpg
# 2       5.155  /kFky1paYEfHxfCYByEc9g7gn6Zk.jpg
# 3       2.190  /aYbeNeNID1wLBp9l214w8CU00xd.jpg
# 4       9.226  /dKHoRIicgHLoNPKiRJpRPHd96Gx.jpg
#
#                                 production_companies  \
# 0  [{'id': 85, 'logo_path': None, 'name': 'Konrad...
# 1  [{'id': 96241, 'logo_path': None, 'name': 'Poe...
# 2  [{'id': 36547, 'logo_path': None, 'name': 'SAC...
# 3                                                 []
# 4  [{'id': 53282, 'logo_path': None, 'name': 'Har...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-12-25  76019000.0
# 1            [{'iso_3166_1': 'CL', 'name': 'Chile'}]   2020-02-21         0.0
# 2  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2018-11-02         0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2005-04-22         0.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2020-02-17         0.0
#
#    runtime                                   spoken_languages    status  \
# 0    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     63.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 2    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     74.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  video  vote_average  \
# 0  If they lived in the same century they'd be pe...      0           6.3
# 1                                               None      0           5.3
# 2                             40 years in the making      0           6.7
# 3                                               None      0           3.4
# 4      The Stage Is Set... And The Dinner Is Served.      0           4.4
#
#    vote_count certification
# 0        1112         PG-13
# 1           3          None
# 2         155             R
# 3           5          None
# 4          14          None

# %% [markdown]
# # Final Tables Check

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#    Tables_in_movies
# 0            genres
# 1  name_professions
# 2       professions
# 3      title_basics
# 4      title_genres
# 5     title_ratings
# 6     tmdb_data_aab
# 7     tmdb_data_mvp

# %% [markdown]
# ## New Files

# %% [markdown]
# ### Names Basics

# %% [markdown]
# - How to normalize names basics:
#     - names table:
#         - nconst, primaryName, birthYear, deathYear
#     - names_profession table (many to many)
#         - nconst, profession_id
#     - profession:
#         - profession_id, profession_name
#     - names_known_for (many to many):
#         - nconst, tconst

# %%
names = pd.read_csv('Data/names_basics.csv.gz')
names
# Out:
#             nconst        primaryName  birthYear  deathYear  \
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 1        nm0000035       James Horner     1953.0     2015.0
# 2        nm0000049      Henry Mancini     1924.0     1994.0
# 3        nm0000055      Alfred Newman     1900.0     1970.0
# 4        nm0000056        Paul Newman     1925.0     2008.0
# ...            ...                ...        ...        ...
# 2426761  nm9993653  Marek Jastrzebski        NaN        NaN
# 2426762  nm9993684          Angela Ng        NaN        NaN
# 2426763  nm9993685          John Root        NaN        NaN
# 2426764  nm9993693        Apsara Rani        NaN        NaN
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN
#
#                             primaryProfession  \
# 0        composer,soundtrack,music_department
# 1        music_department,soundtrack,composer
# 2        music_department,soundtrack,composer
# 3        music_department,composer,soundtrack
# 4                     actor,producer,director
# ...                                       ...
# 2426761                        producer,actor
# 2426762                         miscellaneous
# 2426763                         miscellaneous
# 2426764                               actress
# 2426765   animation_department,art_department
#
#                                      knownForTitles
# 0           tt0091763,tt8847712,tt0096320,tt0069946
# 1           tt0120746,tt0120338,tt0499549,tt0090633
# 2           tt0085101,tt0054698,tt0383216,tt0057413
# 3           tt0049408,tt0434409,tt0065377,tt0042192
# 4           tt0061512,tt0084855,tt0257044,tt0054997
# ...                                             ...
# 2426761               tt8308330,tt8649186,tt8739208
# 2426762                        tt3741700,tt10182516
# 2426763                                   tt3741700
# 2426764  tt11580944,tt12856788,tt8302382,tt13847502
# 2426765             tt11657662,tt14069590,tt2455546
#
# [2426766 rows x 6 columns]

# %% [markdown]
# ### Normalizing Profession

# %%
## Explode the dataframe to make each genre into a separate row
names['primaryProfession']= names['primaryProfession'].str.split(',')
exploded_names = names.explode('primaryProfession')
exploded_names
# Out:
#             nconst        primaryName  birthYear  deathYear  \
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 1        nm0000035       James Horner     1953.0     2015.0
# 1        nm0000035       James Horner     1953.0     2015.0
# ...            ...                ...        ...        ...
# 2426762  nm9993684          Angela Ng        NaN        NaN
# 2426763  nm9993685          John Root        NaN        NaN
# 2426764  nm9993693        Apsara Rani        NaN        NaN
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN
#
#             primaryProfession                              knownForTitles
# 0                    composer     tt0091763,tt8847712,tt0096320,tt0069946
# 0                  soundtrack     tt0091763,tt8847712,tt0096320,tt0069946
# 0            music_department     tt0091763,tt8847712,tt0096320,tt0069946
# 1            music_department     tt0120746,tt0120338,tt0499549,tt0090633
# 1                  soundtrack     tt0120746,tt0120338,tt0499549,tt0090633
# ...                       ...                                         ...
# 2426762         miscellaneous                        tt3741700,tt10182516
# 2426763         miscellaneous                                   tt3741700
# 2426764               actress  tt11580944,tt12856788,tt8302382,tt13847502
# 2426765  animation_department             tt11657662,tt14069590,tt2455546
# 2426765        art_department             tt11657662,tt14069590,tt2455546
#
# [3794257 rows x 6 columns]

# %% [markdown]
# #### Create names_profession Table
# nconst:profession_id

# %%
## Save just tconst and genres_split as new df
name_professions = exploded_names[['nconst','primaryProfession']].copy()
name_professions.head()
# Out:
#       nconst primaryProfession
# 0  nm0000016          composer
# 0  nm0000016        soundtrack
# 0  nm0000016  music_department
# 1  nm0000035  music_department
# 1  nm0000035        soundtrack

# %% [markdown]
# #### Replacing Text Genres with Integer IDs

# %%
## Getting unique list of genres
unique_profs = sorted(name_professions['primaryProfession'].dropna().unique())
unique_profs
# Out:
# ['actor',
#  'actress',
#  'animation_department',
#  'art_department',
#  'art_director',
#  'assistant',
#  'assistant_director',
#  'camera_department',
#  'casting_department',
#  'casting_director',
#  'cinematographer',
#  'composer',
#  'costume_department',
#  'costume_designer',
#  'director',
#  'editor',
#  'editorial_department',
#  'electrical_department',
#  'executive',
#  'legal',
#  'location_management',
#  'make_up_department',
#  'manager',
#  'miscellaneous',
#  'music_department',
#  'producer',
#  'production_department',
#  'production_designer',
#  'production_manager',
#  'publicist',
#  'script_department',
#  'set_decorator',
#  'sound_department',
#  'soundtrack',
#  'special_effects',
#  'stunts',
#  'talent_agent',
#  'transportation_department',
#  'visual_effects',
#  'writer']

# %%
## Make a dictionary with list of unique genres as the key and the new iteger id as vlaues
profession_id_map = dict(zip(unique_profs, range(len(unique_profs))))
profession_id_map
# Out:
# {'actor': 0,
#  'actress': 1,
#  'animation_department': 2,
#  'art_department': 3,
#  'art_director': 4,
#  'assistant': 5,
#  'assistant_director': 6,
#  'camera_department': 7,
#  'casting_department': 8,
#  'casting_director': 9,
#  'cinematographer': 10,
#  'composer': 11,
#  'costume_department': 12,
#  'costume_designer': 13,
#  'director': 14,
#  'editor': 15,
#  'editorial_department': 16,
#  'electrical_department': 17,
#  'executive': 18,
#  'legal': 19,
#  'location_management': 20,
#  'make_up_department': 21,
#  'manager': 22,
#  'miscellaneous': 23,
#  'music_department': 24,
#  'producer': 25,
#  'production_department': 26,
#  'production_designer': 27,
#  'production_manager': 28,
#  'publicist': 29,
#  'script_department': 30,
#  'set_decorator': 31,
#  'sound_department': 32,
#  'soundtrack': 33,
#  'special_effects': 34,
#  'stunts': 35,
#  'talent_agent': 36,
#  'transportation_department': 37,
#  'visual_effects': 38,
#  'writer': 39}

# %% [markdown]
# #### Replacing Values in names_professions Table with professon_id

# %%
## Use .map or .replace with our genre_id_map dictionary
name_professions['Profession_ID'] = name_professions['primaryProfession'].replace(profession_id_map)

## Drop the original genre column
name_professions.drop(columns=['primaryProfession'],inplace=True)
name_professions
# Out:
#             nconst  Profession_ID
# 0        nm0000016           11.0
# 0        nm0000016           33.0
# 0        nm0000016           24.0
# 1        nm0000035           24.0
# 1        nm0000035           33.0
# ...            ...            ...
# 2426762  nm9993684           23.0
# 2426763  nm9993685           23.0
# 2426764  nm9993693            1.0
# 2426765  nm9993714            2.0
# 2426765  nm9993714            3.0
#
# [3794257 rows x 2 columns]

# %% [markdown]
# #### Saving to DB

# %%
key_len = name_professions['nconst'].apply(len).max() +1
key_len
# Out:
# 11

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
name_professions.to_sql('name_professions', engine,dtype={'nconst':String(key_len)},
                        index=False,
                    if_exists='replace' )
# Out:
# 3794257

# %% [markdown]
# #### Create `profession` table
# - Profession_ID :Profession_Name

# %%
## Manaully make dataframe with named cols from the .keyd and .values
profession_lookup = pd.DataFrame({'Profession_ID':profession_id_map.values(),
                                  'Profession_Name': profession_id_map.keys()})
profession_lookup.head()
# Out:
#    Profession_ID       Profession_Name
# 0              0                 actor
# 1              1               actress
# 2              2  animation_department
# 3              3        art_department
# 4              4          art_director

# %% [markdown]
# #### Saving to DB

# %%
profession_lookup.to_sql('professions', engine,#dtype={'nconst':String(key_len)},
                        index=False, if_exists='replace' )
engine.execute('ALTER TABLE professions ADD PRIMARY KEY (`Profession_ID`);')

# %%
names= names.drop(columns=['primaryProfession'])
names
# Out:
#             nconst        primaryName  birthYear  deathYear  \
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 1        nm0000035       James Horner     1953.0     2015.0
# 2        nm0000049      Henry Mancini     1924.0     1994.0
# 3        nm0000055      Alfred Newman     1900.0     1970.0
# 4        nm0000056        Paul Newman     1925.0     2008.0
# ...            ...                ...        ...        ...
# 2426761  nm9993653  Marek Jastrzebski        NaN        NaN
# 2426762  nm9993684          Angela Ng        NaN        NaN
# 2426763  nm9993685          John Root        NaN        NaN
# 2426764  nm9993693        Apsara Rani        NaN        NaN
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN
#
#                                      knownForTitles
# 0           tt0091763,tt8847712,tt0096320,tt0069946
# 1           tt0120746,tt0120338,tt0499549,tt0090633
# 2           tt0085101,tt0054698,tt0383216,tt0057413
# 3           tt0049408,tt0434409,tt0065377,tt0042192
# 4           tt0061512,tt0084855,tt0257044,tt0054997
# ...                                             ...
# 2426761               tt8308330,tt8649186,tt8739208
# 2426762                        tt3741700,tt10182516
# 2426763                                   tt3741700
# 2426764  tt11580944,tt12856788,tt8302382,tt13847502
# 2426765             tt11657662,tt14069590,tt2455546
#
# [2426766 rows x 5 columns]

# %% [markdown]
# ### Normalizing knownForTitles

# %%
## Explode the dataframe to make each genre into a separate row
names['knownForTitles']= names['knownForTitles'].str.split(',')
exploded_names = names.explode('knownForTitles')
exploded_names
# Out:
#             nconst        primaryName  birthYear  deathYear knownForTitles
# 0        nm0000016    Georges Delerue     1925.0     1992.0      tt0091763
# 0        nm0000016    Georges Delerue     1925.0     1992.0      tt8847712
# 0        nm0000016    Georges Delerue     1925.0     1992.0      tt0096320
# 0        nm0000016    Georges Delerue     1925.0     1992.0      tt0069946
# 1        nm0000035       James Horner     1953.0     2015.0      tt0120746
# ...            ...                ...        ...        ...            ...
# 2426764  nm9993693        Apsara Rani        NaN        NaN      tt8302382
# 2426764  nm9993693        Apsara Rani        NaN        NaN     tt13847502
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN     tt11657662
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN     tt14069590
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN      tt2455546
#
# [6039028 rows x 5 columns]

# %% [markdown]
# #### Create names_titles Table
# nconst:tconst

# %%
## Save just tconst and genres_split as new df
name_titles = exploded_names[['nconst','knownForTitles']].copy()
name_titles.head()
# Out:
#       nconst knownForTitles
# 0  nm0000016      tt0091763
# 0  nm0000016      tt8847712
# 0  nm0000016      tt0096320
# 0  nm0000016      tt0069946
# 1  nm0000035      tt0120746

# %%
# key_len = name_professions['nconst'].apply(len).max() +1
# key_len

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
name_titles.to_sql('names_titles', engine,
                        index=False,
                    if_exists='replace' )
# Out:
# 6039028

# %% [markdown]
# ### Saving names

# %%
names= names.drop(columns=['knownForTitles'])
names
# Out:
#             nconst        primaryName  birthYear  deathYear
# 0        nm0000016    Georges Delerue     1925.0     1992.0
# 1        nm0000035       James Horner     1953.0     2015.0
# 2        nm0000049      Henry Mancini     1924.0     1994.0
# 3        nm0000055      Alfred Newman     1900.0     1970.0
# 4        nm0000056        Paul Newman     1925.0     2008.0
# ...            ...                ...        ...        ...
# 2426761  nm9993653  Marek Jastrzebski        NaN        NaN
# 2426762  nm9993684          Angela Ng        NaN        NaN
# 2426763  nm9993685          John Root        NaN        NaN
# 2426764  nm9993693        Apsara Rani        NaN        NaN
# 2426765  nm9993714  Romeo del Rosario        NaN        NaN
#
# [2426766 rows x 4 columns]

# %% [markdown]
# # BOOKMARK: encoding issues

# %%
## Suggestion source: https://stackoverflow.com/questions/45279863/how-to-use-charset-and-encoding-in-create-engine-of-sqlalchemy-to-create

## suggestion 1
# add_charset = "?charset=utf8mb4"
# connect_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies{add_charset}"
# engine = create_engine(connect_str)

## suggestion 2
connect_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies"
engine = create_engine(connect_str,encoding='utf8')

# %%
names.to_sql('names_basics', engine,dtype={'nconst':String(key_len)},
                        index=False, if_exists='replace' )
engine.execute('ALTER TABLE names_basics ADD PRIMARY KEY (`nconst`);')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:173, in Cursor.executemany(self, query, args)
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#     176         q_postfix,
#     177         args,
#     178         self.max_stmt_length,
#     179         self._get_db().encoding,
#     180     )
#     182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:206, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     205 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 206     rows += self.execute(sql + postfix)
#     207     sql = bytearray(prefix)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# DataError: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x91 R...' for column 'primaryName' at row 8275")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Input In [235], in <cell line: 1>()
# ----> 1 names.to_sql('names_basics', engine,dtype={'nconst':String(key_len)},
#       2                         index=False, if_exists='replace' )
#       3 engine.execute('ALTER TABLE names_basics ADD PRIMARY KEY (`nconst`);')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1727 sql_engine = get_engine(engine)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
# -> 1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    1742     frame=frame,
#    1743     name=name,
#    1744     index=index,
#    1745     schema=schema,
#    1746     chunksize=chunksize,
#    1747     method=method,
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:1332, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1330     raise ValueError("inf cannot be used with MySQL") from err
#    1331 else:
# -> 1332     raise err
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:1322, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1319 from sqlalchemy import exc
#    1321 try:
# -> 1322     return table.insert(chunksize=chunksize, method=method)
#    1323 except exc.SQLAlchemyError as err:
#    1324     # GH34431
#    1325     # https://stackoverflow.com/a/67358288/6067848
#    1326     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1327     )|inf can not be used with MySQL"""
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:950, in SQLTable.insert(self, chunksize, method)
#     947     break
#     949 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 950 num_inserted = exec_insert(conn, keys, chunk_iter)
#     951 if num_inserted is None:
#     952     total_inserted = None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pandas/io/sql.py:857, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     845 """
#     846 Execute SQL statement inserting data
#     847
#    (...)
#     854    Each item contains a list of values to be inserted
#     855 """
#     856 data = [dict(zip(keys, row)) for row in data_iter]
# --> 857 result = conn.execute(self.table.insert(), data)
#     858 return result.rowcount
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                 break
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#    1803     if self.dialect._has_events:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#     195         context._rowcount = rowcount
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:173, in Cursor.executemany(self, query, args)
#     171     q_postfix = m.group(3) or ""
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#     176         q_postfix,
#     177         args,
#     178         self.max_stmt_length,
#     179         self._get_db().encoding,
#     180     )
#     182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     183 return self.rowcount
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:206, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     204     v = v.encode(encoding, "surrogateescape")
#     205 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 206     rows += self.execute(sql + postfix)
#     207     sql = bytearray(prefix)
#     208 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env-m1/lib/python3.8/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\x91 R...' for column 'primaryName' at row 8275")
# [SQL: INSERT INTO names_basics (nconst, `primaryName`, `birthYear`, `deathYear`) VALUES (%(nconst)s, %(primaryName)s, %(birthYear)s, %(deathYear)s)]
# [parameters: ({'nconst': 'nm0000016', 'primaryName': 'Georges Delerue', 'birthYear': 1925.0, 'deathYear': 1992.0}, {'nconst': 'nm0000035', 'primaryName': 'James Horner', 'birthYear': 1953.0, 'deathYear': 2015.0}, {'nconst': 'nm0000049', 'primaryName': 'Henry Mancini', 'birthYear': 1924.0, 'deathYear': 1994.0}, {'nconst': 'nm0000055', 'primaryName': 'Alfred Newman', 'birthYear': 1900.0, 'deathYear': 1970.0}, {'nconst': 'nm0000056', 'primaryName': 'Paul Newman', 'birthYear': 1925.0, 'deathYear': 2008.0}, {'nconst': 'nm0000082', 'primaryName': 'Victor Young', 'birthYear': 1900.0, 'deathYear': 1956.0}, {'nconst': 'nm0000083', 'primaryName': 'Alan Miller', 'birthYear': None, 'deathYear': None}, {'nconst': 'nm0000084', 'primaryName': 'Gong Li', 'birthYear': 1965.0, 'deathYear': None}  ... displaying 10 of 2426766 total bound parameter sets ...  {'nconst': 'nm9993693', 'primaryName': 'Apsara Rani', 'birthYear': None, 'deathYear': None}, {'nconst': 'nm9993714', 'primaryName': 'Romeo del Rosario', 'birthYear': None, 'deathYear': None})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %% [markdown]
# ### title principals

# %% [markdown]
# ### title crew
