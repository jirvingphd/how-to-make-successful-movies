# %% [markdown]
# # Part 2C - Extracting Movie Reviews for NLP (WIP)

# %% [markdown]
# - 11/23/23
# - Extract the reviews from TMDB for any movies from the TMDB API calls from Part 2A to prepare for Part 8 / Streamlit app.

# %% [markdown]
# ## WARNING:
# - Weird issue with API calls cell getting skipped over. Almost like its index is wrong in the raw ipynb?

# %%
import pandas as pd
pd.set_option('display.max_columns',100)

# %%
import glob

# # Get all filepaths that match the pattern (*=wildcard)
# tmdb_files = sorted(glob.glob("Data/final_tmdb_data*.csv.gz"))
# tmdb_files
# Out:
# ['Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz',
#  'Data/final_tmdb_data_2010.csv.gz',
#  'Data/final_tmdb_data_2011.csv.gz',
#  'Data/final_tmdb_data_2012.csv.gz',
#  'Data/final_tmdb_data_2013.csv.gz',
#  'Data/final_tmdb_data_2014.csv.gz',
#  'Data/final_tmdb_data_2015.0.csv.gz',
#  'Data/final_tmdb_data_2015.csv.gz',
#  'Data/final_tmdb_data_2016.0.csv.gz',
#  'Data/final_tmdb_data_2016.csv.gz',
#  'Data/final_tmdb_data_2017.0.csv.gz',
#  'Data/final_tmdb_data_2017.csv.gz',
#  'Data/final_tmdb_data_2018.0.csv.gz',
#  'Data/final_tmdb_data_2018.csv.gz',
#  'Data/final_tmdb_data_2019.0.csv.gz',
#  'Data/final_tmdb_data_2019.csv.gz',
#  'Data/final_tmdb_data_2020.0.csv.gz',
#  'Data/final_tmdb_data_2020.csv.gz',
#  'Data/final_tmdb_data_2021.0.csv.gz',
#  'Data/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2022.0.csv.gz',
#  'Data/final_tmdb_data_2022.csv.gz',
#  'Data/final_tmdb_data_2023.0.csv.gz']

# %%
# # Use read_csv in a list comprehension and combine with concat to load all files
# df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in tmdb_files] )
df = pd.read_csv('Data/combined_tmdb_api_data.csv.gz', lineterminator="\n")
df
# Out:
#         adult                     backdrop_path belongs_to_collection  \
# 0       False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1       False                               NaN                   NaN
# 2       False                               NaN                   NaN
# 3       False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4       False                               NaN                   NaN
# ...       ...                               ...                   ...
# 126806  False  /aO9BxxjAFVy5yUIk0aJdCf5uCNO.jpg                   NaN
# 126807  False                               NaN                   NaN
# 126808  False                               NaN                   NaN
# 126809  False                               NaN                   NaN
# 126810  False  /o5wORV1PskudzMXMgxG6viSPRlM.jpg                   NaN
#
#           budget                                             genres  \
# 0       10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              0           [{'id': 878, 'name': 'Science Fiction'}]
# 2              0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3         150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4              0                      [{'id': 18, 'name': 'Drama'}]
# ...          ...                                                ...
# 126806     20000  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
# 126807         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 126808         0                      [{'id': 18, 'name': 'Drama'}]
# 126809         0                [{'id': 99, 'name': 'Documentary'}]
# 126810         0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                                  homepage       id    imdb_id  \
# 0                                                     NaN    62127  tt0113026
# 1                                                     NaN   110977  tt0113092
# 2                                                     NaN   442869  tt0116391
# 3                    http://www.wkw-inthemoodforlove.com/      843  tt0118694
# 4                                                     NaN    49511  tt0118852
# ...                                                   ...      ...        ...
# 126806                       http://www.chapterxmovie.com  1187025  tt9881678
# 126807                                                NaN  1186271  tt9884202
# 126808                                                NaN  1173411  tt9884388
# 126809                                                NaN  1141136  tt9897230
# 126810  https://tv.apple.com/movie/umc.cmc.7kjdwwm5m1c...  1186957  tt9900816
#
#        original_language        original_title  \
# 0                     en       The Fantasticks
# 1                     en         For the Cause
# 2                     hi                  Gang
# 3                     cn                  花樣年華
# 4                     en        Chinese Coffee
# ...                  ...                   ...
# 126806                en           Chapter Ten
# 126807                pa     Zindagi Zindabaad
# 126808                en               The Mux
# 126809                ka  ღიმილიანი საქართველო
# 126810                en  The Velveteen Rabbit
#
#                                                  overview  popularity  \
# 0       Two rural teens sing and dance their way throu...       2.510
# 1       Earth is in a state of constant war and two co...       1.518
# 2       After falling prey to underworld, four friends...       0.600
# 3       Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 4       When Harry Levine, an aging, unsuccessful Gree...       4.164
# ...                                                   ...         ...
# 126806  Decades after the gruesome murder of his paren...       7.448
# 126807  It is always been said that "Addiction to Life...       1.274
# 126808  Rex, a DJ, is convinced he can find a better '...       1.400
# 126809  During its 2012 election campaign titled “Smil...       0.737
# 126810  When seven-year-old William receives a new fav...      31.199
#
#                              poster_path  \
# 0       /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3       /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       /s6yQFnJohmvdkbeHbx6fFOTpYwR.jpg
# ...                                  ...
# 126806  /uyG1OTVvUJNDLdCpphZUMeCDXSt.jpg
# 126807  /xL0DIfGkeytaEOfMfIOKLBcuGkw.jpg
# 126808  /kdUjn1iF52Hxfv5iicKVzI391fM.jpg
# 126809  /vxv0hm6UYf8JBoLgNBbTkBSx8Fj.jpg
# 126810  /aM0ViG6LVkN1PQGe9Bon1gQXpc7.jpg
#
#                                      production_companies  \
# 0       [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1       [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                      []
# 3       [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4       [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...                                                   ...
# 126806  [{'id': 211313, 'logo_path': None, 'name': 'CS...
# 126807                                                 []
# 126808  [{'id': 207703, 'logo_path': None, 'name': 'Ob...
# 126809  [{'id': 144860, 'logo_path': None, 'name': '19...
# 126810  [{'id': 5644, 'logo_path': '/uuj37wq2xE3Vru17B...
#
#                                      production_countries release_date  \
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                 [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3             [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                   ...          ...
# 126806  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-11-07
# 126807            [{'iso_3166_1': 'IN', 'name': 'India'}]   2023-10-27
# 126808                                                 []          NaN
# 126809  [{'iso_3166_1': 'GE', 'name': 'Georgia'}, {'is...   2023-07-04
# 126810   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2023-11-21
#
#          revenue  runtime                                   spoken_languages  \
# 0              0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1              0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2              0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3       12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4              0     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 126806         0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126807         0      0.0  [{'english_name': 'Punjabi', 'iso_639_1': 'pa'...
# 126808         0     65.0                                                 []
# 126809         0     62.0  [{'english_name': 'Georgian', 'iso_639_1': 'ka...
# 126810         0     44.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#           status                                            tagline  \
# 0       Released      Try to remember the first time magic happened
# 1       Released       The ultimate showdown on a forbidden planet.
# 2       Released                                                NaN
# 3       Released  Feel the heat, keep the feeling burning, let t...
# 4       Released  There's a fine line between friendship and bet...
# ...          ...                                                ...
# 126806  Released              One day, you will know true darkness.
# 126807  Released                                                NaN
# 126808  Released                                                NaN
# 126809  Released                                                NaN
# 126810  Released                    Imagine how love makes us real.
#
#                        title  video  vote_average  vote_count certification  \
# 0            The Fantasticks  False           5.4          21           NaN
# 1              For the Cause  False           4.4           7           NaN
# 2                       Gang  False           0.0           0           NaN
# 3       In the Mood for Love  False           8.1        1879            PG
# 4             Chinese Coffee  False           6.9          46             R
# ...                      ...    ...           ...         ...           ...
# 126806             Chapter X  False           3.0           1           NaN
# 126807     Zindagi Zindabaad  False           0.0           0           NaN
# 126808               The Mux  False           0.0           0           NaN
# 126809       Smiling Georgia  False           0.0           0           NaN
# 126810  The Velveteen Rabbit  False           7.0           1             G
#
#         Release Year
# 0             2000.0
# 1             2000.0
# 2             2000.0
# 3             2000.0
# 4             2000.0
# ...              ...
# 126806        2023.0
# 126807        2023.0
# 126808           NaN
# 126809        2023.0
# 126810        2023.0
#
# [126811 rows x 27 columns]

# %%
# df = pd.read_csv("Data/Combined_TMDB_API_results.csv.gz", index_col=0)
df = df.loc[df['imdb_id'] != "0"].reset_index(drop=True)
df = df.dropna(subset=['original_title','id'])
df['id']= df['id'].astype(int)
# df = pd.concat([pd.read_csv(f) for f in tmdb_files] )
df
# Out:
#         adult                     backdrop_path belongs_to_collection  \
# 0       False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1       False                               NaN                   NaN
# 2       False                               NaN                   NaN
# 3       False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4       False                               NaN                   NaN
# ...       ...                               ...                   ...
# 126806  False  /aO9BxxjAFVy5yUIk0aJdCf5uCNO.jpg                   NaN
# 126807  False                               NaN                   NaN
# 126808  False                               NaN                   NaN
# 126809  False                               NaN                   NaN
# 126810  False  /o5wORV1PskudzMXMgxG6viSPRlM.jpg                   NaN
#
#           budget                                             genres  \
# 0       10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              0           [{'id': 878, 'name': 'Science Fiction'}]
# 2              0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3         150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4              0                      [{'id': 18, 'name': 'Drama'}]
# ...          ...                                                ...
# 126806     20000  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
# 126807         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 126808         0                      [{'id': 18, 'name': 'Drama'}]
# 126809         0                [{'id': 99, 'name': 'Documentary'}]
# 126810         0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                                  homepage       id    imdb_id  \
# 0                                                     NaN    62127  tt0113026
# 1                                                     NaN   110977  tt0113092
# 2                                                     NaN   442869  tt0116391
# 3                    http://www.wkw-inthemoodforlove.com/      843  tt0118694
# 4                                                     NaN    49511  tt0118852
# ...                                                   ...      ...        ...
# 126806                       http://www.chapterxmovie.com  1187025  tt9881678
# 126807                                                NaN  1186271  tt9884202
# 126808                                                NaN  1173411  tt9884388
# 126809                                                NaN  1141136  tt9897230
# 126810  https://tv.apple.com/movie/umc.cmc.7kjdwwm5m1c...  1186957  tt9900816
#
#        original_language        original_title  \
# 0                     en       The Fantasticks
# 1                     en         For the Cause
# 2                     hi                  Gang
# 3                     cn                  花樣年華
# 4                     en        Chinese Coffee
# ...                  ...                   ...
# 126806                en           Chapter Ten
# 126807                pa     Zindagi Zindabaad
# 126808                en               The Mux
# 126809                ka  ღიმილიანი საქართველო
# 126810                en  The Velveteen Rabbit
#
#                                                  overview  popularity  \
# 0       Two rural teens sing and dance their way throu...       2.510
# 1       Earth is in a state of constant war and two co...       1.518
# 2       After falling prey to underworld, four friends...       0.600
# 3       Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 4       When Harry Levine, an aging, unsuccessful Gree...       4.164
# ...                                                   ...         ...
# 126806  Decades after the gruesome murder of his paren...       7.448
# 126807  It is always been said that "Addiction to Life...       1.274
# 126808  Rex, a DJ, is convinced he can find a better '...       1.400
# 126809  During its 2012 election campaign titled “Smil...       0.737
# 126810  When seven-year-old William receives a new fav...      31.199
#
#                              poster_path  \
# 0       /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3       /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       /s6yQFnJohmvdkbeHbx6fFOTpYwR.jpg
# ...                                  ...
# 126806  /uyG1OTVvUJNDLdCpphZUMeCDXSt.jpg
# 126807  /xL0DIfGkeytaEOfMfIOKLBcuGkw.jpg
# 126808  /kdUjn1iF52Hxfv5iicKVzI391fM.jpg
# 126809  /vxv0hm6UYf8JBoLgNBbTkBSx8Fj.jpg
# 126810  /aM0ViG6LVkN1PQGe9Bon1gQXpc7.jpg
#
#                                      production_companies  \
# 0       [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1       [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                      []
# 3       [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4       [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...                                                   ...
# 126806  [{'id': 211313, 'logo_path': None, 'name': 'CS...
# 126807                                                 []
# 126808  [{'id': 207703, 'logo_path': None, 'name': 'Ob...
# 126809  [{'id': 144860, 'logo_path': None, 'name': '19...
# 126810  [{'id': 5644, 'logo_path': '/uuj37wq2xE3Vru17B...
#
#                                      production_countries release_date  \
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                 [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3             [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                   ...          ...
# 126806  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-11-07
# 126807            [{'iso_3166_1': 'IN', 'name': 'India'}]   2023-10-27
# 126808                                                 []          NaN
# 126809  [{'iso_3166_1': 'GE', 'name': 'Georgia'}, {'is...   2023-07-04
# 126810   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2023-11-21
#
#          revenue  runtime                                   spoken_languages  \
# 0              0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1              0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2              0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3       12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4              0     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 126806         0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126807         0      0.0  [{'english_name': 'Punjabi', 'iso_639_1': 'pa'...
# 126808         0     65.0                                                 []
# 126809         0     62.0  [{'english_name': 'Georgian', 'iso_639_1': 'ka...
# 126810         0     44.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#           status                                            tagline  \
# 0       Released      Try to remember the first time magic happened
# 1       Released       The ultimate showdown on a forbidden planet.
# 2       Released                                                NaN
# 3       Released  Feel the heat, keep the feeling burning, let t...
# 4       Released  There's a fine line between friendship and bet...
# ...          ...                                                ...
# 126806  Released              One day, you will know true darkness.
# 126807  Released                                                NaN
# 126808  Released                                                NaN
# 126809  Released                                                NaN
# 126810  Released                    Imagine how love makes us real.
#
#                        title  video  vote_average  vote_count certification  \
# 0            The Fantasticks  False           5.4          21           NaN
# 1              For the Cause  False           4.4           7           NaN
# 2                       Gang  False           0.0           0           NaN
# 3       In the Mood for Love  False           8.1        1879            PG
# 4             Chinese Coffee  False           6.9          46             R
# ...                      ...    ...           ...         ...           ...
# 126806             Chapter X  False           3.0           1           NaN
# 126807     Zindagi Zindabaad  False           0.0           0           NaN
# 126808               The Mux  False           0.0           0           NaN
# 126809       Smiling Georgia  False           0.0           0           NaN
# 126810  The Velveteen Rabbit  False           7.0           1             G
#
#         Release Year
# 0             2000.0
# 1             2000.0
# 2             2000.0
# 3             2000.0
# 4             2000.0
# ...              ...
# 126806        2023.0
# 126807        2023.0
# 126808           NaN
# 126809        2023.0
# 126810        2023.0
#
# [126811 rows x 27 columns]

# %%
df =  df.drop_duplicates()
df
# Out:
#         adult                     backdrop_path belongs_to_collection  \
# 0       False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1       False                               NaN                   NaN
# 2       False                               NaN                   NaN
# 3       False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4       False                               NaN                   NaN
# ...       ...                               ...                   ...
# 126806  False  /aO9BxxjAFVy5yUIk0aJdCf5uCNO.jpg                   NaN
# 126807  False                               NaN                   NaN
# 126808  False                               NaN                   NaN
# 126809  False                               NaN                   NaN
# 126810  False  /o5wORV1PskudzMXMgxG6viSPRlM.jpg                   NaN
#
#           budget                                             genres  \
# 0       10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              0           [{'id': 878, 'name': 'Science Fiction'}]
# 2              0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3         150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4              0                      [{'id': 18, 'name': 'Drama'}]
# ...          ...                                                ...
# 126806     20000  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
# 126807         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 126808         0                      [{'id': 18, 'name': 'Drama'}]
# 126809         0                [{'id': 99, 'name': 'Documentary'}]
# 126810         0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                                  homepage       id    imdb_id  \
# 0                                                     NaN    62127  tt0113026
# 1                                                     NaN   110977  tt0113092
# 2                                                     NaN   442869  tt0116391
# 3                    http://www.wkw-inthemoodforlove.com/      843  tt0118694
# 4                                                     NaN    49511  tt0118852
# ...                                                   ...      ...        ...
# 126806                       http://www.chapterxmovie.com  1187025  tt9881678
# 126807                                                NaN  1186271  tt9884202
# 126808                                                NaN  1173411  tt9884388
# 126809                                                NaN  1141136  tt9897230
# 126810  https://tv.apple.com/movie/umc.cmc.7kjdwwm5m1c...  1186957  tt9900816
#
#        original_language        original_title  \
# 0                     en       The Fantasticks
# 1                     en         For the Cause
# 2                     hi                  Gang
# 3                     cn                  花樣年華
# 4                     en        Chinese Coffee
# ...                  ...                   ...
# 126806                en           Chapter Ten
# 126807                pa     Zindagi Zindabaad
# 126808                en               The Mux
# 126809                ka  ღიმილიანი საქართველო
# 126810                en  The Velveteen Rabbit
#
#                                                  overview  popularity  \
# 0       Two rural teens sing and dance their way throu...       2.510
# 1       Earth is in a state of constant war and two co...       1.518
# 2       After falling prey to underworld, four friends...       0.600
# 3       Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 4       When Harry Levine, an aging, unsuccessful Gree...       4.164
# ...                                                   ...         ...
# 126806  Decades after the gruesome murder of his paren...       7.448
# 126807  It is always been said that "Addiction to Life...       1.274
# 126808  Rex, a DJ, is convinced he can find a better '...       1.400
# 126809  During its 2012 election campaign titled “Smil...       0.737
# 126810  When seven-year-old William receives a new fav...      31.199
#
#                              poster_path  \
# 0       /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3       /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       /s6yQFnJohmvdkbeHbx6fFOTpYwR.jpg
# ...                                  ...
# 126806  /uyG1OTVvUJNDLdCpphZUMeCDXSt.jpg
# 126807  /xL0DIfGkeytaEOfMfIOKLBcuGkw.jpg
# 126808  /kdUjn1iF52Hxfv5iicKVzI391fM.jpg
# 126809  /vxv0hm6UYf8JBoLgNBbTkBSx8Fj.jpg
# 126810  /aM0ViG6LVkN1PQGe9Bon1gQXpc7.jpg
#
#                                      production_companies  \
# 0       [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1       [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                      []
# 3       [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4       [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...                                                   ...
# 126806  [{'id': 211313, 'logo_path': None, 'name': 'CS...
# 126807                                                 []
# 126808  [{'id': 207703, 'logo_path': None, 'name': 'Ob...
# 126809  [{'id': 144860, 'logo_path': None, 'name': '19...
# 126810  [{'id': 5644, 'logo_path': '/uuj37wq2xE3Vru17B...
#
#                                      production_countries release_date  \
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                 [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3             [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4       [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                   ...          ...
# 126806  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-11-07
# 126807            [{'iso_3166_1': 'IN', 'name': 'India'}]   2023-10-27
# 126808                                                 []          NaN
# 126809  [{'iso_3166_1': 'GE', 'name': 'Georgia'}, {'is...   2023-07-04
# 126810   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2023-11-21
#
#          revenue  runtime                                   spoken_languages  \
# 0              0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1              0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2              0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3       12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4              0     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 126806         0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126807         0      0.0  [{'english_name': 'Punjabi', 'iso_639_1': 'pa'...
# 126808         0     65.0                                                 []
# 126809         0     62.0  [{'english_name': 'Georgian', 'iso_639_1': 'ka...
# 126810         0     44.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#           status                                            tagline  \
# 0       Released      Try to remember the first time magic happened
# 1       Released       The ultimate showdown on a forbidden planet.
# 2       Released                                                NaN
# 3       Released  Feel the heat, keep the feeling burning, let t...
# 4       Released  There's a fine line between friendship and bet...
# ...          ...                                                ...
# 126806  Released              One day, you will know true darkness.
# 126807  Released                                                NaN
# 126808  Released                                                NaN
# 126809  Released                                                NaN
# 126810  Released                    Imagine how love makes us real.
#
#                        title  video  vote_average  vote_count certification  \
# 0            The Fantasticks  False           5.4          21           NaN
# 1              For the Cause  False           4.4           7           NaN
# 2                       Gang  False           0.0           0           NaN
# 3       In the Mood for Love  False           8.1        1879            PG
# 4             Chinese Coffee  False           6.9          46             R
# ...                      ...    ...           ...         ...           ...
# 126806             Chapter X  False           3.0           1           NaN
# 126807     Zindagi Zindabaad  False           0.0           0           NaN
# 126808               The Mux  False           0.0           0           NaN
# 126809       Smiling Georgia  False           0.0           0           NaN
# 126810  The Velveteen Rabbit  False           7.0           1             G
#
#         Release Year
# 0             2000.0
# 1             2000.0
# 2             2000.0
# 3             2000.0
# 4             2000.0
# ...              ...
# 126806        2023.0
# 126807        2023.0
# 126808           NaN
# 126809        2023.0
# 126810        2023.0
#
# [124151 rows x 27 columns]

# %%
filter_has_finances  = (df['budget'] >0 ) & (df['revenue']>9)
df[filter_has_finances]
# Out:
#         adult                     backdrop_path  \
# 3       False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 11      False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13      False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 16      False  /cXXxi0j9sXFt7LbeajuFoKFqWMu.jpg
# 17      False  /8XaohdSqoBEWHhW40q2VTdMBrV0.jpg
# ...       ...                               ...
# 126758  False  /qNmLEOGZy37vKAPqcTuZ47uCOS9.jpg
# 126762  False  /5mzr6JZbrqnqD8rCEvPhuCE5Fw2.jpg
# 126772  False  /4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg
# 126773  False  /3H9NA1KWEQN0ItL3Wl3SFZYP6yV.jpg
# 126786  False  /628Dep6AxEtDxjZoGP78TsOxYbK.jpg
#
#                                     belongs_to_collection     budget  \
# 3                                                     NaN     150000
# 11                                                    NaN     120000
# 13      {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 16                                                    NaN    8000000
# 17      {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
# ...                                                   ...        ...
# 126758                                                NaN   30000000
# 126762  {'id': 742536, 'name': 'The Meg Collection', '...  129000000
# 126772  {'id': 573436, 'name': 'Spider-Man: Spider-Ver...  100000000
# 126773                                                NaN  104000000
# 126786  {'id': 87359, 'name': 'Mission: Impossible Col...  291000000
#
#                                                    genres  \
# 3       [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 11      [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 13      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 16      [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 17      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                   ...
# 126758  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 126762  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 126772  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 126773  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 126786  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                       homepage      id    imdb_id  \
# 3         http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 11                                         NaN   19085  tt0120467
# 13                                         NaN    7443  tt0120630
# 16                                         NaN     318  tt0120753
# 17                                         NaN     955  tt0120755
# ...                                        ...     ...        ...
# 126758         https://www.itsmemargaret.movie  555285  tt9185206
# 126762                https://www.themeg.movie  615656  tt9224104
# 126772  https://www.acrossthespiderverse.movie  569094  tt9362722
# 126773           https://www.dc.com/bluebeetle  565770  tt9362930
# 126786       https://www.missionimpossible.com  575264  tt9603212
#
#        original_language                                 original_title  \
# 3                     cn                                           花樣年華
# 11                    en                                         Vulgar
# 13                    en                                    Chicken Run
# 16                    en                       The Million Dollar Hotel
# 17                    en                         Mission: Impossible II
# ...                  ...                                            ...
# 126758                en          Are You There God? It's Me, Margaret.
# 126762                en                              Meg 2: The Trench
# 126772                en            Spider-Man: Across the Spider-Verse
# 126773                en                                    Blue Beetle
# 126786                en  Mission: Impossible - Dead Reckoning Part One
#
#                                                  overview  popularity  \
# 3       Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 11      Vulgar is about a man who is a children's clow...       3.692
# 13      Having been hopelessly repressed and facing ev...      35.780
# 16      The Million Dollar Hotel starts with a jump fr...       6.431
# 17      With computer genius Luther Stickell at his si...      22.658
# ...                                                   ...         ...
# 126758  When her family moves from New York City to Ne...      47.950
# 126762  An exploratory dive into the deepest depths of...     460.025
# 126772  After reuniting with Gwen Stacy, Brooklyn’s fu...     388.074
# 126773  Recent college grad Jaime Reyes returns home f...     471.802
# 126786  Ethan Hunt and his IMF team embark on their mo...     751.722
#
#                              poster_path  \
# 3       /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 11      /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# 13      /8XgmIsbpVamdhwcNVsYzohFZTtT.jpg
# 16      /7AjzGYybwfndxnpApKXahQiq2Zy.jpg
# 17      /2njB2A85Ni7bRR7vIOrfv6TBPeC.jpg
# ...                                  ...
# 126758  /yb6UB4WC3znlwU0L4AqMnjR9G9S.jpg
# 126762  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
# 126772  /8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg
# 126773  /mXLOHHc1Zeuwsl4xYKjKh2280oL.jpg
# 126786   /NNxYkU70HPurnNCSiCjYAmacwm.jpg
#
#                                      production_companies  \
# 3       [{'id': 539, 'logo_path': None, 'name': 'Block...
# 11      [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 13      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 16      [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 17      [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...                                                   ...
# 126758  [{'id': 18, 'logo_path': '/uqhagSwM7NAkQWVCQhK...
# 126762  [{'id': 56242, 'logo_path': '/1YORRYmg7hgYIgoJ...
# 126772  [{'id': 5, 'logo_path': '/wrweLpBqRYcAM7kCSaHD...
# 126773  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 126786  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                      production_countries release_date  \
# 3             [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 11      [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26
# 13      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-21
# 16      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-02-09
# 17      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2000-05-24
# ...                                                   ...          ...
# 126758  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-03-29
# 126762  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...   2023-08-02
# 126772  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-05-31
# 126773  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-08-16
# 126786  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-07-08
#
#           revenue  runtime                                   spoken_languages  \
# 3        12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 11          14904     87.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13      224834564     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16         105983    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17      546388105    123.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 126758   21826840    107.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126762  384056482    116.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126772  683241751    140.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126773  128600000    128.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126786  567148955    164.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
#
#           status                                            tagline  \
# 3       Released  Feel the heat, keep the feeling burning, let t...
# 11      Released   Everyone loves a clown... some more than others.
# 13      Released  This ain't no chick flick. It's poultry in mot...
# 16      Released                    Everyone has something to hide.
# 17      Released                       Expect the impossible again.
# ...          ...                                                ...
# 126758  Released  Discovering who you are is a journey that last...
# 126762  Released                                  Back for seconds.
# 126772  Released           It's how you wear the mask that matters.
# 126773  Released  Jaime Reyes is a superhero whether he likes it...
# 126786  Released                        We all share the same fate.
#
#                                                 title  video  vote_average  \
# 3                                In the Mood for Love  False         8.100
# 11                                             Vulgar  False         5.400
# 13                                        Chicken Run  False         6.700
# 16                           The Million Dollar Hotel  False         5.900
# 17                             Mission: Impossible II  False         6.100
# ...                                               ...    ...           ...
# 126758          Are You There God? It's Me, Margaret.  False         7.324
# 126762                              Meg 2: The Trench  False         6.749
# 126772            Spider-Man: Across the Spider-Verse  False         8.406
# 126773                                    Blue Beetle  False         6.952
# 126786  Mission: Impossible - Dead Reckoning Part One  False         7.586
#
#         vote_count certification  Release Year
# 3             1879            PG        2000.0
# 11              41             R        2002.0
# 13            4009             G        2000.0
# 16             247             R        2000.0
# 17            5297         PG-13        2000.0
# ...            ...           ...           ...
# 126758         162         PG-13        2023.0
# 126762        2568         PG-13        2023.0
# 126772        4951            PG        2023.0
# 126773        1681         PG-13        2023.0
# 126786        2498         PG-13        2023.0
#
# [7198 rows x 27 columns]

# %%
# import os

# nlp_folder = "Data-NLP/"
# os.makedirs(nlp_folder, exist_ok=True)
# fname_json = nlp_folder +'tmdb-movies.json'
# df.to_json(fname_json)
# # fname = nlp_folder+'tmdb-movies.csv'
# # df.to_csv(fname, index=True)

# %%
# df = pd.read_json(fname_json)
# df

# %%
# df = pd.read_csv(fname, lineterminator='\n')
# df

# %%
df['id']
# Out:
# 0           62127
# 1          110977
# 2          442869
# 3             843
# 4           49511
#            ...
# 126806    1187025
# 126807    1186271
# 126808    1173411
# 126809    1141136
# 126810    1186957
# Name: id, Length: 124151, dtype: int64

# %% [markdown]
# ## Extracting Reviews

# %%
len(df)
# Out:
# 124151

# %%
filter_has_finances.sum()
# Out:
# 7198

# %%
# keeping only movies with financial data
df  = df[filter_has_finances]
df
# Out:
#         adult                     backdrop_path  \
# 3       False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 11      False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13      False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 16      False  /cXXxi0j9sXFt7LbeajuFoKFqWMu.jpg
# 17      False  /8XaohdSqoBEWHhW40q2VTdMBrV0.jpg
# ...       ...                               ...
# 126758  False  /qNmLEOGZy37vKAPqcTuZ47uCOS9.jpg
# 126762  False  /5mzr6JZbrqnqD8rCEvPhuCE5Fw2.jpg
# 126772  False  /4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg
# 126773  False  /3H9NA1KWEQN0ItL3Wl3SFZYP6yV.jpg
# 126786  False  /628Dep6AxEtDxjZoGP78TsOxYbK.jpg
#
#                                     belongs_to_collection     budget  \
# 3                                                     NaN     150000
# 11                                                    NaN     120000
# 13      {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 16                                                    NaN    8000000
# 17      {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
# ...                                                   ...        ...
# 126758                                                NaN   30000000
# 126762  {'id': 742536, 'name': 'The Meg Collection', '...  129000000
# 126772  {'id': 573436, 'name': 'Spider-Man: Spider-Ver...  100000000
# 126773                                                NaN  104000000
# 126786  {'id': 87359, 'name': 'Mission: Impossible Col...  291000000
#
#                                                    genres  \
# 3       [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 11      [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 13      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 16      [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 17      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                   ...
# 126758  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 126762  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 126772  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 126773  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 126786  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                       homepage      id    imdb_id  \
# 3         http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 11                                         NaN   19085  tt0120467
# 13                                         NaN    7443  tt0120630
# 16                                         NaN     318  tt0120753
# 17                                         NaN     955  tt0120755
# ...                                        ...     ...        ...
# 126758         https://www.itsmemargaret.movie  555285  tt9185206
# 126762                https://www.themeg.movie  615656  tt9224104
# 126772  https://www.acrossthespiderverse.movie  569094  tt9362722
# 126773           https://www.dc.com/bluebeetle  565770  tt9362930
# 126786       https://www.missionimpossible.com  575264  tt9603212
#
#        original_language                                 original_title  \
# 3                     cn                                           花樣年華
# 11                    en                                         Vulgar
# 13                    en                                    Chicken Run
# 16                    en                       The Million Dollar Hotel
# 17                    en                         Mission: Impossible II
# ...                  ...                                            ...
# 126758                en          Are You There God? It's Me, Margaret.
# 126762                en                              Meg 2: The Trench
# 126772                en            Spider-Man: Across the Spider-Verse
# 126773                en                                    Blue Beetle
# 126786                en  Mission: Impossible - Dead Reckoning Part One
#
#                                                  overview  popularity  \
# 3       Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 11      Vulgar is about a man who is a children's clow...       3.692
# 13      Having been hopelessly repressed and facing ev...      35.780
# 16      The Million Dollar Hotel starts with a jump fr...       6.431
# 17      With computer genius Luther Stickell at his si...      22.658
# ...                                                   ...         ...
# 126758  When her family moves from New York City to Ne...      47.950
# 126762  An exploratory dive into the deepest depths of...     460.025
# 126772  After reuniting with Gwen Stacy, Brooklyn’s fu...     388.074
# 126773  Recent college grad Jaime Reyes returns home f...     471.802
# 126786  Ethan Hunt and his IMF team embark on their mo...     751.722
#
#                              poster_path  \
# 3       /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 11      /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# 13      /8XgmIsbpVamdhwcNVsYzohFZTtT.jpg
# 16      /7AjzGYybwfndxnpApKXahQiq2Zy.jpg
# 17      /2njB2A85Ni7bRR7vIOrfv6TBPeC.jpg
# ...                                  ...
# 126758  /yb6UB4WC3znlwU0L4AqMnjR9G9S.jpg
# 126762  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
# 126772  /8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg
# 126773  /mXLOHHc1Zeuwsl4xYKjKh2280oL.jpg
# 126786   /NNxYkU70HPurnNCSiCjYAmacwm.jpg
#
#                                      production_companies  \
# 3       [{'id': 539, 'logo_path': None, 'name': 'Block...
# 11      [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 13      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 16      [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 17      [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...                                                   ...
# 126758  [{'id': 18, 'logo_path': '/uqhagSwM7NAkQWVCQhK...
# 126762  [{'id': 56242, 'logo_path': '/1YORRYmg7hgYIgoJ...
# 126772  [{'id': 5, 'logo_path': '/wrweLpBqRYcAM7kCSaHD...
# 126773  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 126786  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                      production_countries release_date  \
# 3             [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 11      [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26
# 13      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-21
# 16      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-02-09
# 17      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2000-05-24
# ...                                                   ...          ...
# 126758  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-03-29
# 126762  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...   2023-08-02
# 126772  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-05-31
# 126773  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-08-16
# 126786  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-07-08
#
#           revenue  runtime                                   spoken_languages  \
# 3        12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 11          14904     87.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13      224834564     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16         105983    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17      546388105    123.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 126758   21826840    107.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126762  384056482    116.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126772  683241751    140.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126773  128600000    128.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 126786  567148955    164.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
#
#           status                                            tagline  \
# 3       Released  Feel the heat, keep the feeling burning, let t...
# 11      Released   Everyone loves a clown... some more than others.
# 13      Released  This ain't no chick flick. It's poultry in mot...
# 16      Released                    Everyone has something to hide.
# 17      Released                       Expect the impossible again.
# ...          ...                                                ...
# 126758  Released  Discovering who you are is a journey that last...
# 126762  Released                                  Back for seconds.
# 126772  Released           It's how you wear the mask that matters.
# 126773  Released  Jaime Reyes is a superhero whether he likes it...
# 126786  Released                        We all share the same fate.
#
#                                                 title  video  vote_average  \
# 3                                In the Mood for Love  False         8.100
# 11                                             Vulgar  False         5.400
# 13                                        Chicken Run  False         6.700
# 16                           The Million Dollar Hotel  False         5.900
# 17                             Mission: Impossible II  False         6.100
# ...                                               ...    ...           ...
# 126758          Are You There God? It's Me, Margaret.  False         7.324
# 126762                              Meg 2: The Trench  False         6.749
# 126772            Spider-Man: Across the Spider-Verse  False         8.406
# 126773                                    Blue Beetle  False         6.952
# 126786  Mission: Impossible - Dead Reckoning Part One  False         7.586
#
#         vote_count certification  Release Year
# 3             1879            PG        2000.0
# 11              41             R        2002.0
# 13            4009             G        2000.0
# 16             247             R        2000.0
# 17            5297         PG-13        2000.0
# ...            ...           ...           ...
# 126758         162         PG-13        2023.0
# 126762        2568         PG-13        2023.0
# 126772        4951            PG        2023.0
# 126773        1681         PG-13        2023.0
# 126786        2498         PG-13        2023.0
#
# [7198 rows x 27 columns]

# %%
df_ids = df[['title','imdb_id','id']]
df_ids = df_ids.drop_duplicates()
df_ids = df_ids.set_index('title')
df = df.set_index('imdb_id')
df_ids
# Out:
#                                                  imdb_id      id
# title
# In the Mood for Love                           tt0118694     843
# Vulgar                                         tt0120467   19085
# Chicken Run                                    tt0120630    7443
# The Million Dollar Hotel                       tt0120753     318
# Mission: Impossible II                         tt0120755     955
# ...                                                  ...     ...
# Are You There God? It's Me, Margaret.          tt9185206  555285
# Meg 2: The Trench                              tt9224104  615656
# Spider-Man: Across the Spider-Verse            tt9362722  569094
# Blue Beetle                                    tt9362930  565770
# Mission: Impossible - Dead Reckoning Part One  tt9603212  575264
#
# [5670 rows x 2 columns]

# %%
df_ids.loc['The Avengers']
# Out:
# imdb_id    tt0848228
# id             24428
# Name: The Avengers, dtype: object

# %%
# df_ids.to_dict(orient='tight')

# %%
# movie_id_lookup =.to_dict(orient='index')
# movie_id_lookup

# %%
# df_ids.duplicated(subset=['title']).sum()

# %%
# df_ids[df_ids.duplicated(subset=['title'], keep=False)].sort_values('title')

# %%
# df_ids['id'].duplicated().sum()

# %%
# df_ids.index.duplicated().sum()

# %%
# id_dict = df_ids.to_dict(orient='index')
# id_dict

# %%
def get_movie_with_rating(movie_id):
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    # save the .info .releases dictionaries
    movie_info = movie.info()
    releases = movie.releases()
    
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
            movie_info['certification'] = c['certification']
    return movie_info


def write_json(new_data, filename, overwrite=False, skip=False): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    if (overwrite==True) & (skip==True):
        raise Exception("Only 1 of overwrite or skip may be set to True")

    # find if file exists
    exists = os.path.exists(filename)

    if exists==False:
        mode = 'w'
    else:
        if overwrite==True:
            # exists=False
            mode = 'w'
            
        elif skip == True:
            return 
            
        else:
            mode = 'r+'

    
    with open(filename,mode) as file:

        if mode == 'r+':
            # First we load existing data into a dict.
            file_data = json.load(file)
            
            ## Choose extend or append
            if (type(new_data) == list) & (type(file_data) == list):
                file_data.extend(new_data)
            else:
                 file_data.append(new_data)
            # Sets file's current position at offset.
            file.seek(0)
        else:
            file_data = new_data
            
        # convert back to json.
        json.dump(file_data, file)
        return

# %%
### Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, time
from tqdm.notebook import tqdm_notebook

# %%
import json
with open('/Users/codingdojo/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key', 'api-token'])

# %%
# !pip install -U tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (2.9.1)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from tmdbsimple) (2.29.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (2023.11.17)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (3.4)

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']
# tmdb.API
# tmdb.API_KEY = login['api-key']+'.' + login['api-read-access-token']
tmdb.REQUESTS_TIMEOUT = 5
# tmdb.API_KEY = login['api-read-access-token']

# %%
df.loc[df['title'].str.contains("Avenger")]
# Out:
#            adult                     backdrop_path  \
# imdb_id
# tt0458339  False  /yFuKvT4Vm3sKHdFY4eG6I4ldAnn.jpg
# tt0848228  False  /nNmJRkg8wWnRmzQDe2FwKbPIsJV.jpg
# tt2395427  False  /6YwkGolwdOMNpbTOmLjoehlVWs5.jpg
# tt2395427  False  /xnqust9Li4oxfhXD5kcPi3UC8i4.jpg
# tt4154756  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# tt4154756  False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg
# tt4154796  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# tt4154796  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
#
#                                        belongs_to_collection     budget  \
# imdb_id
# tt0458339  {'id': 131295, 'name': 'Captain America Collec...  140000000
# tt0848228  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# tt2395427  {'id': 86311, 'name': 'The Avengers Collection...  365000000
# tt2395427  {'id': 86311, 'name': 'The Avengers Collection...  365000000
# tt4154756  {'id': 86311, 'name': 'The Avengers Collection...  300000000
# tt4154756  {'id': 86311, 'name': 'The Avengers Collection...  300000000
# tt4154796  {'id': 86311, 'name': 'The Avengers Collection...  356000000
# tt4154796  {'id': 86311, 'name': 'The Avengers Collection...  356000000
#
#                                                       genres  \
# imdb_id
# tt0458339  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# tt0848228  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# tt2395427  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# tt2395427  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# tt4154756  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# tt4154756  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# tt4154796  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# tt4154796  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
#
#                                                     homepage      id  \
# imdb_id
# tt0458339                  http://captainamerica.marvel.com/    1771
# tt0848228         https://www.marvel.com/movies/the-avengers   24428
# tt2395427  http://marvel.com/movies/movie/193/avengers_ag...   99861
# tt2395427  http://marvel.com/movies/movie/193/avengers_ag...   99861
# tt4154756  https://www.marvel.com/movies/avengers-infinit...  299536
# tt4154756  https://www.marvel.com/movies/avengers-infinit...  299536
# tt4154796     https://www.marvel.com/movies/avengers-endgame  299534
# tt4154796     https://www.marvel.com/movies/avengers-endgame  299534
#
#           original_language                      original_title  \
# imdb_id
# tt0458339                en  Captain America: The First Avenger
# tt0848228                en                        The Avengers
# tt2395427                en             Avengers: Age of Ultron
# tt2395427                en             Avengers: Age of Ultron
# tt4154756                en              Avengers: Infinity War
# tt4154756                en              Avengers: Infinity War
# tt4154796                en                   Avengers: Endgame
# tt4154796                en                   Avengers: Endgame
#
#                                                     overview  popularity  \
# imdb_id
# tt0458339  During World War II, Steve Rogers is a sickly ...     105.404
# tt0848228  When an unexpected enemy emerges and threatens...     268.784
# tt2395427  When Tony Stark tries to jumpstart a dormant p...     108.405
# tt2395427  When Tony Stark tries to jumpstart a dormant p...     188.653
# tt4154756  As the Avengers and their allies have continue...     229.122
# tt4154756  As the Avengers and their allies have continue...     446.041
# tt4154796  After the devastating events of Avengers: Infi...     155.820
# tt4154796  After the devastating events of Avengers: Infi...     297.457
#
#                                 poster_path  \
# imdb_id
# tt0458339  /vSNxAJTlD0r02V9sPYpOjqDZXUK.jpg
# tt0848228   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# tt2395427  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
# tt2395427  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
# tt4154756  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# tt4154756  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# tt4154796  /or06FN3Dka5tukK1e9sl16pB3iy.jpg
# tt4154796  /or06FN3Dka5tukK1e9sl16pB3iy.jpg
#
#                                         production_companies  \
# imdb_id
# tt0458339  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt0848228  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt2395427  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt2395427  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt4154756  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt4154756  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt4154796  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# tt4154796  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
#
#                                         production_countries release_date  \
# imdb_id
# tt0458339  [{'iso_3166_1': 'US', 'name': 'United States o...   2011-07-22
# tt0848228  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-04-25
# tt2395427  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-22
# tt2395427  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-22
# tt4154756  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25
# tt4154756  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25
# tt4154796  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24
# tt4154796  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24
#
#               revenue  runtime  \
# imdb_id
# tt0458339   370569774    124.0
# tt0848228  1518815515    143.0
# tt2395427  1405403694    141.0
# tt2395427  1405403694    141.0
# tt4154756  2052415039    149.0
# tt4154756  2046239637    149.0
# tt4154796  2800000000    181.0
# tt4154796  2797800564    181.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0458339  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# tt0848228  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt2395427  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt2395427  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt4154756  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt4154756  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt4154796  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt4154796  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline  \
# imdb_id
# tt0458339            When patriots become heroes
# tt0848228                Some assembly required.
# tt2395427                    A new age has come.
# tt2395427                    A New Age Has Come.
# tt4154756  An entire universe. Once and for all.
# tt4154756  An entire universe. Once and for all.
# tt4154796                     Avenge the fallen.
# tt4154796        Part of the journey is the end.
#
#                                         title  video  vote_average  \
# imdb_id
# tt0458339  Captain America: The First Avenger  False         7.000
# tt0848228                        The Avengers  False         7.700
# tt2395427             Avengers: Age of Ultron  False         7.274
# tt2395427             Avengers: Age of Ultron  False         7.300
# tt4154756              Avengers: Infinity War  False         8.253
# tt4154756              Avengers: Infinity War  False         8.300
# tt4154796                   Avengers: Endgame  False         8.261
# tt4154796                   Avengers: Endgame  False         8.300
#
#            vote_count certification  Release Year
# imdb_id
# tt0458339       18581         PG-13        2011.0
# tt0848228       26914         PG-13        2012.0
# tt2395427       21916         PG-13        2015.0
# tt2395427       19832         PG-13        2015.0
# tt4154756       27981         PG-13        2018.0
# tt4154756       24593         PG-13        2018.0
# tt4154796       24086         PG-13        2019.0
# tt4154796       21035         PG-13        2019.0

# %% [markdown]
# ```
# imdb_id    tt0848228
# id             24428
# ```

# %%
imdb_id = 'tt0848228'
movie_id = 24428

df.loc[imdb_id]
# Out:
# adult                                                                False
# backdrop_path                             /nNmJRkg8wWnRmzQDe2FwKbPIsJV.jpg
# belongs_to_collection    {'id': 86311, 'name': 'The Avengers Collection...
# budget                                                           220000000
# genres                   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# homepage                        https://www.marvel.com/movies/the-avengers
# id                                                                   24428
# original_language                                                       en
# original_title                                                The Avengers
# overview                 When an unexpected enemy emerges and threatens...
# popularity                                                         268.784
# poster_path                                /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# production_companies     [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    2012-04-25
# revenue                                                         1518815515
# runtime                                                              143.0
# spoken_languages         [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                            Released
# tagline                                            Some assembly required.
# title                                                         The Avengers
# video                                                                False
# vote_average                                                           7.7
# vote_count                                                           26914
# certification                                                        PG-13
# Release Year                                                        2012.0
# Name: tt0848228, dtype: object

# %%
# # Barbie
# movie_id = 346698

# %%
res = tmdb.Movies(movie_id)
res.info()
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 145.128,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.711,
#  'vote_count': 29350}

# %% [markdown]
# ## Road Block: Issue with Getting the avengers reviews

# %%
import requests

def request_reviews(movie_id,page=1):
    # source: https://developer.themoviedb.org/reference/movie-reviews
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews?language=en-US&page={page}"

    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {login['api-token']}"
    }
    response = requests.get(url, headers=headers)
    try:
        return response.json()
    except:
        print("[!] Error returning response.json()")
        return response 
    # print(response.text)

def get_reviews(movie_id,start_page=1):
    
    reviews_json = request_reviews(movie_id, page=start_page)
    try:
        n_pages = reviews_json['total_pages']
    except:
        n_pages=1
        
    all_responses = reviews_json['results']
    
    for page in range(2, n_pages+1):
        reviews_json = request_reviews(movie_id, page=page)
        all_responses.extend(reviews_json['results'])

    ## Add movie id to all results
    final_results = []
    for review in all_responses:
        
        review_results = {
                    "movie_id": movie_id, #review["movie_id"],
                    "review_id": review["id"],
                    "author_rating": review["author_details"]["rating"],
                    "review_text": review["content"],
                    "created_at": review['created_at'],
                    # 'updated_at':review['updated_at']
        }
    
        final_results.append(review_results)
        
    return final_results

# %%
reviews_json = get_reviews(movie_id)
len(reviews_json)
# Out:
# 41

# %%
pd.DataFrame(reviews_json)
# Out:
#     movie_id                 review_id  author_rating  \
# 0      24428  4fce8f8819c29523880000de            8.0
# 1      24428  59f29e47c3a3687126003ccd            9.0
# 2      24428  5a657f809251410b2d030491            NaN
# 3      24428  5c8426f992514127631f9b36            8.0
# 4      24428  5cad1876c3a36812a018fc9c            8.5
# 5      24428  5d46cf540f2fbd7864efbe30            9.0
# 6      24428  5dc32f2f5aadc4001520e0dd            NaN
# 7      24428  5dc389f37d2bc100133d06df            NaN
# 8      24428  5dc3930999259c00157aa7cb            NaN
# 9      24428  5dc3993d470ead00138cf1ec            NaN
# 10     24428  5dc56e556f8d950013c2d977            NaN
# 11     24428  5dc579c56f8d950010c2f5c5            NaN
# 12     24428  5e00e8fb75110d0018d85d20            NaN
# 13     24428  5e00ee5565686e0013987f15            NaN
# 14     24428  5e0102250284200014af5898            NaN
# 15     24428  5e011ac665686e0018983449            NaN
# 16     24428  5e02862b26dac10012674852            NaN
# 17     24428  5e08f6e5a1c59d0018aac032            NaN
# 18     24428  5e091b9d5ff34e0013b9ce5f            NaN
# 19     24428  5e09b284383df20018b90384            NaN
# 20     24428  5e09b5c86d97e600173c5508            NaN
# 21     24428  5e0e0c41fd4f8000155f3cf4            NaN
# 22     24428  5e0e160b6dc6c000134d1fa6            NaN
# 23     24428  5e0e200d12c60400143fa896            NaN
# 24     24428  5e0e29dc6dc6c000154cd86b            NaN
# 25     24428  5e0e4062c2f44b0013301af8            NaN
# 26     24428  5e0e528712c6040017401e24            NaN
# 27     24428  5e0f03159f37b00015561eb1            NaN
# 28     24428  5e0f2bcf663b8700177ef84f            NaN
# 29     24428  5e104c6cd64ac20018608071            NaN
# 30     24428  5e1210fae78e2d0017768edd            NaN
# 31     24428  5e1244e15907de0017de881d            NaN
# 32     24428  5e125949d64ac2001864cba3            NaN
# 33     24428  5e12c5af9020120013b74f2e            NaN
# 34     24428  5e12c9c68741c400123d9d8a            NaN
# 35     24428  5e12cdc25907de0012deea04            NaN
# 36     24428  5e12d1cafc5f06001590b427            NaN
# 37     24428  5e20d3be8f26bc001171c86e            NaN
# 38     24428  5e20ddf38f26bc001571bb9e            NaN
# 39     24428  5eddc7268d52c90022a60a4b            8.0
# 40     24428  600233081c635b0055ef5f7e            7.0
#
#                                           review_text  \
# 0   With a movie like this you wonder how all of t...
# 1   **A long format review from 2012**\r\n\r\nMy n...
# 2   After the recent disappointments from Marvel, ...
# 3   One of the few movies to actually make me feel...
# 4   I give this 10 Stars based on it being not onl...
# 5   Everything that's happening, the things that a...
# 6   The Avengers is a dream movie come true for su...
# 7   Definitely the greatest superhero movie of all...
# 8   I found it creative of Marvel to introduce eac...
# 9   Perfect casting! You can really see and feel t...
# 10  Wonderful movie to watch if you want to be ent...
# 11  When you have a bunch of flashy superheroes fi...
# 12  The Avengers is a dream movie come true for su...
# 13  I tried my best to avoid getting carried away ...
# 14  One word for this movie: AWESOME. It’s an amaz...
# 15  One of the many things I loved in this film wa...
# 16  The cast really delivered. Sure they were play...
# 17  Kudos to the fight choreographers who designed...
# 18  If you haven't seen this film yet, do yourself...
# 19  Good fighting sequences but camerawork feels t...
# 20  I thought I would be able to enjoy it upon hea...
# 21  It was a great idea to bring together this gro...
# 22  I appreciate how they made sure to introduce e...
# 23  I gotta admit I was not ready for all that sha...
# 24  I'm not exaggerating when I say that this is t...
# 25  The title says it all, you will really MARVEL ...
# 26  Marvel really outdid themselves on this one. T...
# 27  Are you a fan of epic adventure movies? Then t...
# 28  More than just a superhero film, this movie ha...
# 29  The best thing about this movie is that it gav...
# 30  Stan Lee cameos are the best! It's too bad he ...
# 31  This is not a good movie... It's a GREAT MOVIE...
# 32  Superhero with not only super-awesome heroes b...
# 33  I don't think Marvel could've found a better c...
# 34  If you're a comic book fan like me, you'd unde...
# 35  The incredible mix of superheroes together wit...
# 36  Count on the Avengers to make man-tights and c...
# 37  It takes more than just great actors to make a...
# 38  When you have an amazing team of actors with g...
# 39  Probably only my third time watching and still...
# 40  The last hour is a lot of fun, but I found the...
#
#                   created_at
# 0   2012-06-05T23:00:24.000Z
# 1   2017-10-27T02:47:35.267Z
# 2   2018-01-22T06:06:56.333Z
# 3   2019-03-09T20:50:01.703Z
# 4   2019-04-09T22:11:02.850Z
# 5   2019-08-04T12:28:04.980Z
# 6   2019-11-06T20:38:07.253Z
# 7   2019-11-07T03:05:23.344Z
# 8   2019-11-07T03:44:09.147Z
# 9   2019-11-07T04:10:37.105Z
# 10  2019-11-08T13:32:05.653Z
# 11  2019-11-08T14:20:53.615Z
# 12  2019-12-23T16:19:07.269Z
# 13  2019-12-23T16:41:57.040Z
# 14  2019-12-23T18:06:29.819Z
# 15  2019-12-23T19:51:34.381Z
# 16  2019-12-24T21:42:03.600Z
# 17  2019-12-29T18:56:37.052Z
# 18  2019-12-29T21:33:17.599Z
# 19  2019-12-30T08:17:08.404Z
# 20  2019-12-30T08:31:04.632Z
# 21  2020-01-02T15:29:05.209Z
# 22  2020-01-02T16:10:51.122Z
# 23  2020-01-02T16:53:33.128Z
# 24  2020-01-02T17:35:24.070Z
# 25  2020-01-02T19:11:30.020Z
# 26  2020-01-02T20:28:55.182Z
# 27  2020-01-03T09:02:13.271Z
# 28  2020-01-03T11:55:59.996Z
# 29  2020-01-04T08:27:24.569Z
# 30  2020-01-05T16:38:18.235Z
# 31  2020-01-05T20:19:45.004Z
# 32  2020-01-05T21:46:49.742Z
# 33  2020-01-06T05:29:19.509Z
# 34  2020-01-06T05:46:46.176Z
# 35  2020-01-06T06:03:46.319Z
# 36  2020-01-06T06:20:58.799Z
# 37  2020-01-16T21:21:02.781Z
# 38  2020-01-16T22:04:35.109Z
# 39  2020-06-08T05:05:42.360Z
# 40  2021-01-16T00:27:52.914Z

# %%
# test_review = reviews_json[0]
# test_review.keys()

# %%
# test_review['id']

# %%
# test_review['movie_id']

# %%
# test_review['author_details']

# %%
# test_review['author_details']['rating']

# %%
# test_review['content']

# %%
# test_review['id','movie_id']

# %%
# final_results = {
#     "movie_id": test_review["movie_id"],
#     "review_id": test_review["id"],
#     "author_rating": test_review["author_details"]["rating"],
#     "review_text": test_review["content"],
#     "created_at": test_review['created_at'],
#     'updated_at':test_review['updated_at']
# }
# final_results

# %%
# reviews_json[1]

# %%
# reviews_json['page']

# %%
# reviews_json['total_pages']

# %%
# len(reviews_json['results'])

# %%
# response.json()

# %%
# reviews = tmdb.Reviews(movie_id)
# reviews.info()

# %%
df['id']
# Out:
# imdb_id
# tt0118694       843
# tt0120467     19085
# tt0120630      7443
# tt0120753       318
# tt0120755       955
#               ...
# tt9185206    555285
# tt9224104    615656
# tt9362722    569094
# tt9362930    565770
# tt9603212    575264
# Name: id, Length: 7198, dtype: int64

# %%
# tmdb.Reviews()

# %%
def get_movie_with_rating(movie_id):
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    # save the .info .releases dictionaries
    movie_info = movie.info()
    releases = movie.releases()
    
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
            movie_info['certification'] = c['certification']
    return movie_info

# %%
# df

# %%
# SET VARS FOR LOOP
FOLDER = "Data-NLP/"
os.makedirs(FOLDER,exist_ok=True)

# Save movie data for just movies with financial data
fname_data = FOLDER+"tmdb-movie-info.csv.gz"
df.to_csv(fname_data, compression='gzip')


# Control saving method
SAVE_TO_DISK_FIRST = True

# %%
pd.read_csv(fname_data)
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0     tt0118694  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 1     tt0120467  False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 2     tt0120630  False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 3     tt0120753  False  /cXXxi0j9sXFt7LbeajuFoKFqWMu.jpg
# 4     tt0120755  False  /8XaohdSqoBEWHhW40q2VTdMBrV0.jpg
# ...         ...    ...                               ...
# 7193  tt9185206  False  /qNmLEOGZy37vKAPqcTuZ47uCOS9.jpg
# 7194  tt9224104  False  /5mzr6JZbrqnqD8rCEvPhuCE5Fw2.jpg
# 7195  tt9362722  False  /4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg
# 7196  tt9362930  False  /3H9NA1KWEQN0ItL3Wl3SFZYP6yV.jpg
# 7197  tt9603212  False  /628Dep6AxEtDxjZoGP78TsOxYbK.jpg
#
#                                   belongs_to_collection     budget  \
# 0                                                   NaN     150000
# 1                                                   NaN     120000
# 2     {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 3                                                   NaN    8000000
# 4     {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
# ...                                                 ...        ...
# 7193                                                NaN   30000000
# 7194  {'id': 742536, 'name': 'The Meg Collection', '...  129000000
# 7195  {'id': 573436, 'name': 'Spider-Man: Spider-Ver...  100000000
# 7196                                                NaN  104000000
# 7197  {'id': 87359, 'name': 'Mission: Impossible Col...  291000000
#
#                                                  genres  \
# 0     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1     [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 4     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                 ...
# 7193  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 7194  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 7195  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 7196  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 7197  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage      id original_language  \
# 0       http://www.wkw-inthemoodforlove.com/     843                cn
# 1                                        NaN   19085                en
# 2                                        NaN    7443                en
# 3                                        NaN     318                en
# 4                                        NaN     955                en
# ...                                      ...     ...               ...
# 7193         https://www.itsmemargaret.movie  555285                en
# 7194                https://www.themeg.movie  615656                en
# 7195  https://www.acrossthespiderverse.movie  569094                en
# 7196           https://www.dc.com/bluebeetle  565770                en
# 7197       https://www.missionimpossible.com  575264                en
#
#                                      original_title  \
# 0                                              花樣年華
# 1                                            Vulgar
# 2                                       Chicken Run
# 3                          The Million Dollar Hotel
# 4                            Mission: Impossible II
# ...                                             ...
# 7193          Are You There God? It's Me, Margaret.
# 7194                              Meg 2: The Trench
# 7195            Spider-Man: Across the Spider-Verse
# 7196                                    Blue Beetle
# 7197  Mission: Impossible - Dead Reckoning Part One
#
#                                                overview  popularity  \
# 0     Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 1     Vulgar is about a man who is a children's clow...       3.692
# 2     Having been hopelessly repressed and facing ev...      35.780
# 3     The Million Dollar Hotel starts with a jump fr...       6.431
# 4     With computer genius Luther Stickell at his si...      22.658
# ...                                                 ...         ...
# 7193  When her family moves from New York City to Ne...      47.950
# 7194  An exploratory dive into the deepest depths of...     460.025
# 7195  After reuniting with Gwen Stacy, Brooklyn’s fu...     388.074
# 7196  Recent college grad Jaime Reyes returns home f...     471.802
# 7197  Ethan Hunt and his IMF team embark on their mo...     751.722
#
#                            poster_path  \
# 0     /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 1     /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# 2     /8XgmIsbpVamdhwcNVsYzohFZTtT.jpg
# 3     /7AjzGYybwfndxnpApKXahQiq2Zy.jpg
# 4     /2njB2A85Ni7bRR7vIOrfv6TBPeC.jpg
# ...                                ...
# 7193  /yb6UB4WC3znlwU0L4AqMnjR9G9S.jpg
# 7194  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
# 7195  /8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg
# 7196  /mXLOHHc1Zeuwsl4xYKjKh2280oL.jpg
# 7197   /NNxYkU70HPurnNCSiCjYAmacwm.jpg
#
#                                    production_companies  \
# 0     [{'id': 539, 'logo_path': None, 'name': 'Block...
# 1     [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 2     [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 3     [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 4     [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...                                                 ...
# 7193  [{'id': 18, 'logo_path': '/uqhagSwM7NAkQWVCQhK...
# 7194  [{'id': 56242, 'logo_path': '/1YORRYmg7hgYIgoJ...
# 7195  [{'id': 5, 'logo_path': '/wrweLpBqRYcAM7kCSaHD...
# 7196  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 7197  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                    production_countries release_date  \
# 0           [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26
# 2     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-21
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-02-09
# 4     [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2000-05-24
# ...                                                 ...          ...
# 7193  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-03-29
# 7194  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...   2023-08-02
# 7195  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-05-31
# 7196  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-08-16
# 7197  [{'iso_3166_1': 'US', 'name': 'United States o...   2023-07-08
#
#         revenue  runtime                                   spoken_languages  \
# 0      12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 1         14904     87.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2     224834564     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3        105983    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     546388105    123.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...         ...      ...                                                ...
# 7193   21826840    107.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7194  384056482    116.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7195  683241751    140.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7196  128600000    128.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7197  567148955    164.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
#
#         status                                            tagline  \
# 0     Released  Feel the heat, keep the feeling burning, let t...
# 1     Released   Everyone loves a clown... some more than others.
# 2     Released  This ain't no chick flick. It's poultry in mot...
# 3     Released                    Everyone has something to hide.
# 4     Released                       Expect the impossible again.
# ...        ...                                                ...
# 7193  Released  Discovering who you are is a journey that last...
# 7194  Released                                  Back for seconds.
# 7195  Released           It's how you wear the mask that matters.
# 7196  Released  Jaime Reyes is a superhero whether he likes it...
# 7197  Released                        We all share the same fate.
#
#                                               title  video  vote_average  \
# 0                              In the Mood for Love  False         8.100
# 1                                            Vulgar  False         5.400
# 2                                       Chicken Run  False         6.700
# 3                          The Million Dollar Hotel  False         5.900
# 4                            Mission: Impossible II  False         6.100
# ...                                             ...    ...           ...
# 7193          Are You There God? It's Me, Margaret.  False         7.324
# 7194                              Meg 2: The Trench  False         6.749
# 7195            Spider-Man: Across the Spider-Verse  False         8.406
# 7196                                    Blue Beetle  False         6.952
# 7197  Mission: Impossible - Dead Reckoning Part One  False         7.586
#
#       vote_count certification  Release Year
# 0           1879            PG        2000.0
# 1             41             R        2002.0
# 2           4009             G        2000.0
# 3            247             R        2000.0
# 4           5297         PG-13        2000.0
# ...          ...           ...           ...
# 7193         162         PG-13        2023.0
# 7194        2568         PG-13        2023.0
# 7195        4951            PG        2023.0
# 7196        1681         PG-13        2023.0
# 7197        2498         PG-13        2023.0
#
# [7198 rows x 27 columns]

# %% [markdown]
# ## ✅ To Do:
# - [ ] Add filenames to tmdb movie data df

# %%
import time

# OVERWRITE = False
SKIP_IF_EXISTS = True

# saving movie ids to list
movie_ids = df['id'].copy()#.to_list()

movie_id_filenames = {}
#Get index and movie id from list
# INNER Loop
for movie_id in tqdm_notebook(movie_ids):
    try:
        #Defining the JSON file to store results for year
        JSON_FILE = f'{FOLDER}tmdb_reviews_{movie_id}.json'
        
        if os.path.exists(JSON_FILE) == True:
            if SKIP_IF_EXISTS==True:
                continue
                
        # Get reviews from API
        reviews_json = get_reviews(movie_id)

        # If no reviews, make a list of a single dict with movie_id
        if len(reviews_json) == 0:
            reviews_json = [{'movie_id':movie_id}]
        
        write_json(reviews_json, JSON_FILE, overwrite=False, skip=True)
        movie_id_filenames[movie_id] = JSON_FILE
        time.sleep(.01)
        
    except Exception as e:
        display(e)
# Out:
#   0%|          | 0/7198 [00:00<?, ?it/s]
# KeyError('results')
# KeyError('results')

# %%
len(movie_id_filenames)
# Out:
# 470

# %%
df['reviews_file'] = df['id'].map(movie_id_filenames)
df['reviews_file'].isna().sum()
# Out:
# 6728

# %%
df.head()
# Out:
#            adult                     backdrop_path  \
# imdb_id
# tt0118694  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# tt0120467  False  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# tt0120630  False  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# tt0120753  False  /cXXxi0j9sXFt7LbeajuFoKFqWMu.jpg
# tt0120755  False  /8XaohdSqoBEWHhW40q2VTdMBrV0.jpg
#
#                                        belongs_to_collection     budget  \
# imdb_id
# tt0118694                                                NaN     150000
# tt0120467                                                NaN     120000
# tt0120630  {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# tt0120753                                                NaN    8000000
# tt0120755  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
#
#                                                       genres  \
# imdb_id
# tt0118694  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# tt0120467  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# tt0120630  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0120753  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# tt0120755  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                        homepage     id original_language  \
# imdb_id
# tt0118694  http://www.wkw-inthemoodforlove.com/    843                cn
# tt0120467                                   NaN  19085                en
# tt0120630                                   NaN   7443                en
# tt0120753                                   NaN    318                en
# tt0120755                                   NaN    955                en
#
#                      original_title  \
# imdb_id
# tt0118694                      花樣年華
# tt0120467                    Vulgar
# tt0120630               Chicken Run
# tt0120753  The Million Dollar Hotel
# tt0120755    Mission: Impossible II
#
#                                                     overview  popularity  \
# imdb_id
# tt0118694  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# tt0120467  Vulgar is about a man who is a children's clow...       3.692
# tt0120630  Having been hopelessly repressed and facing ev...      35.780
# tt0120753  The Million Dollar Hotel starts with a jump fr...       6.431
# tt0120755  With computer genius Luther Stickell at his si...      22.658
#
#                                 poster_path  \
# imdb_id
# tt0118694  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# tt0120467  /aLdezroGbHDP0w0jOLwxXjgrgma.jpg
# tt0120630  /8XgmIsbpVamdhwcNVsYzohFZTtT.jpg
# tt0120753  /7AjzGYybwfndxnpApKXahQiq2Zy.jpg
# tt0120755  /2njB2A85Ni7bRR7vIOrfv6TBPeC.jpg
#
#                                         production_companies  \
# imdb_id
# tt0118694  [{'id': 539, 'logo_path': None, 'name': 'Block...
# tt0120467  [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# tt0120630  [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# tt0120753  [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# tt0120755  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                         production_countries release_date  \
# imdb_id
# tt0118694        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# tt0120467  [{'iso_3166_1': 'US', 'name': 'United States o...   2002-04-26
# tt0120630  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2000-06-21
# tt0120753  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-02-09
# tt0120755  [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2000-05-24
#
#              revenue  runtime  \
# imdb_id
# tt0118694   12854953     99.0
# tt0120467      14904     87.0
# tt0120630  224834564     84.0
# tt0120753     105983    122.0
# tt0120755  546388105    123.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0118694  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# tt0120467  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120630  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120753  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120755  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                      tagline  \
# imdb_id
# tt0118694  Feel the heat, keep the feeling burning, let t...
# tt0120467   Everyone loves a clown... some more than others.
# tt0120630  This ain't no chick flick. It's poultry in mot...
# tt0120753                    Everyone has something to hide.
# tt0120755                       Expect the impossible again.
#
#                               title  video  vote_average  vote_count  \
# imdb_id
# tt0118694      In the Mood for Love  False           8.1        1879
# tt0120467                    Vulgar  False           5.4          41
# tt0120630               Chicken Run  False           6.7        4009
# tt0120753  The Million Dollar Hotel  False           5.9         247
# tt0120755    Mission: Impossible II  False           6.1        5297
#
#           certification  Release Year reviews_file
# imdb_id
# tt0118694            PG        2000.0          NaN
# tt0120467             R        2002.0          NaN
# tt0120630             G        2000.0          NaN
# tt0120753             R        2000.0          NaN
# tt0120755         PG-13        2000.0          NaN

# %%
# Save movie data for just movies with financial data
fname_data = FOLDER+"tmdb-movie-info.csv.gz"
df.to_csv(fname_data, compression='gzip')

# %% [markdown]
# ## Combine Reviews

# %%
import glob
# review_files = sorted(glob.glob(FOLDER+"*review*.json"))
review_files = df['reviews_file'].dropna().to_list()
len(review_files)
# Out:
# 470

# %%
loaded = []

for file in review_files:
    temp = pd.read_json(file)
    loaded.append(temp)

reviews = pd.concat(loaded)
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1239 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1239 non-null   int64
#  1   review_id      1054 non-null   object
#  2   author_rating  953 non-null    float64
#  3   review_text    1054 non-null   object
#  4   created_at     1054 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(2)
# memory usage: 58.1+ KB

# %%
import missingno
missingno.matrix(reviews)
# Out:
# <Axes: >

# %%
reviews.isna().sum()/len(reviews)
# Out:
# movie_id         0.000000
# review_id        0.149314
# author_rating    0.230831
# review_text      0.149314
# created_at       0.149314
# dtype: float64

# %%
reviews = reviews.dropna(subset=['review_text'])
reviews
# Out:
#     movie_id                 review_id  author_rating  \
# 0     248574  561264349251415e530084af            6.0
# 1     248574  591b61b7925141061e06aff2            6.0
# 2     248574  632226301b722c0084369586            6.0
# 0     294963  56c0b64cc3a36817f200c7c7            9.0
# 1     294963  5787c6c292514131c2000f77            7.0
# ..       ...                       ...            ...
# 4     575264  64ba5c5706f98400e1169ed0            7.0
# 5     575264  64bdab4dad50f0013b127c02            6.0
# 6     575264  64cca28c43cd5400add62db6            9.0
# 7     575264  652e4978caef2d0139df3b6c            8.0
# 8     575264  653df83bc8a5ac011d6d5767            8.0
#
#                                           review_text  \
# 0   This movie is absolutely ludicrous! The core o...
# 1   **For some people, living a normal life is a c...
# 2   **You have definitely seen the movie before, j...
# 0   It's sure to be a bone of contention...\r\n\r\...
# 1   > Meet the most savage people of the American ...
# ..                                                ...
# 4   I'm not really a great fan of Tom Cruise. Yes,...
# 5   Spectacular cinematic action let down by an in...
# 6   The Tom Cruise “Mission Impossible” franchise ...
# 7   It was a good movie. Not better than the pervi...
# 8   Good stuntwork as usual from this series and t...
#
#                          created_at
# 0  2015-10-05 11:51:16.762000+00:00
# 1  2017-05-16 20:31:51.606000+00:00
# 2  2022-09-14 19:06:24.986000+00:00
# 0  2016-02-14 17:15:56.656000+00:00
# 1  2016-07-14 17:07:14.684000+00:00
# ..                              ...
# 4  2023-07-21 10:22:15.048000+00:00
# 5  2023-07-23 22:35:58.004000+00:00
# 6  2023-08-04 07:02:36.097000+00:00
# 7  2023-10-17 08:44:40.250000+00:00
# 8  2023-10-29 06:14:19.708000+00:00
#
# [1054 rows x 5 columns]

# %%
 missingno.matrix(reviews)
# Out:
# <Axes: >

# %%
combined_reviews_fname = FOLDER+"tmdb-movie-reviews.csv.gz"
reviews.to_csv(combined_reviews_fname, index=False, compression='gzip')

# %%
combined_reviews_fname
# Out:
# 'Data-NLP/tmdb-movie-reviews.csv.gz'
