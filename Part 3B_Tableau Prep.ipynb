# %% [markdown]
# # Tableau prep

# %%
# !pip install -U cdds
from cdds.imports import *
# Out:
# cdds v1.0.3 loaded.
# <style type="text/css">
# #T_377b9_row0_col0, #T_377b9_row0_col2, #T_377b9_row0_col3, #T_377b9_row1_col0, #T_377b9_row1_col2, #T_377b9_row1_col3, #T_377b9_row2_col0, #T_377b9_row2_col2, #T_377b9_row2_col3, #T_377b9_row3_col0, #T_377b9_row3_col2, #T_377b9_row3_col3, #T_377b9_row4_col0, #T_377b9_row4_col2, #T_377b9_row4_col3, #T_377b9_row5_col0, #T_377b9_row5_col2, #T_377b9_row5_col3, #T_377b9_row6_col0, #T_377b9_row6_col2, #T_377b9_row6_col3, #T_377b9_row7_col0, #T_377b9_row7_col2, #T_377b9_row7_col3 {
#   text-align: left;
# }
# #T_377b9_row0_col1, #T_377b9_row0_col4, #T_377b9_row1_col1, #T_377b9_row1_col4, #T_377b9_row2_col1, #T_377b9_row2_col4, #T_377b9_row3_col1, #T_377b9_row3_col4, #T_377b9_row4_col1, #T_377b9_row4_col4, #T_377b9_row5_col1, #T_377b9_row5_col4, #T_377b9_row6_col1, #T_377b9_row6_col4, #T_377b9_row7_col1, #T_377b9_row7_col4 {
#   text-align: left;
#   text-align: center;
# }
# </style>
# <table id="T_377b9">
#   <caption>Loaded Packages & Info</caption>
#   <thead>
#     <tr>
#       <th id="T_377b9_level0_col0" class="col_heading level0 col0" >Package</th>
#       <th id="T_377b9_level0_col1" class="col_heading level0 col1" >Handle</th>
#       <th id="T_377b9_level0_col2" class="col_heading level0 col2" >Version</th>
#       <th id="T_377b9_level0_col3" class="col_heading level0 col3" >Documentation</th>
#       <th id="T_377b9_level0_col4" class="col_heading level0 col4" >Imported</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_377b9_row0_col0" class="data row0 col0" >pandas</td>
#       <td id="T_377b9_row0_col1" class="data row0 col1" >pd</td>
#       <td id="T_377b9_row0_col2" class="data row0 col2" >1.4.2</td>
#       <td id="T_377b9_row0_col3" class="data row0 col3" ><a href="https://pandas.pydata.org/docs/">https://pandas.pydata.org/docs/</a></td>
#       <td id="T_377b9_row0_col4" class="data row0 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row1_col0" class="data row1 col0" >cdds</td>
#       <td id="T_377b9_row1_col1" class="data row1 col1" >ds</td>
#       <td id="T_377b9_row1_col2" class="data row1 col2" >1.0.3</td>
#       <td id="T_377b9_row1_col3" class="data row1 col3" ><a href="Coming Soon!">Coming Soon!</a></td>
#       <td id="T_377b9_row1_col4" class="data row1 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row2_col0" class="data row2 col0" >numpy</td>
#       <td id="T_377b9_row2_col1" class="data row2 col1" >np</td>
#       <td id="T_377b9_row2_col2" class="data row2 col2" >1.22.4</td>
#       <td id="T_377b9_row2_col3" class="data row2 col3" ><a href="https://numpy.org/doc/stable/reference/">https://numpy.org/doc/stable/reference/</a></td>
#       <td id="T_377b9_row2_col4" class="data row2 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row3_col0" class="data row3 col0" >matplotlib</td>
#       <td id="T_377b9_row3_col1" class="data row3 col1" >mpl</td>
#       <td id="T_377b9_row3_col2" class="data row3 col2" >3.4.3</td>
#       <td id="T_377b9_row3_col3" class="data row3 col3" ><a href="https://matplotlib.org/stable/api/index.html">https://matplotlib.org/stable/api/index.html</a></td>
#       <td id="T_377b9_row3_col4" class="data row3 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row4_col0" class="data row4 col0" >matplotlib.pyplot</td>
#       <td id="T_377b9_row4_col1" class="data row4 col1" >plt</td>
#       <td id="T_377b9_row4_col2" class="data row4 col2" ></td>
#       <td id="T_377b9_row4_col3" class="data row4 col3" ><a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot">https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot</a></td>
#       <td id="T_377b9_row4_col4" class="data row4 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row5_col0" class="data row5 col0" >seaborn</td>
#       <td id="T_377b9_row5_col1" class="data row5 col1" >sns</td>
#       <td id="T_377b9_row5_col2" class="data row5 col2" >0.11.2</td>
#       <td id="T_377b9_row5_col3" class="data row5 col3" ><a href="https://seaborn.pydata.org/api.html">https://seaborn.pydata.org/api.html</a></td>
#       <td id="T_377b9_row5_col4" class="data row5 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row6_col0" class="data row6 col0" >IPython.display</td>
#       <td id="T_377b9_row6_col1" class="data row6 col1" >dp</td>
#       <td id="T_377b9_row6_col2" class="data row6 col2" ></td>
#       <td id="T_377b9_row6_col3" class="data row6 col3" ><a href="https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html">https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html</a></td>
#       <td id="T_377b9_row6_col4" class="data row6 col4" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_377b9_row7_col0" class="data row7 col0" >sklearn</td>
#       <td id="T_377b9_row7_col1" class="data row7 col1" ></td>
#       <td id="T_377b9_row7_col2" class="data row7 col2" >1.0.2</td>
#       <td id="T_377b9_row7_col3" class="data row7 col3" ><a href=""></a></td>
#       <td id="T_377b9_row7_col4" class="data row7 col4" >N</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ds.utils.

# %%
ds.inspect.inspect_file('Data/title_akas_cleaned.csv.gz')
# Out:
# - Data/title_akas_cleaned.csv.gz is 20.061937 MB on disk.
# {'Filepath': 'Data/title_akas_cleaned.csv.gz',
#  'Name': 'title_akas_cleaned.csv.gz',
#  'Created': 'Fri Nov 18 14:39:23 2022',
#  'Modified': 'Fri Nov 18 14:39:23 2022',
#  'Size': '20.061937 mb',
#  'Folder': 'Data',
#  'Ext': '.gz',
#  'Size (bytes)': 20061937,
#  'Relative Path': 'Data/title_akas_cleaned.csv.gz',
#  'Absolute Path': '/Users/codingdojo/Documents/GitHub/_MY_PROJECTS/how-to-make-successful-movies/Data/title_akas_cleaned.csv.gz'}

# %%
basics = pd.read_csv('Data/title_basics_cleaned.csv.gz')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0067683     movie
# 3       tt0069049     movie
# 4       tt0088751     movie
# ...           ...       ...
# 116399  tt9915436     movie
# 116400  tt9915872     movie
# 116401  tt9916170     movie
# 116402  tt9916190     movie
# 116403  tt9916362     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                Workers '71: Nothing About Us Without Us
# 3                              The Other Side of the Wind
# 4                                       The Naked Monster
# ...                                                   ...
# 116399                                  Vida em Movimento
# 116400                               The Last White Witch
# 116401                                      The Rehearsal
# 116402                                          Safeguard
# 116403                                              Coven
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 1       El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2              Robotnicy 1971 - Nic o nas bez nas        0     2006.0
# 3                      The Other Side of the Wind        0     2018.0
# 4                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 116399                          Vida em Movimento        0     2019.0
# 116400                  My Girlfriend is a Wizard        0     2019.0
# 116401                                   O Ensaio        0     2019.0
# 116402                                  Safeguard        0     2020.0
# 116403                                   Akelarre        0     2020.0
#
#         runtimeMinutes                     genres
# 0                  118     Comedy,Fantasy,Romance
# 1                   70                      Drama
# 2                   47                Documentary
# 3                  122                      Drama
# 4                  100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 116399              70                Documentary
# 116400              97       Comedy,Drama,Fantasy
# 116401              51                      Drama
# 116402              95  Action,Adventure,Thriller
# 116403              92              Drama,History
#
# [116404 rows x 8 columns]

# %%
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0067683     movie
# 3       tt0069049     movie
# 4       tt0088751     movie
# ...           ...       ...
# 116399  tt9915436     movie
# 116400  tt9915872     movie
# 116401  tt9916170     movie
# 116402  tt9916190     movie
# 116403  tt9916362     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                Workers '71: Nothing About Us Without Us
# 3                              The Other Side of the Wind
# 4                                       The Naked Monster
# ...                                                   ...
# 116399                                  Vida em Movimento
# 116400                               The Last White Witch
# 116401                                      The Rehearsal
# 116402                                          Safeguard
# 116403                                              Coven
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 1       El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2              Robotnicy 1971 - Nic o nas bez nas        0     2006.0
# 3                      The Other Side of the Wind        0     2018.0
# 4                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 116399                          Vida em Movimento        0     2019.0
# 116400                  My Girlfriend is a Wizard        0     2019.0
# 116401                                   O Ensaio        0     2019.0
# 116402                                  Safeguard        0     2020.0
# 116403                                   Akelarre        0     2020.0
#
#         runtimeMinutes                     genres
# 0                  118     Comedy,Fantasy,Romance
# 1                   70                      Drama
# 2                   47                Documentary
# 3                  122                      Drama
# 4                  100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 116399              70                Documentary
# 116400              97       Comedy,Drama,Fantasy
# 116401              51                      Drama
# 116402              95  Action,Adventure,Thriller
# 116403              92              Drama,History
#
# [116404 rows x 8 columns]

# %%
tmdb = pd.read_csv('Data/combined_tmdb_api_data.csv.gz', lineterminator='\n')
tmdb
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1      False                               NaN                   NaN
# 2      False                               NaN                   NaN
# 3      False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4      False                               NaN                   NaN
# ...      ...                               ...                   ...
# 78392  False                               NaN                   NaN
# 78393  False  /l9pTUWSHpD9MdEZySCM4e146MCd.jpg                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False  /ibWj2ARVrAabIWDq5vSXoJRZfVV.jpg                   NaN
#
#          budget                                             genres  \
# 0      10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1             0           [{'id': 878, 'name': 'Science Fiction'}]
# 2             0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3        150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4             0                      [{'id': 18, 'name': 'Drama'}]
# ...         ...                                                ...
# 78392         0                      [{'id': 80, 'name': 'Crime'}]
# 78393         0  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 78394         0  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 78395         0  [{'id': 80, 'name': 'Crime'}, {'id': 10749, 'n...
# 78396         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                    homepage      id    imdb_id  \
# 0                                       NaN   62127  tt0113026
# 1                                       NaN  110977  tt0113092
# 2                                       NaN  442869  tt0116391
# 3      http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 4                                       NaN   49511  tt0118852
# ...                                     ...     ...        ...
# 78392                                   NaN  969840  tt9854058
# 78393                                   NaN  661078  tt9867628
# 78394                                   NaN  972731  tt9893130
# 78395                                   NaN  796955  tt9893158
# 78396            https://contrastmovie.com/  933557  tt9904648
#
#       original_language             original_title  \
# 0                    en            The Fantasticks
# 1                    en              For the Cause
# 2                    hi                       Gang
# 3                    cn                       花樣年華
# 4                    en             Chinese Coffee
# ...                 ...                        ...
# 78392                en                    Shadows
# 78393                ml                    തുറമുഖം
# 78394                en  2025: Blood, White & Blue
# 78395                en                   Clowning
# 78396                en               The Contrast
#
#                                                 overview  popularity  \
# 0      Two rural teens sing and dance their way throu...       2.510
# 1      Earth is in a state of constant war and two co...       1.518
# 2      After falling prey to underworld, four friends...       0.600
# 3      Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      14.944
# 4      When Harry Levine, an aging, unsuccessful Gree...       4.164
# ...                                                  ...         ...
# 78392  A young low-level drug dealer is reunited with...       3.118
# 78393  The Harbour shows how two brothers end up on o...       2.487
# 78394  Undercover U.S. agent Bill Wilson makes the bu...       0.840
# 78395  With his girlfriend pregnant, Dante, a pacifis...       3.591
# 78396  On the day before her wedding to a hipster pla...       1.893
#
#                             poster_path  \
# 0      /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1      /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2      /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3      /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4      /s6yQFnJohmvdkbeHbx6fFOTpYwR.jpg
# ...                                 ...
# 78392  /2HaAOGM1EmiSwsJrdq1RNhYehce.jpg
# 78393  /rQ2lPXyAwm0c5Sre9xyvnTPEt0Z.jpg
# 78394  /1S9pjiZejBiSVV88qU59ifZ7q0N.jpg
# 78395  /xppIANX9DQoRYg3FlNCifDYuFwP.jpg
# 78396  /sioXCmW4Q2VXLYm9hIY8GcnU3m7.jpg
#
#                                     production_companies  \
# 0      [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1      [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                     []
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4      [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...                                                  ...
# 78392                                                 []
# 78393  [{'id': 47460, 'logo_path': '/9OTmYAzW2URLSE76...
# 78394  [{'id': 16600, 'logo_path': None, 'name': 'Aud...
# 78395  [{'id': 109533, 'logo_path': '/xtQJYJg54jp5QVS...
# 78396                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3            [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                  ...          ...
# 78392                                                 []   2022-05-13
# 78393            [{'iso_3166_1': 'IN', 'name': 'India'}]   2022-06-03
# 78394  [{'iso_3166_1': 'US', 'name': 'United States o...          NaN
# 78395  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-03-13
# 78396                                                 []   2022-01-18
#
#         revenue  runtime                                   spoken_languages  \
# 0             0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3      12854953     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4             0     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...         ...      ...                                                ...
# 78392         0    101.0                                                 []
# 78393         0    171.0  [{'english_name': 'Malayalam', 'iso_639_1': 'm...
# 78394         0    135.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78395         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78396         0     82.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                 status                                            tagline  \
# 0             Released      Try to remember the first time magic happened
# 1             Released       The ultimate showdown on a forbidden planet.
# 2             Released                                                NaN
# 3             Released  Feel the heat, keep the feeling burning, let t...
# 4             Released  There's a fine line between friendship and bet...
# ...                ...                                                ...
# 78392         Released                 Family Is The Last Line Of Defense
# 78393  Post Production                                                NaN
# 78394         Released                                 THE PURGE meets US
# 78395         Released  Warm nights... Feels like death in the sand du...
# 78396         Released                  Everybody loves... somebody else.
#
#                            title  video  vote_average  vote_count  \
# 0                The Fantasticks  False           5.4          21
# 1                  For the Cause  False           4.4           7
# 2                           Gang  False           0.0           0
# 3           In the Mood for Love  False           8.1        1879
# 4                 Chinese Coffee  False           6.9          46
# ...                          ...    ...           ...         ...
# 78392                    Shadows  False           0.0           0
# 78393                The Harbour  False           0.0           0
# 78394  2025: Blood, White & Blue  False           0.0           0
# 78395                   Clowning  False           0.0           0
# 78396               The Contrast  False           0.0           0
#
#       certification  Release Year
# 0               NaN        2000.0
# 1               NaN        2000.0
# 2               NaN        2000.0
# 3                PG        2000.0
# 4                 R        2000.0
# ...             ...           ...
# 78392           NaN        2022.0
# 78393           NaN        2022.0
# 78394           NaN           NaN
# 78395           NaN        2022.0
# 78396           NaN        2022.0
#
# [78397 rows x 27 columns]

# %%
import os
folder = 'Data/For Tableau/Raw/'
os.makedirs(folder, exist_ok=True)

# %%
fname = folder+'tmdb_api_results.csv'
tmdb.to_csv(fname,index=False)

# %%
ds.inspect.inspect_file(fname)
# Out:
# - Data/For Tableau/Raw/tmdb_api_results.csv is 64.717508 MB on disk.
# {'Filepath': 'Data/For Tableau/Raw/tmdb_api_results.csv',
#  'Name': 'tmdb_api_results.csv',
#  'Created': 'Tue Nov 22 17:18:22 2022',
#  'Modified': 'Tue Nov 22 17:18:22 2022',
#  'Size': '64.717508 mb',
#  'Folder': 'Data/For Tableau/Raw',
#  'Ext': '.csv',
#  'Size (bytes)': 64717508,
#  'Relative Path': 'Data/For Tableau/Raw/tmdb_api_results.csv',
#  'Absolute Path': '/Users/codingdojo/Documents/GitHub/_MY_PROJECTS/how-to-make-successful-movies/Data/For Tableau/Raw/tmdb_api_results.csv'}

# %%
fname = folder+"title-basics.csv"
basics.to_csv(fname,index=False)
ds.inspect.inspect_file(fname)
# Out:
# - Data/For Tableau/Raw/title-basics.csv is 9.51879 MB on disk.
# {'Filepath': 'Data/For Tableau/Raw/title-basics.csv',
#  'Name': 'title-basics.csv',
#  'Created': 'Tue Nov 22 17:18:22 2022',
#  'Modified': 'Tue Nov 22 17:18:22 2022',
#  'Size': '9.51879 mb',
#  'Folder': 'Data/For Tableau/Raw',
#  'Ext': '.csv',
#  'Size (bytes)': 9518790,
#  'Relative Path': 'Data/For Tableau/Raw/title-basics.csv',
#  'Absolute Path': '/Users/codingdojo/Documents/GitHub/_MY_PROJECTS/how-to-make-successful-movies/Data/For Tableau/Raw/title-basics.csv'}

# %%
ratings = pd.read_csv('Data/title_ratings_cleaned.csv.gz')
ratings
# Out:
#           tconst  averageRating  numVotes
# 0      tt0035423            6.4     85245
# 1      tt0062336            6.4       163
# 2      tt0067683            6.4        90
# 3      tt0069049            6.7      7435
# 4      tt0088751            5.2       327
# ...          ...            ...       ...
# 87812  tt9915436            7.4         5
# 87813  tt9915872            7.7         8
# 87814  tt9916170            7.0         7
# 87815  tt9916190            3.7       238
# 87816  tt9916362            6.4      4998
#
# [87817 rows x 3 columns]

# %%
fname = folder+"title-ratings.csv"
ratings.to_csv(fname,index=False)
ds.inspect.inspect_file(fname)
# Out:
# - Data/For Tableau/Raw/title-ratings.csv is 1.582021 MB on disk.
# {'Filepath': 'Data/For Tableau/Raw/title-ratings.csv',
#  'Name': 'title-ratings.csv',
#  'Created': 'Tue Nov 22 17:18:22 2022',
#  'Modified': 'Tue Nov 22 17:18:22 2022',
#  'Size': '1.582021 mb',
#  'Folder': 'Data/For Tableau/Raw',
#  'Ext': '.csv',
#  'Size (bytes)': 1582021,
#  'Relative Path': 'Data/For Tableau/Raw/title-ratings.csv',
#  'Absolute Path': '/Users/codingdojo/Documents/GitHub/_MY_PROJECTS/how-to-make-successful-movies/Data/For Tableau/Raw/title-ratings.csv'}

# %% [markdown]
# ## MySQL Version

# %%
import json
with open("/Users/codingdojo/.secret/mysql.json") as f:
	login = json.load(f)
	
login.keys()
# Out:
# dict_keys(['user', 'password'])

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (1.0.2)

# %%
import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

connection = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies-viz"
engine = create_engine(connection)


if database_exists(engine.url):
	print(f"{connection} exists.")
else:
	create_database(engine.url)
# Out:
# mysql+pymysql://root:l3gg0mysql!@localhost/movies-viz exists.

# %%
import pandas as pd

q  = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#        Tables_in_movies-viz
# 0                    genres
# 1      production_companies
# 2              title_basics
# 3              title_genres
# 4  title_production_company
# 5             title_ratings
# 6                      tmdb

# %%
tables = pd.read_sql(q, engine)
tables
# Out:
#        Tables_in_movies-viz
# 0                    genres
# 1      production_companies
# 2              title_basics
# 3              title_genres
# 4  title_production_company
# 5             title_ratings
# 6                      tmdb

# %%
folder = "Data/For Tableau/mysql/"
os.makedirs(folder, exist_ok=True)

# %%
DATA = {}
table_names = tables['Tables_in_movies-viz'].to_list()

new_files = []
for table in table_names:
    temp = pd.read_sql(f"SELECT * FROM {table}", engine )

    fname = folder+f"{table}_mysql.csv"
    temp.to_csv(fname,index=False)
    new_files.append(fname)
    DATA[table] = pd.read_csv(fname)

# %%
DATA.keys()
# Out:
# dict_keys(['genres', 'production_companies', 'title_basics', 'title_genres', 'title_production_company', 'title_ratings', 'tmdb'])

# %%
DATA['production_companies'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39872 entries, 0 to 39871
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_id    39872 non-null  int64
#  1   company_name  39872 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 623.1+ KB

# %%
DATA['title_production_company'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106553 entries, 0 to 106552
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   imdb_id     106553 non-null  object
#  1   company_id  106553 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ MB

# %%
# table_names = tables['Tables_in_movies-viz'].to_list()

# new_files = []
# for table in table_names:
# 	temp = pd.read_sql(f"SELECT * FROM {table}", engine )
	
# 	fname = folder+f"{table}_mysql.csv"
# 	temp.to_csv(fname,index=False)
# 	new_files.append(fname)

# %%
new_files
# Out:
# ['Data/For Tableau/mysql/genres_mysql.csv',
#  'Data/For Tableau/mysql/production_companies_mysql.csv',
#  'Data/For Tableau/mysql/title_basics_mysql.csv',
#  'Data/For Tableau/mysql/title_genres_mysql.csv',
#  'Data/For Tableau/mysql/title_production_company_mysql.csv',
#  'Data/For Tableau/mysql/title_ratings_mysql.csv',
#  'Data/For Tableau/mysql/tmdb_mysql.csv']

# %%
# title_genres = pd.read_csv("Data/For Tableau/title_genres_mysql.csv")
# title_genres.isna().sum() / len(title_genres)

# %%
for file in new_files:
    temp_df = pd.read_csv(file)
    print(file)
    display(temp_df.head(), temp_df.tail())
# Out:
# Data/For Tableau/mysql/genres_mysql.csv
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4
#    Genre_Name  Genre_ID
# 22      Sport        22
# 23  Talk-Show        23
# 24   Thriller        24
# 25        War        25
# 26    Western        26
# Data/For Tableau/mysql/production_companies_mysql.csv
#    company_id                   company_name
# 0           0  # Andrea Sperling Productions
# 1           1              #Beardforce Films
# 2           2                 #Sinning Works
# 3           3              #littlesecretfilm
# 4           4                        (주)라인필름
#        company_id company_name
# 39867       39867      타임스토리그룹
# 39868       39868        파파스필름
# 39869       39869       플랫폼픽쳐스
# 39870       39870         한맥문화
# 39871       39871    환타지엔터테인먼트
# Data/For Tableau/mysql/title_basics_mysql.csv
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0067683           Workers '71: Nothing About Us Without Us     2006.0
# 3  tt0069049                         The Other Side of the Wind     2018.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    runtimeMinutes
# 0           118.0
# 1            70.0
# 2            47.0
# 3           122.0
# 4           100.0
#            tconst          primaryTitle  startYear  runtimeMinutes
# 116399  tt9915436     Vida em Movimento     2019.0            70.0
# 116400  tt9915872  The Last White Witch     2019.0            97.0
# 116401  tt9916170         The Rehearsal     2019.0            51.0
# 116402  tt9916190             Safeguard     2020.0            95.0
# 116403  tt9916362                 Coven     2020.0            92.0
# Data/For Tableau/mysql/title_genres_mysql.csv
#       tconst  Genre_ID
# 0  tt0035423         5
# 1  tt0035423        10
# 2  tt0035423        19
# 3  tt0062336         8
# 4  tt0067683         7
#            tconst  Genre_ID
# 207418  tt9916190         0
# 207419  tt9916190         2
# 207420  tt9916190        24
# 207421  tt9916362         8
# 207422  tt9916362        12
# Data/For Tableau/mysql/title_production_company_mysql.csv
#      imdb_id  company_id
# 0  tt0204250     14402.0
# 1  tt0206634     36827.0
# 2  tt0206634     33356.0
# 3  tt0206634     16040.0
# 4  tt0244521     11845.0
#           imdb_id  company_id
# 106548  tt7098636      6068.0
# 106549  tt7098636     26073.0
# 106550  tt7098636      2167.0
# 106551  tt7637550       961.0
# 106552  tt9641790     20583.0
# Data/For Tableau/mysql/title_ratings_mysql.csv
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4   85245.0
# 1  tt0062336            6.4     163.0
# 2  tt0067683            6.4      90.0
# 3  tt0069049            6.7    7435.0
# 4  tt0088751            5.2     327.0
#           tconst  averageRating  numVotes
# 87812  tt9915436            7.4       5.0
# 87813  tt9915872            7.7       8.0
# 87814  tt9916170            7.0       7.0
# 87815  tt9916190            3.7     238.0
# 87816  tt9916362            6.4    4998.0
# Data/For Tableau/mysql/tmdb_mysql.csv
#      imdb_id      budget     revenue certification original_language
# 0  tt0035423  48000000.0  76019000.0         PG-13                en
# 1  tt0062336         0.0         0.0           NaN                es
# 2  tt0069049  12000000.0         0.0             R                en
# 3  tt0088751    350000.0         0.0           NaN                en
# 4  tt0093119   7500000.0         0.0           NaN                en
#          imdb_id  budget  revenue certification original_language
# 78392  tt9914644     0.0      0.0           NaN                en
# 78393  tt9914942     0.0      0.0           NaN                ca
# 78394  tt9915872     0.0      0.0           NaN                en
# 78395  tt9916190     0.0      0.0           NaN                en
# 78396  tt9916362     0.0      0.0            NR                eu

# %% [markdown]
# ## COPY TO TABLEAU REPO

# %%
new_files
# Out:
# ['Data/For Tableau/mysql/genres_mysql.csv',
#  'Data/For Tableau/mysql/production_companies_mysql.csv',
#  'Data/For Tableau/mysql/title_basics_mysql.csv',
#  'Data/For Tableau/mysql/title_genres_mysql.csv',
#  'Data/For Tableau/mysql/title_production_company_mysql.csv',
#  'Data/For Tableau/mysql/title_ratings_mysql.csv',
#  'Data/For Tableau/mysql/tmdb_mysql.csv']

# %%
import os,shutil
out_folder ="/Users/codingdojo/Documents/GitHub/_CURRICULUM/curriculum-tableau/Data/Movies/mysql/"
os.makedirs(out_folder,exist_ok=True)

# %%
for file in new_files:
    basename = os.path.basename(file)
    shutil.copy2(file,out_folder+basename)

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'LICENSE',
#  'project_functions.py',
#  'Images',
#  'Part 3 - ETL & MySQL - Revisited.ipynb',
#  'Part 5 - Model Insights - Regressions-WIP.ipynb',
#  'Part 2A - TMDB API Calls.ipynb',
#  'Part 2B - EDA Overview of TMDB Data.ipynb',
#  'Reference-Viz',
#  '__pycache__',
#  'Part 3 - ETL & MySQL.ipynb',
#  'README.md',
#  'Part 4 - Hypothesis Testing - WIP.ipynb',
#  '.gitignore',
#  'tmdb_api_errors.json',
#  '.gitattributes',
#  'Data-Previous',
#  'README construction.ipynb',
#  'Part 1 - Initial IMDB Data Processing.ipynb',
#  '.ipynb_checkpoints',
#  'Part 3B_Tableau Prep.ipynb',
#  '.git',
#  'Part 6 - Model Insights - Classification.ipynb',
#  'Data',
#  'SQL']
