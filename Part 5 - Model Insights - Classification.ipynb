# %% [markdown]
# # Part 5: Model Insights Using Classification Models

# %% [markdown]
# ## Custom Functions/Package

# %% [markdown]
# Previously used local modules, but changing to using dojo_ds versions as of 01/22/24 & dojo_ds v1.0

# %%
# Importing custom function for project
# %load_ext autoreload
# %autoreload 2
import project_functions as pf

# %%
# !pip install -U dojo_ds -q
import dojo_ds as ds
ds.__version__
# Out:
# '1.0.0'

# %% [markdown]
# ## Loading the Data

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector, ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
## fixing random for lesson generation
np.random.seed(321)

##import statsmodels correctly
import statsmodels.api as sm

# %%
from sklearn import set_config
set_config(transform_output='pandas')

# %%
# # plt.style.use('fivethirtyeight')

# import matplotlib.pyplot as plt

# fav_style = ('ggplot','fivethirtyeight')#,'tableau-colorblind10')
# fav_context  ={'context':'notebook', 'font_scale':1.1}
# plt.style.use(fav_style)
# sns.set_context(**fav_context)
# plt.rcParams['savefig.transparent'] = False
# plt.rcParams['savefig.bbox'] = 'tight'

# plt.plot([1,2,3],[2,5,6]);

# %%
pd.set_option('display.max_columns',100)

# %% [markdown]
# ### 📚 Finding & Loading Batches of Files with `glob`

# %%
## Checking what data we already in our Data folder using os.listdir
import os
FOLDER = 'Data/'
# file_list = sorted(os.listdir(FOLDER))
# file_list

# %%
df = pd.read_csv(FOLDER+'combined_tmdb_api_data.csv.gz',lineterminator='\n')
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1      False                               NaN                   NaN
# 2      False   /krEZg9tb6blhc7sV6Us2ZGQ0gA.jpg                   NaN
# 3      False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4      False  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
# ...      ...                               ...                   ...
# 93054  False  /dyQvD0BDlWk187fDBmJTU2uUVGH.jpg                   NaN
# 93055  False                               NaN                   NaN
# 93056  False                               NaN                   NaN
# 93057  False   /C28T7GAlCJQFWVDB4vUV8eZyf9.jpg                   NaN
# 93058  False  /klb3yODwKMRle19EcvdeSatEZL7.jpg                   NaN
#
#          budget                                             genres  \
# 0      10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1             0           [{'id': 878, 'name': 'Science Fiction'}]
# 2             0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3        150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4             0                      [{'id': 18, 'name': 'Drama'}]
# ...         ...                                                ...
# 93054         0  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 93055         0  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 93056         0                      [{'id': 18, 'name': 'Drama'}]
# 93057         0  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 93058  15000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage       id    imdb_id original_language  \
# 0                                 NaN    62127  tt0113026                en
# 1                                 NaN   110977  tt0113092                en
# 2                                 NaN   442869  tt0116391                hi
# 3                                 NaN      843  tt0118694                cn
# 4                                 NaN    49511  tt0118852                en
# ...                               ...      ...        ...               ...
# 93054  https://www.todiealonefilm.com  1167732  tt8736506                en
# 93055                             NaN   560016  tt9214772                en
# 93056                             NaN  1163894  tt9357860                en
# 93057                             NaN  1184693  tt9680562                mr
# 93058     https://www.nightswim.movie  1072342  tt9682428                en
#
#         original_title                                           overview  \
# 0      The Fantasticks  Two rural teens sing and dance their way throu...
# 1        For the Cause  Earth is in a state of constant war and two co...
# 2                 Gang  After falling prey to underworld, four friends...
# 3                 花樣年華  Two neighbors become intimate after discoverin...
# 4       Chinese Coffee  When Harry Levine, an aging, unsuccessful Gree...
# ...                ...                                                ...
# 93054     To Die Alone  After suffering a terrible injury while hiking...
# 93055       Monkey Man  An unlikely hero emerges from prison to take o...
# 93056      The Hopeful  Aboard a steamship sailing across the Atlantic...
# 93057         सत्यशोधक  The film follows the life of social reformer a...
# 93058       Night Swim  Forced into early retirement by a degenerative...
#
#        popularity                       poster_path  \
# 0           2.559  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1           3.393  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2           2.748  /dYcuiiBDpPUvCcPbiWdH4REjGn3.jpg
# 3          27.940  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4           5.495  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
# ...           ...                               ...
# 93054       5.474  /d7rHwkRlCHhVGBTQQkvGALeC5oz.jpg
# 93055       7.925                               NaN
# 93056       2.594  /9zRA1Vefx1gJdt6fKPDt4JJ6FGC.jpg
# 93057       4.889  /jzQPp0oSYPgu8crP3aq8EIjQ6Ti.jpg
# 93058     168.637  /gSkfBGdxdialBMM7P02V4hcI6Ij.jpg
#
#                                     production_companies  \
# 0      [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1      [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                     []
# 3      [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 4      [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...                                                  ...
# 93054  [{'id': 114245, 'logo_path': None, 'name': 'Gl...
# 93055  [{'id': 3528, 'logo_path': '/cCzCClIzIh81Fa79h...
# 93056  [{'id': 206035, 'logo_path': None, 'name': 'Ad...
# 93057  [{'id': 209731, 'logo_path': None, 'name': 'Sa...
# 93058  [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3      [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                  ...          ...
# 93054  [{'iso_3166_1': 'US', 'name': 'United States o...   2024-02-10
# 93055  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2024-01-22
# 93056           [{'iso_3166_1': 'CA', 'name': 'Canada'}]   2024-02-14
# 93057            [{'iso_3166_1': 'IN', 'name': 'India'}]   2024-01-05
# 93058  [{'iso_3166_1': 'US', 'name': 'United States o...   2024-01-03
#
#         revenue  runtime                                   spoken_languages  \
# 0             0       86  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0      100  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0      165  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3      14204632       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4             0       99  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...         ...      ...                                                ...
# 93054         0       84  [{'english_name': 'English', 'iso_639_1': 'en'...
# 93055         0        0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 93056         0       90  [{'english_name': 'English', 'iso_639_1': 'en'...
# 93057         0      145  [{'english_name': 'Marathi', 'iso_639_1': 'mr'...
# 93058  30600000       98  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                 status                                            tagline  \
# 0             Released      Try to remember the first time magic happened
# 1             Released       The ultimate showdown on a forbidden planet.
# 2             Released                                                NaN
# 3             Released  Feel the heat, keep the feeling burning, let t...
# 4             Released  There's a fine line between friendship and bet...
# ...                ...                                                ...
# 93054    In Production                                                NaN
# 93055  Post Production                                                NaN
# 93056  Post Production        The end of the world is just the beginning.
# 93057         Released  HE BRINGS THE TORCH OF REVOLUTION TO ENLIGHTEN...
# 93058         Released          Everything you fear is under the surface.
#
#                       title  video  vote_average  vote_count certification  \
# 0           The Fantasticks  False         5.500          22           NaN
# 1             For the Cause  False         4.958          12           NaN
# 2                      Gang  False         5.000           2           NaN
# 3      In the Mood for Love  False         8.109        2433            PG
# 4            Chinese Coffee  False         6.600          56             R
# ...                     ...    ...           ...         ...           ...
# 93054          To Die Alone  False         0.000           0            NR
# 93055            Monkey Man  False         0.000           0           NaN
# 93056           The Hopeful  False         0.000           0           NaN
# 93057          Satyashodhak  False         0.000           0           NaN
# 93058            Night Swim  False         5.095          41         PG-13
#
#        Release Year
# 0            2000.0
# 1            2000.0
# 2            2000.0
# 3            2000.0
# 4            2000.0
# ...             ...
# 93054        2024.0
# 93055        2024.0
# 93056        2024.0
# 93057        2024.0
# 93058        2024.0
#
# [93059 rows x 27 columns]

# %% [markdown]
# # Preprocessing

# %%
## Columns to exclude
drop_cols = ['backdrop_path','backdrop_path','original_title','overview',
                 'poster_path','tagline','id','homepage', 'status',
                 'production_countries','video','spoken_languages',
            'original_language']
df = df.drop(columns=drop_cols)
df
# Out:
#        adult belongs_to_collection    budget  \
# 0      False                   NaN  10000000
# 1      False                   NaN         0
# 2      False                   NaN         0
# 3      False                   NaN    150000
# 4      False                   NaN         0
# ...      ...                   ...       ...
# 93054  False                   NaN         0
# 93055  False                   NaN         0
# 93056  False                   NaN         0
# 93057  False                   NaN         0
# 93058  False                   NaN  15000000
#
#                                                   genres    imdb_id  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...  tt0113026
# 1               [{'id': 878, 'name': 'Science Fiction'}]  tt0113092
# 2      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...  tt0116391
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...  tt0118694
# 4                          [{'id': 18, 'name': 'Drama'}]  tt0118852
# ...                                                  ...        ...
# 93054  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt8736506
# 93055  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt9214772
# 93056                      [{'id': 18, 'name': 'Drama'}]  tt9357860
# 93057  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...  tt9680562
# 93058  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...  tt9682428
#
#        popularity                               production_companies  \
# 0           2.559  [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1           3.393  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2           2.748                                                 []
# 3          27.940  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 4           5.495  [{'id': 67930, 'logo_path': None, 'name': 'Cha...
# ...           ...                                                ...
# 93054       5.474  [{'id': 114245, 'logo_path': None, 'name': 'Gl...
# 93055       7.925  [{'id': 3528, 'logo_path': '/cCzCClIzIh81Fa79h...
# 93056       2.594  [{'id': 206035, 'logo_path': None, 'name': 'Ad...
# 93057       4.889  [{'id': 209731, 'logo_path': None, 'name': 'Sa...
# 93058     168.637  [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
#
#       release_date   revenue  runtime                 title  vote_average  \
# 0       2000-09-22         0       86       The Fantasticks         5.500
# 1       2000-11-15         0      100         For the Cause         4.958
# 2       2000-04-14         0      165                  Gang         5.000
# 3       2000-09-29  14204632       99  In the Mood for Love         8.109
# 4       2000-09-02         0       99        Chinese Coffee         6.600
# ...            ...       ...      ...                   ...           ...
# 93054   2024-02-10         0       84          To Die Alone         0.000
# 93055   2024-01-22         0        0            Monkey Man         0.000
# 93056   2024-02-14         0       90           The Hopeful         0.000
# 93057   2024-01-05         0      145          Satyashodhak         0.000
# 93058   2024-01-03  30600000       98            Night Swim         5.095
#
#        vote_count certification  Release Year
# 0              22           NaN        2000.0
# 1              12           NaN        2000.0
# 2               2           NaN        2000.0
# 3            2433            PG        2000.0
# 4              56             R        2000.0
# ...           ...           ...           ...
# 93054           0            NR        2024.0
# 93055           0           NaN        2024.0
# 93056           0           NaN        2024.0
# 93057           0           NaN        2024.0
# 93058          41         PG-13        2024.0
#
# [93059 rows x 15 columns]

# %% [markdown]
# ## Dropping Movies without Financial Data

# %%
filter_finances = (df['revenue']>0) & (df['budget']>0)
filter_finances.sum()
# Out:
# 6153

# %%
df = df[filter_finances]
df
# Out:
#        adult                              belongs_to_collection     budget  \
# 3      False                                                NaN     150000
# 12     False                                                NaN     120000
# 14     False  {'id': 718551, 'name': 'Chicken Run Collection...   45000000
# 17     False                                                NaN    8000000
# 18     False  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000
# ...      ...                                                ...        ...
# 92808  False                                                NaN   36000000
# 92833  False                                                NaN   24066000
# 92961  False                                                NaN       1000
# 93025  False                                                NaN          5
# 93058  False                                                NaN   15000000
#
#                                                   genres     imdb_id  \
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   tt0118694
# 12     [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...   tt0120467
# 14     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   tt0120630
# 17     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...   tt0120753
# 18     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...   tt0120755
# ...                                                  ...         ...
# 92808                     [{'id': 35, 'name': 'Comedy'}]  tt11762114
# 92833  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...  tt14564000
# 92961  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...  tt28630947
# 93025  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  tt30828956
# 93058  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...   tt9682428
#
#        popularity                               production_companies  \
# 3          27.940  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 12          7.887  [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 14         91.080  [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...
# 17         11.473  [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 18         43.305  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...           ...                                                ...
# 92808     276.559  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...
# 92833      40.886  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...
# 92961       1.004  [{'id': 209845, 'logo_path': None, 'name': 'Cr...
# 93025       2.127  [{'id': 157524, 'logo_path': None, 'name': 'Ma...
# 93058     168.637  [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
#
#       release_date    revenue  runtime                          title  \
# 3       2000-09-29   14204632       99           In the Mood for Love
# 12      2002-04-26      14904       87                         Vulgar
# 14      2000-06-23  224834564       84                    Chicken Run
# 17      2000-02-09     105983      122       The Million Dollar Hotel
# 18      2000-05-24  546400000      123         Mission: Impossible II
# ...            ...        ...      ...                            ...
# 92808   2024-01-10   33200000      113                     Mean Girls
# 92833   2024-01-11   15323439      159                  Guntur Kaaram
# 92961   2023-01-10        100       58  The haunting in rosemary lane
# 93025   2024-01-31          4      117           The bigfoot prophecy
# 93058   2024-01-03   30600000       98                     Night Swim
#
#        vote_average  vote_count certification  Release Year
# 3             8.109        2433            PG        2000.0
# 12            5.444          45             R        2002.0
# 14            6.800        4704             G        2000.0
# 17            5.893         303             R        2000.0
# 18            6.123        6299           NaN        2000.0
# ...             ...         ...           ...           ...
# 92808         6.800          53         PG-13        2024.0
# 92833         6.000           3           NaN        2024.0
# 92961         0.000           0           NaN        2023.0
# 93025         0.000           0            NR        2024.0
# 93058         5.095          41         PG-13        2024.0
#
# [6153 rows x 15 columns]

# %% [markdown]
# ### Check Duplicates

# %%
df.duplicated(subset=['imdb_id']).sum()
# Out:
# 0

# %% [markdown]
# ### Set Index - tmdb_id

# %%
df = df.set_index('imdb_id')
df
# Out:
#             adult                              belongs_to_collection  \
# imdb_id
# tt0118694   False                                                NaN
# tt0120467   False                                                NaN
# tt0120630   False  {'id': 718551, 'name': 'Chicken Run Collection...
# tt0120753   False                                                NaN
# tt0120755   False  {'id': 87359, 'name': 'Mission: Impossible Col...
# ...           ...                                                ...
# tt11762114  False                                                NaN
# tt14564000  False                                                NaN
# tt28630947  False                                                NaN
# tt30828956  False                                                NaN
# tt9682428   False                                                NaN
#
#                budget                                             genres  \
# imdb_id
# tt0118694      150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# tt0120467      120000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# tt0120630    45000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0120753     8000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# tt0120755   125000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...               ...                                                ...
# tt11762114   36000000                     [{'id': 35, 'name': 'Comedy'}]
# tt14564000   24066000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# tt28630947       1000  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...
# tt30828956          5  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt9682428    15000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#             popularity                               production_companies  \
# imdb_id
# tt0118694       27.940  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# tt0120467        7.887  [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# tt0120630       91.080  [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...
# tt0120753       11.473  [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# tt0120755       43.305  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# ...                ...                                                ...
# tt11762114     276.559  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...
# tt14564000      40.886  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...
# tt28630947       1.004  [{'id': 209845, 'logo_path': None, 'name': 'Cr...
# tt30828956       2.127  [{'id': 157524, 'logo_path': None, 'name': 'Ma...
# tt9682428      168.637  [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
#
#            release_date    revenue  runtime                          title  \
# imdb_id
# tt0118694    2000-09-29   14204632       99           In the Mood for Love
# tt0120467    2002-04-26      14904       87                         Vulgar
# tt0120630    2000-06-23  224834564       84                    Chicken Run
# tt0120753    2000-02-09     105983      122       The Million Dollar Hotel
# tt0120755    2000-05-24  546400000      123         Mission: Impossible II
# ...                 ...        ...      ...                            ...
# tt11762114   2024-01-10   33200000      113                     Mean Girls
# tt14564000   2024-01-11   15323439      159                  Guntur Kaaram
# tt28630947   2023-01-10        100       58  The haunting in rosemary lane
# tt30828956   2024-01-31          4      117           The bigfoot prophecy
# tt9682428    2024-01-03   30600000       98                     Night Swim
#
#             vote_average  vote_count certification  Release Year
# imdb_id
# tt0118694          8.109        2433            PG        2000.0
# tt0120467          5.444          45             R        2002.0
# tt0120630          6.800        4704             G        2000.0
# tt0120753          5.893         303             R        2000.0
# tt0120755          6.123        6299           NaN        2000.0
# ...                  ...         ...           ...           ...
# tt11762114         6.800          53         PG-13        2024.0
# tt14564000         6.000           3           NaN        2024.0
# tt28630947         0.000           0           NaN        2023.0
# tt30828956         0.000           0            NR        2024.0
# tt9682428          5.095          41         PG-13        2024.0
#
# [6153 rows x 14 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# - Collection: convert to boolean
# - Genres: get just name and OHE
# - Cleaning Certification
# - Converting release date to year, month, and day.

# %% [markdown]
# #### belongs to collection

# %%
# there are 3,700+ movies that belong to collections
df['belongs_to_collection'].notna().sum()
# Out:
# 1366

# %%
## Use .notna() to get True if it belongs to a collection
df['belongs_to_collection'] = df['belongs_to_collection'].notna()
df['belongs_to_collection'].value_counts()
# Out:
# False    4787
# True     1366
# Name: belongs_to_collection, dtype: int64

# %% [markdown]
# #### Converting year to sep features

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['DayofWeek'] = df['release_date'].dt.day_name()
df['MonthName'] = df['release_date'].dt.month_name()
df['Month'] = df['release_date'].dt.month

df['YearReleased'] = df['release_date'].dt.year

# %%
df
# Out:
#             adult  belongs_to_collection     budget  \
# imdb_id
# tt0118694   False                  False     150000
# tt0120467   False                  False     120000
# tt0120630   False                   True   45000000
# tt0120753   False                  False    8000000
# tt0120755   False                   True  125000000
# ...           ...                    ...        ...
# tt11762114  False                  False   36000000
# tt14564000  False                  False   24066000
# tt28630947  False                  False       1000
# tt30828956  False                  False          5
# tt9682428   False                  False   15000000
#
#                                                        genres  popularity  \
# imdb_id
# tt0118694   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      27.940
# tt0120467   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...       7.887
# tt0120630   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      91.080
# tt0120753   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      11.473
# tt0120755   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      43.305
# ...                                                       ...         ...
# tt11762114                     [{'id': 35, 'name': 'Comedy'}]     276.559
# tt14564000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      40.886
# tt28630947  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...       1.004
# tt30828956  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...       2.127
# tt9682428   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...     168.637
#
#                                          production_companies release_date  \
# imdb_id
# tt0118694   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...   2000-09-29
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...   2002-04-26
# tt0120630   [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...   2000-06-23
# tt0120753   [{'id': 1490, 'logo_path': None, 'name': 'Kint...   2000-02-09
# tt0120755   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...   2000-05-24
# ...                                                       ...          ...
# tt11762114  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...   2024-01-10
# tt14564000  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...   2024-01-11
# tt28630947  [{'id': 209845, 'logo_path': None, 'name': 'Cr...   2023-01-10
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...   2024-01-31
# tt9682428   [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...   2024-01-03
#
#               revenue  runtime                          title  vote_average  \
# imdb_id
# tt0118694    14204632       99           In the Mood for Love         8.109
# tt0120467       14904       87                         Vulgar         5.444
# tt0120630   224834564       84                    Chicken Run         6.800
# tt0120753      105983      122       The Million Dollar Hotel         5.893
# tt0120755   546400000      123         Mission: Impossible II         6.123
# ...               ...      ...                            ...           ...
# tt11762114   33200000      113                     Mean Girls         6.800
# tt14564000   15323439      159                  Guntur Kaaram         6.000
# tt28630947        100       58  The haunting in rosemary lane         0.000
# tt30828956          4      117           The bigfoot prophecy         0.000
# tt9682428    30600000       98                     Night Swim         5.095
#
#             vote_count certification  Release Year  DayofWeek  MonthName  \
# imdb_id
# tt0118694         2433            PG        2000.0     Friday  September
# tt0120467           45             R        2002.0     Friday      April
# tt0120630         4704             G        2000.0     Friday       June
# tt0120753          303             R        2000.0  Wednesday   February
# tt0120755         6299           NaN        2000.0  Wednesday        May
# ...                ...           ...           ...        ...        ...
# tt11762114          53         PG-13        2024.0  Wednesday    January
# tt14564000           3           NaN        2024.0   Thursday    January
# tt28630947           0           NaN        2023.0    Tuesday    January
# tt30828956           0            NR        2024.0  Wednesday    January
# tt9682428           41         PG-13        2024.0  Wednesday    January
#
#             Month  YearReleased
# imdb_id
# tt0118694     9.0        2000.0
# tt0120467     4.0        2002.0
# tt0120630     6.0        2000.0
# tt0120753     2.0        2000.0
# tt0120755     5.0        2000.0
# ...           ...           ...
# tt11762114    1.0        2024.0
# tt14564000    1.0        2024.0
# tt28630947    1.0        2023.0
# tt30828956    1.0        2024.0
# tt9682428     1.0        2024.0
#
# [6153 rows x 18 columns]

# %%
# ## split release date into 3 columns
# new_cols = ['year','month','day']
# df[new_cols] = df['release_date'].str.split('-',expand=True)
# df[new_cols] = df[new_cols].astype(float)
# ## drop original feature
df = df.drop(columns=['release_date'])
df
# Out:
#             adult  belongs_to_collection     budget  \
# imdb_id
# tt0118694   False                  False     150000
# tt0120467   False                  False     120000
# tt0120630   False                   True   45000000
# tt0120753   False                  False    8000000
# tt0120755   False                   True  125000000
# ...           ...                    ...        ...
# tt11762114  False                  False   36000000
# tt14564000  False                  False   24066000
# tt28630947  False                  False       1000
# tt30828956  False                  False          5
# tt9682428   False                  False   15000000
#
#                                                        genres  popularity  \
# imdb_id
# tt0118694   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      27.940
# tt0120467   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...       7.887
# tt0120630   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      91.080
# tt0120753   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      11.473
# tt0120755   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      43.305
# ...                                                       ...         ...
# tt11762114                     [{'id': 35, 'name': 'Comedy'}]     276.559
# tt14564000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      40.886
# tt28630947  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...       1.004
# tt30828956  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...       2.127
# tt9682428   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...     168.637
#
#                                          production_companies    revenue  \
# imdb_id
# tt0118694   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...   14204632
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...      14904
# tt0120630   [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...  224834564
# tt0120753   [{'id': 1490, 'logo_path': None, 'name': 'Kint...     105983
# tt0120755   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...  546400000
# ...                                                       ...        ...
# tt11762114  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...   33200000
# tt14564000  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...   15323439
# tt28630947  [{'id': 209845, 'logo_path': None, 'name': 'Cr...        100
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...          4
# tt9682428   [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...   30600000
#
#             runtime                          title  vote_average  vote_count  \
# imdb_id
# tt0118694        99           In the Mood for Love         8.109        2433
# tt0120467        87                         Vulgar         5.444          45
# tt0120630        84                    Chicken Run         6.800        4704
# tt0120753       122       The Million Dollar Hotel         5.893         303
# tt0120755       123         Mission: Impossible II         6.123        6299
# ...             ...                            ...           ...         ...
# tt11762114      113                     Mean Girls         6.800          53
# tt14564000      159                  Guntur Kaaram         6.000           3
# tt28630947       58  The haunting in rosemary lane         0.000           0
# tt30828956      117           The bigfoot prophecy         0.000           0
# tt9682428        98                     Night Swim         5.095          41
#
#            certification  Release Year  DayofWeek  MonthName  Month  \
# imdb_id
# tt0118694             PG        2000.0     Friday  September    9.0
# tt0120467              R        2002.0     Friday      April    4.0
# tt0120630              G        2000.0     Friday       June    6.0
# tt0120753              R        2000.0  Wednesday   February    2.0
# tt0120755            NaN        2000.0  Wednesday        May    5.0
# ...                  ...           ...        ...        ...    ...
# tt11762114         PG-13        2024.0  Wednesday    January    1.0
# tt14564000           NaN        2024.0   Thursday    January    1.0
# tt28630947           NaN        2023.0    Tuesday    January    1.0
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt9682428          PG-13        2024.0  Wednesday    January    1.0
#
#             YearReleased
# imdb_id
# tt0118694         2000.0
# tt0120467         2002.0
# tt0120630         2000.0
# tt0120753         2000.0
# tt0120755         2000.0
# ...                  ...
# tt11762114        2024.0
# tt14564000        2024.0
# tt28630947        2023.0
# tt30828956        2024.0
# tt9682428         2024.0
#
# [6153 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6153 entries, tt0118694 to tt9682428
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  6153 non-null   bool
#  1   belongs_to_collection  6153 non-null   bool
#  2   budget                 6153 non-null   int64
#  3   genres                 6153 non-null   object
#  4   popularity             6153 non-null   float64
#  5   production_companies   6153 non-null   object
#  6   revenue                6153 non-null   int64
#  7   runtime                6153 non-null   int64
#  8   title                  6153 non-null   object
#  9   vote_average           6153 non-null   float64
#  10  vote_count             6153 non-null   int64
#  11  certification          4142 non-null   object
#  12  Release Year           6138 non-null   float64
#  13  DayofWeek              6138 non-null   object
#  14  MonthName              6138 non-null   object
#  15  Month                  6138 non-null   float64
#  16  YearReleased           6138 non-null   float64
# dtypes: bool(2), float64(5), int64(4), object(6)
# memory usage: 781.1+ KB

# %% [markdown]
# #### genre

# %%
## Function to get just the genre names as a list 
import json
def get_genre_name(x):
    x = x.replace("'",'"')
    x = json.loads(x)
    
    genres = []
    for genre in x:
        genres.append(genre['name'])
    return genres

# %%
## Use ourn function and exploding the new column
df['genres_list'] = df['genres'].apply(get_genre_name)
df_explode = df.explode('genres_list')
df_explode
# Out:
#             adult  belongs_to_collection    budget  \
# imdb_id
# tt0118694   False                  False    150000
# tt0118694   False                  False    150000
# tt0120467   False                  False    120000
# tt0120467   False                  False    120000
# tt0120467   False                  False    120000
# ...           ...                    ...       ...
# tt30828956  False                  False         5
# tt30828956  False                  False         5
# tt30828956  False                  False         5
# tt9682428   False                  False  15000000
# tt9682428   False                  False  15000000
#
#                                                        genres  popularity  \
# imdb_id
# tt0118694   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      27.940
# tt0118694   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      27.940
# tt0120467   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...       7.887
# tt0120467   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...       7.887
# tt0120467   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...       7.887
# ...                                                       ...         ...
# tt30828956  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...       2.127
# tt30828956  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...       2.127
# tt30828956  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...       2.127
# tt9682428   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...     168.637
# tt9682428   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...     168.637
#
#                                          production_companies   revenue  \
# imdb_id
# tt0118694   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...  14204632
# tt0118694   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...  14204632
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...     14904
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...     14904
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...     14904
# ...                                                       ...       ...
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...         4
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...         4
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...         4
# tt9682428   [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...  30600000
# tt9682428   [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...  30600000
#
#             runtime                 title  vote_average  vote_count  \
# imdb_id
# tt0118694        99  In the Mood for Love         8.109        2433
# tt0118694        99  In the Mood for Love         8.109        2433
# tt0120467        87                Vulgar         5.444          45
# tt0120467        87                Vulgar         5.444          45
# tt0120467        87                Vulgar         5.444          45
# ...             ...                   ...           ...         ...
# tt30828956      117  The bigfoot prophecy         0.000           0
# tt30828956      117  The bigfoot prophecy         0.000           0
# tt30828956      117  The bigfoot prophecy         0.000           0
# tt9682428        98            Night Swim         5.095          41
# tt9682428        98            Night Swim         5.095          41
#
#            certification  Release Year  DayofWeek  MonthName  Month  \
# imdb_id
# tt0118694             PG        2000.0     Friday  September    9.0
# tt0118694             PG        2000.0     Friday  September    9.0
# tt0120467              R        2002.0     Friday      April    4.0
# tt0120467              R        2002.0     Friday      April    4.0
# tt0120467              R        2002.0     Friday      April    4.0
# ...                  ...           ...        ...        ...    ...
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt9682428          PG-13        2024.0  Wednesday    January    1.0
# tt9682428          PG-13        2024.0  Wednesday    January    1.0
#
#             YearReleased genres_list
# imdb_id
# tt0118694         2000.0       Drama
# tt0118694         2000.0     Romance
# tt0120467         2002.0       Drama
# tt0120467         2002.0      Horror
# tt0120467         2002.0    Thriller
# ...                  ...         ...
# tt30828956        2024.0   Adventure
# tt30828956        2024.0     Fantasy
# tt30828956        2024.0      Horror
# tt9682428         2024.0      Horror
# tt9682428         2024.0    Thriller
#
# [15808 rows x 18 columns]

# %%
## save unique genres
unique_genres = df_explode['genres_list'].dropna().unique()

## Manually One-Hot-Encode Genres
for genre in unique_genres:
    df[f"Genre_{genre}"] = df['genres'].str.contains(genre,regex=False)    

## Drop original genre cols
df = df.drop(columns=['genres','genres_list'])
df
# Out:
#             adult  belongs_to_collection     budget  popularity  \
# imdb_id
# tt0118694   False                  False     150000      27.940
# tt0120467   False                  False     120000       7.887
# tt0120630   False                   True   45000000      91.080
# tt0120753   False                  False    8000000      11.473
# tt0120755   False                   True  125000000      43.305
# ...           ...                    ...        ...         ...
# tt11762114  False                  False   36000000     276.559
# tt14564000  False                  False   24066000      40.886
# tt28630947  False                  False       1000       1.004
# tt30828956  False                  False          5       2.127
# tt9682428   False                  False   15000000     168.637
#
#                                          production_companies    revenue  \
# imdb_id
# tt0118694   [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...   14204632
# tt0120467   [{'id': 102045, 'logo_path': None, 'name': 'Ch...      14904
# tt0120630   [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...  224834564
# tt0120753   [{'id': 1490, 'logo_path': None, 'name': 'Kint...     105983
# tt0120755   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...  546400000
# ...                                                       ...        ...
# tt11762114  [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...   33200000
# tt14564000  [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...   15323439
# tt28630947  [{'id': 209845, 'logo_path': None, 'name': 'Cr...        100
# tt30828956  [{'id': 157524, 'logo_path': None, 'name': 'Ma...          4
# tt9682428   [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...   30600000
#
#             runtime                          title  vote_average  vote_count  \
# imdb_id
# tt0118694        99           In the Mood for Love         8.109        2433
# tt0120467        87                         Vulgar         5.444          45
# tt0120630        84                    Chicken Run         6.800        4704
# tt0120753       122       The Million Dollar Hotel         5.893         303
# tt0120755       123         Mission: Impossible II         6.123        6299
# ...             ...                            ...           ...         ...
# tt11762114      113                     Mean Girls         6.800          53
# tt14564000      159                  Guntur Kaaram         6.000           3
# tt28630947       58  The haunting in rosemary lane         0.000           0
# tt30828956      117           The bigfoot prophecy         0.000           0
# tt9682428        98                     Night Swim         5.095          41
#
#            certification  Release Year  DayofWeek  MonthName  Month  \
# imdb_id
# tt0118694             PG        2000.0     Friday  September    9.0
# tt0120467              R        2002.0     Friday      April    4.0
# tt0120630              G        2000.0     Friday       June    6.0
# tt0120753              R        2000.0  Wednesday   February    2.0
# tt0120755            NaN        2000.0  Wednesday        May    5.0
# ...                  ...           ...        ...        ...    ...
# tt11762114         PG-13        2024.0  Wednesday    January    1.0
# tt14564000           NaN        2024.0   Thursday    January    1.0
# tt28630947           NaN        2023.0    Tuesday    January    1.0
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt9682428          PG-13        2024.0  Wednesday    January    1.0
#
#             YearReleased  Genre_Drama  Genre_Romance  Genre_Horror  \
# imdb_id
# tt0118694         2000.0         True           True         False
# tt0120467         2002.0         True          False          True
# tt0120630         2000.0        False          False         False
# tt0120753         2000.0         True          False         False
# tt0120755         2000.0        False          False         False
# ...                  ...          ...            ...           ...
# tt11762114        2024.0        False          False         False
# tt14564000        2024.0         True          False         False
# tt28630947        2023.0        False          False          True
# tt30828956        2024.0        False          False          True
# tt9682428         2024.0        False          False          True
#
#             Genre_Thriller  Genre_Crime  Genre_Animation  Genre_Comedy  \
# imdb_id
# tt0118694            False        False            False         False
# tt0120467             True         True            False         False
# tt0120630            False        False             True          True
# tt0120753             True        False            False         False
# tt0120755             True        False            False         False
# ...                    ...          ...              ...           ...
# tt11762114           False        False            False          True
# tt14564000           False        False            False         False
# tt28630947           False        False            False         False
# tt30828956           False        False            False         False
# tt9682428             True        False            False         False
#
#             Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# tt0118694          False            False         False
# tt0120467          False            False         False
# tt0120630           True            False         False
# tt0120753          False            False         False
# tt0120755          False             True          True
# ...                  ...              ...           ...
# tt11762114         False            False         False
# tt14564000         False            False          True
# tt28630947         False            False         False
# tt30828956         False             True         False
# tt9682428          False            False         False
#
#             Genre_Science Fiction  Genre_Fantasy  Genre_Mystery  Genre_War  \
# imdb_id
# tt0118694                   False          False          False      False
# tt0120467                   False          False          False      False
# tt0120630                   False          False          False      False
# tt0120753                   False          False          False      False
# tt0120755                   False          False          False      False
# ...                           ...            ...            ...        ...
# tt11762114                  False          False          False      False
# tt14564000                  False          False          False      False
# tt28630947                  False          False          False      False
# tt30828956                  False           True          False      False
# tt9682428                   False          False          False      False
#
#             Genre_History  Genre_Music  Genre_Western  Genre_Documentary  \
# imdb_id
# tt0118694           False        False          False              False
# tt0120467           False        False          False              False
# tt0120630           False        False          False              False
# tt0120753           False        False          False              False
# tt0120755           False        False          False              False
# ...                   ...          ...            ...                ...
# tt11762114          False        False          False              False
# tt14564000          False        False          False              False
# tt28630947          False        False          False               True
# tt30828956          False        False          False              False
# tt9682428           False        False          False              False
#
#             Genre_TV Movie
# imdb_id
# tt0118694            False
# tt0120467            False
# tt0120630            False
# tt0120753            False
# tt0120755            False
# ...                    ...
# tt11762114           False
# tt14564000           False
# tt28630947           False
# tt30828956           False
# tt9682428            False
#
# [6153 rows x 35 columns]

# %% [markdown]
# #### certification

# %%
## Checking Certification values
# df['certification'].value_counts(dropna=False)

# fix extra space certs
df['certification'] = df['certification'].str.strip()

## fix certification col
repl_cert = {'UR':'NR',
             'Not Rated':'NR',
             'Unrated':'NR',
             '-':'NR',
             '10':np.nan,
             'ScreamFest Horror Film Festival':'NR'}
df['certification'] = df['certification'].replace(repl_cert)
df['certification'].value_counts(dropna=False)
# Out:
# NaN      2011
# R        1755
# PG-13    1475
# PG        597
# NR        203
# G          95
# NC-17      17
# Name: certification, dtype: int64

# %% [markdown]
# ### Production Company

# %%
df['production_companies']
# Out:
# imdb_id
# tt0118694     [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# tt0120467     [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# tt0120630     [{'id': 297, 'logo_path': '/58TnhYZqbMYgkHM6lg...
# tt0120753     [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# tt0120755     [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#                                     ...
# tt11762114    [{'id': 26402, 'logo_path': '/1BFbFgEhD1tJShFT...
# tt14564000    [{'id': 69898, 'logo_path': '/bvPo07eG1gz3r6OC...
# tt28630947    [{'id': 209845, 'logo_path': None, 'name': 'Cr...
# tt30828956    [{'id': 157524, 'logo_path': None, 'name': 'Ma...
# tt9682428     [{'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQh...
# Name: production_companies, Length: 6153, dtype: object

# %%
## getting longest string to check for multiple companies
idxmax = df['production_companies'].apply(len).idxmax()
idxmax
# Out:
# 'tt1816518'

# %%
test = df.loc[idxmax, 'production_companies']
test
# Out:
# '[{\'id\': 6973, \'logo_path\': None, \'name\': \'Les Armateurs\', \'origin_country\': \'FR\'}, {\'id\': 27350, \'logo_path\': None, \'name\': \'Maybe Movies\', \'origin_country\': \'FR\'}, {\'id\': 694, \'logo_path\': \'/5LEHONGkZBIoWvp1ygHOF8iyi1M.png\', \'name\': \'StudioCanal\', \'origin_country\': \'FR\'}, {\'id\': 591, \'logo_path\': \'/q5I5RDwMEiqoNmfaJgd2LraEOJY.png\', \'name\': \'France 3 Cinéma\', \'origin_country\': \'FR\'}, {\'id\': 2565, \'logo_path\': \'/i7ecMuPlAvNJjg9Rp26gJWzeEmu.png\', \'name\': \'La Parti Production\', \'origin_country\': \'BE\'}, {\'id\': 13351, \'logo_path\': \'/sj74baixfiB8uIdTJWzU26E25ef.png\', \'name\': \'Melusine Productions\', \'origin_country\': \'LU\'}, {\'id\': 792, \'logo_path\': \'/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png\', \'name\': \'RTBF\', \'origin_country\': \'BE\'}, {\'id\': 104, \'logo_path\': \'/9aotxauvc9685tq9pTcRJszuT06.png\', \'name\': \'Canal+\', \'origin_country\': \'FR\'}, {\'id\': 10611, \'logo_path\': \'/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png\', \'name\': \'Ciné+\', \'origin_country\': \'FR\'}, {\'id\': 7131, \'logo_path\': \'/eLvjHPYZ12GR58lrDgg6MXZp2a3.png\', \'name\': \'France Télévisions\', \'origin_country\': \'FR\'}, {\'id\': 850, \'logo_path\': \'/aF7qajGJGtMpdrtvssM9g90YanX.png\', \'name\': \'Eurimages\', \'origin_country\': \'FR\'}, {\'id\': 851, \'logo_path\': \'/kieSA3GFVysJcAUXNRer06u6e5x.png\', \'name\': \'MEDIA Programme of the European Union\', \'origin_country\': \'BE\'}, {\'id\': 310, \'logo_path\': \'/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png\', \'name\': \'CNC\', \'origin_country\': \'FR\'}, {\'id\': 191641, \'logo_path\': None, \'name\': "Centre National du Cinéma et de L\'image Animée", \'origin_country\': \'FR\'}, {\'id\': 11246, \'logo_path\': \'/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png\', \'name\': \'La Région Île-de-France\', \'origin_country\': \'FR\'}, {\'id\': 142985, \'logo_path\': \'/A7x8YrUJNm4S8btV1thTBvtOwvC.png\', \'name\': \'Pôle Image Magelis\', \'origin_country\': \'FR\'}, {\'id\': 76912, \'logo_path\': None, \'name\': \'Département de la Charente\', \'origin_country\': \'\'}, {\'id\': 76911, \'logo_path\': None, \'name\': \'Région Poitou-Charentes\', \'origin_country\': \'\'}, {\'id\': 311, \'logo_path\': \'/TNGvZ8zOklntjPP3EcsHtrR8Rc.png\', \'name\': \'PROCIREP\', \'origin_country\': \'FR\'}, {\'id\': 309, \'logo_path\': \'/eVdJe4ha50lW1Eop1tq93TMh1XW.png\', \'name\': \'Angoa-Agicoa\', \'origin_country\': \'FR\'}, {\'id\': 11796, \'logo_path\': \'/tx6LOQcTSqgW8ffKxovuJHjlYVw.png\', \'name\': "Centre du Cinéma et de l\'Audiovisuel de la FWB", \'origin_country\': \'BE\'}, {\'id\': 11797, \'logo_path\': \'/61JT9Ldht918n04Q73l2KhCjss.png\', \'name\': \'VOO\', \'origin_country\': \'BE\'}, {\'id\': 28507, \'logo_path\': None, \'name\': \'Région Wallonne\', \'origin_country\': \'\'}, {\'id\': 202363, \'logo_path\': None, \'name\': \'Tax Shelter du Gouvernement Fédéral Belge\', \'origin_country\': \'\'}, {\'id\': 11924, \'logo_path\': \'/3uGsFGMUjLw52rvEllvs2txnJmn.png\', \'name\': \'Casa Kafka Pictures\', \'origin_country\': \'BE\'}, {\'id\': 212368, \'logo_path\': None, \'name\': \'Dexia\', \'origin_country\': \'\'}, {\'id\': 11776, \'logo_path\': \'/33JMuTtwY5UhPwkmCEyH1YaCD23.png\', \'name\': \'Film Fund Luxembourg\', \'origin_country\': \'LU\'}]'

# %%
# using regular expressions to extrap just the name
import re
exp= r"\'name\'\:.?\'(\w*.*?)\'"
re.findall(exp, test)
# Out:
# ['Les Armateurs',
#  'Maybe Movies',
#  'StudioCanal',
#  'France 3 Cinéma',
#  'La Parti Production',
#  'Melusine Productions',
#  'RTBF',
#  'Canal+',
#  'Ciné+',
#  'France Télévisions',
#  'Eurimages',
#  'MEDIA Programme of the European Union',
#  'CNC',
#  'La Région Île-de-France',
#  'Pôle Image Magelis',
#  'Département de la Charente',
#  'Région Poitou-Charentes',
#  'PROCIREP',
#  'Angoa-Agicoa',
#  'VOO',
#  'Région Wallonne',
#  'Tax Shelter du Gouvernement Fédéral Belge',
#  'Casa Kafka Pictures',
#  'Dexia',
#  'Film Fund Luxembourg']

# %%
def get_prod_company_names(x):
    if x=='[]':
        return ["MISSING"]
    
    exp= r"\'name\'\:.?\'(\w*.*?)\'"
    companies = re.findall(exp, x)
    return companies

# %%
## test function
get_prod_company_names(test)
# Out:
# ['Les Armateurs',
#  'Maybe Movies',
#  'StudioCanal',
#  'France 3 Cinéma',
#  'La Parti Production',
#  'Melusine Productions',
#  'RTBF',
#  'Canal+',
#  'Ciné+',
#  'France Télévisions',
#  'Eurimages',
#  'MEDIA Programme of the European Union',
#  'CNC',
#  'La Région Île-de-France',
#  'Pôle Image Magelis',
#  'Département de la Charente',
#  'Région Poitou-Charentes',
#  'PROCIREP',
#  'Angoa-Agicoa',
#  'VOO',
#  'Région Wallonne',
#  'Tax Shelter du Gouvernement Fédéral Belge',
#  'Casa Kafka Pictures',
#  'Dexia',
#  'Film Fund Luxembourg']

# %%
## Save new clean prod_comapny col and explode
df['prod_company'] = df['production_companies'].apply(get_prod_company_names)
prod_companies = df['prod_company'].explode()
prod_companies.value_counts().head(49)
# Out:
# Universal Pictures           322
# Warner Bros. Pictures        295
# Columbia Pictures            265
# Paramount                    216
# 20th Century Fox             213
# MISSING                      190
# Canal+                       168
# Lionsgate                    157
# New Line Cinema              157
# Walt Disney Pictures         149
# Relativity Media             126
# StudioCanal                  119
# Summit Entertainment         110
# Metro-Goldwyn-Mayer          103
# DreamWorks Pictures          102
# Village Roadshow Pictures     93
# Focus Features                92
# Miramax                       88
# Screen Gems                   82
# Touchstone Pictures           72
# Fox Searchlight Pictures      70
# Film4 Productions             69
# Dune Entertainment            68
# Working Title Films           68
# Blumhouse Productions         67
# TSG Entertainment             67
# Regency Enterprises           65
# France 2 Cinéma               62
# Millennium Media              60
# Dimension Films               59
# Ingenious Media               59
# BBC Film                      58
# France 3 Cinéma               57
# Ciné+                         57
# TF1 Films Production          55
# Film i Väst                   52
# Legendary Pictures            52
# The Weinstein Company         51
# Mandate International         49
# Original Film                 49
# Fox 2000 Pictures             49
# Wild Bunch                    48
# FilmNation Entertainment      47
# CNC                           47
# New Regency Pictures          46
# Pathé                         45
# Scott Rudin Productions       45
# EuropaCorp                    45
# ARTE France Cinéma            45
# Name: prod_company, dtype: int64

# %%
prod_companies.nunique()
# Out:
# 7815

# %%
# df['prod_company'].nunique()

# %% [markdown]
# - Common Prod Company Encoding:
#     - Keep top 50 most common companies an one hot encode

# %%
## saving the 50 most common companies
common_companies = sorted(prod_companies.value_counts().head(50).index)
common_companies
# Out:
# ['20th Century Fox',
#  'ARTE France Cinéma',
#  'BBC Film',
#  'Blumhouse Productions',
#  'CNC',
#  'Canal+',
#  'Ciné+',
#  'Columbia Pictures',
#  'Dimension Films',
#  'DreamWorks Pictures',
#  'Dune Entertainment',
#  'EuropaCorp',
#  'Film i Väst',
#  'Film4 Productions',
#  'FilmNation Entertainment',
#  'Focus Features',
#  'Fox 2000 Pictures',
#  'Fox Searchlight Pictures',
#  'France 2 Cinéma',
#  'France 3 Cinéma',
#  'Ingenious Media',
#  'Legendary Pictures',
#  'Lionsgate',
#  'MISSING',
#  'Mandate International',
#  'Metro-Goldwyn-Mayer',
#  'Millennium Media',
#  'Miramax',
#  'New Line Cinema',
#  'New Regency Pictures',
#  'Original Film',
#  'Paramount',
#  'Pathé',
#  'Regency Enterprises',
#  'Relativity Media',
#  'Scott Free Productions',
#  'Scott Rudin Productions',
#  'Screen Gems',
#  'StudioCanal',
#  'Summit Entertainment',
#  'TF1 Films Production',
#  'TSG Entertainment',
#  'The Weinstein Company',
#  'Touchstone Pictures',
#  'Universal Pictures',
#  'Village Roadshow Pictures',
#  'Walt Disney Pictures',
#  'Warner Bros. Pictures',
#  'Wild Bunch',
#  'Working Title Films']

# %%
## manually ohe top 20 companies
for company in common_companies:
    df[f"ProdComp_{company}"] = df['production_companies'].str.contains(company, regex=False)

# %%
df = df.drop(columns=['production_companies','prod_company'])

# %% [markdown]
# ### Saving Lists of Engineering OHE Cols

# %%
## Saving list of one hot encoded feature to easily dorp

genre_cols = list(filter(lambda x: x.startswith('Genre'),df.columns))
prod_comp_cols = list(filter(lambda x: x.startswith('ProdC'),df.columns))

genre_cols,prod_comp_cols
# Out:
# (['Genre_Drama',
#   'Genre_Romance',
#   'Genre_Horror',
#   'Genre_Thriller',
#   'Genre_Crime',
#   'Genre_Animation',
#   'Genre_Comedy',
#   'Genre_Family',
#   'Genre_Adventure',
#   'Genre_Action',
#   'Genre_Science Fiction',
#   'Genre_Fantasy',
#   'Genre_Mystery',
#   'Genre_War',
#   'Genre_History',
#   'Genre_Music',
#   'Genre_Western',
#   'Genre_Documentary',
#   'Genre_TV Movie'],
#  ['ProdComp_20th Century Fox',
#   'ProdComp_ARTE France Cinéma',
#   'ProdComp_BBC Film',
#   'ProdComp_Blumhouse Productions',
#   'ProdComp_CNC',
#   'ProdComp_Canal+',
#   'ProdComp_Ciné+',
#   'ProdComp_Columbia Pictures',
#   'ProdComp_Dimension Films',
#   'ProdComp_DreamWorks Pictures',
#   'ProdComp_Dune Entertainment',
#   'ProdComp_EuropaCorp',
#   'ProdComp_Film i Väst',
#   'ProdComp_Film4 Productions',
#   'ProdComp_FilmNation Entertainment',
#   'ProdComp_Focus Features',
#   'ProdComp_Fox 2000 Pictures',
#   'ProdComp_Fox Searchlight Pictures',
#   'ProdComp_France 2 Cinéma',
#   'ProdComp_France 3 Cinéma',
#   'ProdComp_Ingenious Media',
#   'ProdComp_Legendary Pictures',
#   'ProdComp_Lionsgate',
#   'ProdComp_MISSING',
#   'ProdComp_Mandate International',
#   'ProdComp_Metro-Goldwyn-Mayer',
#   'ProdComp_Millennium Media',
#   'ProdComp_Miramax',
#   'ProdComp_New Line Cinema',
#   'ProdComp_New Regency Pictures',
#   'ProdComp_Original Film',
#   'ProdComp_Paramount',
#   'ProdComp_Pathé',
#   'ProdComp_Regency Enterprises',
#   'ProdComp_Relativity Media',
#   'ProdComp_Scott Free Productions',
#   'ProdComp_Scott Rudin Productions',
#   'ProdComp_Screen Gems',
#   'ProdComp_StudioCanal',
#   'ProdComp_Summit Entertainment',
#   'ProdComp_TF1 Films Production',
#   'ProdComp_TSG Entertainment',
#   'ProdComp_The Weinstein Company',
#   'ProdComp_Touchstone Pictures',
#   'ProdComp_Universal Pictures',
#   'ProdComp_Village Roadshow Pictures',
#   'ProdComp_Walt Disney Pictures',
#   'ProdComp_Warner Bros. Pictures',
#   'ProdComp_Wild Bunch',
#   'ProdComp_Working Title Films'])

# %% [markdown]
# ## Defining "Successful"

# %% [markdown]
# - Want to use ROI but need to be careful about movies with 0's for budget or revenue

# %%
# ## Dropping rows with 0's for budget and revenue
# df = df[~(df['revenue']==0) & ~(df['budget']==0)]
# df

# %%
fig,axes = plt.subplots(ncols=2, figsize=(10,5))
sns.histplot(data=df, x='revenue', ax=axes[0])
sns.histplot(data=df, x='budget', ax=axes[1])
# Out:
# <Axes: xlabel='budget', ylabel='Count'>

# %% [markdown]
# ### Calculating Target

# %%
# Calculating Financial Target
df['profit'] = df['revenue'] - df['budget']
df['ROI'] = df['profit']/ df['budget'] *100

# %%
df.describe()
# Out:
#              budget   popularity       revenue      runtime  vote_average  \
# count  6.153000e+03  6153.000000  6.153000e+03  6153.000000   6153.000000
# mean   3.105222e+07    27.603687  8.553828e+07   109.116529      6.294637
# std    4.454177e+07    53.681315  1.846379e+08    21.541736      1.198593
# min    1.000000e+00     0.000000  1.000000e+00     0.000000      0.000000
# 25%    4.500000e+06    10.337000  2.636637e+06    95.000000      5.845000
# 50%    1.500000e+07    17.710000  1.900000e+07   105.000000      6.413000
# 75%    3.700000e+07    29.970000  8.239114e+07   120.000000      6.995000
# max    4.600000e+08  2738.782000  2.923706e+09   310.000000     10.000000
#
#          vote_count  Release Year        Month  YearReleased        profit  \
# count   6153.000000   6138.000000  6138.000000   6138.000000  6.153000e+03
# mean    1970.464326   2011.366080     6.884816   2011.366080  5.448606e+07
# std     3404.284654      6.283722     3.418684      6.283722  1.537355e+08
# min        0.000000   2000.000000     1.000000   2000.000000 -1.995460e+08
# 25%      141.000000   2006.000000     4.000000   2006.000000 -2.847262e+06
# 50%      661.000000   2011.000000     7.000000   2011.000000  4.040871e+06
# 75%     2169.000000   2016.000000    10.000000   2016.000000  4.716216e+07
# max    35072.000000   2024.000000    12.000000   2024.000000  2.686706e+09
#
#                 ROI
# count  6.153000e+03
# mean   8.583700e+03
# std    3.466150e+05
# min   -9.999990e+01
# 25%   -4.701489e+01
# 50%    5.839125e+01
# 75%    2.496088e+02
# max    1.666657e+07

# %%
sns.boxplot(data=df, y='ROI')
# Out:
# <Axes: ylabel='ROI'>

# %%
# Viewing ROI outliers
df[stats.zscore(df['ROI']).abs()>3]
# Out:
#             adult  belongs_to_collection  budget  popularity   revenue  \
# imdb_id
# tt0404802   False                  False      90      12.084   1410778
# tt6416676   False                  False     528       1.957   7436000
# tt13925862  False                  False     128       1.467  17130489
# tt23845954  False                  False      30       0.600   5000000
# tt29425073  False                  False      30       0.600   5000000
#
#             runtime                      title  vote_average  vote_count  \
# imdb_id
# tt0404802        91  The Notorious Bettie Page         6.345         148
# tt6416676        96                   Jailbait         6.800           8
# tt13925862      128             Dad, I'm Sorry         7.300           6
# tt23845954      143             Nosce Te Ipsum         0.000           0
# tt29425073      143    Nosce Te Ipsum Part Two         0.000           0
#
#            certification  Release Year  DayofWeek  MonthName  Month  \
# imdb_id
# tt0404802              R        2005.0  Wednesday  September    9.0
# tt6416676            NaN        2017.0     Friday      April    4.0
# tt13925862            NR        2021.0     Friday      March    3.0
# tt23845954           NaN           NaN        NaN        NaN    NaN
# tt29425073           NaN           NaN        NaN        NaN    NaN
#
#             YearReleased  Genre_Drama  Genre_Romance  Genre_Horror  \
# imdb_id
# tt0404802         2005.0         True          False         False
# tt6416676         2017.0         True          False         False
# tt13925862        2021.0         True          False         False
# tt23845954           NaN        False          False         False
# tt29425073           NaN        False          False         False
#
#             Genre_Thriller  Genre_Crime  Genre_Animation  Genre_Comedy  \
# imdb_id
# tt0404802            False        False            False          True
# tt6416676            False        False            False          True
# tt13925862           False        False            False          True
# tt23845954           False        False            False         False
# tt29425073           False        False            False         False
#
#             Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# t
#
#             ProdComp_Screen Gems  ProdComp_StudioCanal  \
# imdb_id
# tt0404802                  False                 False
# tt6416676                  False                 False
# tt13925862                 False                 False
# tt23845954                 False                 False
# tt29425073                 False                 False
#
#             ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# imdb_id
# tt0404802                           False                          False
# tt6416676                           False                          False
# tt13925862                          False                          False
# tt23845954                          False                          False
# tt29425073                          False                          False
#
#             ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# imdb_id
# tt0404802                        False                           False
# tt6416676                        False                           False
# tt13925862                       False                           False
# tt23845954                       False                           False
# tt29425073                       False                           False
#
#             ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# imdb_id
# tt0404802                          False                        False
# tt6416676                          False                        False
# tt13925862                         False                        False
# tt23845954                         False                        False
# tt29425073                         False                        False
#
#             ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# imdb_id
# tt0404802                                False                          False
# tt6416676                                False                          False
# tt13925862                               False                          False
# tt23845954                               False                          False
# tt29425073                               False                          False
#
#             ProdComp_Warner Bros. Pictures  ProdComp_Wild Bunch  \
# imdb_id
# tt0404802                            False                False
# tt6416676                            False                False
# tt13925862                           False                False
# tt23845954                           False                False
# tt29425073                           False                False
#
#             ProdComp_Working Title Films    profit           ROI
# imdb_id
# tt0404802                          False   1410688  1.567431e+06
# tt6416676                          False   7435472  1.408233e+06
# tt13925862                         False  17130361  1.338309e+07
# tt23845954                         False   4999970  1.666657e+07
# tt29425073                         False   4999970  1.666657e+07

# %%
df = df[stats.zscore(df['ROI']).abs()<=3]
df
# Out:
#             adult  belongs_to_collection     budget  popularity    revenue  \
# imdb_id
# tt0118694   False                  False     150000      27.940   14204632
# tt0120467   False                  False     120000       7.887      14904
# tt0120630   False                   True   45000000      91.080  224834564
# tt0120753   False                  False    8000000      11.473     105983
# tt0120755   False                   True  125000000      43.305  546400000
# ...           ...                    ...        ...         ...        ...
# tt11762114  False                  False   36000000     276.559   33200000
# tt14564000  False                  False   24066000      40.886   15323439
# tt28630947  False                  False       1000       1.004        100
# tt30828956  False                  False          5       2.127          4
# tt9682428   False                  False   15000000     168.637   30600000
#
#             runtime                          title  vote_average  vote_count  \
# imdb_id
# tt0118694        99           In the Mood for Love         8.109        2433
# tt0120467        87                         Vulgar         5.444          45
# tt0120630        84                    Chicken Run         6.800        4704
# tt0120753       122       The Million Dollar Hotel         5.893         303
# tt0120755       123         Mission: Impossible II         6.123        6299
# ...             ...                            ...           ...         ...
# tt11762114      113                     Mean Girls         6.800          53
# tt14564000      159                  Guntur Kaaram         6.000           3
# tt28630947       58  The haunting in rosemary lane         0.000           0
# tt30828956      117           The bigfoot prophecy         0.000           0
# tt9682428        98                     Night Swim         5.095          41
#
#            certification  Release Year  DayofWeek  MonthName  Month  \
# imdb_id
# tt0118694             PG        2000.0     Friday  September    9.0
# tt0120467              R        2002.0     Friday      April    4.0
# tt0120630              G        2000.0     Friday       June    6.0
# tt0120753              R        2000.0  Wednesday   February    2.0
# tt0120755            NaN        2000.0  Wednesday        May    5.0
# ...                  ...           ...        ...        ...    ...
# tt11762114         PG-13        2024.0  Wednesday    January    1.0
# tt14564000           NaN        2024.0   Thursday    January    1.0
# tt28630947           NaN        2023.0    Tuesday    January    1.0
# tt30828956            NR        2024.0  Wednesday    January    1.0
# tt9682428          PG-13        2024.0  Wednesday    January    1.0
#
#             YearReleased  Genre_Drama  Genre_Romance  Genre_Horror  \
# imdb_id
# tt0118694         2000.0         True           True         False
# tt0120467         2002.0         True          False          True
# tt0120630         2000.0        False          False         False
# tt0120753         2000.0         True          False         False
# tt0120755         2000.0        False          False         False
# ...                  ...          ...            ...           ...
# tt11762114        2024.0        False          False         False
# tt14564000        2024.0         True          False         False
# tt28630947        2023.0        False          False          True
# tt30828956        2024.0        False          False          True
# tt9682428         2024.0        False          False          True
#
#             Genre_Thriller  Genre_Crime  Genre_Animation  Genre_Comedy  \
# imdb_id
# tt0118694            False        False            False         False
# tt0120467             True         True            False         False
# tt0120630            False        False             True          True
# tt0120753             True        False            False         False
# tt0120755             True        False            False         False
# ...                    ...          ...              ...           ...
# tt11762114           False        False            False          True
# tt14564000           False        False            False         False
# tt28630947           False        False            False         False
# tt30828956           False        False            False         False
# tt9682428             True        False            False         False
#
#             Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# tt0118694          False            False         False
# tt0120467          False            False         False
# tt0120630           True            False         False
# tt0120753          False            False         False
# tt0120755          False             True          True
# ...                  ...              ...           ...
# tt11762114         False            False         False
# tt14564000         False            False          True
# tt28630947         False            False         False
# tt30828956         False             True         False
# tt9682428          False            False         False
#
#             Genre_Science Fiction  Genre_Fantasy  Genre_Mystery  Genre_War  \
# imdb_id
# tt0118694                   False          False          False      False
# tt0120467                   False          False          False      False
# tt0120630                   False          False          False      False
# tt0120753                   False          False          False      False
# tt0120755                   False          False          False      False
# ...                           ...            ...            ...        ...
# tt11762114                  False          False          False      False
# tt14564000                  False          False          False      False
# tt28630947                  False          False          False      False
# tt30828956                  False           True          False      False
# tt9682428                   False          False          False      False
#
#             Genre_History  Genre_Music  Genre_Western  Genre_Documentary  \
# imdb_id
# tt0118694           False        False          False              False
# tt0120467           False        False          False              False
# tt0120630           False        False          False              False
# tt0120753           False        False          False              False
# tt0120755           False        False          False              False
# ...                   ...          ...            ...                ...
# tt11762114          False        False          False              False
# tt14564000          False        False          False              False
# tt28630947          False        False          False               True
# tt30828956          False        False          False              False
# tt9682428           False        False          False              False
#
#             Genre_TV Movie  ProdComp_20th Century Fox  \
# imdb_id
# tt0118694            False                      False
# tt0120467            False                      False
# tt0120630            False                      False
# tt0120753            False                      False
# tt0120755            False                      False
# ...                    ...                        ...
# tt11762114           False                      False
# tt14564000           False                      False
# tt28630947           False                      False
# tt30828956           False                      False
# tt9682428            False                      False
#
#             ProdComp_ARTE France Cinéma  ProdComp_BBC Film  \
# imdb_id
# tt0118694                         False              False
# tt0120467                         False              False
# tt0120630                         False              False
# tt0120753                         False              False
# tt0120755                         False              False
# ...                                 ...                ...
# tt11762114                        False              False
# tt14564000                        False              False
# tt28630947                        False              False
# tt30828956                        False              False
# tt9682428                         False              False
#
#             ProdComp_Blumhouse Productions  ProdComp_CNC  ProdComp_Canal+  \
# imdb_id
# tt0118694                            False         False            False
# tt0120467                            False         False            False
# tt0120630                            False         False            False
# tt0120753                            False         False            False
# tt0120755                            False         False            False
# ...                                    ...           ...              ...
# tt11762114                           False         False            False
# tt14564000                           False         False            False
# tt28630947                           False         False            False
# tt30828956                           False         False            False
# tt9682428                             True         False            False
#
#             ProdComp_Ciné+  ProdComp_Columbia Pictures  \
# imdb_id
# tt0118694            False                       False
# tt0120467            False                       False
# tt0120630            False                       False
# tt0120753            False                       False
# tt0120755            False                       False
# ...                    ...                         ...
# tt11762114           False                       False
# tt14564000           False                       False
# tt28630947           False                       False
# tt30828956           False                       False
# tt9682428            False                       False
#
#             ProdComp_Dimension Films  ProdComp_DreamWorks Pictures  \
# imdb_id
# t
# <Axes: ylabel='ROI'>

# %%
ax = sns.histplot(data=df, x='ROI', )
ax.set_xlim(right=100);

# %%
df['successful']  = df['revenue'] > df['budget']#df['ROI'] >0 
df['successful'].value_counts(1)
# Out:
# True     0.619714
# False    0.380286
# Name: successful, dtype: float64

# %%
sns.barplot(data=df,x='successful',y='revenue')
# Out:
# <Axes: xlabel='successful', ylabel='revenue'>

# %%
df[df['successful']==False]
# Out:
#             adult  belongs_to_collection    budget  popularity   revenue  \
# imdb_id
# tt0120467   False                  False    120000       7.887     14904
# tt0120753   False                  False   8000000      11.473    105983
# tt0120913   False                  False  75000000      18.657  36754634
# tt0127349   False                  False   8500000      10.865    327418
# tt0131704   False                  False  76000000      10.001  35100000
# ...           ...                    ...       ...         ...       ...
# tt9362492   False                  False   2000000       5.193    821731
# tt11762114  False                  False  36000000     276.559  33200000
# tt14564000  False                  False  24066000      40.886  15323439
# tt28630947  False                  False      1000       1.004       100
# tt30828956  False                  False         5       2.127         4
#
#             runtime                                 title  vote_average  \
# imdb_id
# tt0120467        87                                Vulgar         5.444
# tt0120753       122              The Million Dollar Hotel         5.893
# tt0120913        94                            Titan A.E.         6.556
# tt0127349       105                       Waking the Dead         6.099
# tt0131704        88  The Adventures of Rocky & Bullwinkle         4.082
# ...             ...                                   ...           ...
# tt9362492       111                         Restore Point         7.500
# tt11762114      113                            Mean Girls         6.800
# tt14564000      159                         Guntur Kaaram         6.000
# tt28630947       58         The haunting in rosemary lane         0.000
# tt30828956      117                  The bigfoot prophecy         0.000
#
#             vote_count certification  Release Year  DayofWeek  MonthName  \
# imdb_id
# tt0120467           45             R        2002.0     Friday      April
# tt0120753          303             R        2000.0  Wednesday   February
# tt0120913         1022            PG        2000.0     Friday       June
# tt0127349           81             R        2000.0     Friday      March
# tt0131704          340            PG        2000.0     Friday       June
# ...                ...           ...           ...        ...        ...
# tt9362492            6           NaN        2023.0   Thursday  September
# tt11762114          53         PG-13        2024.0  Wednesday    January
# tt14564000           3           NaN        2024.0   Thursday    January
# tt28630947           0           NaN        2023.0    Tuesday    January
# tt30828956           0            NR        2024.0  Wednesday    January
#
#             Month  YearReleased  Genre_Drama  Genre_Romance  Genre_Horror  \
# imdb_id
# tt0120467     4.0        2002.0         True          False          True
# tt0120753     2.0        2000.0         True          False         False
# tt0120913     6.0        2000.0        False          False         False
# tt0127349     3.0        2000.0         True           True         False
# tt0131704     6.0        2000.0        False          False         False
# ...           ...           ...          ...            ...           ...
# tt9362492     9.0        2023.0        False          False         False
# tt11762114    1.0        2024.0        False          False         False
# tt14564000    1.0        2024.0         True          False         False
# tt28630947    1.0        2023.0        False          False          True
# tt30828956    1.0        2024.0        False          False          True
#
#             Genre_Thriller  Genre_Crime  Genre_Animation  Genre_Comedy  \
# imdb_id
# tt0120467             True         True            False         False
# tt0120753             True        False            False         False
# tt0120913            False        False             True         False
# tt0127349            False        False            False         False
# tt0131704            False        False             True          True
# ...                    ...          ...              ...           ...
# tt9362492             True         True            False         False
# tt11762114           False        False            False          True
# tt14564000           False        False            False         False
# tt28630947           False        False            False         False
# tt30828956           False        False            False         False
#
#             Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# t
#
#             ProdComp_Screen Gems  ProdComp_StudioCanal  \
# imdb_id
# tt0120467                  False                 False
# tt0120753                  False                 False
# tt0120913                  False                 False
# tt0127349                  False                 False
# tt0131704                  False                 False
# ...                          ...                   ...
# tt9362492                  False                 False
# tt11762114                 False                 False
# tt14564000                 False                 False
# tt28630947                 False                 False
# tt30828956                 False                 False
#
#             ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# imdb_id
# tt0120467                           False                          False
# tt0120753                           False                          False
# tt0120913                           False                          False
# tt0127349                           False                          False
# tt0131704                           False                          False
# ...                                   ...                            ...
# tt9362492                           False                          False
# tt11762114                          False                          False
# tt14564000                          False                          False
# tt28630947                          False                          False
# tt30828956                          False                          False
#
#             ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# imdb_id
# tt0120467                        False                           False
# tt0120753                        False                           False
# tt0120913                        False                           False
# tt0127349                        False                           False
# tt0131704                        False                           False
# ...                                ...                             ...
# tt9362492                        False                           False
# tt11762114                       False                           False
# tt14564000                       False                           False
# tt28630947                       False                           False
# tt30828956                       False                           False
#
#             ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# imdb_id
# tt0120467                          False                        False
# tt0120753                          False                        False
# tt0120913                          False                        False
# tt0127349                          False                        False
# tt0131704                          False                         True
# ...                                  ...                          ...
# tt9362492                          False                        False
# tt11762114                         False                        False
# tt14564000                         False                        False
# tt28630947                         False                        False
# tt30828956                         False                        False
#
#             ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# imdb_id
# tt0120467                                False                          False
# tt0120753                                False                          False
# tt0120913                                False                          False
# tt0127349                                False                          False
# tt0131704                                False                          False
# ...                                        ...                            ...
# tt9362492                                False                          False
# tt11762114                               False                          False
# tt14564000                               False                          False
# tt28630947                               False                          False
# tt30828956                               False                          False
#
#             ProdComp_Warner Bros. Pictures  ProdComp_Wild Bunch  \
# imdb_id
# tt0120467                            False                False
# tt0120753                            False                False
# tt0120913                            False                False
# tt0127349                            False                False
# tt0131704                            False                False
# ...                                    ...                  ...
# tt9362492                            False                False
# tt11762114                           False                False
# tt14564000                           False                False
# tt28630947                           False                False
# tt30828956                           False                False
#
#             ProdComp_Working Title Films    profit        ROI  successful
# imdb_id
# tt0120467                          False   -105096 -87.580000       False
# tt0120753                          False  -7894017 -98.675213       False
# tt0120913                          False -38245366 -50.993821       False
# tt0127349                          False  -8172582 -96.148024       False
# tt0131704                          False -40900000 -53.815789       False
# ...                                  ...       ...        ...         ...
# tt9362492                          False  -1178269 -58.913450       False
# tt11762114                         False  -2800000  -7.777778       False
# tt14564000                         False  -8742561 -36.327437       False
# tt28630947                         False      -900 -90.000000       False
# tt30828956                         False        -1 -20.000000       False
#
# [2338 rows x 87 columns]

# %% [markdown]
# ## Train Test Split

# %%
drop_for_model = ['title','ROI','revenue','profit']
df_ml = df.drop(columns=drop_for_model)
df_ml
# Out:
#             adult  belongs_to_collection     budget  popularity  runtime  \
# imdb_id
# tt0118694   False                  False     150000      27.940       99
# tt0120467   False                  False     120000       7.887       87
# tt0120630   False                   True   45000000      91.080       84
# tt0120753   False                  False    8000000      11.473      122
# tt0120755   False                   True  125000000      43.305      123
# ...           ...                    ...        ...         ...      ...
# tt11762114  False                  False   36000000     276.559      113
# tt14564000  False                  False   24066000      40.886      159
# tt28630947  False                  False       1000       1.004       58
# tt30828956  False                  False          5       2.127      117
# tt9682428   False                  False   15000000     168.637       98
#
#             vote_average  vote_count certification  Release Year  DayofWeek  \
# imdb_id
# tt0118694          8.109        2433            PG        2000.0     Friday
# tt0120467          5.444          45             R        2002.0     Friday
# tt0120630          6.800        4704             G        2000.0     Friday
# tt0120753          5.893         303             R        2000.0  Wednesday
# tt0120755          6.123        6299           NaN        2000.0  Wednesday
# ...                  ...         ...           ...           ...        ...
# tt11762114         6.800          53         PG-13        2024.0  Wednesday
# tt14564000         6.000           3           NaN        2024.0   Thursday
# tt28630947         0.000           0           NaN        2023.0    Tuesday
# tt30828956         0.000           0            NR        2024.0  Wednesday
# tt9682428          5.095          41         PG-13        2024.0  Wednesday
#
#             MonthName  Month  YearReleased  Genre_Drama  Genre_Romance  \
# imdb_id
# tt0118694   September    9.0        2000.0         True           True
# tt0120467       April    4.0        2002.0         True          False
# tt0120630        June    6.0        2000.0        False          False
# tt0120753    February    2.0        2000.0         True          False
# tt0120755         May    5.0        2000.0        False          False
# ...               ...    ...           ...          ...            ...
# tt11762114    January    1.0        2024.0        False          False
# tt14564000    January    1.0        2024.0         True          False
# tt28630947    January    1.0        2023.0        False          False
# tt30828956    January    1.0        2024.0        False          False
# tt9682428     January    1.0        2024.0        False          False
#
#             Genre_Horror  Genre_Thriller  Genre_Crime  Genre_Animation  \
# imdb_id
# tt0118694          False           False        False            False
# tt0120467           True            True         True            False
# tt0120630          False           False        False             True
# tt0120753          False            True        False            False
# tt0120755          False            True        False            False
# ...                  ...             ...          ...              ...
# tt11762114         False           False        False            False
# tt14564000         False           False        False            False
# tt28630947          True           False        False            False
# tt30828956          True           False        False            False
# tt9682428           True            True        False            False
#
#             Genre_Comedy  Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# tt0118694          False         False            False         False
# tt0120467          False         False            False         False
# tt0120630           True          True            False         False
# tt0120753          False         False            False         False
# tt0120755          False         False             True          True
# ...                  ...           ...              ...           ...
# tt11762114          True         False            False         False
# tt14564000         False         False            False          True
# tt28630947         False         False            False         False
# tt30828956         False         False             True         False
# tt9682428          False         False            False         False
#
#             Genre_Science Fiction  Genre_Fantasy  Genre_Mystery  Genre_War  \
# imdb_id
# tt0118694                   False          False          False      False
# tt0120467                   False          False          False      False
# tt0120630                   False          False          False      False
# tt0120753                   False          False          False      False
# tt0120755                   False          False          False      False
# ...                           ...            ...            ...        ...
# tt11762114                  False          False          False      False
# tt14564000                  False          False          False      False
# tt28630947                  False          False          False      False
# tt30828956                  False           True          False      False
# tt9682428                   False          False          False      False
#
#             Genre_History  Genre_Music  Genre_Western  Genre_Documentary  \
# imdb_id
# tt0118694           False        False          False              False
# tt0120467           False        False          False              False
# tt0120630           False        False          False              False
# tt0120753           False        False          False              False
# tt0120755           False        False          False              False
# ...                   ...          ...            ...                ...
# tt11762114          False        False          False              False
# tt14564000          False        False          False              False
# tt28630947          False        False          False               True
# tt30828956          False        False          False              False
# tt9682428           False        False          False              False
#
#             Genre_TV Movie  ProdComp_20th Century Fox  \
# imdb_id
# tt0118694            False                      False
# tt0120467            False                      False
# tt0120630            False                      False
# tt0120753            False                      False
# tt0120755            False                      False
# ...                    ...                        ...
# tt11762114           False                      False
# tt14564000           False                      False
# tt28630947           False                      False
# tt30828956           False                      False
# tt9682428            False                      False
#
#             ProdComp_ARTE France Cinéma  ProdComp_BBC Film  \
# imdb_id
# tt0118694                         False              False
# tt0120467                         False              False
# tt0120630                         False              False
#
#             ProdComp_Warner Bros. Pictures  ProdComp_Wild Bunch  \
# imdb_id
# tt0118694                            False                False
# tt0120467                            False                False
# tt0120630                            False                False
# tt0120753                            False                False
# tt0120755                            False                False
# ...                                    ...                  ...
# tt11762114                           False                False
# tt14564000                           False                False
# tt28630947                           False                False
# tt30828956                           False                False
# tt9682428                            False                False
#
#             ProdComp_Working Title Films  successful
# imdb_id
# tt0118694                          False        True
# tt0120467                          False       False
# tt0120630                          False        True
# tt0120753                          False       False
# tt0120755                          False        True
# ...                                  ...         ...
# tt11762114                         False       False
# tt14564000                         False       False
# tt28630947                         False       False
# tt30828956                         False       False
# tt9682428                          False        True
#
# [6148 rows x 83 columns]

# %%
## Make x and y variables
y = df_ml['successful'].copy()
X = df_ml.drop(columns=['successful']).copy()

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=321)
X_train.head()
# Out:
#             adult  belongs_to_collection    budget  popularity  runtime  \
# imdb_id
# tt1013752   False                   True  85000000       7.908      107
# tt0854678   False                  False   1000000       5.388      106
# tt11138512  False                  False  80000000      66.951      137
# tt1442576   False                  False   9500000       6.111      130
# tt6439020   False                  False  15600000      17.578      119
#
#             vote_average  vote_count certification  Release Year DayofWeek  \
# imdb_id
# tt1013752          6.682        6852         PG-13        2009.0  Thursday
# tt0854678          6.963         200           NaN        2007.0    Monday
# tt11138512         7.084        3825             R        2022.0  Thursday
# tt1442576          5.580          75           NaN        2010.0    Friday
# tt6439020          6.455         432            PG        2019.0  Thursday
#
#            MonthName  Month  YearReleased  Genre_Drama  Genre_Romance  \
# imdb_id
# tt1013752      April    4.0        2009.0         True          False
# tt0854678      April    4.0        2007.0        False          False
# tt11138512     April    4.0        2022.0        False          False
# tt1442576    January    1.0        2010.0         True          False
# tt6439020   November   11.0        2019.0        False          False
#
#             Genre_Horror  Genre_Thriller  Genre_Crime  Genre_Animation  \
# imdb_id
# tt1013752          False            True         True            False
# tt0854678          False           False        False            False
# tt11138512         False           False        False            False
# tt1442576          False           False        False            False
# tt6439020          False           False        False            False
#
#             Genre_Comedy  Genre_Family  Genre_Adventure  Genre_Action  \
# imdb_id
# tt1013752          False         False            False          True
# tt0854678          False         False            False         False
# tt11138512         False         False             True          True
# tt1442576          False         False            False         False
# tt6439020           True         False            False         False
#
#             Genre_Science Fiction  Genre_Fantasy  Genre_Mystery  Genre_War  \
# imdb_id
# tt1013752                   False          False          False      False
# tt0854678                   False          False          False      False
# tt11138512                  False           True          False      False
# tt1442576                   False          False          False      False
# tt6439020                   False          False          False      False
#
#             Genre_History  Genre_Music  Genre_Western  Genre_Documentary  \
# imdb_id
# tt1013752           False        False          False              False
# tt0854678           False        False          False               True
# tt11138512          False        False          False              False
# tt1442576            True        False          False              False
# tt6439020           False        False          False              False
#
#             Genre_TV Movie  ProdComp_20th Century Fox  \
# imdb_id
# tt1013752            False                      False
# tt0854678            False                      False
# tt11138512           False                      False
# tt1442576            False                      False
# tt6439020            False                      False
#
#             ProdComp_ARTE France Cinéma  ProdComp_BBC Film  \
# imdb_id
# tt1013752                         False              False
# tt0854678                         False              False
# tt11138512                        False              False
# tt1442576                         False              False
# tt6439020                         False              False
#
#             ProdComp_Blumhouse Productions  ProdComp_CNC  ProdComp_Canal+  \
# imdb_id
# tt1013752                            False         False            False
# tt0854678                            False         False            False
# tt11138512                           False         False            False
# tt1442576                            False         False            False
# tt6439020                            False         False            False
#
#             ProdComp_Ciné+  ProdComp_Columbia Pictures  \
# imdb_id
# t
type: int64

# %%
## make cat selector and using it to save list of column names
cat_select = make_column_selector(dtype_include='object')
cat_cols = cat_select(X_train)
cat_cols
# Out:
# ['certification', 'DayofWeek', 'MonthName']

# %%
## make num selector and using it to save list of column names
num_select = make_column_selector(dtype_include='number')
num_cols = num_select(X_train)
num_cols
# Out:
# ['budget',
#  'popularity',
#  'runtime',
#  'vote_average',
#  'vote_count',
#  'Release Year',
#  'Month',
#  'YearReleased']

# %%
## select manually OHE cols for later
bool_select = make_column_selector(dtype_include='bool')
already_ohe_cols = bool_select(X_train)
already_ohe_cols[:10]
# Out:
# ['adult',
#  'belongs_to_collection',
#  'Genre_Drama',
#  'Genre_Romance',
#  'Genre_Horror',
#  'Genre_Thriller',
#  'Genre_Crime',
#  'Genre_Animation',
#  'Genre_Comedy',
#  'Genre_Family']

# %% [markdown]
# #### Adding Custom Transformer for Boolean Columns

# %%
# ## convert manual ohe to int
# X_train[already_ohe_cols] = X_train[already_ohe_cols].astype(int)
# X_test[already_ohe_cols] = X_test[already_ohe_cols].astype(int)
# X_train

# %%
from sklearn.preprocessing import FunctionTransformer
def transform_boolean(x):
    return x.astype(int)

boolean_transformer = FunctionTransformer(transform_boolean)
boolean_transformer
# Out:
# FunctionTransformer(func=<function transform_boolean at 0x29cea2cb0>)

# %%
## make pipelines
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse_output=False))
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),#StandardScaler()
                        )

preprocessor = ColumnTransformer(transformers=[('num',num_pipe, num_select),#num_cols),
                                             ('cat',cat_pipe,cat_select),#cat_cols)],
                                               ('bool',boolean_transformer, bool_select)
                                              ],
                                       verbose_feature_names_out=False, ## SIMPLIFIES NAMES
                                       remainder='passthrough')
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x29ced52d0>),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x29ced4c40>),
#                                 ('bool',
#                                  FunctionTransformer(func=<function transform_boolean at 0x29cea2cb0>),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x29ced5120>)],
#                   verbose_feature_names_out=False)

# %%
X_train_df = preprocessor.fit_transform(X_train)
X_test_df = preprocessor.transform(X_test)
X_train_df.head()
# Out:
#                 budget  popularity  runtime  vote_average  vote_count  \
# imdb_id
# tt1013752   85000000.0       7.908    107.0         6.682      6852.0
# tt0854678    1000000.0       5.388    106.0         6.963       200.0
# tt11138512  80000000.0      66.951    137.0         7.084      3825.0
# tt1442576    9500000.0       6.111    130.0         5.580        75.0
# tt6439020   15600000.0      17.578    119.0         6.455       432.0
#
#             Release Year  Month  YearReleased  certification_G  \
# imdb_id
# tt1013752         2009.0    4.0        2009.0              0.0
# tt0854678         2007.0    4.0        2007.0              0.0
# tt11138512        2022.0    4.0        2022.0              0.0
# tt1442576         2010.0    1.0        2010.0              0.0
# tt6439020         2019.0   11.0        2019.0              0.0
#
#             certification_MISSING  certification_NC-17  certification_NR  \
# imdb_id
# tt1013752                     0.0                  0.0               0.0
# tt0854678                     1.0                  0.0               0.0
# tt11138512                    0.0                  0.0               0.0
# tt1442576                     1.0                  0.0               0.0
# tt6439020                     0.0                  0.0               0.0
#
#             certification_PG  certification_PG-13  certification_R  \
# imdb_id
# tt1013752                0.0                  1.0              0.0
# tt0854678                0.0                  0.0              0.0
# tt11138512               0.0                  0.0              1.0
# tt1442576                0.0                  0.0              0.0
# tt6439020                1.0                  0.0              0.0
#
#             DayofWeek_Friday  DayofWeek_MISSING  DayofWeek_Monday  \
# imdb_id
# tt1013752                0.0                0.0               0.0
# tt0854678                0.0                0.0               1.0
# tt11138512               0.0                0.0               0.0
# tt1442576                1.0                0.0               0.0
# tt6439020                0.0                0.0               0.0
#
#             DayofWeek_Saturday  DayofWeek_Sunday  DayofWeek_Thursday  \
# imdb_id
# tt1013752                  0.0               0.0                 1.0
# tt0854678                  0.0               0.0                 0.0
# tt11138512                 0.0               0.0                 1.0
ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# imdb_id
# tt1013752                               0                              0
# tt0854678                               0                              0
# tt11138512                              0                              0
# tt1442576                               0                              0
# tt6439020                               0                              0
#
#             ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# imdb_id
# tt1013752                            0                               0
# tt0854678                            0                               0
# tt11138512                           0                               0
# tt1442576                            0                               0
# tt6439020                            0                               0
#
#             ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# imdb_id
# tt1013752                              0                            1
# tt0854678                              0                            0
# tt11138512                             0                            0
# tt1442576                              0                            0
# tt6439020                              0                            0
#
#             ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# imdb_id
# tt1013752                                    0                              0
# tt0854678                                    0                              0
# tt11138512                                   0                              0
# tt1442576                                    0                              0
# tt6439020                                    0                              0
#
#             ProdComp_Warner Bros. Pictures  ProdComp_Wild Bunch  \
# imdb_id
# tt1013752                                0                    0
# tt0854678                                0                    0
# tt11138512                               0                    0
# tt1442576                                0                    0
# tt6439020                                0                    0
#
#             ProdComp_Working Title Films
# imdb_id
# tt1013752                              0
# tt0854678                              0
# tt11138512                             0
# tt1442576                              0
# tt6439020                              0
#
# [5 rows x 107 columns]

# %% [markdown]
# # Classification Modeling

# %% [markdown]
# ## Model 1: DummyClassifier

# %%
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline

clf_pipe = Pipeline([('preprocessor',preprocessor),
                     ('clf',DummyClassifier(strategy='stratified'))])
clf_pipe.fit(X_train, y_train)

ds.evaluate.evaluate_classification(clf_pipe, X_train, y_train,X_test, y_test,)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.38      0.39      0.39      1744
#         True       0.63      0.62      0.62      2867
#
#     accuracy                           0.53      4611
#    macro avg       0.50      0.50      0.50      4611
# weighted avg       0.53      0.53      0.53      4611
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.39      0.38      0.39       594
#         True       0.62      0.63      0.62       943
#
#     accuracy                           0.53      1537
#    macro avg       0.50      0.50      0.50      1537
# weighted avg       0.53      0.53      0.53      1537

# %% [markdown]
# > We are definitely violating the assumptions of normal residuals and homoscedasticity.

# %% [markdown]
# ## Model# 2: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(class_weight='balanced')
rf_pipe = Pipeline([('preprocessor',preprocessor),
                     ('clf',rf_clf)])
rf_pipe.fit(X_train, y_train)

ds.evaluate.evaluate_classification(rf_pipe, X_train, y_train, X_test, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1744
#         True       1.00      1.00      1.00      2867
#
#     accuracy                           1.00      4611
#    macro avg       1.00      1.00      1.00      4611
# weighted avg       1.00      1.00      1.00      4611
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.69      0.64      0.66       594
#         True       0.78      0.82      0.80       943
#
#     accuracy                           0.75      1537
#    macro avg       0.74      0.73      0.73      1537
# weighted avg       0.75      0.75      0.75      1537

# %%
importances = ds.insights.get_importances(rf_pipe[-1])
importances.sort_values(ascending=False)
# Out:
# vote_count           0.162826
# popularity           0.100784
# vote_average         0.083585
# runtime              0.076598
# budget               0.070107
#                        ...
# DayofWeek_MISSING    0.000298
# MonthName_MISSING    0.000264
# adult                0.000003
# Genre_TV Movie       0.000000
# ProdComp_MISSING     0.000000
# Name: Feature Importance, Length: 107, dtype: float64

# %% [markdown]
# ## Model 3: LogisticRegression

# %%
# ## Use our function to make new x,y vars
# X_train_df, y_train, X_test_df, y_test = get_train_test_split(df,add_scaler=False)
# X_train_df

# %%
from sklearn.linear_model import LogisticRegressionCV

logreg_clf = LogisticRegressionCV(class_weight='balanced')
logreg_pipe = Pipeline([('preprocessor',preprocessor),
                     ('clf',logreg_clf)])
logreg_pipe.fit(X_train, y_train)

ds.evaluate.evaluate_classification(logreg_pipe,  X_train, y_train,X_test, y_test,)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.53      0.88      0.66      1744
#         True       0.88      0.53      0.66      2867
#
#     accuracy                           0.66      4611
#    macro avg       0.71      0.71      0.66      4611
# weighted avg       0.75      0.66      0.66      4611
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.55      0.89      0.68       594
#         True       0.88      0.54      0.67       943
#
#     accuracy                           0.67      1537
#    macro avg       0.71      0.71      0.67      1537
# weighted avg       0.75      0.67      0.67      1537

# %% [markdown]
# #### Adding Scaling [PAUSED]

# %%
# from sklearn import clone

# %%
# preprocessor_scaled = clone(preprocessor)
# preprocessor_scaled

# %%
# steps = preprocessor_scaled.transformers[0]
# type(steps)

# %%
# steps

# %%
# ## Use our function to make new x,y vars
# X_train_df, y_train, X_test_df, y_test = get_train_test_split(df,add_scaler=True)
# X_train_df

# %%
logreg_cv_clf = LogisticRegressionCV(max_iter=200, class_weight='balanced')
logreg_cv_pipe = Pipeline([('preprocessor',preprocessor),
                     ('clf',logreg_cv_clf)])
logreg_cv_pipe.fit(X_train, y_train)
ds.evaluate.evaluate_classification(logreg_cv_pipe,  X_train, y_train,X_test, y_test,)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.53      0.88      0.66      1744
#         True       0.88      0.53      0.66      2867
#
#     accuracy                           0.66      4611
#    macro avg       0.71      0.71      0.66      4611
# weighted avg       0.75      0.66      0.66      4611
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.55      0.89      0.68       594
#         True       0.88      0.54      0.67       943
#
#     accuracy                           0.67      1537
#    macro avg       0.71      0.71      0.67      1537
# weighted avg       0.75      0.67      0.67      1537

# %% [markdown]
# # APPENDIX: Updating Code Below

# %% [markdown]
# - Reference for manipulating pipelines post-creation: [Jessica Miles NLP Project](https://github.com/jess-miles/nlp-sentiment/blob/main/colab_gridsearch.ipynb)

# %% [markdown]
# # Model Insights

# %% [markdown]
# ### Built-In Importances

# %%
importances = ds.insights.get_importances(rf_pipe[-1])

with plt.style.context('fivethirtyeight'):
    ax = ds.insights.plot_importance(importances,top_n=25)
    ax.set_title('Random Forest Feature Importance')
    pf.savefig('Images/rf_clf_importance.png',ax=ax, facecolor='white')
# Out:
# - Figure saved as Images/rf_clf_importance.png

# %%
# importances = pd.Series(rf_clf.feature_importances_, index=X_train_df.columns)
# ax = importances.sort_values().tail(25).plot(kind='barh',figsize=(6,10))
# ax.set_title('Random Forest Feature Importance')
# pf.savefig('Images/rf_clf_importance.png',ax=ax, facecolor='white')

# %% [markdown]
# ### Permutation Importance

# %% [markdown]
# > Permutation Importances will iteratively shuffle the rows of a single feature at a time to asses the model's change in performance with that feature's relationship with the target disrupted.
# - https://scikit-learn.org/stable/modules/permutation_importance.html
#
# ```python
# from sklearn.inspection import permutation_importance
# r = permutation_importance(svc_linear, X_test_df, y_test, n_repeats=30)
# r.keys()
# ```
# - Interesting Observation:
#     - permutation_importance takes a `scoring` argument!
#
# > "**Warning Features that are deemed of low importance for a bad model (low cross-validation score) could be very important for a good model.** Therefore it is always important to evaluate the predictive power of a model using a held-out set (or better with cross-validation) prior to computing importances. Permutation importance does not reflect to the intrinsic predictive value of a feature by itself but how important this feature is for a particular model."

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# ### From Pipeline

# %%
## Permutation importance takes a fit mode and test data. 
r = permutation_importance(rf_pipe, X_test, y_test,
                           n_repeats=30)
r.keys()
# Out:
# dict_keys(['importances_mean', 'importances_std', 'importances'])

# %%
## can make the mean importances into a series
permutation_importances = pd.Series(r['importances_mean'],index=X_test.columns,
                           name = 'permutation importance')
permutation_importances
# Out:
# adult                                 0.000000
# belongs_to_collection                 0.022251
# budget                                0.018478
# popularity                            0.009824
# runtime                               0.014877
#                                         ...
# ProdComp_Village Roadshow Pictures   -0.000022
# ProdComp_Walt Disney Pictures        -0.000586
# ProdComp_Warner Bros. Pictures       -0.001518
# ProdComp_Wild Bunch                  -0.000108
# ProdComp_Working Title Films          0.000022
# Name: permutation importance, Length: 82, dtype: float64

# %%
len(X_train.columns)
# Out:
# 82

# %%
# ax = permutation_importances.sort_values().tail(25).plot(kind='barh',figsize=(6,10))
with plt.style.context('fivethirtyeight'):
    
    ax = ds.insights.plot_importance(permutation_importances,top_n=25)
    ax.set_title('Permutation Importance')
    pf.savefig('Images/clf_permutation_importance.png',ax=ax,facecolor='white')
# Out:
# - Figure saved as Images/clf_permutation_importance.png

# %% [markdown]
# ### From Transformed Features

# %%
X_train_df = preprocessor.fit_transform(X_train)
X_test_df = preprocessor.transform(X_test)
rf_clf = RandomForestClassifier(class_weight='balanced')
rf_clf.fit(X_train_df, y_train)
ds.evaluate.evaluate_classification(rf_clf, X_train_df, y_train, X_test_df, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1744
#         True       1.00      1.00      1.00      2867
#
#     accuracy                           1.00      4611
#    macro avg       1.00      1.00      1.00      4611
# weighted avg       1.00      1.00      1.00      4611
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        False       0.70      0.62      0.66       594
#         True       0.78      0.83      0.80       943
#
#     accuracy                           0.75      1537
#    macro avg       0.74      0.73      0.73      1537
# weighted avg       0.75      0.75      0.75      1537

# %%
## Permutation importance takes a fit mode and test data. 
r = permutation_importance(rf_clf,
                           X_test_df, y_test,
                           n_repeats=30)
r.keys()
# Out:
# dict_keys(['importances_mean', 'importances_std', 'importances'])

# %%
len(X_train_df.columns)
# Out:
# 107

# %%
## can make the mean importances into a series
permutation_importances = pd.Series(r['importances_mean'],index=X_test_df.columns,
                           name = 'permutation importance')
permutation_importances
# Out:
# budget                                0.020863
# popularity                            0.013771
# runtime                               0.025070
# vote_average                          0.027261
# vote_count                            0.062936
#                                         ...
# ProdComp_Village Roadshow Pictures    0.000108
# ProdComp_Walt Disney Pictures        -0.000260
# ProdComp_Warner Bros. Pictures       -0.001648
# ProdComp_Wild Bunch                   0.000022
# ProdComp_Working Title Films         -0.000043
# Name: permutation importance, Length: 107, dtype: float64

# %%
with plt.style.context('fivethirtyeight'):
    # ax = permutation_importances.sort_values().tail(25).plot(kind='barh',figsize=(6,10))
    ax = ds.insights.plot_importance(permutation_importances,top_n=25)
    ax.set_title('Permutation Importance')
    pf.savefig('Images/clf_permutation_importance.png',ax=ax,facecolor='white')
# Out:
# - Figure saved as Images/clf_permutation_importance.png

# %% [markdown]
# ## Using SHAP and Shapely Values for Model Interpretation

# %% [markdown]
# >- SHAP (SHapley Additive exPlanations))
#     - [Repository](https://github.com/slundberg/shap)
#     - [Documentation](https://shap.readthedocs.io/en/latest/?badge=latest)
#         - Install via pip or conda.
#
#
# - SHAP uses game theory to calcualte Shapely values for each feature in the dataset.
# - Shapely values are calculated by iteratively testing each feature's contribution to the model by comparing the model's  performance with vs. without the feature. (The "marginal contribution" of the feature to the model's performance).

# %% [markdown]
# #### Papers, Book Excerpts, and  Blogs
# - [White Paper on Shapely Values](https://arxiv.org/abs/1705.07874)
#
# - [Intepretable Machine Learning Book - Section on SHAP](https://christophm.github.io/interpretable-ml-book/shap.html)
#
# - Towards Data Science Blog Posts:
#     - [Explain Your Model with SHAP Values](https://towardsdatascience.com/explain-your-model-with-the-shap-values-bc36aac4de3d)
#
#     - [Explain Any Model with SHAP KernelExplaibner](https://towardsdatascience.com/explain-any-models-with-the-shap-values-use-the-kernelexplainer-79de9464897a)
#
#
#
#
#
# #### Videos/Talks:
# - Explaining Machine Learning Models (in general).
#     - ["Open the Black Box: an intro to Model Interpretability with LIME and SHAP](https://youtu.be/C80SQe16Rao)
# - Understanding Shapely/SHAP Values:
#     - [AI Simplified: SHAP Values in Machine Learning ](https://youtu.be/Tg8aPwPPJ9c)- (Intuitive Explanation)
#     - [Explainable AI explained! | #4 SHAP  ](https://youtu.be/9haIOplEIGM)- (Math Calculation Explanation)

# %% [markdown]
# ### How to Use Shap

# %% [markdown]
# - Uses game theory to explain feature importance and how a feature steered a model's prediction(s) by removing each feature and seeing the effect on the error.
#
# - SHAP has:
#     - `TreeExplainer`:
#         - compatible with sckit learn, xgboost, Catboost
#     - `KernelExplainer`:
#         - compatible with "any" model
#
#
#
# - See [this blog post](https://towardsdatascience.com/explain-your-model-with-the-shap-values-bc36aac4de3d) for intro to topic and how to use with trees
#
# - For non-tree/random forest models [see this follow up post]( https://towardsdatascience.com/explain-any-models-with-the-shap-values-use-the-kernelexplainer-79de9464897a)

# %% [markdown]
# ### Using Shap for Regression Models
# - https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html

# %%
import shap 
print(shap.__version__)
shap.initjs()
# Out:
# 0.41.0
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
## Initialize an explainer with the model
explainer = shap.TreeExplainer(rf_clf)

## Calculaate shap values for test data
shap_values = explainer.shap_values(X_test_df,y_test)
len(shap_values)
# Out:
# 2

# %% [markdown]
# **`shap.summary_plot`**
# > - Feature importance: Variables are ranked in descending order.
# - Impact: The horizontal location shows whether the effect of that value is associated with a higher or lower prediction.
# - Original value: Color shows whether that variable is high (in red) or low (in blue) for that observation.

# %%
shap.summary_plot(shap_values[1], X_test_df,plot_type='bar')

# %%
shap.summary_plot(shap_values[1], X_test_df,show=False)
fig = plt.gcf()
pf.savefig('Images/rf_shap_summary.png',fig=fig)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# - Figure saved as Images/rf_shap_summary.png

# %% [markdown]
# ### Shap Dependence Plot
#
# ```python
# ## To Auto-Select Feature Most correlated with a specific feature, just pass the desired feature's column name.
#
# shap.dependence_plot('super_dist', shap_values, X_train)
#
# ## There is a way to specifically call out multiple features but I wasn't able to summarize it quickly for this nb
# ```

# %%
# shap.dependence_plot('budget',shap_values[1],X_test_df)
