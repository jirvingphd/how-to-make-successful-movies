# %% [markdown]
# # Part 3 - ETL & MySQL Database (Revisited)

# %% [markdown]
# - 11/22/22
# - Revisiting to normalize more tables for Tableau viz.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Your stakeholder wants you to take the data you have been cleaning and collecting in Parts 1 &amp; 2 of the project, and wants you to create a MySQL database for them.
# <p>You should normalize the tables as best you can before adding them to your new database.</p>
# <ul>
# <li>Note: an important exception to their request is that they would like you to keep all of the data from the TMDB API in 1 table together (even though it will not be perfectly normalized).&nbsp;&nbsp;</li><li>You only need to keep the imdb_id, revenue, budget, and certification columns</li>
# </ul>
# </li>
# </ul>
# <h4>Required Transformation steps:</h4>
# <ul>
# <li>
# <p><strong>Normalize Genre:</strong></p>
# <ul>
# <li>Convert the single string of genres from title basics into 2 new tables.
# <ol>
# <li>
# <p><code>title_genres</code>:  with the columns:</p>
# <ul>
# <li>tconst</li>
# <li>genre_id</li>
# </ul>
# </li>
# <li>
# <p><code>genres</code>:</p>
# <ul>
# <li>genre_id</li>
# <li>genre_name</li>
# </ul>
# </li>
# </ol>
# </li>
# </ul>
# </li>
# <li>
# <p><strong>Discard unnecessary information:</strong></p>
# <ul>
# <li>For the <code>title basics</code> table, drop the following columns:
# <ul>
# <li>"original_title" (we will use the primary title column instead)</li>
# <li>"isAdult" ("Adult" will show up in the genres so this is redundant information).</li>
# <li>"titleType" (every row will be a movie).</li>
# <li>"genres" and other variants of genre (genre is now represented in the 2 new tables described above.</li>
# </ul>
# </li>
# <li>Do not include the <code>title_akas</code> table in your SQL database.
# <ul>
# <li>You have already filtered out the desired movies using this table and the remaining data is mostly nulls and not of-interest to the stakeholder.</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# <h4>MySQL Database Requirements</h4>
# <ul>
# <li>
# <p>Use sqlalchemy with pandas to execute your SQL queries inside your notebook.</p>
# </li>
# <li>
# <p>Create a new database on your MySQL server and  call it "movies".</p>
# </li>
# <li>
# <p>Make sure to have the following tables in your "movies" database:</p>
# <ul>
# <li><code>title_basics</code></li>
# <li><code>title_ratings</code></li>
# <li><code>title_genres</code></li>
# <li><code>genres</code></li>
# <li><code>tmdb_data</code></li>
# </ul>
# </li>
# <li>
# <p>Make sure to set a Primary Key for each table.</p>
# </li>
# <li>
# <p>After creating each table, show the first 5 rows of that table using a SQL query.</p>
# </li>
# <li>
# <p>Make sure to run the "SHOW TABLES" SQL query at the end of your notebook to show that all required tables have been created.</p></li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json
import missingno as ms

plt.rcParams['figure.facecolor'] = 'white'

pd.set_option('display.max_columns',100)

# %%
## Folder to save IMDB files
FOLDER = "Data/"
# os.makedirs(FOLDER,exist_ok=True)
sorted(os.listdir(FOLDER))
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'For Tableau',
#  'combined_tmdb_api_data.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'final_tmdb_data_2022.csv.gz',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json']

# %% [markdown]
# ## Extract: Loading Previous Data

# %% [markdown]
# ### Title Basics

# %%
## title basics
basics = pd.read_csv(f'{FOLDER}title_basics_cleaned.csv.gz',low_memory=False)
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116404 entries, 0 to 116403
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          116404 non-null  object
#  1   titleType       116404 non-null  object
#  2   primaryTitle    116404 non-null  object
#  3   originalTitle   116404 non-null  object
#  4   isAdult         116404 non-null  int64
#  5   startYear       116404 non-null  float64
#  6   runtimeMinutes  116404 non-null  int64
#  7   genres          116404 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0067683     movie           Workers '71: Nothing About Us Without Us
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0     2001.0
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2         Robotnicy 1971 - Nic o nas bez nas        0     2006.0
# 3                 The Other Side of the Wind        0     2018.0
# 4                          The Naked Monster        0     2005.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              47             Documentary
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %% [markdown]
# ### Title Ratings

# %%
## title ratings
ratings = pd.read_csv(f"{FOLDER}/title_ratings_cleaned.csv.gz",low_memory=False)
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87817 entries, 0 to 87816
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         87817 non-null  object
#  1   averageRating  87817 non-null  float64
#  2   numVotes       87817 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ MB
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     85245
# 1  tt0062336            6.4       163
# 2  tt0067683            6.4        90
# 3  tt0069049            6.7      7435
# 4  tt0088751            5.2       327

# %% [markdown]
# ### TMDB API Results

# %% [markdown]
# - Students should have combined the years 2000 and 2001 as part of Part 2. I forgot to do so so I am doing here

# %%
## INSTRUCTOR CODE (not taught to students)
import glob
q = f"{FOLDER}final*.csv.gz"
files = glob.glob(q)
files
# Out:
# ['Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2018.csv.gz',
#  'Data/final_tmdb_data_2014.csv.gz',
#  'Data/final_tmdb_data_2022.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2016.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2020.csv.gz',
#  'Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2012.csv.gz',
#  'Data/final_tmdb_data_2010.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2019.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2015.csv.gz',
#  'Data/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2017.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2013.csv.gz',
#  'Data/final_tmdb_data_2011.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz']

# %%
## INSTRUCTOR CODE (not taught to students)
df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in files])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78397 entries, 0 to 1516
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  78397 non-null  bool
#  1   backdrop_path          43654 non-null  object
#  2   belongs_to_collection  3943 non-null   object
#  3   budget                 78397 non-null  int64
#  4   genres                 78397 non-null  object
#  5   homepage               21370 non-null  object
#  6   id                     78397 non-null  int64
#  7   imdb_id                78397 non-null  object
#  8   original_language      78397 non-null  object
#  9   original_title         78397 non-null  object
#  10  overview               76518 non-null  object
#  11  popularity             78397 non-null  float64
#  12  poster_path            68663 non-null  object
#  13  production_companies   78397 non-null  object
#  14  production_countries   78397 non-null  object
#  15  release_date           76442 non-null  object
#  16  revenue                78397 non-null  int64
#  17  runtime                76952 non-null  float64
#  18  spoken_languages       78397 non-null  object
#  19  status                 78397 non-null  object
#  20  tagline                26818 non-null  object
#  21  title                  78397 non-null  object
#  22  video                  78397 non-null  bool
#  23  vote_average           78397 non-null  float64
#  24  vote_count             78397 non-null  int64
#  25  certification          16961 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(17)
# memory usage: 15.1+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False                               NaN                   NaN    100000
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
#
#                                               genres  \
# 0                                                 []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                                                NaN   30356  tt0144280
# 1                                                NaN   58520  tt0197633
# 2                                                NaN  459563  tt0204250
# 3  http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                NaN    9925  tt0244521
#
#   original_language                 original_title  \
# 0                en  Whispers from a Shallow Grave
# 1                en         Live Freaky Die Freaky
# 2                en          Death of a Saleswoman
# 3                en                Children of Men
# 4                en                    Funny Money
#
#                                             overview  popularity  \
# 0  When a beautiful photo model disappears, polic...       0.714
# 1  It is the year 3069 and the Earth has been rob...       1.957
# 2  Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3  In 2027, in a chaotic world in which humans ca...      18.314
# 4  Henry Perkins, a mild-mannered accountant, acc...       4.218
#
#                         poster_path  \
# 0  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                 production_companies  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FW...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31         0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18         0
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22  70595464
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01         0
#
#    runtime                                   spoken_languages    status  \
# 0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  6 housewives. 1 dead body. A trunk full of pla...
# 3                  The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases w...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R

# %%
## Dropping Placeholder rows with id=0
df = df.loc[ df['imdb_id']!='0']
df
# Out:
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False                               NaN                   NaN    100000
# 1     False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2     False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3     False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4     False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
# ...     ...                               ...                   ...       ...
# 1512  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN         0
# 1513  False                               NaN                   NaN         0
# 1514  False                               NaN                   NaN         0
# 1515  False                               NaN                   NaN         0
# 1516  False                               NaN                   NaN       400
#
#                                                  genres  \
# 0                                                    []
# 1     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                 ...
# 1512                [{'id': 99, 'name': 'Documentary'}]
# 1513  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1514                [{'id': 99, 'name': 'Documentary'}]
# 1515                [{'id': 99, 'name': 'Documentary'}]
# 1516  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage      id    imdb_id  \
# 0                                                   NaN   30356  tt0144280
# 1                                                   NaN   58520  tt0197633
# 2                                                   NaN  459563  tt0204250
# 3     http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                   NaN    9925  tt0244521
# ...                                                 ...     ...        ...
# 1512                      http://icarusfilms.com/if-cli  387250  tt7098636
# 1513                                                NaN  640680  tt7246872
# 1514  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 1515                                                NaN  713681  tt9414698
# 1516                                                NaN  253999  tt9641790
#
#      original_language                 original_title  \
# 0                   en  Whispers from a Shallow Grave
# 1                   en         Live Freaky Die Freaky
# 2                   en          Death of a Saleswoman
# 3                   en                Children of Men
# 4                   en                    Funny Money
# ...                ...                            ...
# 1512                fr   Le Clitoris, ce cher inconnu
# 1513                en         Tokyo Bedoone Tavaghof
# 1514                en             Zimbabwe Countdown
# 1515                en                   The Hot Shoe
# 1516                en                     Clearwater
#
#                                                overview  popularity  \
# 0     When a beautiful photo model disappears, polic...       0.714
# 1     It is the year 3069 and the Earth has been rob...       1.957
# 2     Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3     In 2027, in a chaotic world in which humans ca...      18.314
# 4     Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                 ...         ...
# 1512  Topics about female sexuality are growing in p...       1.400
# 1513                                                NaN       0.600
# 1514  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 1515  A Documentary Movie About Card Counting In The...       0.600
# 1516  A woman has been abducted by the Clearwater ki...       2.744
#
#                            poster_path  \
# 0     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1     /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4     /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                ...
# 1512  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 1513  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 1514  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 1515                               NaN
# 1516  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                    production_companies  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4     [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                 ...
# 1512  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 1513                                                 []
# 1514  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 1515                                                 []
# 1516  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                 ...          ...
# 1512           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 1513             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 1514  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 1515                                                 []   2003-01-01
# 1516                                                 []   2003-06-10
#
#        revenue  runtime                                   spoken_languages  \
# 0            0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3     70595464    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...        ...      ...                                                ...
# 1512         0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1513         0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 1514         0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1515         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1516         0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 0     Released                                                NaN
# 1     Released                                                NaN
# 2     Released  6 housewives. 1 dead body. A trunk full of pla...
# 3     Released                  The future's a thing of the past.
# 4     Released  Henry Perkins accidentally trades briefcases w...
# ...        ...                                                ...
# 1512  Released                                                NaN
# 1513  Released                                                NaN
# 1514  Released                                                NaN
# 1515  Released                                                NaN
# 1516  Released                                                NaN
#
#                                  title  video  vote_average  vote_count  \
# 0        Whispers from a Shallow Grave  False           2.0           2
# 1               Live Freaky Die Freaky  False           3.8           8
# 2                Death of a Saleswoman  False           3.0           1
# 3                      Children of Men  False           7.6        5794
# 4                          Funny Money  False           5.4          39
# ...                                ...    ...           ...         ...
# 1512  The Clitoris: Forbidden Pleasure  False           8.0           2
# 1513                   Tokyo, Non-Stop  False           0.0           0
# 1514                Zimbabwe Countdown  False           5.0           4
# 1515                      The Hot Shoe  False           0.0           0
# 1516                        Clearwater  False           0.0           0
#
#      certification
# 0              NaN
# 1               NR
# 2              NaN
# 3                R
# 4                R
# ...            ...
# 1512           NaN
# 1513           NaN
# 1514           NaN
# 1515           NaN
# 1516           NaN
#
# [78397 rows x 26 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#          budget                                             genres  \
# 0        100000                                                 []
# 1             0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2             0  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3      76000000  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4             0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...         ...                                                ...
# 78392         0                [{'id': 99, 'name': 'Documentary'}]
# 78393         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 78394         0                [{'id': 99, 'name': 'Documentary'}]
# 78395         0                [{'id': 99, 'name': 'Documentary'}]
# 78396       400  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 0                                                    NaN   30356  tt0144280
# 1                                                    NaN   58520  tt0197633
# 2                                                    NaN  459563  tt0204250
# 3      http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                    NaN    9925  tt0244521
# ...                                                  ...     ...        ...
# 78392                      http://icarusfilms.com/if-cli  387250  tt7098636
# 78393                                                NaN  640680  tt7246872
# 78394  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 78395                                                NaN  713681  tt9414698
# 78396                                                NaN  253999  tt9641790
#
#       original_language                 original_title  \
# 0                    en  Whispers from a Shallow Grave
# 1                    en         Live Freaky Die Freaky
# 2                    en          Death of a Saleswoman
# 3                    en                Children of Men
# 4                    en                    Funny Money
# ...                 ...                            ...
# 78392                fr   Le Clitoris, ce cher inconnu
# 78393                en         Tokyo Bedoone Tavaghof
# 78394                en             Zimbabwe Countdown
# 78395                en                   The Hot Shoe
# 78396                en                     Clearwater
#
#                                                 overview  popularity  \
# 0      When a beautiful photo model disappears, polic...       0.714
# 1      It is the year 3069 and the Earth has been rob...       1.957
# 2      Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3      In 2027, in a chaotic world in which humans ca...      18.314
# 4      Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                  ...         ...
# 78392  Topics about female sexuality are growing in p...       1.400
# 78393                                                NaN       0.600
# 78394  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 78395  A Documentary Movie About Card Counting In The...       0.600
# 78396  A woman has been abducted by the Clearwater ki...       2.744
#
#                             poster_path  \
# 0      /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1      /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2      /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3      /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4      /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                 ...
# 78392  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395                               NaN
# 78396  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                     production_companies  \
# 0                                                     []
# 1                                                     []
# 2      [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                  ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 78393                                                 []
# 78394  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 78395                                                 []
# 78396  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                  ...          ...
# 78392           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 78393             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 78394  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 78395                                                 []   2003-01-01
# 78396                                                 []   2003-06-10
#
#         revenue  runtime                                   spoken_languages  \
# 0             0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      70595464    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4             0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...         ...      ...                                                ...
# 78392         0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 78393         0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 78394         0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78395         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78396         0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released                                                NaN
# 2      Released  6 housewives. 1 dead body. A trunk full of pla...
# 3      Released                  The future's a thing of the past.
# 4      Released  Henry Perkins accidentally trades briefcases w...
# ...         ...                                                ...
# 78392  Released                                                NaN
# 78393  Released                                                NaN
# 78394  Released                                                NaN
# 78395  Released                                                NaN
# 78396  Released                                                NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 78392           NaN
# 78393           NaN
# 78394           NaN
# 78395           NaN
# 78396           NaN
#
# [78397 rows x 26 columns]

# %% [markdown]
# # Transform

# %% [markdown]
# ## basics

# %% [markdown]
# - normalize and separate genre
# - "original_title" (we will use the primary title column instead)
# - "isAdult" ("Adult" will show up in the genres so this is redundant information).
# - "titleType" (every row will be a movie).
# - "genres" and other variants of genre (genre is now represented in the 2 new tables described above.

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116404 entries, 0 to 116403
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          116404 non-null  object
#  1   titleType       116404 non-null  object
#  2   primaryTitle    116404 non-null  object
#  3   originalTitle   116404 non-null  object
#  4   isAdult         116404 non-null  int64
#  5   startYear       116404 non-null  float64
#  6   runtimeMinutes  116404 non-null  int64
#  7   genres          116404 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ MB

# %%
cols_to_drop = ['originalTitle','isAdult','titleType'] #endYear not req'd
basics = basics.drop(columns=cols_to_drop)
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 3       tt0069049                         The Other Side of the Wind
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 116399  tt9915436                                  Vida em Movimento
# 116400  tt9915872                               The Last White Witch
# 116401  tt9916170                                      The Rehearsal
# 116402  tt9916190                                          Safeguard
# 116403  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2006.0              47                Documentary
# 3          2018.0             122                      Drama
# 4          2005.0             100       Comedy,Horror,Sci-Fi
# ...           ...             ...                        ...
# 116399     2019.0              70                Documentary
# 116400     2019.0              97       Comedy,Drama,Fantasy
# 116401     2019.0              51                      Drama
# 116402     2020.0              95  Action,Adventure,Thriller
# 116403     2020.0              92              Drama,History
#
# [116404 rows x 5 columns]

# %% [markdown]
# ### Normalizing Genre

# %%
## Fill Missing Genres 
## Create a new column with the single-string genres as a list of strings
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 3       tt0069049                         The Other Side of the Wind
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 116399  tt9915436                                  Vida em Movimento
# 116400  tt9915872                               The Last White Witch
# 116401  tt9916170                                      The Rehearsal
# 116402  tt9916190                                          Safeguard
# 116403  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres  \
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2006.0              47                Documentary
# 3          2018.0             122                      Drama
# 4          2005.0             100       Comedy,Horror,Sci-Fi
# ...           ...             ...                        ...
# 116399     2019.0              70                Documentary
# 116400     2019.0              97       Comedy,Drama,Fantasy
# 116401     2019.0              51                      Drama
# 116402     2020.0              95  Action,Adventure,Thriller
# 116403     2020.0              92              Drama,History
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                       [Documentary]
# 3                             [Drama]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 116399                  [Documentary]
# 116400       [Comedy, Drama, Fantasy]
# 116401                        [Drama]
# 116402  [Action, Adventure, Thriller]
# 116403               [Drama, History]
#
# [116404 rows x 6 columns]

# %%
## Explode the dataframe to make each genre into a separate row
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# ...           ...                                                ...
# 116402  tt9916190                                          Safeguard
# 116402  tt9916190                                          Safeguard
# 116402  tt9916190                                          Safeguard
# 116403  tt9916362                                              Coven
# 116403  tt9916362                                              Coven
#
#         startYear  runtimeMinutes                     genres genres_split
# 0          2001.0             118     Comedy,Fantasy,Romance       Comedy
# 0          2001.0             118     Comedy,Fantasy,Romance      Fantasy
# 0          2001.0             118     Comedy,Fantasy,Romance      Romance
# 1          2020.0              70                      Drama        Drama
# 2          2006.0              47                Documentary  Documentary
# ...           ...             ...                        ...          ...
# 116402     2020.0              95  Action,Adventure,Thriller       Action
# 116402     2020.0              95  Action,Adventure,Thriller    Adventure
# 116402     2020.0              95  Action,Adventure,Thriller     Thriller
# 116403     2020.0              92              Drama,History        Drama
# 116403     2020.0              92              Drama,History      History
#
# [207423 rows x 6 columns]

# %% [markdown]
# #### Create title_genres Table - title_genres
# tconst: GenreID

# %%
## Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0067683  Documentary

# %% [markdown]
# #### Replacing Text Genres with Integer IDs

# %%
## Getting unique list of genres
unique_genres = sorted(title_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
## Make a dictionary with list of unique genres as the key and the new iteger id as vlaues
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Documentary': 7,
#  'Drama': 8,
#  'Family': 9,
#  'Fantasy': 10,
#  'Game-Show': 11,
#  'History': 12,
#  'Horror': 13,
#  'Music': 14,
#  'Musical': 15,
#  'Mystery': 16,
#  'News': 17,
#  'Reality-TV': 18,
#  'Romance': 19,
#  'Sci-Fi': 20,
#  'Short': 21,
#  'Sport': 22,
#  'Talk-Show': 23,
#  'Thriller': 24,
#  'War': 25,
#  'Western': 26}

# %% [markdown]
# #### Replacing Values in title_genres Table with Genre ID

# %%
## Use .map or .replace with our genre_id_map dictionary
title_genres['Genre_ID'] = title_genres['genres_split'].replace(genre_id_map)

## Drop the original genre column
title_genres.drop(columns=['genres_split'],inplace=True)
title_genres
# Out:
#            tconst  Genre_ID
# 0       tt0035423         5
# 0       tt0035423        10
# 0       tt0035423        19
# 1       tt0062336         8
# 2       tt0067683         7
# ...           ...       ...
# 116402  tt9916190         0
# 116402  tt9916190         2
# 116402  tt9916190        24
# 116403  tt9916362         8
# 116403  tt9916362        12
#
# [207423 rows x 2 columns]

# %% [markdown]
# #### Create `genres` table
# - Genre : Genre_ID

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Dropping original genre columns 
basics = basics.drop(columns=['genres','genres_split'])
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 3       tt0069049                         The Other Side of the Wind
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 116399  tt9915436                                  Vida em Movimento
# 116400  tt9915872                               The Last White Witch
# 116401  tt9916170                                      The Rehearsal
# 116402  tt9916190                                          Safeguard
# 116403  tt9916362                                              Coven
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2006.0              47
# 3          2018.0             122
# 4          2005.0             100
# ...           ...             ...
# 116399     2019.0              70
# 116400     2019.0              97
# 116401     2019.0              51
# 116402     2020.0              95
# 116403     2020.0              92
#
# [116404 rows x 4 columns]

# %% [markdown]
# ## Normalizing TMDB API Data

# %%
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#          budget                                             genres  \
# 0        100000                                                 []
# 1             0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2             0  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 3      76000000  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4             0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...         ...                                                ...
# 78392         0                [{'id': 99, 'name': 'Documentary'}]
# 78393         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 78394         0                [{'id': 99, 'name': 'Documentary'}]
# 78395         0                [{'id': 99, 'name': 'Documentary'}]
# 78396       400  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 0                                                    NaN   30356  tt0144280
# 1                                                    NaN   58520  tt0197633
# 2                                                    NaN  459563  tt0204250
# 3      http://www.universalstudiosentertainment.com/c...    9693  tt0206634
# 4                                                    NaN    9925  tt0244521
# ...                                                  ...     ...        ...
# 78392                      http://icarusfilms.com/if-cli  387250  tt7098636
# 78393                                                NaN  640680  tt7246872
# 78394  https://www.michaelraeburn.com/site/web/mr/zim...  515137  tt7637550
# 78395                                                NaN  713681  tt9414698
# 78396                                                NaN  253999  tt9641790
#
#       original_language                 original_title  \
# 0                    en  Whispers from a Shallow Grave
# 1                    en         Live Freaky Die Freaky
# 2                    en          Death of a Saleswoman
# 3                    en                Children of Men
# 4                    en                    Funny Money
# ...                 ...                            ...
# 78392                fr   Le Clitoris, ce cher inconnu
# 78393                en         Tokyo Bedoone Tavaghof
# 78394                en             Zimbabwe Countdown
# 78395                en                   The Hot Shoe
# 78396                en                     Clearwater
#
#                                                 overview  popularity  \
# 0      When a beautiful photo model disappears, polic...       0.714
# 1      It is the year 3069 and the Earth has been rob...       1.957
# 2      Top-ranking RubberTubber saleswoman Agatha J. ...       0.676
# 3      In 2027, in a chaotic world in which humans ca...      18.314
# 4      Henry Perkins, a mild-mannered accountant, acc...       4.218
# ...                                                  ...         ...
# 78392  Topics about female sexuality are growing in p...       1.400
# 78393                                                NaN       0.600
# 78394  Once touted as Zimbabwe's saviour, Robert Muga...       0.711
# 78395  A Documentary Movie About Card Counting In The...       0.600
# 78396  A woman has been abducted by the Clearwater ki...       2.744
#
#                             poster_path  \
# 0      /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1      /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2      /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3      /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4      /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                 ...
# 78392  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395                               NaN
# 78396  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                     production_companies  \
# 0                                                     []
# 1                                                     []
# 2      [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 3      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                  ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cat...
# 78393                                                 []
# 78394  [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# 78395                                                 []
# 78396  [{'id': 174685, 'logo_path': None, 'name': 'Li...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                  ...          ...
# 78392           [{'iso_3166_1': 'FR', 'name': 'France'}]   2004-01-16
# 78393             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2003-09-10
# 78394  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2003-08-28
# 78395                                                 []   2003-01-01
# 78396                                                 []   2003-06-10
#
#         revenue  runtime                                   spoken_languages  \
# 0             0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      70595464    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4             0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...         ...      ...                                                ...
# 78392         0     60.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 78393         0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
# 78394         0     55.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78395         0     96.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 78396         0     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released                                                NaN
# 2      Released  6 housewives. 1 dead body. A trunk full of pla...
# 3      Released                  The future's a thing of the past.
# 4      Released  Henry Perkins accidentally trades briefcases w...
# ...         ...                                                ...
# 78392  Released                                                NaN
# 78393  Released                                                NaN
# 78394  Released                                                NaN
# 78395  Released                                                NaN
# 78396  Released                                                NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 78392           NaN
# 78393           NaN
# 78394           NaN
# 78395           NaN
# 78396           NaN
#
# [78397 rows x 26 columns]

# %% [markdown]
# ### Clean & Normalize Production Companies

# %%
test = df.iloc[3]['production_companies']
test
# Out:
# "[{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]"

# %%
## Function to get just the genre names as a list 
import json
def get_company_name(x):
    try:
        x = x.replace('None','"None"')
        x = x.replace('\\','')
        
#         x = x.replace("'",'"')
        x = x.replace("'s",'s')
        for key in ['id','logo_path','name','origin_country']:
            x = x.replace(f"'{key}'",f'"{key}"')
            
        x = x.replace("'",'"')
        
        x = json.loads(x)

        companies = []
        for company in x:
            companies.append(company['name'])
        return companies
    except:
        print(x)

# %%
get_company_name(test)
# Out:
# ['Universal Pictures', 'Strike Entertainment', 'Hit & Run Productions']

# %%
# json.loads(test)

# %%
## Use ourn function and exploding the new column
df['production_company_list'] = df['production_companies'].fillna('[]').apply(get_company_name)
# Out:
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}]
# [{"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 122638, "logo_path": "None", "name": "République de Côte d"Ivoire", "origin_country": ""}, {"id": 13542, "logo_path": "/sJ0R9LDMGR5ildYS4GMhQcbKJVD.png", "name": "CNRS Images", "origin_country": "FR"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 2326, "logo_path": "None", "name": "Autonomous", "origin_country": ""}, {"id": 122639, "logo_path": "None", "name": "Éliane de Latour Production", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 1249, "logo_path": "None", "name": "Les Films du Lendemain", "origin_country": "FR"}, {"id": 122640, "logo_path": "None", "name": "Cognition", "origin_country": ""}, {"id": 122641, "logo_path": "None", "name": "Ice Breaker", "origin_country": ""}, {"id": 122642, "logo_path": "None", "name": "Kings Road Picture Company", "origin_country": ""}]
# [{"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 4045, "logo_path": "None", "name": "Cinegram", "origin_country": "GR"}, {"id": 23495, "logo_path": "None", "name": "Titania Produzioni", "origin_country": "IT"}, {"id": 98757, "logo_path": "None", "name": "Les films de l"instant", "origin_country": ""}, {"id": 98758, "logo_path": "None", "name": "Films 18", "origin_country": ""}, {"id": 98759, "logo_path": "None", "name": "CG Studios", "origin_country": ""}]
# [{"id": 1088, "logo_path": "/9WOE5AQUXbOtLU6GTwfjS8OMF0v.png", "name": "Alcon Entertainment", "origin_country": "US"}, {"id": 10405, "logo_path": "None", "name": "EFO Films", "origin_country": "US"}, {"id": 890, "logo_path": "None", "name": "Cheyenne Enterprises", "origin_country": ""}, {"id": 10885, "logo_path": "None", "name": "Equity Pictures Medienfonds GmbH & Co. KG III", "origin_country": ""}, {"id": 10886, "logo_path": "None", "name": "16 Block Productions", "origin_country": ""}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 1020, "logo_path": "/kuUIHNwMec4dwOLghDhhZJzHZTd.png", "name": "Millennium Films", "origin_country": "US"}, {"id": 925, "logo_path": "/dIb9hjXNOkgxu4kBWdIdK8nM4w.png", "name": "Nu Image", "origin_country": "US"}, {"id": 1420, "logo_path": "None", "name": "ContentFilm", "origin_country": ""}]
# [{"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 113973, "logo_path": "None", "name": "Ciné Cinéma", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 2318, "logo_path": "None", "name": "Région Provence Côte d"Azur", "origin_country": "FR"}, {"id": 2700, "logo_path": "/jqmxhA0HVNPiRD80MbBPLSNaIzA.png", "name": "Rectangle Productions", "origin_country": "FR"}, {"id": 694, "logo_path": "/5LEHONGkZBIoWvp1ygHOF8iyi1M.png", "name": "StudioCanal", "origin_country": "FR"}, {"id": 6844, "logo_path": "/yilspcMjH7xgb0AdTg1cFUowUj3.png", "name": "Thelma Films", "origin_country": "FR"}, {"id": 69459, "logo_path": "None", "name": "Uni Etoile 3", "origin_country": "FR"}]
# [{"id": 95594, "logo_path": "None", "name": "Train A Comin" Productions Inc.", "origin_country": ""}, {"id": 2274, "logo_path": "None", "name": "Element Films", "origin_country": "BG"}]
# [{"id": 83, "logo_path": "/9OQ0rm55xtlgX7KcAKMUePJSrQc.png", "name": "France 2 Cinéma", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 136842, "logo_path": "None", "name": "Atlan Films", "origin_country": ""}, {"id": 157982, "logo_path": "None", "name": "CNC", "origin_country": "FR"}, {"id": 11798, "logo_path": "None", "name": "Région Provence-Alpes-Côte d"Azur", "origin_country": ""}, {"id": 856, "logo_path": "/3tfzS2CrX6Ntbu927XzHXEPDA6y.png", "name": "Wild Bunch", "origin_country": "FR"}, {"id": 6586, "logo_path": "None", "name": "TPS Star", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 3373, "logo_path": "None", "name": "KS2 Productions", "origin_country": ""}, {"id": 28401, "logo_path": "None", "name": "Tovo Films", "origin_country": ""}, {"id": 12389, "logo_path": "/6yilbEvoHtPcTb4LwAueAq091iT.png", "name": "Les Films Pelléas", "origin_country": "FR"}]
# [{"id": 2318, "logo_path": "None", "name": "Région Provence Côte d"Azur", "origin_country": "FR"}, {"id": 2673, "logo_path": "/kgqoT0BfqE1vWEXuliWoAsglH.png", "name": "La Fabrique de Films", "origin_country": "FR"}, {"id": 9011, "logo_path": "None", "name": "Toloda", "origin_country": ""}, {"id": 21083, "logo_path": "None", "name": "Soficinéma 2", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 174, "logo_path": "/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png", "name": "Warner Bros. Pictures", "origin_country": "US"}, {"id": 79, "logo_path": "/tpFpsqbleCzEE2p5EgvUq6ozfCA.png", "name": "Village Roadshow Pictures", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}]
# [{"id": 4740, "logo_path": "/20IuOPEwlHRXnn0MTOsEmw0wcql.png", "name": "Gary Sanchez Productions", "origin_country": "US"}, {"id": 746, "logo_path": "/kc7bdIVTBkJYy9aDK1QDDTAL463.png", "name": "MTV Films", "origin_country": "US"}, {"id": 164585, "logo_path": "None", "name": "You Know I Can"t Kiss You", "origin_country": ""}]
# [{"id": 20971, "logo_path": "None", "name": "BL Production", "origin_country": ""}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 13728, "logo_path": "/bpsUvoLS3Xms2xXOPQFq5nLZI5J.png", "name": "Nomadis Images", "origin_country": "TN"}]
# [{"id": 21356, "logo_path": "/u8A0TytlOh1GTSv5wmoJV7VuFqV.png", "name": "Svarog Films Company", "origin_country": "RU"}, {"id": 108054, "logo_path": "None", "name": "Studio "Bereg"", "origin_country": "RU"}, {"id": 108056, "logo_path": "None", "name": "Film company "Sterkh"", "origin_country": "RU"}]
# [{"id": 36547, "logo_path": "None", "name": "SACI", "origin_country": "IR"}, {"id": 7573, "logo_path": "None", "name": "Les Films de l"Astrophore", "origin_country": "FR"}]
# [{"id": 104698, "logo_path": "None", "name": "Rock n" Tape Films", "origin_country": ""}, {"id": 92398, "logo_path": "None", "name": "Thunder Alley Productions", "origin_country": ""}, {"id": 104699, "logo_path": "None", "name": "New Heits Entertainment", "origin_country": ""}]
# [{"id": 50163, "logo_path": "None", "name": "Ulysses Filmproduktion", "origin_country": "DE"}, {"id": 50164, "logo_path": "None", "name": "Fabrique d"images", "origin_country": "LU"}, {"id": 3922, "logo_path": "/aCdyqd55D2XvjbdpPGvaIY7G64t.png", "name": "A. Film Production", "origin_country": "DK"}]
# [{"id": 102966, "logo_path": "None", "name": "TODFILM", "origin_country": ""}, {"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 109365, "logo_path": "None", "name": "Manekino Film", "origin_country": "RO"}, {"id": 18485, "logo_path": "None", "name": "Rohfilm", "origin_country": "DE"}, {"id": 15608, "logo_path": "None", "name": "Agitprop", "origin_country": "BG"}, {"id": 88412, "logo_path": "None", "name": "Les Films de L"Etranger", "origin_country": "FR"}, {"id": 24701, "logo_path": "None", "name": "Pink Productions", "origin_country": "CZ"}]
# [{"id": 108014, "logo_path": "/7yL2CvXDHpBWUBJtxoTZEyPcg3A.png", "name": "Electric Pictures", "origin_country": "AU"}, {"id": 80468, "logo_path": "/2ZfFXAksjh7RKyldXpo8pP32WoW.png", "name": "Xeitgeist Entertainment Group", "origin_country": ""}, {"id": 56277, "logo_path": "None", "name": "Cyan Films", "origin_country": "AU"}, {"id": 3528, "logo_path": "/cCzCClIzIh81Fa79hpW5nXoUsHK.png", "name": "Thunder Road", "origin_country": "US"}, {"id": 7584, "logo_path": "/eGkfvvyf4fJTvBUR1xt1669IPA3.png", "name": "Screen Australia", "origin_country": "AU"}, {"id": 2806, "logo_path": "/vxOhCbpsRBh10m6LZ3HyImTYpPY.png", "name": "South Australian Film Corporation", "origin_country": "AU"}, {"id": 120234, "logo_path": "None", "name": "Hamilton Films", "origin_country": ""}, {"id": 100185, "logo_path": "None", "name": "S"YA Concept", "origin_country": ""}, {"id": 2520, "logo_path": "None", "name": "Arclight Films", "origin_country": "US"}, {"id": 120236, "logo_path": "None", "name": "Ikaria", "origin_country": ""}, {"id": 18988, "logo_path": "None", "name": "Story Bridge Films", "origin_country": "AU"}, {"id": 988, "logo_path": "None", "name": "Kojo Pictures", "origin_country": ""}, {"id": 86886, "logo_path": "None", "name": "Double Barrel Productions", "origin_country": ""}, {"id": 290, "logo_path": "/Q8mw2AOQQc8Qg0uNwLWq86DVZv.png", "name": "Ingenious Media", "origin_country": "GB"}]
# [{"id": 101884, "logo_path": "None", "name": "Refinaria Filmes", "origin_country": "BR"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 8492, "logo_path": "/wYhNCpXIThYDXevad6n90vsMXZ2.png", "name": "RTP", "origin_country": "PT"}, {"id": 83651, "logo_path": "None", "name": "Faux", "origin_country": "PT"}]
# [{"id": 109099, "logo_path": "None", "name": "Don"t Touch My Radio", "origin_country": ""}, {"id": 94397, "logo_path": "None", "name": "Sledgehammer Films", "origin_country": ""}, {"id": 109100, "logo_path": "None", "name": "Till Death do Us Part Pictures", "origin_country": ""}]
# [{"id": 110242, "logo_path": "None", "name": "Free Ramblin" Productions", "origin_country": ""}]
# [{"id": 45015, "logo_path": "/ur1MRx1vINi0pwAAkRjdTJsFA7H.png", "name": "Juliette Films", "origin_country": "LU"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 11794, "logo_path": "/vjyzeaIhRdtMfDIVGAECNirIkGw.png", "name": "Lunanime", "origin_country": "BE"}, {"id": 116013, "logo_path": "None", "name": "ithinkasia", "origin_country": ""}, {"id": 122123, "logo_path": "None", "name": "WebSpider Productions", "origin_country": ""}, {"id": 122124, "logo_path": "None", "name": "Epuar", "origin_country": ""}, {"id": 122125, "logo_path": "None", "name": "Amopix", "origin_country": ""}, {"id": 122126, "logo_path": "/aCwFe0dlIUCBcw9iaatYrRjEBKm.png", "name": "Cinéfeel 4", "origin_country": "FR"}, {"id": 122127, "logo_path": "None", "name": "Gaoshan Pictures", "origin_country": ""}, {"id": 122128, "logo_path": "None", "name": "Special Touch Studios", "origin_country": ""}, {"id": 20662, "logo_path": "/rxfxm2P7zJdUsXB9d5Zrg9DOXfd.png", "name": "TV5 Monde", "origin_country": "FR"}]
# [{"id": 20338, "logo_path": "/yCTqaPPzFfjqKU2YAGWce4qQk1S.png", "name": "Bidibul Productions", "origin_country": "LU"}, {"id": 62055, "logo_path": "None", "name": "EMAfilms", "origin_country": "CA"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}]
# [{"id": 149314, "logo_path": "None", "name": soilfilms", "origin_country": ""}, {"id": 172824, "logo_path": "None", "name": "Zoneart Films", "origin_country": ""}]
# [{"id": 99855, "logo_path": "None", "name": sbs distribution", "origin_country": ""}, {"id": 207, "logo_path": "/uskenzq65wJe0cT0D8StQI3hJnO.png", "name": "Agat Films & Cie / Ex Nihilo", "origin_country": "FR"}]
# [{"id": 45489, "logo_path": "/h9pjnrYbpEqWwPZDEyJfUzHFCG9.png", "name": "Lupa Film", "origin_country": "DE"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 13573, "logo_path": "/4dqepK1XdLklrsYdnFpCEkOPXLX.png", "name": "Canal Brasil", "origin_country": "BR"}]
# [{"id": 30816, "logo_path": "None", "name": "O" Groove", "origin_country": "IT"}, {"id": 30817, "logo_path": "None", "name": "Tramp LTD", "origin_country": "IT"}]
# [{"id": 6003, "logo_path": "/mEswQx1seYJjA2knd0lrdDGvxvu.png", "name": "Box Productions", "origin_country": "CH"}, {"id": 7465, "logo_path": "/e28RwIpRcOSFaeKkzLQBzvMXbK0.png", "name": "Novak Prod", "origin_country": "BE"}, {"id": 21990, "logo_path": "None", "name": "Office Fédéral de la Culture", "origin_country": ""}, {"id": 78505, "logo_path": "None", "name": "Fonds Culturel de Suissimage", "origin_country": ""}, {"id": 92233, "logo_path": "None", "name": "Cinéforom", "origin_country": ""}, {"id": 21996, "logo_path": "None", "name": "Loterie Suisse Romande", "origin_country": ""}, {"id": 95061, "logo_path": "/gAt0ztKNX5gKyzNmIdaVxI5aoHv.png", "name": "Shelter Prod", "origin_country": "BE"}, {"id": 11922, "logo_path": "None", "name": "Taxshelter. be", "origin_country": ""}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 13668, "logo_path": "/azhapBvZ8g1UWyyQQhhcRR9bM9x.png", "name": "RTS", "origin_country": "CH"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 26027, "logo_path": "/sHNTPJu0ePn5PqHRcA6nncNWN0L.png", "name": "Teleclub", "origin_country": "CH"}]
# [{"id": 28738, "logo_path": "None", "name": "Hand "n" Hand Films", "origin_country": ""}]
# [{"id": 109061, "logo_path": "None", "name": ""S Wonderful Pictures", "origin_country": ""}]
# [{"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 3040, "logo_path": "/25t2aPa5uNerf9Pq5cLUsYhs8ZA.png", "name": "Versus Production", "origin_country": "BE"}, {"id": 7395, "logo_path": "/cGOGYYfbJZ1uJHynRIf8yj4phRn.png", "name": "Les films du Worso", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}]
# [{"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 27334, "logo_path": "None", "name": "Laïla Films", "origin_country": ""}, {"id": 110086, "logo_path": "None", "name": "24images", "origin_country": "FR"}]
# [{"id": 135805, "logo_path": "None", "name": "Tamara Films", "origin_country": ""}, {"id": 17469, "logo_path": "None", "name": "Tu Vas Voir Productions", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 135807, "logo_path": "None", "name": "Brouillon d"Un Rêve de la SCAM", "origin_country": ""}]
# [{"id": 116071, "logo_path": "/bIiULtcXju3Ut2utfJgeG4c7rNH.png", "name": "Les Films d"un Jour", "origin_country": "FR"}]
# [{"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 130970, "logo_path": "None", "name": "IDFA Bertha Fund", "origin_country": ""}, {"id": 130971, "logo_path": "None", "name": "Adok Films", "origin_country": "CH"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}]
# [{"id": 121251, "logo_path": "None", "name": "Les Films d"Argile", "origin_country": "FR"}]
# [{"id": 70098, "logo_path": "None", "name": "Klas Film", "origin_country": "BG"}, {"id": 8698, "logo_path": "None", "name": "Hi Film Productions", "origin_country": "RO"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 24870, "logo_path": "None", "name": "Endorfilm", "origin_country": "CZ"}, {"id": 1618, "logo_path": "/dacmPYkpGE9Mbu2dqG2sFTXpsqr.png", "name": "Komplizen Film", "origin_country": "DE"}, {"id": 11237, "logo_path": "None", "name": "ZDF/Arte", "origin_country": "DE"}, {"id": 73926, "logo_path": "/fQtClxlHLBnPdlV5HBPi0Tzj38d.png", "name": "Televiziunea Română", "origin_country": "RO"}]
# [{"id": 107196, "logo_path": "None", "name": "D"Souza Media", "origin_country": "US"}]
# [{"id": 94865, "logo_path": "None", "name": "Chimney", "origin_country": "PL"}, {"id": 100885, "logo_path": "/2vYdB9OVYQqsczlnslPfTiK2zYT.png", "name": "Multi Media Est", "origin_country": "RO"}, {"id": 6669, "logo_path": "None", "name": "Les Films de l"Après-Midi", "origin_country": "FR"}, {"id": 2801, "logo_path": "/bswb1PLLsKDUXMLgy42bZtCtIde.png", "name": "Film i Väst", "origin_country": "SE"}]
# [{"id": 72551, "logo_path": "None", "name": "Les Artisans du Film", "origin_country": ""}, {"id": 30056, "logo_path": "/pCcVg35wQOaAdClPp10IdVSvys4.png", "name": "Alter Ego Productions", "origin_country": "FR"}, {"id": 76742, "logo_path": "/7DPDeTgKBiuiRUtX4VLQJo2ojpr.png", "name": "L"Atelier Animation", "origin_country": "CA"}]
# [{"id": 168714, "logo_path": "None", "name": "Can"t Stop / Won"t Stop Films", "origin_country": ""}]
# [{"id": 121124, "logo_path": "None", "name": "Diversion", "origin_country": "TH"}, {"id": 88412, "logo_path": "None", "name": "Les Films de L"Etranger", "origin_country": "FR"}, {"id": 112167, "logo_path": "None", "name": "Youku Original", "origin_country": ""}, {"id": 126451, "logo_path": "None", "name": "Mit Out Sound Films", "origin_country": ""}]
# [{"id": 109751, "logo_path": "None", "name": "5 o"clock creativity", "origin_country": ""}]
# [{"id": 80653, "logo_path": "None", "name": "Else Films", "origin_country": ""}, {"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 29036, "logo_path": "None", "name": "Fog"n"Desire Films", "origin_country": "CZ"}, {"id": 118507, "logo_path": "None", "name": "Heavens Gate", "origin_country": "CZ"}, {"id": 487, "logo_path": "/x3BUIowxU2skXOpnOeOkl7kIYDo.png", "name": "Česká televize", "origin_country": "CZ"}, {"id": 118509, "logo_path": "None", "name": "KFS Production", "origin_country": "SK"}]
# [{"id": 74735, "logo_path": "None", "name": "Centre de l"Audiovisuel à Bruxelles (CBA)", "origin_country": "BE"}, {"id": 20482, "logo_path": "/ncZtCy1XzmVeN674GNBDdvMc8b0.png", "name": "Iota Production", "origin_country": "BE"}]
# [{"id": 7505, "logo_path": "/837VMM4wOkODc1idNxGT0KQJlej.png", "name": "Marvel Entertainment", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}, {"id": 22213, "logo_path": "/qx9K6bFWJupwde0xQDwOvXkOaL8.png", "name": "TSG Entertainment", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 31076, "logo_path": "None", "name": "Simon Kinberg Productions", "origin_country": "US"}]
# [{"id": 5405, "logo_path": "None", "name": "Roy Andersson Filmproduktion AB", "origin_country": ""}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 11237, "logo_path": "None", "name": "ZDF/Arte", "origin_country": "DE"}, {"id": 20691, "logo_path": "None", "name": "Essential Filmproduktion", "origin_country": "DE"}, {"id": 22627, "logo_path": "/mZsZ3IYzoheUPTPN3WeFwOYxAkP.png", "name": "Film- und Medienstiftung NRW", "origin_country": "DE"}, {"id": 25522, "logo_path": "None", "name": "Société Parisienne de Production", "origin_country": "FR"}, {"id": 46201, "logo_path": "None", "name": "Norsk Filmfond", "origin_country": ""}, {"id": 2302, "logo_path": "/rPXEdpqwFycAY9ZgrAJXv13qcWW.png", "name": "Svenska Filminstitutet", "origin_country": "SE"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 2999, "logo_path": "/zGSqFee9aDgDuLD6vcs2mcJUem4.png", "name": "SVT", "origin_country": "SE"}, {"id": 7843, "logo_path": "None", "name": "4 1/2", "origin_country": "NO"}]
# [{"id": 59471, "logo_path": "None", "name": "N" Credible Entertainment", "origin_country": ""}]
# [{"id": 36484, "logo_path": "None", "name": "Niu d"Indi", "origin_country": ""}]
# [{"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 12046, "logo_path": "/wauD5HrRmaR5TdQr0ylGTLyifpQ.png", "name": "Fu Works", "origin_country": "NL"}, {"id": 22071, "logo_path": "None", "name": "Mollywood", "origin_country": "BE"}, {"id": 59086, "logo_path": "None", "name": "I"m Filming Productions", "origin_country": ""}]
# [{"id": 19615, "logo_path": "None", "name": "Camera", "origin_country": ""}, {"id": 108430, "logo_path": "None", "name": "Teach Co Art Company", "origin_country": ""}, {"id": 72961, "logo_path": "None", "name": "Chouchkov Brothers", "origin_country": "BG"}, {"id": 32469, "logo_path": "None", "name": "Dream Team Films", "origin_country": "BG"}, {"id": 101866, "logo_path": "None", "name": "Gala Film", "origin_country": "BG"}, {"id": 108431, "logo_path": "None", "name": "New Bulgarian University", "origin_country": ""}, {"id": 108432, "logo_path": "None", "name": "Post Scriptum 2", "origin_country": ""}, {"id": 108433, "logo_path": "None", "name": "Sofia Municipality", "origin_country": ""}, {"id": 108434, "logo_path": "None", "name": "State Cultural Institute "Iskar", Sofia", "origin_country": ""}]
# [{"id": 36483, "logo_path": "None", "name": "No Hay Banda", "origin_country": ""}, {"id": 36484, "logo_path": "None", "name": "Niu d"Indi", "origin_country": ""}]
# [{"id": 15465, "logo_path": "/vk1lVkUzNEkhxP0PEn9ZUEdPTwY.png", "name": "Amasia Entertainment", "origin_country": "US"}, {"id": 15462, "logo_path": "None", "name": "Troika Pictures", "origin_country": "US"}, {"id": 17379, "logo_path": "None", "name": "Coup d"Etat Films", "origin_country": ""}]
# [{"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 819, "logo_path": "/cEqVIluQuO1ubtID8RvOem4ZiIg.png", "name": "Mars Films", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 12098, "logo_path": "None", "name": "Cofimage 23", "origin_country": ""}, {"id": 27123, "logo_path": "/bJEE8LfNpFUNXSXzZXZWzqJJ0XN.png", "name": "Cinémage 8", "origin_country": "FR"}, {"id": 73893, "logo_path": "None", "name": "Cofimage 25", "origin_country": ""}, {"id": 27125, "logo_path": "None", "name": "Cofinova 10", "origin_country": "FR"}, {"id": 32668, "logo_path": "/rYw6AZjNyxvoOQy8gcvAOJUmXlk.png", "name": "Indéfilms 2", "origin_country": "FR"}, {"id": 73894, "logo_path": "None", "name": "Palatine Étoile 11", "origin_country": ""}, {"id": 311, "logo_path": "/TNGvZ8zOklntjPP3EcsHtrR8Rc.png", "name": "PROCIREP", "origin_country": "FR"}, {"id": 11773, "logo_path": "/8fCjsqh43LbPV6pm3SfR5Jx64GU.png", "name": "Artémis Productions", "origin_country": "BE"}, {"id": 15893, "logo_path": "/y7hjwCEM0c2YBlOQiDpcjs29ody.png", "name": "Tax Shelter Film Funding", "origin_country": "BE"}, {"id": 11921, "logo_path": "/gqvfasbanyk8hIKDM2EVT6Sn2AO.png", "name": "Le Tax Shelter du Gouvernement Fédéral de Belgique", "origin_country": "BE"}, {"id": 8009, "logo_path": "/jMXTbZ35gAiHCjIfdDq1B7On9fv.png", "name": "Belgacom", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 792, "logo_path": "/cRhBQP1FFNugNxKkO1pUgeD2Rkr.png", "name": "RTBF", "origin_country": "BE"}, {"id": 57752, "logo_path": "/2k3j1B8TEbZPQgckP6zh75pIb4s.png", "name": "Nord-Ouest Films", "origin_country": "FR"}]
# [{"id": 11773, "logo_path": "/8fCjsqh43LbPV6pm3SfR5Jx64GU.png", "name": "Artémis Productions", "origin_country": "BE"}, {"id": 790, "logo_path": "/k0MnHFovKIeev0ANR0Ww6HO6tfF.png", "name": "Samsa Film", "origin_country": "LU"}, {"id": 57752, "logo_path": "/2k3j1B8TEbZPQgckP6zh75pIb4s.png", "name": "Nord-Ouest Films", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 5236, "logo_path": "/cEqVIluQuO1ubtID8RvOem4ZiIg.png", "name": "Mars Films", "origin_country": "FR"}, {"id": 26172, "logo_path": "None", "name": "Cool Industrie", "origin_country": ""}, {"id": 8009, "logo_path": "/jMXTbZ35gAiHCjIfdDq1B7On9fv.png", "name": "Belgacom", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 7131, "logo_path": "/eLvjHPYZ12GR58lrDgg6MXZp2a3.png", "name": "France Télévisions", "origin_country": "FR"}, {"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 851, "logo_path": "None", "name": "MEDIA Programme of the European Union", "origin_country": ""}, {"id": 15893, "logo_path": "/y7hjwCEM0c2YBlOQiDpcjs29ody.png", "name": "Tax Shelter Film Funding", "origin_country": "BE"}, {"id": 11924, "logo_path": "/3uGsFGMUjLw52rvEllvs2txnJmn.png", "name": "Casa Kafka Pictures", "origin_country": "BE"}, {"id": 115736, "logo_path": "None", "name": "Belfius", "origin_country": "BE"}, {"id": 11921, "logo_path": "/gqvfasbanyk8hIKDM2EVT6Sn2AO.png", "name": "Le Tax Shelter du Gouvernement Fédéral de Belgique", "origin_country": "BE"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 11797, "logo_path": "/oeBCBsLLlIj2UNQBZZkhlPdDOJG.png", "name": "VOO", "origin_country": "BE"}, {"id": 27125, "logo_path": "None", "name": "Cofinova 10", "origin_country": "FR"}, {"id": 135975, "logo_path": "None", "name": "Sofica Manon 4", "origin_country": ""}, {"id": 52594, "logo_path": "None", "name": "SofiTVCiné", "origin_country": ""}, {"id": 73893, "logo_path": "None", "name": "Cofimage 25", "origin_country": ""}, {"id": 11776, "logo_path": "/33JMuTtwY5UhPwkmCEyH1YaCD23.png", "name": "Film Fund Luxembourg", "origin_country": "LU"}]
# [{"id": 21972, "logo_path": "None", "name": "Media Programme of the European Community", "origin_country": "FR"}, {"id": 1533, "logo_path": "/6ZdM1yg1LXtzS5zpuZPtZsn9YdA.png", "name": "Indigo Film", "origin_country": "IT"}, {"id": 22393, "logo_path": "None", "name": "Babe Film", "origin_country": ""}, {"id": 5051, "logo_path": "None", "name": "Faso Film", "origin_country": "IT"}, {"id": 38591, "logo_path": "None", "name": "Friuli Venezia Giulia Film Commission", "origin_country": ""}, {"id": 20416, "logo_path": "None", "name": "Regione Lazio", "origin_country": "IT"}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 14016, "logo_path": "/snclwsIZQbgvqYCBJP8fqNlCA5y.png", "name": "MiBAC", "origin_country": "IT"}, {"id": 1583, "logo_path": "/gKP4egMJOi5rksdnplfPV1wa0sd.png", "name": "RAI", "origin_country": "IT"}]
# [{"id": 15197, "logo_path": "None", "name": "Loin Derrière L"Oural", "origin_country": ""}]
# [{"id": 850, "logo_path": "/aF7qajGJGtMpdrtvssM9g90YanX.png", "name": "Eurimages", "origin_country": "FR"}, {"id": 3984, "logo_path": "/pvOBu9K0zTRuwJW7WII34x17kdz.png", "name": "Entre Chien et Loup", "origin_country": "BE"}, {"id": 7254, "logo_path": "/x5m947rMvwJbNpoGil5W76dIJjB.png", "name": "Greek Film Centre", "origin_country": "GR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 72596, "logo_path": "None", "name": "L"Aide aux Cinémas du Monde", "origin_country": ""}, {"id": 73368, "logo_path": "None", "name": "100% Synthetic Films", "origin_country": ""}, {"id": 73369, "logo_path": "None", "name": "Wrong Men", "origin_country": "GR"}, {"id": 73370, "logo_path": "None", "name": "Movie Partners In Motion Film", "origin_country": ""}, {"id": 73371, "logo_path": "None", "name": "Media", "origin_country": ""}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}]
# [{"id": 3040, "logo_path": "/25t2aPa5uNerf9Pq5cLUsYhs8ZA.png", "name": "Versus Production", "origin_country": "BE"}, {"id": 8009, "logo_path": "/jMXTbZ35gAiHCjIfdDq1B7On9fv.png", "name": "Belgacom", "origin_country": "BE"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 11798, "logo_path": "None", "name": "Région Provence-Alpes-Côte d"Azur", "origin_country": ""}, {"id": 11921, "logo_path": "/gqvfasbanyk8hIKDM2EVT6Sn2AO.png", "name": "Le Tax Shelter du Gouvernement Fédéral de Belgique", "origin_country": "BE"}, {"id": 11923, "logo_path": "None", "name": "Inver Invest", "origin_country": ""}, {"id": 12389, "logo_path": "/6yilbEvoHtPcTb4LwAueAq091iT.png", "name": "Les Films Pelléas", "origin_country": "FR"}, {"id": 78966, "logo_path": "None", "name": "Soficinéma 9", "origin_country": ""}, {"id": 81541, "logo_path": "None", "name": "Région Bourgogne", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 119549, "logo_path": "None", "name": "Creators" Union", "origin_country": ""}, {"id": 5822, "logo_path": "/qyTbRgCyU9NLKvKaiQVbadtr7RY.png", "name": "Toei Company", "origin_country": "JP"}]
# [{"id": 2567, "logo_path": "None", "name": "Abbout Productions", "origin_country": "LB"}, {"id": 94997, "logo_path": "None", "name": "Atlantic Group", "origin_country": ""}, {"id": 94998, "logo_path": "None", "name": "Breaking Walls Productions", "origin_country": ""}, {"id": 32837, "logo_path": "None", "name": "Film Commission Regione Valle d"Aosta", "origin_country": ""}, {"id": 85651, "logo_path": "None", "name": "German Film and Television Academy Berlin", "origin_country": "DE"}, {"id": 94999, "logo_path": "None", "name": "Mediafisch", "origin_country": ""}, {"id": 95000, "logo_path": "None", "name": "SAP11", "origin_country": ""}, {"id": 95001, "logo_path": "None", "name": "Sarajevo City of Film", "origin_country": "BA"}, {"id": 451, "logo_path": "/g1GRk1SdwxNwg5J3aXtrqTaXo8k.png", "name": "Medienboard Berlin-Brandenburg", "origin_country": "DE"}]
# [{"id": 32223, "logo_path": "None", "name": "Clin d"oeil Films", "origin_country": "BE"}]
# [{"id": 356, "logo_path": "/9tW5wZEGotn1Ei5pErA88m47XiD.png", "name": "TF1 Films Production", "origin_country": "FR"}, {"id": 22123, "logo_path": "/zPTy6QDAlCKGeAALZoFEL3QAlut.png", "name": "TF1", "origin_country": "FR"}, {"id": 3012, "logo_path": "None", "name": "Pathé Distribution", "origin_country": "FR"}, {"id": 23441, "logo_path": "None", "name": "Les Productions du Ch"timi", "origin_country": ""}, {"id": 11773, "logo_path": "/8fCjsqh43LbPV6pm3SfR5Jx64GU.png", "name": "Artémis Productions", "origin_country": "BE"}, {"id": 23081, "logo_path": "None", "name": "Fortis Film Fund", "origin_country": ""}, {"id": 11924, "logo_path": "/3uGsFGMUjLw52rvEllvs2txnJmn.png", "name": "Casa Kafka Pictures", "origin_country": "BE"}, {"id": 15893, "logo_path": "/y7hjwCEM0c2YBlOQiDpcjs29ody.png", "name": "Tax Shelter Film Funding", "origin_country": "BE"}, {"id": 33956, "logo_path": "None", "name": "La Wallonie", "origin_country": ""}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 39643, "logo_path": "None", "name": "We"re Not Brothers Productions", "origin_country": ""}, {"id": 39644, "logo_path": "/ls2IbZacuJSJL37SXu8uwDjKvdC.png", "name": "Cinelou Films", "origin_country": "US"}, {"id": 7382, "logo_path": "/vW2v0PPCDsp3qbB7aXRVavhxmu6.png", "name": "Echo Films", "origin_country": "US"}]
# [{"id": 7980, "logo_path": "None", "name": "Hold Up Films", "origin_country": "FR"}, {"id": 43649, "logo_path": "/5pv3tUlq25IiuMuok57YBZIiKn.png", "name": "Lilies Films", "origin_country": "FR"}, {"id": 11935, "logo_path": "None", "name": "Fonds Images de la Diversité", "origin_country": ""}, {"id": 11245, "logo_path": "None", "name": "Agence Nationale pour la Cohésion Sociale et l"Egalité des Chances (ACSE)", "origin_country": ""}, {"id": 11246, "logo_path": "/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png", "name": "Région Ile-de-France", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 20881, "logo_path": "None", "name": "Playtime", "origin_country": "FR"}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 14268, "logo_path": "/dt8foss5srgTblxN4flZ5CRxRqI.png", "name": "Cofinova 9", "origin_country": "FR"}]
# [{"id": 57318, "logo_path": "None", "name": "Proaction Film", "origin_country": ""}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}]
# [{"id": 153882, "logo_path": "None", "name": "Hot "n" Tedious Films", "origin_country": ""}]
# [{"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}]
# [{"id": 147587, "logo_path": "None", "name": "Redbox Entertainment", "origin_country": ""}, {"id": 25140, "logo_path": "/6SeV4YCwyIDktJlvrVwiEDSLovF.png", "name": "The Exchange", "origin_country": "US"}, {"id": 163840, "logo_path": "None", "name": "Media Capital Group", "origin_country": ""}, {"id": 163841, "logo_path": "None", "name": "B.A.R. "None" Productions", "origin_country": ""}, {"id": 68628, "logo_path": "None", "name": "308 Enterprises", "origin_country": "CA"}, {"id": 163842, "logo_path": "None", "name": "Vector Film Services", "origin_country": ""}, {"id": 163843, "logo_path": "None", "name": "T.N.G. Capital Corp", "origin_country": ""}]
# [{"id": 166117, "logo_path": "None", "name": shy kids", "origin_country": ""}, {"id": 72063, "logo_path": "None", "name": "Zapruder Films", "origin_country": ""}]
# [{"id": 168818, "logo_path": "None", "name": spicefilm", "origin_country": ""}]
# [{"id": 8147, "logo_path": "/q6HOAdSNgCbeOqwoMVRc6REgbXF.png", "name": "Entertainment One", "origin_country": "CA"}, {"id": 20664, "logo_path": "/iRrZpxnYNDnVXJkr6HiLgSLlqRc.png", "name": "Anton Capital Entertainment (ACE)", "origin_country": ""}, {"id": 91331, "logo_path": "/uYyo3szZqWKn5p2bfAXMXzqVo8.png", "name": "Main Journey", "origin_country": "CA"}, {"id": 6623, "logo_path": "/qvtEf5tM9IAEJUUhX9EcBl12Fhr.png", "name": "Caramel Films", "origin_country": "CA"}, {"id": 76742, "logo_path": "/7DPDeTgKBiuiRUtX4VLQJo2ojpr.png", "name": "L"Atelier Animation", "origin_country": "CA"}]
# [{"id": 20102, "logo_path": "None", "name": "L"Altro Film", "origin_country": ""}, {"id": 114547, "logo_path": "None", "name": "Regione Piemonte", "origin_country": ""}]
# [{"id": 2387, "logo_path": "None", "name": sabotage film GmbH", "origin_country": ""}, {"id": 1251, "logo_path": "/ucgmv8vBIA3Tr2VbqQ1NKYgkTsN.png", "name": "ARD", "origin_country": "DE"}]
# [{"id": 6332, "logo_path": "/42UPdZl6B2cFXgNUASR8hSt9mpS.png", "name": "Dune Entertainment III", "origin_country": "US"}, {"id": 43, "logo_path": "/4RgIPr55kBakgupWkzdDxqXJEqr.png", "name": "Fox Searchlight Pictures", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 907, "logo_path": "/ca5SWI5uvU985f8Kbb4xc8AmVWH.png", "name": "Overbrook Entertainment", "origin_country": "US"}]
# [{"id": 26772, "logo_path": "None", "name": "J&J JAKUBISKO FILM EUROPE Production s.r.o.", "origin_country": "SK"}, {"id": 16016, "logo_path": "None", "name": "Eurofilm Stúdió", "origin_country": "HU"}, {"id": 26773, "logo_path": "None", "name": "J&J Jakubisko Film", "origin_country": "CZ"}, {"id": 2568, "logo_path": "None", "name": "Lunar Films", "origin_country": "GB"}, {"id": 26774, "logo_path": "None", "name": "Concorde Film Trust", "origin_country": "HU"}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 26775, "logo_path": "None", "name": "Ministry of Culture of the Slovak Republic", "origin_country": "SK"}, {"id": 6062, "logo_path": "None", "name": "Státní fond ČR pro podporu a rozvoj české kinematografie", "origin_country": "CZ"}]
# [{"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}, {"id": 1001, "logo_path": "None", "name": "Solaris Film", "origin_country": "DE"}, {"id": 12066, "logo_path": "None", "name": "O"Connor Brothers", "origin_country": ""}, {"id": 1565, "logo_path": "None", "name": "Avery Pix", "origin_country": "US"}, {"id": 12067, "logo_path": "None", "name": "Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG", "origin_country": ""}]
# [{"id": 2381, "logo_path": "/hmzO0vmTZjfGoMoS5pykenpmHWH.png", "name": "Musée d"Orsay", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 6586, "logo_path": "None", "name": "TPS Star", "origin_country": "FR"}]
# [{"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}, {"id": 748, "logo_path": "None", "name": "Mosaic Media Group", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 2648, "logo_path": "None", "name": "Road Rebel", "origin_country": ""}]
# [{"id": 5975, "logo_path": "/vvjgoKygWWYZvYyidT3RmOCq5If.png", "name": "YLE", "origin_country": "FI"}, {"id": 118, "logo_path": "/AiBorgNTCS1lT1FdFPYheax9jfF.png", "name": "Det Danske Filminstitut", "origin_country": "DK"}, {"id": 204, "logo_path": "None", "name": "Wüste Filmproduktion", "origin_country": "DE"}, {"id": 264, "logo_path": "/fA90qwUKgPhMONqtwY60GaHRyrW.png", "name": "Studio Babelsberg", "origin_country": "DE"}, {"id": 758, "logo_path": "/fft3jrctrZNcgAxgN1w5Givtzip.png", "name": "TV 2", "origin_country": "DK"}, {"id": 7306, "logo_path": "/qeZiPsQpCq7r1MrQgM7op2BQcPZ.png", "name": "The Match Factory", "origin_country": "DE"}, {"id": 9111, "logo_path": "/uyH9qC2BDSlt8aep2nCgbDmET0K.png", "name": "Sirena Film", "origin_country": "CZ"}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 11673, "logo_path": "None", "name": "Wüste Film Ost", "origin_country": "DE"}, {"id": 11674, "logo_path": "None", "name": "OC Film", "origin_country": ""}, {"id": 11675, "logo_path": "None", "name": "Duckling", "origin_country": "DK"}, {"id": 11676, "logo_path": "None", "name": "Mainstream", "origin_country": ""}, {"id": 11677, "logo_path": "None", "name": "Kameraudlejningen", "origin_country": ""}, {"id": 11678, "logo_path": "None", "name": "4½", "origin_country": ""}, {"id": 11680, "logo_path": "/thDuwlPhKqGkfPzk0qd6zIiSw4m.png", "name": "Filmförderung Hamburg Schleswig-Holstein", "origin_country": "DE"}, {"id": 11683, "logo_path": "None", "name": "NFP Marketing & Distribution", "origin_country": ""}, {"id": 11685, "logo_path": "None", "name": "Substanz Film", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 2999, "logo_path": "/zGSqFee9aDgDuLD6vcs2mcJUem4.png", "name": "SVT", "origin_country": "SE"}, {"id": 155, "logo_path": "/cDY49SOQwJixJSMun9Haerx8dAQ.png", "name": "Nimbus Film", "origin_country": "DK"}, {"id": 5403, "logo_path": "/fAz2WhTpoMxutBA92JqlfeHEGuz.png", "name": "Nordisk Film & TV Fond", "origin_country": "NO"}, {"id": 6690, "logo_path": "/gilqi5hbNH7y9UlWg1P0TjAqZa8.png", "name": "Sandrew Metronome Danmark", "origin_country": "DK"}, {"id": 45198, "logo_path": "/9z46Z8Px88a30wkr7G0QUDbbtt2.png", "name": "Deutscher Filmförderfonds", "origin_country": "DE"}, {"id": 3389, "logo_path": "/ppNofD7TAGZPbCWqdRZL10D7Yg9.png", "name": "TV 2", "origin_country": "NO"}, {"id": 451, "logo_path": "/g1GRk1SdwxNwg5J3aXtrqTaXo8k.png", "name": "Medienboard Berlin-Brandenburg", "origin_country": "DE"}]
# [{"id": 2558, "logo_path": "None", "name": "P"Artisan Filmproduktion", "origin_country": ""}, {"id": 12955, "logo_path": "None", "name": "Zip Films", "origin_country": ""}, {"id": 2560, "logo_path": "None", "name": "KV Entertainment", "origin_country": ""}]
# [{"id": 1533, "logo_path": "/6ZdM1yg1LXtzS5zpuZPtZsn9YdA.png", "name": "Indigo Film", "origin_country": "IT"}, {"id": 779, "logo_path": "/KFFOFoztyjV5epvnW5GerPbcvx.png", "name": "Lucky Red", "origin_country": "IT"}, {"id": 103454, "logo_path": "None", "name": "Parco Film", "origin_country": ""}, {"id": 22393, "logo_path": "None", "name": "Babe Film", "origin_country": ""}, {"id": 694, "logo_path": "/5LEHONGkZBIoWvp1ygHOF8iyi1M.png", "name": "StudioCanal", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}, {"id": 21649, "logo_path": "/6Ji6E59Wt9O4VA6nqwAd6RW7ijs.png", "name": "Sky Cinema", "origin_country": "IT"}, {"id": 14016, "logo_path": "/snclwsIZQbgvqYCBJP8fqNlCA5y.png", "name": "MiBAC", "origin_country": "IT"}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 26261, "logo_path": "/thn5VXJ5JegdrtiJn7mFuV2NWB6.png", "name": "Film Commission Torino Piemonte", "origin_country": "IT"}, {"id": 20388, "logo_path": "None", "name": "Regione Campania", "origin_country": "IT"}, {"id": 20389, "logo_path": "None", "name": "Campania Film Commission", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}]
# [{"id": 89721, "logo_path": "None", "name": "Toons"N"Tales", "origin_country": "DE"}, {"id": 89722, "logo_path": "None", "name": "Amuse Films", "origin_country": ""}, {"id": 98751, "logo_path": "None", "name": "Dacodac", "origin_country": "RO"}]
# [{"id": 9081, "logo_path": "None", "name": "Phase 4 Films", "origin_country": ""}, {"id": 6724, "logo_path": "None", "name": "Upload Films", "origin_country": ""}, {"id": 12230, "logo_path": "None", "name": "Roberts/David Films", "origin_country": ""}, {"id": 55945, "logo_path": "None", "name": "Snappe" Production Company", "origin_country": ""}]
# [{"id": 17931, "logo_path": "None", "name": "Bridgit Folman Film Gang", "origin_country": "IL"}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 703, "logo_path": "/lMV4teVPQWJxIaiDsAsU7Vdh1iC.png", "name": "Razor Film Produktion", "origin_country": "DE"}]
# [{"id": 186, "logo_path": "/1xlcFvAz1PQIkMhO0pBLBPW4PWY.png", "name": "Pyramide Productions", "origin_country": "FR"}, {"id": 225, "logo_path": "/cmxkBc3dmwWaIHFCrkXZoAfGoOa.png", "name": "BIM Distribuzione", "origin_country": "IT"}, {"id": 27099, "logo_path": "None", "name": "Ministry of Culture and Tourism", "origin_country": ""}, {"id": 27100, "logo_path": "None", "name": "Zeynofilm", "origin_country": "TR"}, {"id": 27101, "logo_path": "None", "name": "NBC Film", "origin_country": ""}, {"id": 27102, "logo_path": "None", "name": "Conseil de l"Europe", "origin_country": ""}, {"id": 27103, "logo_path": "None", "name": "Imaj Sound Post Production", "origin_country": ""}, {"id": 27104, "logo_path": "None", "name": "Imaj", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}]
# [{"id": 24301, "logo_path": "None", "name": "Drugaya Kul"tura (DK) Produkt", "origin_country": ""}]
# [{"id": 93386, "logo_path": "None", "name": "Associazione Culturale "La fanciulla del Lago"", "origin_country": ""}, {"id": 54221, "logo_path": "None", "name": "Arsenali Medicei", "origin_country": ""}, {"id": 93387, "logo_path": "None", "name": "Intolerance", "origin_country": ""}]
# [{"id": 25, "logo_path": "/qZCc1lty5FzX30aOCVRBLzaVmcp.png", "name": "20th Century Fox", "origin_country": "US"}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 28788, "logo_path": "None", "name": "Genre Films", "origin_country": "US"}]
# [{"id": 73666, "logo_path": "None", "name": "Covert Media", "origin_country": "US"}, {"id": 1632, "logo_path": "/cisLn1YAUuptXVBa0xjq7ST9cH0.png", "name": "Lionsgate", "origin_country": "US"}, {"id": 90185, "logo_path": "None", "name": "BillBlock Media", "origin_country": "US"}, {"id": 11029, "logo_path": "/aEqqnFZjCW10ODE4TYQ1qkjvokr.png", "name": "QED International", "origin_country": "US"}, {"id": 1894, "logo_path": "None", "name": "Josephson Entertainment", "origin_country": ""}, {"id": 28200, "logo_path": "None", "name": "Ninjas Runnin" Wild Productions", "origin_country": "US"}]
# [{"id": 69987, "logo_path": "None", "name": "Uncork"d Entertainment", "origin_country": ""}, {"id": 83173, "logo_path": "None", "name": "I.D. Entertainment", "origin_country": ""}]
# [{"id": 91331, "logo_path": "/uYyo3szZqWKn5p2bfAXMXzqVo8.png", "name": "Main Journey", "origin_country": "CA"}, {"id": 6623, "logo_path": "/qvtEf5tM9IAEJUUhX9EcBl12Fhr.png", "name": "Caramel Films", "origin_country": "CA"}, {"id": 7038, "logo_path": "/9YDo78sKAy6xxqBwVBT2Vi9FSZl.png", "name": "Quad Productions", "origin_country": "FR"}, {"id": 76742, "logo_path": "/7DPDeTgKBiuiRUtX4VLQJo2ojpr.png", "name": "L"Atelier Animation", "origin_country": "CA"}]
# ...
# [{"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}, {"id": 95794, "logo_path": "None", "name": "Beauty Killed The Beast – Lenke & Weidenhöfer Filmproduktion GbR", "origin_country": ""}]
# [{"id": 17227, "logo_path": "None", "name": "L"espace Vision", "origin_country": ""}, {"id": 17228, "logo_path": "/7agfWcZa25AD8QKvSf9IbLlsQzA.png", "name": "T-JOY", "origin_country": "JP"}]
# [{"id": 29036, "logo_path": "None", "name": "Fog"n"Desire Films", "origin_country": "CZ"}, {"id": 487, "logo_path": "/x3BUIowxU2skXOpnOeOkl7kIYDo.png", "name": "Česká televize", "origin_country": "CZ"}, {"id": 118264, "logo_path": "None", "name": "K Film Plus", "origin_country": "CZ"}, {"id": 56779, "logo_path": "None", "name": "Sokol Kollár", "origin_country": "SK"}]
# [{"id": 8009, "logo_path": "/jMXTbZ35gAiHCjIfdDq1B7On9fv.png", "name": "Belgacom", "origin_country": "BE"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 11797, "logo_path": "/oeBCBsLLlIj2UNQBZZkhlPdDOJG.png", "name": "VOO", "origin_country": "BE"}, {"id": 11921, "logo_path": "/gqvfasbanyk8hIKDM2EVT6Sn2AO.png", "name": "Le Tax Shelter du Gouvernement Fédéral de Belgique", "origin_country": "BE"}, {"id": 12043, "logo_path": "None", "name": "Fonds Film in Vlaanderen", "origin_country": "BE"}, {"id": 17234, "logo_path": "/xGv8hlqyaQHIkZITB5FKlj7RCp1.png", "name": "Red Lion", "origin_country": "LU"}, {"id": 22071, "logo_path": "None", "name": "Mollywood", "origin_country": "BE"}, {"id": 24439, "logo_path": "None", "name": "Tobina Film", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 11776, "logo_path": "/33JMuTtwY5UhPwkmCEyH1YaCD23.png", "name": "Film Fund Luxembourg", "origin_country": "LU"}]
# [{"id": 34780, "logo_path": "None", "name": "Chi-Fou-Mi Productions", "origin_country": "FR"}, {"id": 6896, "logo_path": "/2Q89KvzxTKB5BAv9RqFIPI1qb7E.png", "name": "EuropaCorp", "origin_country": "FR"}, {"id": 591, "logo_path": "/q5I5RDwMEiqoNmfaJgd2LraEOJY.png", "name": "France 3 Cinéma", "origin_country": "FR"}, {"id": 3984, "logo_path": "/pvOBu9K0zTRuwJW7WII34x17kdz.png", "name": "Entre Chien et Loup", "origin_country": "BE"}, {"id": 82018, "logo_path": "None", "name": "Antilope Joyeuse", "origin_country": ""}, {"id": 7464, "logo_path": "None", "name": "Kiss Films", "origin_country": ""}, {"id": 7131, "logo_path": "/eLvjHPYZ12GR58lrDgg6MXZp2a3.png", "name": "France Télévisions", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 11246, "logo_path": "/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png", "name": "Région Ile-de-France", "origin_country": "FR"}, {"id": 11997, "logo_path": "None", "name": "BNP Paribas Fortis", "origin_country": "BE"}, {"id": 11245, "logo_path": "None", "name": "Agence Nationale pour la Cohésion Sociale et l"Egalité des Chances (ACSE)", "origin_country": ""}, {"id": 8009, "logo_path": "/jMXTbZ35gAiHCjIfdDq1B7On9fv.png", "name": "Belgacom", "origin_country": "BE"}, {"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 1145, "logo_path": "/995rL7XQxJiG4eE7gHYB82sO61S.png", "name": "Belga Films", "origin_country": "BE"}, {"id": 11797, "logo_path": "/oeBCBsLLlIj2UNQBZZkhlPdDOJG.png", "name": "VOO", "origin_country": "BE"}]
# [{"id": 60990, "logo_path": "None", "name": "MAMOKO Entertainment", "origin_country": "DE"}, {"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}]
# [{"id": 6960, "logo_path": "/trBnlOgJMYZrU4aOMGGvQdj51vj.png", "name": "Moteur s"il vous plaît", "origin_country": "FR"}, {"id": 20482, "logo_path": "/ncZtCy1XzmVeN674GNBDdvMc8b0.png", "name": "Iota Production", "origin_country": "BE"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 46111, "logo_path": "None", "name": "IBC MOvie", "origin_country": "IT"}, {"id": 7704, "logo_path": "None", "name": "Pupkin Production", "origin_country": "IT"}, {"id": 26261, "logo_path": "/thn5VXJ5JegdrtiJn7mFuV2NWB6.png", "name": "Film Commission Torino Piemonte", "origin_country": "IT"}, {"id": 114547, "logo_path": "None", "name": "Regione Piemonte", "origin_country": ""}, {"id": 22141, "logo_path": "None", "name": "Film Investment Piedmont (FIP)", "origin_country": ""}, {"id": 20648, "logo_path": "/lh17Uva8X5wPYZSBKh7CYXqlmFF.png", "name": "BNL - Gruppo BNP Paribas", "origin_country": "IT"}, {"id": 32837, "logo_path": "None", "name": "Film Commission Regione Valle d"Aosta", "origin_country": ""}, {"id": 1583, "logo_path": "/gKP4egMJOi5rksdnplfPV1wa0sd.png", "name": "RAI", "origin_country": "IT"}]
# [{"id": 48977, "logo_path": "None", "name": "Proaction", "origin_country": ""}, {"id": 48978, "logo_path": "None", "name": seen", "origin_country": ""}, {"id": 24518, "logo_path": "None", "name": "Dubai Film Market", "origin_country": "AE"}]
# [{"id": 32229, "logo_path": "None", "name": "Gallant Films", "origin_country": "US"}, {"id": 7315, "logo_path": "/pn1L5r75URMfY1XQB38NLKTlX3U.png", "name": "A&E IndieFilms", "origin_country": "US"}, {"id": 9038, "logo_path": "None", "name": "Far Hills Pictures", "origin_country": "US"}, {"id": 9039, "logo_path": "None", "name": "Stick "N" Stone Productions", "origin_country": "US"}]
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}]
# [{"id": 18588, "logo_path": "None", "name": "Motion Picture Public Foundation of Hungary", "origin_country": "HU"}, {"id": 8138, "logo_path": "/4P6c8TiJZhL2z7b0LbPOUTZwP4z.png", "name": "Vega Film", "origin_country": "CH"}, {"id": 9206, "logo_path": "None", "name": "Zero Fiction Film", "origin_country": ""}, {"id": 11011, "logo_path": "None", "name": "Fonds Eurimages du Conseil de l"Europe", "origin_country": "FR"}, {"id": 15424, "logo_path": "None", "name": "TT Filmmûhely", "origin_country": ""}, {"id": 53303, "logo_path": "None", "name": "Werc Werk Works", "origin_country": ""}, {"id": 73370, "logo_path": "None", "name": "Movie Partners In Motion Film", "origin_country": ""}, {"id": 451, "logo_path": "/g1GRk1SdwxNwg5J3aXtrqTaXo8k.png", "name": "Medienboard Berlin-Brandenburg", "origin_country": "DE"}]
# [{"id": 12393, "logo_path": "/aN7Pvcc1KWzJXtLsePQeQ86sBYE.png", "name": "Cinémage 5", "origin_country": "FR"}, {"id": 6301, "logo_path": "/jma8ZaHq1KAzlXW3v0RswVOWSdn.png", "name": "CinéCinéma", "origin_country": "FR"}, {"id": 7981, "logo_path": "/6Yv1gIAuGkHS5Vis4UjnqHhCPWV.png", "name": "Pathé", "origin_country": "FR"}, {"id": 8620, "logo_path": "None", "name": "A.S. Films", "origin_country": ""}, {"id": 8907, "logo_path": "None", "name": "Banque Postale Image 4", "origin_country": ""}, {"id": 11798, "logo_path": "None", "name": "Région Provence-Alpes-Côte d"Azur", "origin_country": ""}, {"id": 12394, "logo_path": "None", "name": "Cofimage 22", "origin_country": ""}, {"id": 20347, "logo_path": "None", "name": "Banque Populaire Images 11", "origin_country": ""}, {"id": 20349, "logo_path": "None", "name": "Uni Étoile 8", "origin_country": ""}, {"id": 26337, "logo_path": "None", "name": "Zack Films", "origin_country": ""}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 356, "logo_path": "/9tW5wZEGotn1Ei5pErA88m47XiD.png", "name": "TF1 Films Production", "origin_country": "FR"}]
# [{"id": 13693, "logo_path": "None", "name": "Swingin" Productions", "origin_country": ""}, {"id": 1020, "logo_path": "/kuUIHNwMec4dwOLghDhhZJzHZTd.png", "name": "Millennium Films", "origin_country": "US"}]
# [{"id": 8029, "logo_path": "None", "name": sharp 7 films", "origin_country": ""}, {"id": 8031, "logo_path": "/cwqjz3XBu0fEtTLpHDlNANddbTU.png", "name": "Isotope Films", "origin_country": "US"}]
# [{"id": 29137, "logo_path": "None", "name": "Scrambled Eggs Productions", "origin_country": ""}, {"id": 29138, "logo_path": "None", "name": "And They"re Off...", "origin_country": ""}]
# [{"id": 2783, "logo_path": "/nxQjhLzml7CSWRAOiyo4yG0GCEY.png", "name": "Motlys", "origin_country": "NO"}, {"id": 49936, "logo_path": "None", "name": "Don"t Look Now", "origin_country": ""}, {"id": 16551, "logo_path": "/8VlPbyw3BoflxIDGkyUiQnEaair.png", "name": "Norsk Filminstitutt", "origin_country": "NO"}]
# [{"id": 29201, "logo_path": "/93Cu4sHMvJLgCwk9wpQY5xrb3XA.png", "name": "Les Films de L"Autre", "origin_country": "CA"}, {"id": 14683, "logo_path": "None", "name": "Ciné-Tamaris", "origin_country": "FR"}, {"id": 10611, "logo_path": "/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png", "name": "Ciné+", "origin_country": "FR"}, {"id": 851, "logo_path": "None", "name": "MEDIA Programme of the European Union", "origin_country": ""}, {"id": 78986, "logo_path": "None", "name": "Fondation Groupama Gan pour le Cinéma", "origin_country": ""}, {"id": 26606, "logo_path": "None", "name": "Région des Pays-de-la-Loire", "origin_country": ""}, {"id": 310, "logo_path": "/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png", "name": "CNC", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}, {"id": 94, "logo_path": "/huC7HqorvUThGIrENrbcHmQVUA0.png", "name": "ARTE France Cinéma", "origin_country": "FR"}]
# [{"id": 15197, "logo_path": "None", "name": "Loin Derrière L"Oural", "origin_country": ""}, {"id": 6301, "logo_path": "/jma8ZaHq1KAzlXW3v0RswVOWSdn.png", "name": "CinéCinéma", "origin_country": "FR"}, {"id": 104, "logo_path": "/9aotxauvc9685tq9pTcRJszuT06.png", "name": "Canal+", "origin_country": "FR"}]
# [{"id": 11796, "logo_path": "/tx6LOQcTSqgW8ffKxovuJHjlYVw.png", "name": "Centre du Cinéma et de l"Audiovisuel de la Fédération Wallonie-Bruxelles", "origin_country": "BE"}, {"id": 3040, "logo_path": "/25t2aPa5uNerf9Pq5cLUsYhs8ZA.png", "name": "Versus Production", "origin_country": "BE"}]
# [{"id": 60804, "logo_path": "/eyXvY18fl5I1JQjBAsyE7vwYc9h.png", "name": "Les Films d"Avalon", "origin_country": "FR"}, {"id": 76710, "logo_path": "None", "name": "Mördred Films", "origin_country": ""}, {"id": 76711, "logo_path": "None", "name": "Dark Factory", "origin_country": ""}, {"id": 76712, "logo_path": "None", "name": "Cosmodigital", "origin_country": ""}]
# [{"id": 6104, "logo_path": "/dQTIRYC5DMz9N4lZpCOfJQzONlq.png", "name": "Universal Production Partners", "origin_country": "CZ"}, {"id": 29036, "logo_path": "None", "name": "Fog"n"Desire Films", "origin_country": "CZ"}, {"id": 487, "logo_path": "/x3BUIowxU2skXOpnOeOkl7kIYDo.png", "name": "Česká televize", "origin_country": "CZ"}, {"id": 56779, "logo_path": "None", "name": "Sokol Kollár", "origin_country": "SK"}, {"id": 119331, "logo_path": "None", "name": "Samastinor", "origin_country": "CZ"}, {"id": 5926, "logo_path": "None", "name": "Slovenská televízia", "origin_country": "SK"}]
# [{"id": 8373, "logo_path": "None", "name": "Kinokompaniya "Kvadrat"", "origin_country": ""}, {"id": 102465, "logo_path": "None", "name": "Square Film Company", "origin_country": "RU"}]
# [{"id": 19673, "logo_path": "None", "name": "Hochschule für Film und Fernsehen "Konrad Wolf"", "origin_country": ""}, {"id": 38482, "logo_path": "/9YTCqFY9UonkrW01nMXF1Rpejvs.png", "name": "Mafilm", "origin_country": "DE"}, {"id": 4606, "logo_path": "/otZHbf1HmzLRQsZFSqJXkf8EHz7.png", "name": "ZDF", "origin_country": "DE"}]
# [{"id": 88412, "logo_path": "None", "name": "Les Films de L"Etranger", "origin_country": "FR"}]
# [{"id": 1410, "logo_path": "None", "name": "Tag/Traum Filmproduktion", "origin_country": ""}, {"id": 76921, "logo_path": "/2r3bPkN23MRdAD1iaTKVfK8NtEQ.png", "name": "Les Films d"ici", "origin_country": "FR"}, {"id": 101459, "logo_path": "None", "name": "Prounen Film", "origin_country": "DE"}]
# [{"id": 5688, "logo_path": "None", "name": "Xi"an Qujian Film &  TV Investment Group Company", "origin_country": ""}]
# [{"id": 40752, "logo_path": "None", "name": "Don"t Go There Productions", "origin_country": ""}, {"id": 40753, "logo_path": "None", "name": "DreamQuest Entertainment", "origin_country": ""}]
# [{"id": 75068, "logo_path": "None", "name": "Yif"at Prestelnik Films", "origin_country": ""}, {"id": 24477, "logo_path": "None", "name": "Rabinovich Film Fund Cinema Project", "origin_country": "IL"}, {"id": 16, "logo_path": "/7690NQfOfnbvrY3vFgyMO2Pc8WS.png", "name": "United King Films", "origin_country": "IL"}]
# [{"id": 32837, "logo_path": "None", "name": "Film Commission Regione Valle d"Aosta", "origin_country": ""}, {"id": 2534, "logo_path": "None", "name": "Colorado Film", "origin_country": "IT"}]
# [{"id": 1038, "logo_path": "/o62j8ZNXmRTrq6ThviFWiL9zb8J.png", "name": "Bazelevs Production", "origin_country": "RU"}, {"id": 8910, "logo_path": "None", "name": "Animation Studio "Petersburg"", "origin_country": "RU"}]
# [{"id": 54635, "logo_path": "None", "name": "Reelin" in the Years", "origin_country": ""}, {"id": 214, "logo_path": "/qIptM4dZBNflgv2OXzYECv8iQNH.png", "name": "Eagle Vision", "origin_country": "GB"}, {"id": 22642, "logo_path": "/gqFSMOsv68FkYalHrKbUvq3pGwh.png", "name": "Ina", "origin_country": "FR"}]
# [{"id": 16450, "logo_path": "None", "name": "Filmes do Tejo", "origin_country": "PT"}, {"id": 6669, "logo_path": "None", "name": "Les Films de l"Après-Midi", "origin_country": "FR"}]
# [{"id": 16791, "logo_path": "None", "name": "Newman/Tooley Films", "origin_country": ""}, {"id": 37103, "logo_path": "None", "name": ""DIA" Productions GmbH & Co. KG", "origin_country": ""}, {"id": 21975, "logo_path": "None", "name": "Joseph Nittolo Entertainment", "origin_country": ""}, {"id": 12, "logo_path": "/iaYpEp3LQmb8AfAtmTvpqd4149c.png", "name": "New Line Cinema", "origin_country": "US"}]
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 9168, "logo_path": "/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png", "name": "Bad Hat Harry Productions", "origin_country": "US"}]
# [{"id": 4, "logo_path": "/gz66EfNoYPqHTYI4q9UEN4CbHRc.png", "name": "Paramount", "origin_country": "US"}, {"id": 762, "logo_path": "None", "name": "Mutual Film Company", "origin_country": ""}, {"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}, {"id": 18619, "logo_path": "None", "name": "Cobalt Media Group", "origin_country": ""}, {"id": 18620, "logo_path": "None", "name": "Artists Production Group (APG)", "origin_country": ""}]
# [{"id": 7943, "logo_path": "None", "name": "Mascaret Films", "origin_country": ""}, {"id": 1523, "logo_path": "None", "name": "Ciné Valse", "origin_country": ""}, {"id": 5757, "logo_path": "None", "name": "P"Artisan Filmproduktion GmbH", "origin_country": ""}, {"id": 260, "logo_path": "None", "name": "Heritage Films", "origin_country": "PL"}]
# [{"id": 79751, "logo_path": "None", "name": "Sidecar Films & TV", "origin_country": ""}, {"id": 97958, "logo_path": "None", "name": "L"Ottava", "origin_country": ""}]
# [{"id": 33290, "logo_path": "None", "name": "Livin" Man Productions", "origin_country": ""}]
# [{"id": 141687, "logo_path": "None", "name": "Cine L"Mod Productions", "origin_country": ""}]
# [{"id": 61370, "logo_path": "None", "name": "Grupong Sinehan", "origin_country": ""}, {"id": 131854, "logo_path": "None", "name": "Up Cineastes" Studio", "origin_country": ""}]
# [{"id": 50458, "logo_path": "/kJr7qaViqRAKVWqgHuGSq8Bgc8p.png", "name": "Pink"O", "origin_country": "IT"}]

# %%
df['production_company_list'].isna().sum() / len(df)
# Out:
# 0.006262994757452453

# %%
edge_case = df.loc[df['production_companies'].str.contains("Donner"),'production_companies'].index#.iloc[0]
edge_case
# Out:
# Int64Index([   66,   466,  1023,  8292, 14047, 14362, 16771, 17416, 28453,
#             41839, 57045, 62114, 62179, 65211, 67553, 68679, 73284, 77021,
#             77054],
#            dtype='int64')

# %%
donner_ids = [ 66,  466, 1023,  298,   42,  357,   76,  721,   18, 2975,  452,
              47,  112,  125,  482,  150,  221,  141,  174]
donner_ids
# Out:
# [66,
#  466,
#  1023,
#  298,
#  42,
#  357,
#  76,
#  721,
#  18,
#  2975,
#  452,
#  47,
#  112,
#  125,
#  482,
#  150,
#  221,
#  141,
#  174]

# %%
df.loc[donner_ids[0], 'production_companies']
# Out:
# '[{\'id\': 431, \'logo_path\': None, \'name\': "The Donners\' Company", \'origin_country\': \'US\'}]'

# %%
get_company_name(df.loc[donner_ids[0], 'production_companies'])
# Out:
# [{"id": 431, "logo_path": "None", "name": "The Donners" Company", "origin_country": "US"}]

# %% [markdown]
# - Issue with company names that include an apostrophe.

# %%
pd.set_option('display.max_colwidth',300)

# %%
df[df['production_company_list'].isna()]['production_companies']
# Out:
# 66                                                                                                                                                                                                                          [{'id': 431, 'logo_path': None, 'name': "The Donners' Company", 'origin_country': 'US'}]
# 207      [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}, {'id': 122638, 'logo_path': None, 'name': "République de Côte d'Ivoire", 'origin_country': ''}, {'id': 13542, 'logo_path': '/sJ0R9LDMGR5ildYS4GMhQcbKJVD.png', 'name': 'CNRS Images'...
# 399      [{'id': 83, 'logo_path': '/9OQ0rm55xtlgX7KcAKMUePJSrQc.png', 'name': 'France 2 Cinéma', 'origin_country': 'FR'}, {'id': 4045, 'logo_path': None, 'name': 'Cinegram', 'origin_country': 'GR'}, {'id': 23495, 'logo_path': None, 'name': 'Titania Produzioni', 'origin_country': 'IT'}, {'id': 98757, 'log...
# 466      [{'id': 1088, 'logo_path': '/9WOE5AQUXbOtLU6GTwfjS8OMF0v.png', 'name': 'Alcon Entertainment', 'origin_country': 'US'}, {'id': 10405, 'logo_path': None, 'name': 'EFO Films', 'origin_country': 'US'}, {'id': 890, 'logo_path': None, 'name': 'Cheyenne Enterprises', 'origin_country': ''}, {'id': 10885...
# 695      [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png', 'name': 'Canal+', 'origin_country': 'FR'}, {'id': 113973, 'logo_path': None, 'name': 'Ciné Cinéma', 'origin_country': 'FR'}, {'id': 591, 'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png', 'name': 'France 3 Cinéma', 'origin_country': 'FR...
#                                                                                                                                                             ...
# 77733                                                                                                                                             [{'id': 79751, 'logo_path': None, 'name': 'Sidecar Films & TV', 'origin_country': ''}, {'id': 97958, 'logo_path': None, 'name': "L'Ottava", 'origin_country': ''}]
# 77875                                                                                                                                                                                                                     [{'id': 33290, 'logo_path': None, 'name': "Livin' Man Productions", 'origin_country': ''}]
# 78042                                                                                                                                                                                                                    [{'id': 141687, 'logo_path': None, 'name': "Cine L'Mod Productions", 'origin_country': ''}]
# 78159                                                                                                                                   [{'id': 61370, 'logo_path': None, 'name': 'Grupong Sinehan', 'origin_country': ''}, {'id': 131854, 'logo_path': None, 'name': "Up Cineastes' Studio", 'origin_country': ''}]
# 78386                                                                                                                                                                                                     [{'id': 50458, 'logo_path': '/kJr7qaViqRAKVWqgHuGSq8Bgc8p.png', 'name': "Pink'O", 'origin_country': 'IT'}]
# Name: production_companies, Length: 491, dtype: object

# %% [markdown]
# #### Explode & Separate

# %%
df_explode = df.explode('production_company_list')
df_explode
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#          budget  \
# 0        100000
# 1             0
# 2             0
# 3      76000000
# 3      76000000
# ...         ...
# 78392         0
# 78393         0
# 78394         0
# 78395         0
# 78396       400
#
#                                                                                                                                                                       genres  \
# 0                                                                                                                                                                         []
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                            [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# ...                                                                                                                                                                      ...
# 78392                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78393                                                                           [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}, {'id': 18, 'name': 'Drama'}]
# 78394                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78395                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78396                                                                                                         [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
#
#                                                                         homepage  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                  http://www.universalstudiosentertainment.com/children-of-men/
# 3                  http://www.universalstudiosentertainment.com/children-of-men/
# ...                                                                          ...
# 78392                                              http://icarusfilms.com/if-cli
# 78393                                                                        NaN
# 78394  https://www.michaelraeburn.com/site/web/mr/zimbabwe-countdown_documentary
# 78395                                                                        NaN
# 78396                                                                        NaN
#
#            id    imdb_id original_language                 original_title  \
# 0       30356  tt0144280                en  Whispers from a Shallow Grave
# 1       58520  tt0197633                en         Live Freaky Die Freaky
# 2      459563  tt0204250                en          Death of a Saleswoman
# 3        9693  tt0206634                en                Children of Men
# 3        9693  tt0206634                en                Children of Men
# ...       ...        ...               ...                            ...
# 78392  387250  tt7098636                fr   Le Clitoris, ce cher inconnu
# 78393  640680  tt7246872                en         Tokyo Bedoone Tavaghof
# 78394  515137  tt7637550                en             Zimbabwe Countdown
# 78395  713681  tt9414698                en                   The Hot Shoe
# 78396  253999  tt9641790                en                     Clearwater
#
#                                                                                                                                                                                                                                                                                                           overview  \
# 0                                                                                                                                                            When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                            It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2      Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                                   In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 3                                                                   In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  Topics about female sexuality are growing in popularity. Magazines and talk shows all discuss it. Yet a fair percentage of women are said to suffer from female sexual dysfunction. While male sexual problems have traditionally received the most publicity, only recently has research begun into the...
# 78393                                                                                                                                                                                                                                                                                                          NaN
# 78394                                                                                                                                                                       Once touted as Zimbabwe's saviour, Robert Mugabe has become synonymous with bad government and misrule. But where did it all go wrong?
# 78395                                                                                                                          A Documentary Movie About Card Counting In The Casino Game of 21. The director used $5,000 of the movie's budget to learn the counting methods, and put them to the test on screen.
# 78396                                                                                                                                                                                   A woman has been abducted by the Clearwater killer, and it's down to one man to solve the murderer's clues and rescue her.
#
#        popularity                       poster_path  \
# 0           0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1           1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2           0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# ...           ...                               ...
# 78392       1.400  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393       0.600  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394       0.711  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395       0.600                               NaN
# 78396       2.744  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                                                                                                                                                                                                                                                                               production_companies  \
# 0                                                                                                                                                                                                                                                                                                               []
# 1                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                   [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3               [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 3               [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cats & Dogs Films', 'origin_country': 'FR'}, {'id': 7106, 'logo_path': None, 'name': 'Sylicone', 'origin_country': 'FR'}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 639, 'logo_path': '/fN...
# 78393                                                                                                                                                                                                                                                                                                           []
# 78394                                                                                                                                                                                          [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}]
# 78395                                                                                                                                                                                                                                                                                                           []
# 78396                                                                                                                                                                                                                   [{'id': 174685, 'logo_path': None, 'name': 'Little Buster Studios', 'origin_country': ''}]
#
#                                                                                              production_countries  \
# 0                                                      [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                      [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                      [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# ...                                                                                                           ...
# 78392                                                                    [{'iso_3166_1': 'FR', 'name': 'France'}]
# 78393                                                                      [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 78394                          [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'ZW', 'name': 'Zimbabwe'}]
# 78395                                                                                                          []
# 78396                                                                                                          []
#
#       release_date   revenue  runtime  \
# 0       1997-01-01         0     90.0
# 1       2006-01-31         0     75.0
# 2       2006-09-18         0     77.0
# 3       2006-09-22  70595464    109.0
# 3       2006-09-22  70595464    109.0
# ...            ...       ...      ...
# 78392   2004-01-16         0     60.0
# 78393   2003-09-10         0     98.0
# 78394   2003-08-28         0     55.0
# 78395   2003-01-01         0     96.0
# 78396   2003-06-10         0     60.0
#
#                                                           spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                    ...
# 78392  [{'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}]
# 78393    [{'english_name': 'Persian', 'iso_639_1': 'fa', 'name': 'فارسی'}]
# 78394  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78395  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78396  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#          status  \
# 0      Released
# 1      Released
# 2      Released
# 3      Released
# 3      Released
# ...         ...
# 78392  Released
# 78393  Released
# 78394  Released
# 78395  Released
# 78396  Released
#
#                                                                 tagline  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2      6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                     The future's a thing of the past.
# 3                                     The future's a thing of the past.
# ...                                                                 ...
# 78392                                                               NaN
# 78393                                                               NaN
# 78394                                                               NaN
# 78395                                                               NaN
# 78396                                                               NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 3                       Children of Men  False           7.6        5794
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification     production_company_list
# 0               NaN                         NaN
# 1                NR                         NaN
# 2               NaN  Girl Next Door Productions
# 3                 R          Universal Pictures
# 3                 R        Strike Entertainment
# ...             ...                         ...
# 78392           NaN                Angoa-Agicoa
# 78393           NaN                         NaN
# 78394           NaN          ARTE France Cinéma
# 78395           NaN                         NaN
# 78396           NaN       Little Buster Studios
#
# [138213 rows x 27 columns]

# %%
## save unique genres
unique_companies = sorted(df_explode['production_company_list'].dropna().unique())
len(unique_companies)
# Out:
# 39872

# %%
company_map = dict(zip(unique_companies, range(len(unique_companies))))
company_map
# Out:
# {'# Andrea Sperling Productions': 0,
#  '#Beardforce Films': 1,
#  '#Sinning Works': 2,
#  '#littlesecretfilm': 3,
#  '(주)라인필름': 4,
#  '(주)유비컬쳐': 5,
#  '(주)유비콘텐츠': 6,
#  '+Magenta': 7,
#  '.40 Caliber': 8,
#  '.Mille et Une. Films.': 9,
#  '.hack Conglomerate': 10,
#  '0': 11,
#  '01 Distribution': 12,
#  '011 Productions': 13,
#  '011Films': 14,
#  '02 Filmes': 15,
#  '0708 Films': 16,
#  '1 Bullet in the Gun Productions': 17,
#  '1 Media Productions': 18,
#  '1 Production Film': 19,
#  '1+1 Production': 20,
#  '1-2-3 Production': 21,
#  '1.85 Films': 22,
#  '10 Below Films': 23,
#  '10 Cates Pictures': 24,
#  '10 East Pictures': 25,
#  '10 West Studios': 26,
#  '10-13 Productions': 27,
#  '10.80 Films': 28,
#  '100': 29,
#  '100 Bares': 30,
#  '100 Feet Productions': 31,
#  '100 Year Films': 32,
#  '100 doo': 33,
#  '100% Entertainment': 34,
#  '100% Halal': 35,
#  '1000 Volt': 36,
#  '100th Monkey Films': 37,
#  '101 Films': 38,
#  '101 Studios': 39,
#  '1019 Entertainment': 40,
#  '1019 Pictures': 41,
#  '102 Distribution': 42,
#  '1024 FILM': 43,
#  '1031 Films': 44,
#  '104 Films': 45,
#  '1066 Pictures': 46,
#  '108 Media': 47,
#  '108 Productions': 48,
#  '1091': 49,
#  '1091 Media': 50,
#  '1091 Pictures': 51,
#  '10:15! Productions': 52,
#  '10X Productions': 53,
#  '10th Hole Productions': 54,
#  '10th Street Entertainment': 55,
#  '11 Marzo Film': 56,
#  '1121 Productions': 57,
#  '1171 Production Group': 58,
#  '11:11 Entertainment': 59,
#  '11:11 Mediaworks': 60,
#  '12 A.M. Pictures': 61,
#  '120 Films': 62,
#  '120 Over 80': 63,
#  '1201 Pictures': 64,
#  '120E Films': 65,
#  '120dB Films': 66,
#  '1211 Woodlake Pictures presents': 67,
#  '1212 Entertainment': 68,
#  '1230 Manhattan': 69,
#  '1244': 70,
#  '127 Wall': 71,
#  '12th Street Productions': 72,
#  '13 All Stars LLC': 73,
#  '13 Conejos': 74,
#  '13 Entertainment': 75,
#  '13 Films': 76,
#  '13 Ghosts Productions Canada Inc.': 77,
#  '13 Moons Productions LLC': 78,
#  '13 Motion Pictures': 79,
#  '13 Paces': 80,
#  '13 Productions': 81,
#  '13 TV': 82,
#  '130K Frames': 83,
#  '1366 Films': 84,
#  '137 Films': 85,
#  '13th Studio, The': 86,
#  '14 Pies': 87,
#  '14 Reels Entertainment': 88,
#  '14 Reels Plus': 89,
#  '14-18 NOW': 90,
#  '1405 comunicaciones': 91,
#  '141 Entertainment': 92,
#  '1428 Films': 93,
#  '1492 Pictures': 94,
#  '14ème Art Production': 95,
#  '15 in the Dark': 96,
#  '1500 Entertainment': 97,
#  '1518 Films': 98,
#  '152 WEST Productions': 99,
#  '1618 Action Limited': 100,
#  '16:14 Entertainment': 101,
#  '17 Road': 102,
#  '17-28 Black Production': 103,
#  '1718 Studio': 104,
#  '18 Reels': 105,
#  '180 Degrees': 106,
#  '1804 Productions': 107,
#  '1812 Productions': 108,
#  '1821 Pictures': 109,
#  '185 Films': 110,
#  '185 Trax': 111,
#  '185º Equator': 112,
#  '1891 Productions': 113,
#  '1895 Films': 114,
#  '18th Street Films': 115,
#  '19 Entertainment': 116,
#  '1922 Films': 117,
#  '19340 Productions': 118,
#  '1976 Productions': 119,
#  '1984 Pictures': 120,
#  '1984 Private Defense Contractors': 121,
#  '1991 Broadway Theatre Group': 122,
#  '1991 Productions': 123,
#  '19th & Wilson': 124,
#  '19th Floor Productions': 125,
#  '1A Productions': 126,
#  '1AMDC Productions, LLC': 127,
#  '1Tentertainment': 128,
#  '1inMM Productions': 129,
#  '1st Boll Kino Beteiligungs GmbH and Co. KG': 130,
#  '1st Wave Productions': 131,
#  '1stAveMachine': 132,
#  '2 A.M. Productions': 133,
#  '2 Bridges Productions': 134,
#  '2 Cities Productions': 135,
#  '2 Crackers and a Lamp Productions': 136,
#  '2 Die 4 Films': 137,
#  '2 Entertain': 138,
#  '2 Focus': 139,
#  '2 Friends Media': 140,
#  '2 Loop Films': 141,
#  '2 Man Production': 142,
#  '2 Minutes': 143,
#  '2 Player Productions': 144,
#  '2 Red Rabbit Films': 145,
#  '2 Weeks Notice': 146,
#  '2 Wolves Films': 147,
#  '2 Wonder Full To Be': 148,
#  '2-G Multi-Media': 149,
#  '2-Team Productions': 150,
#  '2.0 Entertainment': 151,
#  '2.4.7. Films': 152,
#  '20 Max Films': 153,
#  '20 Minuten 20 Minutes 20 Minuti': 154,
#  '20 Steps Productions': 155,
#  '20/20': 156,
#  '20/20 Visions Entertainment Group': 157,
#  '200 NotOut Productions': 158,
#  '2000 Bilder': 159,
#  '2003 Productions': 160,
#  '2015 Project Love Live Movie': 161,
#  '2050 Productions': 162,
#  '2076 Kolektib': 163,
#  '2077883 Ontario': 164,
#  '20ten Media': 165,
#  '20th Century Animation': 166,
#  '20th Century Fox': 167,
#  '20th Century Fox Animation': 168,
#  '20th Century Fox Argentina': 169,
#  '20th Century Fox Brazil': 170,
#  '20th Century Fox Home Entertainment': 171,
#  '20th Century Fox Korea': 172,
#  '20th Century Fox Russia': 173,
#  '20th Century Fox Television': 174,
#  '20th Century Studios': 175,
#  '21 Balloons Productions': 176,
#  '21 Century Shengkai Film': 177,
#  '21 Laps Entertainment': 178,
#  '21 One Productions': 179,
#  '21/31 Productions': 180,
#  '211 Productions': 181,
#  '212 BERLIN': 182,
#  '212 Productions': 183,
#  '21juin Cinema': 184,
#  '21kin.com': 185,
#  '21st Century': 186,
#  '21st Century 3D': 187,
#  '21st Century DreamQuest Films': 188,
#  '21st Century Film Production': 189,
#  '22 & Green': 190,
#  '22 & Indiana Pictures': 191,
#  '22 Hours Films': 192,
#  '221 Films': 193,
#  '222 Productions': 194,
#  '224 Entertainment': 195,
#  '2262730 Ontario': 196,
#  '22DOGS': 197,
#  '22h22': 198,
#  '22six Productions': 199,
#  '23 Feet': 200,
#  '23 Hues Entertainment': 201,
#  '23 Productions': 202,
#  '23/5 Filmproduktion': 203,
#  '235 Films': 204,
#  '23rd Street Films': 205,
#  '23ten': 206,
#  '24 25 Films': 207,
#  '24 Frames Factory': 208,
#  '24 Mai Production': 209,
#  '24 Media Production Company': 210,
#  '24/7 Films': 211,
#  '24:25 Films': 212,
#  '24AM Studios': 213,
#  '24MEDIA': 214,
#  '24TL Productions': 215,
#  '24fs Chitra': 216,
#  '24images': 217,
#  '25 Film': 218,
#  '25 Laps': 219,
#  '25-One Productions': 220,
#  '2500 entertainment': 221,
#  '2506 Sinema': 222,
#  '25th Frame': 223,
#  '26 Company': 224,
#  '26 Films': 225,
#  '26 Keys Productions': 226,
#  '260 Degrees Entertainment': 227,
#  '26DB Productions': 228,
#  '27 Films Production': 229,
#  '27 Producciones': 230,
#  '27 Productions': 231,
#  '27 Ten Productions': 232,
#  '28 Entertainment': 233,
#  '28 Productions': 234,
#  '282 Studios': 235,
#  '29 Libran Films': 236,
#  '2920 Entertainment': 237,
#  '2929 Entertainment': 238,
#  '2929 Productions': 239,
#  '29P Films': 240,
#  '29Pictures': 241,
#  '29th February Film Company': 242,
#  '2:1 Film': 243,
#  '2:59 Films': 244,
#  '2B Films': 245,
#  '2B Productions': 246,
#  '2CFilm': 247,
#  '2D Celluloid': 248,
#  '2D Entertainment': 249,
#  '2DS Productions': 250,
#  '2DUX²': 251,
#  '2Feet Entertainment': 252,
#  '2Könige Filmproduktion': 253,
#  '2L Productions': 254,
#  '2Mr Films': 255,
#  '2Pilots Filmproduction': 256,
#  '2Plan2': 257,
#  '2R Productions': 258,
#  '2S Films': 259,
#  '2afilm': 260,
#  '2am': 261,
#  '2am Films': 262,
#  '2btube': 263,
#  '2d3D Animations': 264,
#  '2mCine': 265,
#  '2nd Nature Films': 266,
#  '2nd Try LLC.': 267,
#  '2|35': 268,
#  '3 Arts Entertainment': 269,
#  '3 Bean Productions': 270,
#  '3 Daughters Films': 271,
#  '3 Dogs & a Pony': 272,
#  '3 Doubles Producciones': 273,
#  '3 Faces Films': 274,
#  '3 Generations': 275,
#  '3 Legged Dog Films': 276,
#  '3 Marys Entertainment': 277,
#  '3 Men in a Tub Productions': 278,
#  '3 Moinhos Produções Artísticas': 279,
#  '3 Ng Film': 280,
#  '3 Ring Circus Films': 281,
#  '3 Spears Pty. Ltd.': 282,
#  '3 Wall Productions': 283,
#  '3 in the Box': 284,
#  '3 minutes West': 285,
#  '3, 4 Women Productions': 286,
#  '3-D Film Archive': 287,
#  '3-Dimension Films': 288,
#  '3-H Films': 289,
#  '30 Bones Cinema': 290,
#  '30 Pictures': 291,
#  '30 Something Productions': 292,
#  '300 & Co.': 293,
#  '305 Media Group': 294,
#  '308 Enterprises': 295,
#  '30WEST': 296,
#  '31 Juin Films': 297,
#  '310 Studios': 298,
#  '315 Films': 299,
#  '316 Productions': 300,
#  '321 Films': 301,
#  '3210 Films': 302,
#  '33 Degrees': 303,
#  '33 Pictures': 304,
#  '3311 Productions': 305,
#  '333 Experience': 306,
#  '3332472 Nova Scotia': 307,
#  '33andOut Productions': 308,
#  '34 Filmes': 309,
#  '341 House Productions': 310,
#  '341Production': 311,
#  '343 Industries': 312,
#  '344 Productions': 313,
#  '34th Street Films': 314,
#  '360 Film Group': 315,
#  '360 Pictures': 316,
#  '365 Film Group': 317,
#  '369 Productions': 318,
#  '371 Productions': 319,
#  '377 Films': 320,
#  '3807 Productions': 321,
#  '388 Studios': 322,
#  '39 Steps': 323,
#  '39Films': 324,
#  '3:00 am Productions': 325,
#  '3:1 Cinema': 326,
#  '3:16 Productions': 327,
#  '3:41am': 328,
#  '3:59': 329,
#  '3B Productions': 330,
#  '3B Studios': 331,
#  '3Beep': 332,
#  '3BlackDot': 333,
#  '3Brane Entertainment': 334,
#  '3C Films Group': 335,
#  '3D Animagics Entertainment': 336,
#  '3D Content Hub': 337,
#  '3D Entertainment': 338,
#  '3D Produzioni': 339,
#  '3D Safari LC': 340,
#  '3D Video System': 341,
#  '3DD Productions': 342,
#  '3F': 343,
#  '3Foot7': 344,
#  '3Frogs Productions': 345,
#  '3H Productions': 346,
#  '3L Filmproduktion GmbH': 347,
#  '3L Filmverleih': 348,
#  '3L Productions': 349,
#  '3Mark Entertainment': 350,
#  '3Pas Studios': 351,
#  '3QU Media': 352,
#  '3Roundburst Productions': 353,
#  '3YFILM': 354,
#  '3ality Digital Entertainment': 355,
#  '3am Cinematic Escapes': 356,
#  '3am Entertainment': 357,
#  '3bros Film': 358,
#  '3dar': 359,
#  '3dot Productions': 360,
#  '3leven': 361,
#  '3paw Pictures': 362,
#  '3rd Coast Digital Films': 363,
#  '3rd Films': 364,
#  '3rd Identity Films': 365,
#  '3rd Monkey Productions': 366,
#  '3rd Partner Productions': 367,
#  '3rd Shift Media': 368,
#  '3rd Vision Films': 369,
#  '3sat': 370,
#  '3x7 production': 371,
#  '3xMedia': 372,
#  '4 1/2': 373,
#  '4 Cats Pictures': 374,
#  '4 Film': 375,
#  '4 Leagues Media': 376,
#  '4 Proof Film': 377,
#  '4 Reel Productions': 378,
#  '4 Rocket Surgeons': 379,
#  '4 Rooms': 380,
#  '4 à 4 Productions': 381,
#  '40 Acres & A Mule Filmworks': 382,
#  '40 Acres and a Mule Filmworks': 383,
#  '40 Below Films': 384,
#  '400 Blows Production': 385,
#  '400 Filmes': 386,
#  '403 Productions': 387,
#  '4045 Films': 388,
#  '408 Films': 389,
#  '415 Project': 390,
#  '419 Productions': 391,
#  '42': 392,
#  '42 Films': 393,
#  '42 Km Film': 394,
#  '42 Productions': 395,
#  '424 Post': 396,
#  '4248 Productions': 397,
#  '42ND street films': 398,
#  '42film': 399,
#  '42nd Pictures': 400,
#  '42nd Street Productions': 401,
#  '430 Productions': 402,
#  '435 Films': 403,
#  '44 Filmes': 404,
#  '44 Toons': 405,
#  '441 Films': 406,
#  '44th Floor Productions': 407,
#  '454 Productions': 408,
#  '455 Films': 409,
#  '47ème Parallèle': 410,
#  '48 Days Film Project': 411,
#  '480 Films': 412,
#  '49 Film': 413,
#  '49th Parallel Films': 414,
#  '4:02 PRODUCTIONS': 415,
#  '4AM Film Studios': 416,
#  '4Cows': 417,
#  '4DH Films': 418,
#  '4Digital Media': 419,
#  '4Film': 420,
#  '4G Vision': 421,
#  '4Go West Productions': 422,
#  '4Horsemen Films': 423,
#  '4Js Cinema': 424,
#  '4K ULTRA HD Movies': 425,
#  '4Kids Entertainment': 426,
#  '4L': 427,
#  '4LAP Films': 428,
#  '4M': 429,
#  '4P Pictures': 430,
#  '4PIX': 431,
#  '4k Films': 432,
#  '4th & Alameda Picture Company': 433,
#  '4th Pearl Productions, LLC': 434,
#  '4th Row Films': 435,
#  '4th Vertical Productions': 436,
#  '4th Wall Entertainment': 437,
#  '4th Wall Productions, LLC': 438,
#  '4½': 439,
#  '5 Child Productions': 440,
#  '5 Hole Productions': 441,
#  '5 London Films': 442,
#  '5 Name Films': 443,
#  '5 Nen D Gumi': 444,
#  '5 Star Productions': 445,
#  '5 States': 446,
#  '5-Second Films': 447,
#  '50 Eggs': 448,
#  '50/50 Films': 449,
#  '50/50 Films DC': 450,
#  '5000 Broadway Productions': 451,
#  '501 Pictures': 452,
#  '501st Joint Fighter Wing': 453,
#  '51 Entertainment': 454,
#  '51 Minds Entertainment': 455,
#  '51/50 Films': 456,
#  '512K Entertainment': 457,
#  '5150 Action': 458,
#  '5150 Productions': 459,
#  '51MM Films': 460,
#  '51k': 461,
#  '52 Films': 462,
#  '529 Dragons': 463,
#  '531 Productions': 464,
#  '54&O Productions': 465,
#  '5459 Films': 466,
#  '5656 Films': 467,
#  '57th & Irving Productions': 468,
#  '58 Films Llc': 469,
#  '58.5 Production': 470,
#  '5858 Films': 471,
#  '58Filme': 472,
#  '59 Films': 473,
#  '59%': 474,
#  '5AM Producciones': 475,
#  '5B Productions': 476,
#  '5J Media': 477,
#  '5pb': 478,
#  '5th Element': 479,
#  '5th Floor': 480,
#  '5th Tuesday Films': 481,
#  '5à 7 Films': 482,
#  '5ème Planète': 483,
#  '5’7 Films': 484,
#  '6 Foot Films': 485,
#  '600 West Productions': 486,
#  '606 Films': 487,
#  '610Film': 488,
#  '6140 Productions': 489,
#  '624 Productions': 490,
#  '625 Productions': 491,
#  '64 Films': 492,
#  '64A Films': 493,
#  '65 Wilding Films': 494,
#  '666 Production': 495,
#  '6:41 Productions': 496,
#  '6th & Idaho': 497,
#  '7 Arts': 498,
#  '7 Bucks Entertainment': 499,
#  '7 Continents Films': 500,
#  '7 Cylinders Studio': 501,
#  '7 Eccles Street': 502,
#  '7 Ponies Productions': 503,
#  '7 Región de Murcia': 504,
#  '7 Spencer Productions': 505,
#  '7 Toes Productions': 506,
#  '70 MM Entertainment': 507,
#  '700 Pictures': 508,
#  '700G Films': 509,
#  '70mm Entertainments': 510,
#  '71 Degrees North': 511,
#  '7107 Entertainment': 512,
#  '72 Films': 513,
#  '72 Productions': 514,
#  '721 Productions': 515,
#  '72nd Street Productions': 516,
#  '72° East Production': 517,
#  '73140323 Producciones Cinematográficas': 518,
#  '74 Entertainment': 519,
#  '74 Films': 520,
#  '747 Hallway Productions': 521,
#  '75 Films': 522,
#  '75 Year Plan Productions': 523,
#  '750 Productions': 524,
#  '76 Pictures': 525,
#  '77 Films': 526,
#  '775 Media Corp': 527,
#  '777 Films Corporation': 528,
#  '7930 Entertainment': 529,
#  '79th & Broadway Entertainment': 530,
#  '7A Productions': 531,
#  '7Arte Vital': 532,
#  '7Cs Entertainment': 533,
#  '7DM Studios': 534,
#  '7Films7': 535,
#  '7G Films': 536,
#  '7Glab Entertainment': 537,
#  '7Heaven Productions': 538,
#  '7Land Entertainment': 539,
#  '7cuerdasfilms': 540,
#  '7e Apache Film': 541,
#  '7e Heart Productions': 542,
#  '7th Chakra Films': 543,
#  '7th Empire Media': 544,
#  '7th Sense Films': 545,
#  '7th Street Productions': 546,
#  '7thScreen': 547,
#  '7ype': 548,
#  '8 Ball Stunts of Hollywood': 549,
#  '8 Street Films': 550,
#  '8-Track Productions': 551,
#  '80 Days Productions': 552,
#  '800 Pound Gorilla Pictures': 553,
#  '802 AD Productions': 554,
#  '802 Films': 555,
#  '808 Filmes Fora da Lata': 556,
#  '81 Produce': 557,
#  '8168 Productions Winter Star Productions': 558,
#  '8180 Films': 559,
#  '81st Street Films': 560,
#  '821 Entertainment Group': 561,
#  '8383 Productions': 562,
#  '852 Films': 563,
#  '856 Films': 564,
#  '86 Media': 565,
#  '8750 Films': 566,
#  '87Eleven': 567,
#  '87North Productions': 568,
#  '88 Art & Cinema': 569,
#  '88 Films': 570,
#  '88 Miles': 571,
#  '88 Rising': 572,
#  '88 to 1 Productions': 573,
#  '88mm Productions': 574,
#  '8:38 Productions': 575,
#  '8Heads Productions': 576,
#  '8bit': 577,
#  '8horses': 578,
#  '8th In Line': 579,
#  '8th Sense Productions': 580,
#  '8th Wonder Entertainment': 581,
#  '9 1/2 Comunicaciones': 582,
#  '9 Light Entertainment': 583,
#  '9.14 Pictures': 584,
#  '9.99 Films': 585,
#  '9/02 Entertainment': 586,
#  '9/6 Cinema Factory': 587,
#  '90 Minutes Film Studio': 588,
#  '90 Productions': 589,
#  '900 Films': 590,
#  '9000 Wolves': 591,
#  '909 Productions': 592,
#  '918 Films': 593,
#  '923 Films': 594,
#  '93JV': 595,
#  '93rd Bombardment Group Association': 596,
#  '95 Animation Studio': 597,
#  '96 Film Co., Ltd.': 598,
#  '98 MPH Productions': 599,
#  '99 Ways Entertainment': 600,
#  '9am Media Lab': 601,
#  '9ers Entertainment': 602,
#  'A & D Studios': 603,
#  'A & P GROUPS': 604,
#  'A + D Films': 605,
#  'A Atalanta': 606,
#  'A B Corp': 607,
#  'A Bad Way Ltd': 608,
#  'A Band Apart': 609,
#  'A Baroque House': 610,
#  'A Bellyful of Dreams Entertainment': 611,
#  'A Bigger Boat': 612,
#  'A Bird and a Bear Entertainment': 613,
#  'A Bollywood Yorker Films': 614,
#  'A Buck Short Productions': 615,
#  'A Casual Romance Productions': 616,
#  'A Certain Film Productions': 617,
#  'A Christmas Hero Productions': 618,
#  'A Company Filmproduktionsgesellschaft': 619,
#  'A Company Production': 620,
#  'A Contracorriente Films': 621,
#  'A Contraluz Films': 622,
#  'A Corpse With No Name Productions': 623,
#  'A Cut to the Chase Productions': 624,
#  'A Day in the Life Films': 625,
#  'A Dime And A Dream Pictures': 626,
#  'A Exceção e a Regra': 627,
#  'A Fabrica': 628,
#  'A Farewell to Kings Entertainment Company': 629,
#  'A Film Company': 630,
#  'A Film Estonia': 631,
#  'A Film Location Company': 632,
#  'A Film Monkey Production': 633,
#  'A Fire in the Lake': 634,
#  'A Flying Woman Productions': 635,
#  'A Free World Productions': 636,
#  'A Gardeners Production': 637,
#  'A Geezer & A Blonde Productions London': 638,
#  'A Grand Elephant': 639,
#  'A Grinning Tree Production': 640,
#  'A Happy Place': 641,
#  'A Hot Dog': 642,
#  'A Hype Media Production': 643,
#  'A Juke Film LLC': 644,
#  'A KIMCHI MOVIE PRODUCTION': 645,
#  'A Loopy Production LLC': 646,
#  'A Lucky Old Sun Production': 647,
#  'A Mates Entertainment Release': 648,
#  'A May Sky Picture Entertainment': 649,
#  'A Mile A Way Productions': 650,
#  'A Misspent Day': 651,
#  'A Monster Calls AIE': 652,
#  'A Monster in the Attic': 653,
#  'A Moving Image Productions': 654,
#  'A Mutual Respect': 655,
#  'A Named Viking': 656,
#  'A Narrative Street Production': 657,
#  'A No More Darkness Production': 658,
#  'A Noble Films': 659,
#  'A Palm Springs Joint': 660,
#  'A Peel Production': 661,
#  'A Perfect 14 Pictures': 662,
#  'A Perfect Circle Entertainment': 663,
#  'A Pict Films': 664,
#  'A Plus Entertainment': 665,
#  'A Plus Image': 666,
#  'A Plus Image 2': 667,
#  'A Plus Image 3': 668,
#  'A Plus Image 4': 669,
#  'A Plus Image 5': 670,
#  'A Plus Image 6': 671,
#  'A Plus Image 7': 672,
#  'A Prime Group': 673,
#  'A Private View': 674,
#  'A Product of Malitsky': 675,
#  'A Really Good Home Pictures': 676,
#  'A Really Happy Film': 677,
#  'A Red Arrow Studios Company': 678,
#  'A Russian Bear Production LLC': 679,
#  'A Shadow in the Dark Productions': 680,
#  'A Single Man Productions': 681,
#  'A Skye Vision': 682,
#  'A Slice of Pie Productions': 683,
#  'A Small Production Company': 684,
#  'A Soulworks Production': 685,
#  'A Space Between': 686,
#  'A Spencer Media': 687,
#  'A Stream In The Desert': 688,
#  'A Street Productions': 689,
#  'A Studios': 690,
#  'A Studios LLP': 691,
#  'A Team Productions': 692,
#  'A Thousand Ships': 693,
#  'A Ticklish Tale': 694,
#  'A Tiny But Big Pictures': 695,
#  'A Toda Madre Entertainment': 696,
#  'A United Bros. Cinema Distribution': 697,
#  'A Very Good Production': 698,
#  'A Vif Cinémas': 699,
#  'A Walk in the Parks Productions': 700,
#  'A Walled Garden': 701,
#  'A Wife Alone': 702,
#  'A and A Produktion': 703,
#  'A for Apple Production': 704,
#  'A%26E IndieFilms': 705,
#  'A&A Advisors': 706,
#  'A&A Pictures': 707,
#  'A&D Pictures': 708,
#  'A&E IndieFilms': 709,
#  'A&E Television Networks': 710,
#  'A&F Productions': 711,
#  'A&G': 712,
#  'A&M Sound Pictures': 713,
#  'A&O Buero': 714,
#  'A&O Buero Filmproduktion': 715,
#  'A&P Films': 716,
#  'A+ Images 7': 717,
#  'A+E Studios': 718,
#  'A-1 Kino Video': 719,
#  'A-1 Pictures': 720,
#  'A-1 Productions': 721,
#  'A-Film Distribution': 722,
#  'A-Line Pictures': 723,
#  'A-List Entertainment': 724,
#  'A-Mark Entertainment': 725,
#  'A-Motion': 726,
#  'A-OK Media House': 727,
#  'A-Po Films': 728,
#  'A-Roll Films': 729,
#  'A-Team': 730,
#  'A-Yao Film': 731,
#  'A-toys': 732,
#  'A. Film Production': 733,
#  'A. Smith & Co. Productions': 734,
#  'A.A.C. Productions': 735,
#  'A.B. Seahorse Films': 736,
#  'A.B.C. Pictures Pvt. Ltd.': 737,
#  'A.C.E.': 738,
#  'A.E. Media Corporation': 739,
#  'A.F. Cinema e Vídeo': 740,
#  'A.G. Entertainment': 741,
#  'A.G. Films': 742,
#  'A.Gi.Di.': 743,
#  'A.J. Digital Entertainment': 744,
#  'A.J. Productions': 745,
#  'A.J.O.Z. Films': 746,
#  'A.Pictures Film & TV Production': 747,
#  'A.R.C. Films': 748,
#  'A.R.Murugadoss Productions': 749,
#  'A.S. Films': 750,
#  'A.S. Prod': 751,
#  'A.S. Productions': 752,
#  'A.S.A.P': 753,
#  'A.T.P.I.P. Producciones': 754,
#  'A.U.M. Films': 755,
#  'A.V.A. Prodcutions': 756,
#  'A1 Studios': 757,
#  'A113': 758,
#  'A2 Entertainment Group': 759,
#  'A2 Film Corporation': 760,
#  'A24': 761,
#  'A2B Media': 762,
#  'A2D2 Films': 763,
#  'A2L Production Films': 764,
#  'A2O': 765,
#  'A71 Productions': 766,
#  'A7SLE Films': 767,
#  'AAA Entertainment': 768,
#  'AAA Motion Pictures': 769,
#  'AAA Pro Film': 770,
#  'AAMPI Inc.': 771,
#  'AAND': 772,
#  'AAP Studios': 773,
#  'AARP Studios': 774,
#  'AB Corp Ltd.': 775,
#  'AB3': 776,
#  'ABC Animation': 777,
#  'ABC Family': 778,
#  'ABC News': 779,
#  'ABC Signature': 780,
#  'ABC Studios': 781,
#  'ABC3': 782,
#  'ABCDE Pictures': 783,
#  'ABHO Film': 784,
#  'ABKCO Films': 785,
#  'ABO Entertainment': 786,
#  'ABP Entertainment': 787,
#  'ABR Productions': 788,
#  'ABS Film Company': 789,
#  'ABS Production': 790,
#  'AC Film': 791,
#  'AC Films': 792,
#  'AC Transformative Media': 793,
#  'ACA Films': 794,
#  'ACE': 795,
#  'ACE Entertainment': 796,
#  'ACE Pictures Entertainment': 797,
#  'ACE Productions': 798,
#  'ACEDEUCE': 799,
#  'ACH': 800,
#  'ACI Films Inc.': 801,
#  'ACK Animation Studios': 802,
#  'ACLJ Films': 803,
#  'ACM Films': 804,
#  'ACME Film': 805,
#  'ACPAV': 806,
#  'ACSD ArtinMovimento': 807,
#  'ACT Animation Films': 808,
#  'ACT-PIC': 809,
#  'AD WOOD': 810,
#  'AD406': 811,
#  'ADCB Films': 812,
#  'ADF Acquisitions': 813,
#  'ADF Productions': 814,
#  'ADF Studios': 815,
#  'ADHM Films': 816,
#  'ADIUVO Productions': 817,
#  'ADL Film Fest Fund': 818,
#  'ADR Productions': 819,
#  'ADRA Serbia': 820,
#  'ADTDF Utah Productions': 821,
#  'ADV Films': 822,
#  'AE Electra Productions': 823,
#  'AE Two Film Productions': 824,
#  'AEC Studios': 825,
#  'AEG Live': 826,
#  'AEON ENTERTAINMENT CO.LTD': 827,
#  'AFA Film Productions': 828,
#  'AFAC': 829,
#  'AFC': 830,
#  'AFE': 831,
#  'AFH Films': 832,
#  'AFPI': 833,
#  'AFS Film': 834,
#  'AFTRS': 835,
#  'AG Group': 836,
#  'AG Studio': 837,
#  'AG Studios': 838,
#  'AGBO': 839,
#  'AGC Studios': 840,
#  'AGGK Films': 841,
#  'AGM Factory': 842,
#  'AGS Entertainment': 843,
#  'AGS Productions': 844,
#  'AGUNG INC.': 845,
#  'AGe Industriesllc': 846,
#  'AHTF Films': 847,
#  'AI Film Entertainment': 848,
#  'AI-Film': 849,
#  'AIA Films': 850,
#  'AIASPLUS': 851,
#  'AIC Studios': 852,
#  'AIMZ Media': 853,
#  'AISI film': 854,
#  'AITD Productions': 855,
#  'AJ Entertainement Ltd.': 856,
#  'AJB Productions': 857,
#  'AJL Pictures': 858,
#  'AK Entertainments': 859,
#  'AK Worldwide': 860,
#  'AK47 Presents': 861,
#  'AKA Pictures': 862,
#  'AKELA Films': 863,
#  'AKN Productions': 864,
#  'AKOM Production Company': 865,
#  'AKOOLFILM COMPANY INC.': 866,
#  'AKS Media & Entertainment': 867,
#  'ALEF Film & Media Group': 868,
#  'ALP Productions': 869,
#  'ALT Entertainment': 870,
#  'ALV Entertainment Network': 871,
#  'ALV Films': 872,
#  'AM Associates': 873,
#  'AM Creative': 874,
#  'AM Films': 875,
#  'AM Pictures': 876,
#  'AMA Film': 877,
#  'AMA Media': 878,
#  'AMA Productions': 879,
#  'AMBI': 880,
#  'AMBI Group': 881,
#  'AMBULANTE': 882,
#  'AMC Networks International Iberia': 883,
#  'AMC Pictures': 884,
#  'AMCO Entertainment Group': 885,
#  'AMG Entertainment': 886,
#  'AMG Film Partners': 887,
#  'AMG Media': 888,
#  'AMIB Productions': 889,
#  'AMIP': 890,
#  'AMJ Productions': 891,
#  'AMKO Productions Inc.': 892,
#  'AMP': 893,
#  'AMP Creative': 894,
#  'AMP Filmworks': 895,
#  'AMP International': 896,
#  'AMP Media': 897,
#  'AMPCO Films': 898,
#  'AMPLE': 899,
#  'AMUSE': 900,
#  'AMUSIC FREEATER': 901,
#  'AMV Production': 902,
#  'AMVHell.com': 903,
#  'AMedia': 904,
#  'AMediaVision Productions': 905,
#  'ANA Media': 906,
#  'ANC Entertainment': 907,
#  'ANCINE/Ministério da Cultura, Fundo Setorial do Audiovisual': 908,
#  'ANDMARQ Studio': 909,
#  'ANEW': 910,
#  'ANG Film': 911,
#  'ANGGAR ANANDA': 912,
#  'ANGOA': 913,
#  'ANIMA': 914,
#  'ANIMAL DE LUZ FILMS': 915,
#  'ANOC Productions': 916,
#  'ANS Prodüksiyon': 917,
#  'ANTEC': 918,
#  'ANTEVITA FILMS': 919,
#  'ANTORCHA FILMS': 920,
#  'ANVL Entertainment': 921,
#  'AOA Productions Pty. Ltd.': 922,
#  'AOE Media': 923,
#  'AOI Pro.': 924,
#  'AOPL Entertainment': 925,
#  'APB Productions LLC': 926,
#  'APC': 927,
#  'API Films': 928,
#  'APM - Ana Pinhão Moura Produções': 929,
#  'APPP Company': 930,
#  'APS Films': 931,
#  'APS Films LLC': 932,
#  'APT Entertainment': 933,
#  'APT Film and Television': 934,
#  'APT Films': 935,
#  'APT. 1B Productions': 936,
#  'AR Content': 937,
#  'AR Films': 938,
#  'AR-TL': 939,
#  'ARC FILMS': 940,
#  'ARD': 941,
#  'ARD/Degeto Film': 942,
#  'ARGO PICTURES': 943,
#  'ARK-Film': 944,
#  'ARM Entertainment': 945,
#  'ARM/Cinema 25 Pictures Inc.': 946,
#  'ARO Entertainment': 947,
#  'ARP Sélection': 948,
#  'ARRAY Filmworks': 949,
#  'ARRAY Releasing': 950,
#  'ARRI Film & TV Services': 951,
#  'ARRI Media': 952,
#  'ARRI Media Productions': 953,
#  'ARRI Productions': 954,
#  'ARS Digital Studio': 955,
#  'ARS Film Production': 956,
#  'ARS Films': 957,
#  'ART & BOB': 958,
#  'ARTE': 959,
#  'ARTE Cofinova': 960,
#  'ARTE France Cinéma': 961,
#  'ARTE GEIE': 962,
#  'ARTFO': 963,
#  'ARTISK, INC.': 964,
#  'ARY Films': 965,
#  'AS Entertainment': 966,
#  'ASA Film Production': 967,
#  'ASA Production & Enterprises': 968,
#  'ASA Productions and Enterprises': 969,
#  'ASAF': 970,
#  'ASAP Entertainment': 971,
#  'ASC Audiovisual': 972,
#  'ASCII Media Works': 973,
#  'ASF Productions LLC': 974,
#  'ASFK': 975,
#  'ASG Films': 976,
#  'ASHA': 977,
#  'ASIG Productions': 978,
#  'ASLFilms': 979,
#  'ASM Media': 980,
#  'ASP GmbH': 981,
#  'ASP S.A.': 982,
#  'ASP White': 983,
#  'AST Studios': 984,
#  'AStory': 985,
#  'AT Studio': 986,
#  'AT&T': 987,
#  'AT-X': 988,
#  'ATAEC Studios': 989,
#  'ATC Management': 990,
#  'ATD Entertainment': 991,
#  'ATG Productions': 992,
#  'ATHANOR': 993,
#  'ATKO Films': 994,
#  'ATM Grupa': 995,
#  'ATM Motionwide': 996,
#  'ATO': 997,
#  'ATO Pictures': 998,
#  'ATR Films': 999,
#  ...}

# %%
df_title_companies = df_explode[['imdb_id','production_company_list']]
df_title_companies
# Out:
#          imdb_id     production_company_list
# 0      tt0144280                         NaN
# 1      tt0197633                         NaN
# 2      tt0204250  Girl Next Door Productions
# 3      tt0206634          Universal Pictures
# 3      tt0206634        Strike Entertainment
# ...          ...                         ...
# 78392  tt7098636                Angoa-Agicoa
# 78393  tt7246872                         NaN
# 78394  tt7637550          ARTE France Cinéma
# 78395  tt9414698                         NaN
# 78396  tt9641790       Little Buster Studios
#
# [138213 rows x 2 columns]

# %%
df_title_companies['company_id'] = df_title_companies['production_company_list'].map(company_map)
df_title_companies
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_10067/4204615088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_companies['company_id'] = df_title_companies['production_company_list'].map(company_map)
#          imdb_id     production_company_list  company_id
# 0      tt0144280                         NaN         NaN
# 1      tt0197633                         NaN         NaN
# 2      tt0204250  Girl Next Door Productions     14402.0
# 3      tt0206634          Universal Pictures     36827.0
# 3      tt0206634        Strike Entertainment     33356.0
# ...          ...                         ...         ...
# 78392  tt7098636                Angoa-Agicoa      2167.0
# 78393  tt7246872                         NaN         NaN
# 78394  tt7637550          ARTE France Cinéma       961.0
# 78395  tt9414698                         NaN         NaN
# 78396  tt9641790       Little Buster Studios     20583.0
#
# [138213 rows x 3 columns]

# %%
df_company = pd.DataFrame({'company_id':company_map.values(), 'company_name':company_map.keys()})
df_company
# Out:
#        company_id                   company_name
# 0               0  # Andrea Sperling Productions
# 1               1              #Beardforce Films
# 2               2                 #Sinning Works
# 3               3              #littlesecretfilm
# 4               4                        (주)라인필름
# ...           ...                            ...
# 39867       39867                        타임스토리그룹
# 39868       39868                          파파스필름
# 39869       39869                         플랫폼픽쳐스
# 39870       39870                           한맥문화
# 39871       39871                      환타지엔터테인먼트
#
# [39872 rows x 2 columns]

# %%
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#          budget  \
# 0        100000
# 1             0
# 2             0
# 3      76000000
# 4             0
# ...         ...
# 78392         0
# 78393         0
# 78394         0
# 78395         0
# 78396       400
#
#                                                                                                                                                                       genres  \
# 0                                                                                                                                                                         []
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                            [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 4                                                                                                                [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
# ...                                                                                                                                                                      ...
# 78392                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78393                                                                           [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}, {'id': 18, 'name': 'Drama'}]
# 78394                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78395                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78396                                                                                                         [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
#
#                                                                         homepage  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                  http://www.universalstudiosentertainment.com/children-of-men/
# 4                                                                            NaN
# ...                                                                          ...
# 78392                                              http://icarusfilms.com/if-cli
# 78393                                                                        NaN
# 78394  https://www.michaelraeburn.com/site/web/mr/zimbabwe-countdown_documentary
# 78395                                                                        NaN
# 78396                                                                        NaN
#
#            id    imdb_id original_language                 original_title  \
# 0       30356  tt0144280                en  Whispers from a Shallow Grave
# 1       58520  tt0197633                en         Live Freaky Die Freaky
# 2      459563  tt0204250                en          Death of a Saleswoman
# 3        9693  tt0206634                en                Children of Men
# 4        9925  tt0244521                en                    Funny Money
# ...       ...        ...               ...                            ...
# 78392  387250  tt7098636                fr   Le Clitoris, ce cher inconnu
# 78393  640680  tt7246872                en         Tokyo Bedoone Tavaghof
# 78394  515137  tt7637550                en             Zimbabwe Countdown
# 78395  713681  tt9414698                en                   The Hot Shoe
# 78396  253999  tt9641790                en                     Clearwater
#
#                                                                                                                                                                                                                                                                                                           overview  \
# 0                                                                                                                                                            When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                            It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2      Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                                   In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 4      Henry Perkins, a mild-mannered accountant, accidentally trades briefcases with another man, to find out that there's a million dollars inside. Henry tells his unsuspecting wife of their new-found fortune, but she doesn't embrace it as well as he does. Soon they're joined by their best friends, a...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  Topics about female sexuality are growing in popularity. Magazines and talk shows all discuss it. Yet a fair percentage of women are said to suffer from female sexual dysfunction. While male sexual problems have traditionally received the most publicity, only recently has research begun into the...
# 78393                                                                                                                                                                                                                                                                                                          NaN
# 78394                                                                                                                                                                       Once touted as Zimbabwe's saviour, Robert Mugabe has become synonymous with bad government and misrule. But where did it all go wrong?
# 78395                                                                                                                          A Documentary Movie About Card Counting In The Casino Game of 21. The director used $5,000 of the movie's budget to learn the counting methods, and put them to the test on screen.
# 78396                                                                                                                                                                                   A woman has been abducted by the Clearwater killer, and it's down to one man to solve the murderer's clues and rescue her.
#
#        popularity                       poster_path  \
# 0           0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1           1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2           0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4           4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...           ...                               ...
# 78392       1.400  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393       0.600  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394       0.711  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395       0.600                               NaN
# 78396       2.744  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                                                                                                                                                                                                                                                                               production_companies  \
# 0                                                                                                                                                                                                                                                                                                               []
# 1                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                   [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3               [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FWE Picture Company', 'origin_country': ''}, {'id': 30584, 'logo_path': '/7s0nJTTztkOVeIgavfOwx36EBtj.png', 'name': 'Thinkfactory Media', 'origin_country': 'US'}, {'id': 110623, 'logo_path': None, 'name': 'Tobebo Filmproduktions', 'origin_country': ''}...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cats & Dogs Films', 'origin_country': 'FR'}, {'id': 7106, 'logo_path': None, 'name': 'Sylicone', 'origin_country': 'FR'}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 639, 'logo_path': '/fN...
# 78393                                                                                                                                                                                                                                                                                                           []
# 78394                                                                                                                                                                                          [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}]
# 78395                                                                                                                                                                                                                                                                                                           []
# 78396                                                                                                                                                                                                                   [{'id': 174685, 'logo_path': None, 'name': 'Little Buster Studios', 'origin_country': ''}]
#
#                                                                                                                                production_countries  \
# 0                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3                                        [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# ...                                                                                                                                             ...
# 78392                                                                                                      [{'iso_3166_1': 'FR', 'name': 'France'}]
# 78393                                                                                                        [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 78394                                                            [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'ZW', 'name': 'Zimbabwe'}]
# 78395                                                                                                                                            []
# 78396                                                                                                                                            []
#
#       release_date   revenue  runtime  \
# 0       1997-01-01         0     90.0
# 1       2006-01-31         0     75.0
# 2       2006-09-18         0     77.0
# 3       2006-09-22  70595464    109.0
# 4       2006-01-01         0     98.0
# ...            ...       ...      ...
# 78392   2004-01-16         0     60.0
# 78393   2003-09-10         0     98.0
# 78394   2003-08-28         0     55.0
# 78395   2003-01-01         0     96.0
# 78396   2003-06-10         0     60.0
#
#                                                           spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 4      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                    ...
# 78392  [{'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}]
# 78393    [{'english_name': 'Persian', 'iso_639_1': 'fa', 'name': 'فارسی'}]
# 78394  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78395  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78396  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#          status  \
# 0      Released
# 1      Released
# 2      Released
# 3      Released
# 4      Released
# ...         ...
# 78392  Released
# 78393  Released
# 78394  Released
# 78395  Released
# 78396  Released
#
#                                                                                                                       tagline  \
# 0                                                                                                                         NaN
# 1                                                                                                                         NaN
# 2                                                            6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                                                                           The future's a thing of the past.
# 4      Henry Perkins accidentally trades briefcases with another man, to find out that there's five million dollars inside...
# ...                                                                                                                       ...
# 78392                                                                                                                     NaN
# 78393                                                                                                                     NaN
# 78394                                                                                                                     NaN
# 78395                                                                                                                     NaN
# 78396                                                                                                                     NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification  \
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 78392           NaN
# 78393           NaN
# 78394           NaN
# 78395           NaN
# 78396           NaN
#
#                                                                          production_company_list
# 0                                                                                             []
# 1                                                                                             []
# 2                                                                   [Girl Next Door Productions]
# 3                              [Universal Pictures, Strike Entertainment, Hit & Run Productions]
# 4                 [FWE Picture Company, Thinkfactory Media, Tobebo Filmproduktions, Castel Film]
# ...                                                                                          ...
# 78392  [Cats & Dogs Films, Sylicone, ARTE, DR TV, Planète+, SBS TV, CNC, PROCIREP, Angoa-Agicoa]
# 78393                                                                                         []
# 78394                                                                       [ARTE France Cinéma]
# 78395                                                                                         []
# 78396                                                                    [Little Buster Studios]
#
# [78397 rows x 27 columns]

# %%
# # using regular expressions to extrap just the name
# import re
# exp= r"\'name\'\:.?\'(\w*.*?)\'"
# re.findall(exp, test)

# %%
# def get_prod_company_names(x):
#     if x=='[]':
#         return ["MISSING"]
    
#     exp= r"\'name\'\:.?\'(\w*.*?)\'"
#     companies = re.findall(exp, x)
#     return companies

# %% [markdown]
# ### 📌[TO DO] Clean and Normalize Belongs to collection

# %%
df[~df['belongs_to_collection'].isna()]
# Out:
#        adult                     backdrop_path  \
# 15     False  /tuu79CwctvIo4RUg7E3FGkGIg4I.jpg
# 18     False  /sd4xN5xi8tKRPrJOWwNiZEile7f.jpg
# 19     False  /mOyF7rHVLF6uLbyb18FWTmcrjJe.jpg
# 34     False  /isH5BjYSpAZrNbrDFBfqYWouqfY.jpg
# 36     False  /8eRscFbRYl681zDfkjv1jjW1KAA.jpg
# ...      ...                               ...
# 78301  False  /bIlgVsRkASYjLh5BABmAMAMeHji.jpg
# 78349  False  /dGTQNe1jVYn3zhLsW2PP3PpLaKo.jpg
# 78374  False                               NaN
# 78376  False                               NaN
# 78390  False                               NaN
#
#                                                                                                                                                        belongs_to_collection  \
# 15         {'id': 141084, 'name': "Happily N'Ever After Collection", 'poster_path': '/aPjLYxKIBys6dlxXMZrDi8VowQK.jpg', 'backdrop_path': '/fw6YfVOmK0tVtaSUGb3GvLzEmvK.jpg'}
# 18                          {'id': 87118, 'name': 'Cars Collection', 'poster_path': '/ooYvY9DMEdUHH2dOPHbZmyfMENy.jpg', 'backdrop_path': '/A8DqaTGwZ8iCEjWMNRsZumzfKLw.jpg'}
# 19           {'id': 87359, 'name': 'Mission: Impossible Collection', 'poster_path': '/geEjCGfdmRAA1skBPwojcdvnZ8A.jpg', 'backdrop_path': '/jYl0UuJFcmhymv9ZNO14lPLDY1Z.jpg'}
# 34     {'id': 85817, 'name': 'Arthur and the Invisibles Collection', 'poster_path': '/2zhBMVy8E5fMnixTQUFVHcVncv6.jpg', 'backdrop_path': '/qzi1GxLQp8fk5DBmJ2c8lohhlAr.jpg'}
# 36                       {'id': 8537, 'name': 'Superman Collection', 'poster_path': '/fgTdu62v1jjNDPh68V9TJZMgXbo.jpg', 'backdrop_path': '/la0EhOrgVAiY8sf3ILz3wgoaNXH.jpg'}
# ...                                                                                                                                                                      ...
# 78301            {'id': 39199, 'name': 'Detective Conan Collection', 'poster_path': '/1wBfr532NOQK68wlo5ApjCmiQIB.jpg', 'backdrop_path': '/9bogrpii4e61SR6a9qLHow7I46U.jpg'}
# 78349                                                                       {'id': 977715, 'name': 'Ultraman Cosmos Collection', 'poster_path': None, 'backdrop_path': None}
# 78374                                       {'id': 221910, 'name': 'Raped by an Angel Collection', 'poster_path': '/7nQI5UN2UOwvb5jXPQTE13qaXaC.jpg', 'backdrop_path': None}
# 78376                                                                 {'id': 863888, 'name': 'Twin Dragon Encounter Collection', 'poster_path': None, 'backdrop_path': None}
# 78390              {'id': 180239, 'name': 'Police State Collection', 'poster_path': '/adpHF6sKCJKkUXcUCXKy76Lugz9.jpg', 'backdrop_path': '/pwZIRU71iv6XGUO2iDRS0OlEzW4.jpg'}
#
#           budget  \
# 15      47000000
# 18     120000000
# 19     150000000
# 34      86000000
# 36     270000000
# ...          ...
# 78301          0
# 78349          0
# 78374          0
# 78376          0
# 78390          0
#
#                                                                                                                                                                  genres  \
# 15     [{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]
# 18                                    [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 19                                                                      [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
# 34                                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}]
# 36                                                              [{'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}]
# ...                                                                                                                                                                 ...
# 78301                                                                                                [{'id': 9648, 'name': 'Mystery'}, {'id': 16, 'name': 'Animation'}]
# 78349                          [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}, {'id': 878, 'name': 'Science Fiction'}]
# 78374                                                                                                                                  [{'id': 53, 'name': 'Thriller'}]
# 78376                                                                                                                                    [{'id': 28, 'name': 'Action'}]
# 78390                                                                                                                               [{'id': 99, 'name': 'Documentary'}]
#
#                                                          homepage      id  \
# 15                       http://www.happilyneverafterthefilm.com/    5393
# 18          http://disney.go.com/disneyvideos/animatedfilms/cars/     920
# 19                                                            NaN     956
# 34                                                            NaN    9992
# 36             https://www.warnerbros.com/movies/superman-returns    1452
# ...                                                           ...     ...
# 78301  https://www.tms-e.co.jp/global/alltitles/conan/087307.html   39202
# 78349                                         http://www.m-78.jp/   44045
# 78374                                                         NaN  221913
# 78376                                                         NaN  850062
# 78390                                                         NaN   36025
#
#          imdb_id original_language                             original_title  \
# 15     tt0308353                en                       Happily N'Ever After
# 18     tt0317219                en                                       Cars
# 19     tt0317919                en                    Mission: Impossible III
# 34     tt0344854                en                     Arthur et les Minimoys
# 36     tt0348150                en                           Superman Returns
# ...          ...               ...                                        ...
# 78301  tt1133935                ja                              名探偵コナン 迷宮の十字路
# 78349  tt2243192                ja  ウルトラマンコスモスVSウルトラマンジャスティス THE FINAL BATTLE
# 78374  tt3533690                cn                                    强奸5广告诱惑
# 78376  tt3679304                en                      The Real Twin Dragons
# 78390  tt6352612                en        Police State III: Total Enslavement
#
#                                                                                                                                                                                                                                                                                                           overview  \
# 15                                                                    An alliance of evil-doers, led by Frieda, looks to take over Fairy Tale Land. But when Ella realizes her stepmother is out to ruin her storybook existence, she takes a dramatic turn and blossoms into the leader of the resistance effort.
# 18     Lightning McQueen, a hotshot rookie race car driven to succeed, discovers that life is about the journey, not the finish line, when he finds himself unexpectedly detoured in the sleepy Route 66 town of Radiator Springs. On route across the country to the big Piston Cup Championship in California...
# 19                                                                         Retired from active duty to train new IMF agents, Ethan Hunt is called back into action to confront sadistic arms dealer, Owen Davian. Hunt must try to protect his girlfriend while working with his new team to complete the mission.
# 34     Arthur is a spirited ten-year old whose parents are away looking for work, whose eccentric grandfather has been missing for several years, and who lives with his grandmother in a country house that, in two days, will be repossessed, torn down, and turned into a block of flats unless Arthur's gra...
# 36     Superman returns to discover his 5-year absence has allowed Lex Luthor to walk free, and that those he was closest to felt abandoned and have moved on. Luthor plots his ultimate revenge that could see millions killed and change the face of the planet forever, as well as ridding himself of the Ma...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78301                                                            Mouri Kogoro is called to a special case in the ancient capital of Kyoto. There, Conan meets Heiji and they team up once again to solve the case, recover the stolen Healing Buddha statue, and even discover the identity of Heiji's first love.
# 78349  Once again, Musashi has encounter Ultraman Cosmos. Now Ultraman Cosmos has gained some new modes to defeat Scropis. Musashi has joined Team Sea to save the Blue Area. But there is mysterious evil monster, Sandros, who wants to destroy the Earth. Now it is up Musashi and Ultraman Cosmos to defeat...
# 78374  Aaron is in his twenties, thin and silent. No-one notices that he is psychologically deviant. He is obsessed with three female advertisement models: Judy, from a wedding ad, Pauline, presenting shower gel, and Yen, an advertising girl for soda. He imagines that the women will surrender to him on...
# 78376                                                                                                                                                                                                                                        A true, one of a kind story that is totally unique in the film world.
# 78390  Total Enslavement is the third installment in the critically-acclaimed Police State series and is a must-see for all who leve freedom. This film documents the nightmare rise of the Homeland Security dictatorship, Patriot Acts 1 and 2, the Total Information Awareness Network, government-run white...
#
#        popularity                       poster_path  \
# 15         10.113   /MjfHDN5WrV6RBVhCvfdlPpt7gH.jpg
# 18         80.250  /qa6HCwP4Z15l3hpsASz3auugEW6.jpg
# 19         30.946  /5l0hS4A119jCA1A02XsFZHq1uRD.jpg
# 34         23.025  /gH27K0S7BiZCsNMxzOQTacG9IZp.jpg
# 36         24.129  /385XwTQZDpRX2d3kxtnpiLrjBXw.jpg
# ...           ...                               ...
# 78301       8.046  /lzPnHHhYWSMGwBLTDCIT6sgehF5.jpg
# 78349       2.661  /dEQIkE7S3KCCIE2Mjl0WMdBBkhk.jpg
# 78374       1.042  /myE5lwfRSzevyavMNOmgbJm3jD6.jpg
# 78376       1.091  /kcWKNgsptWfQukYU38lYoxXOcKD.jpg
# 78390       0.600  /q3DTD5YW0FU6Gf3hIC2CeNWGjKx.jpg
#
#                                                                                                                                                                                                                                                                                               production_companies  \
# 15     [{'id': 1718, 'logo_path': None, 'name': 'Odyssey', 'origin_country': 'US'}, {'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}, {'id': 87859, 'logo_path': None, 'name': 'BAF Berlin Animation Film', 'origin_country': ''}, {'id': 149640, 'lo...
# 18                                                                                       [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png', 'name': 'Pixar', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# 19     [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 44, 'logo_path': None, 'name': 'Cruise/Wagner Productions', 'origin_country': ''}, {'id': 658, 'logo_path': None, 'name': 'MI 3 Film', 'origin_country': ''}, {'id': 2269, 'logo_path':...
# 34     [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png', 'name': 'Canal+', 'origin_country': 'FR'}, {'id': 854, 'logo_path': None, 'name': 'Sofica EuropaCorp', 'origin_country': ''}, {'id': 2525, 'logo_path': None, 'name': 'Avalanche Productions', 'origin_country': 'FR'}, {'id': 6896, 'logo...
# 36     [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Pictures', 'origin_country': 'US'}, {'id': 9168, 'logo_path': '/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png', 'name': 'B...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78301                                                                                                                                                                                         [{'id': 7164, 'logo_path': '/vHsaqTkQ2ZTbdqrCA272YahoVlg.png', 'name': 'TMS Entertainment', 'origin_country': 'JP'}]
# 78349                                                                           [{'id': 5905, 'logo_path': '/A9A3W8VyqnznQOf70ROYtwskK4A.png', 'name': 'Tsuburaya Productions', 'origin_country': 'JP'}, {'id': 192, 'logo_path': '/93eAKlnQecDdMtucfOprzcjMw9V.png', 'name': 'Shochiku', 'origin_country': 'JP'}]
# 78374                                                                                                                                                                                                                                                                                                           []
# 78376                                                                                                                                                                                                                                                                                                           []
# 78390                                                                                                                                                                                                                                                                                                           []
#
#                                                                                                                                                                               production_countries  \
# 15     [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 18                                                                                                                                      [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 19                                                      [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 34                                                                                                                                                        [{'iso_3166_1': 'FR', 'name': 'France'}]
# 36                                                                                                                                      [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# ...                                                                                                                                                                                            ...
# 78301                                                                                                                                                      [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# 78349                                                                                                                                                      [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# 78374                                                                                                                                                                                           []
# 78376                                                                                                                                                                                           []
# 78390                                                                                                                                   [{'iso_3166_1': 'US', 'name': 'United States of America'}]
#
#       release_date    revenue  runtime  \
# 15      2007-01-05   38085778     87.0
# 18      2006-06-08  461983149    117.0
# 19      2006-05-03  397850012    126.0
# 34      2006-12-13  107944236     94.0
# 36      2006-06-28  391081192    154.0
# ...            ...        ...      ...
# 78301   2003-04-19          0    110.0
# 78349   2003-08-02          0     77.0
# 78374   2003-01-01          0     88.0
# 78376   2003-09-03          0     78.0
# 78390   2003-01-01          0    156.0
#
#                                                                                                                                                                                                                                                                                                   spoken_languages  \
# 15                                                                                                                                                                                                                                             [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 18                                             [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}, {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}, {'english_name': 'Yiddish', 'iso_639_1': 'yi', 'name': ''}]
# 19     [{'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}, {'english_name': 'Mandarin', 'iso_639_1': 'zh', 'name': '普通话'}, {'english_name': 'Czech', 'iso...
# 34                                                                                                                                                                                                                                             [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 36                                                                                                        [{'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'}, {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                                                                                                                                                                                                                                                            ...
# 78301                                                                                                                                                                                                                                             [{'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}]
# 78349                                                                                                                                                                                                                                             [{'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}]
# 78374                                                                                                                                                                                                                                      [{'english_name': 'Cantonese', 'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}]
# 78376                                                                                                                                                                                                                                                                                                           []
# 78390                                                                                                                                                                                                                                          [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                                     tagline  \
# 15     Released             Fairy Tale Endings Aren't What They Used To Be.
# 18     Released                      Ahhh... it's got that new movie smell.
# 19     Released                                The mission begins 05:05:06.
# 34     Released                      Adventure awaits in your own backyard.
# 36     Released                         You’ll Believe A Man Can Fly Again!
# ...         ...                                                         ...
# 78301  Released                                                         NaN
# 78349  Released                                                         NaN
# 78374  Released                                                         NaN
# 78376  Released  You can't fight the government ... no one told the twins !
# 78390  Released                                                         NaN
#
#                                                         title  video  \
# 15                                       Happily N'Ever After  False
# 18                                                       Cars  False
# 19                                    Mission: Impossible III  False
# 34                                  Arthur and the Invisibles  False
# 36                                           Superman Returns  False
# ...                                                       ...    ...
# 78301       Detective Conan: Crossroad in the Ancient Capital  False
# 78349  Ultraman Cosmos vs. Ultraman Justice: The Final Battle  False
# 78374            Raped by an Angel 5: Advertising Temptations  False
# 78376                                   The Real Twin Dragons  False
# 78390                     Police State III: Total Enslavement   True
#
#        vote_average  vote_count certification  \
# 15              4.9         358            PG
# 18              6.9       11611             G
# 19              6.7        5390         PG-13
# 34              6.4        2464            PG
# 36              5.7        3453         PG-13
# ...             ...         ...           ...
# 78301           7.0         107         PG-13
# 78349           3.5           2           NaN
# 78374           1.0           1           NaN
# 78376           0.0           0           NaN
# 78390           0.5           1           NaN
#
#                                                                                                                                                                                      production_company_list
# 15                                                                                                           [Odyssey, Lionsgate, BAF Berlin Animation Film, BFC Berliner Film Companie, Vanguard Animation]
# 18                                                                                                                                                                             [Pixar, Walt Disney Pictures]
# 19     [Paramount, Cruise/Wagner Productions, MI 3 Film, China Film Co-Production Corporation, The Fourth Production Company Film Group, China Film Group Corporation, Cinecittá Studios, Studio Babelsberg]
# 34                                                                                                                                            [Canal+, Sofica EuropaCorp, Avalanche Productions, EuropaCorp]
# 36                                                                    [DC Comics, Legendary Pictures, Bad Hat Harry Productions, Warner Bros. Pictures, Peters Entertainment, Red Sun Productions Pty. Ltd.]
# ...                                                                                                                                                                                                      ...
# 78301                                                                                                                                                                                    [TMS Entertainment]
# 78349                                                                                                                                                                      [Tsuburaya Productions, Shochiku]
# 78374                                                                                                                                                                                                     []
# 78376                                                                                                                                                                                                     []
# 78390                                                                                                                                                                                                     []
#
# [3943 rows x 27 columns]

# %%
test = df.iloc[19]['belongs_to_collection']
test
# Out:
# "{'id': 87359, 'name': 'Mission: Impossible Collection', 'poster_path': '/geEjCGfdmRAA1skBPwojcdvnZ8A.jpg', 'backdrop_path': '/jYl0UuJFcmhymv9ZNO14lPLDY1Z.jpg'}"

# %%
## Function to get just the genre names as a list 
import json
def get_collection(x):
    try:
        x = x.replace('None','"None"')
        x = x.replace('\\','')

    #         x = x.replace("'",'"')
        x = x.replace("'s",'s')
        for key in ['id','poster_path','name','backdrop_path']:
            x = x.replace(f"'{key}'",f'"{key}"')

        x = x.replace("'",'"')

        x = json.loads(x)
    except:
        return None
    if isinstance(x,dict):
        collections= x['name']
        
    elif isinstance(x,list):
        collections = []
        for collection in x:
            collections.append(collection['name'])
    else:
        collections = "MISSING"
    return collections

# %%
get_collection(test)
# Out:
# 'Mission: Impossible Collection'

# %%
# json.loads(test)

# %%
## Use ourn function and exploding the new column
df['collection'] = df['belongs_to_collection'].apply(get_collection)

# %%
df['collection'].isna().sum() / len(df)
# Out:
# 0.9500363534318915

# %%
df['belongs_to_collection'].isna().sum() / len(df)
# Out:
# 0.9497047080883197

# %%
df['collection'].value_counts()
# Out:
# Detective Conan Collection            18
# Doraemon Collection                   16
# Troublesome Night Collection          15
# One Piece Collection                  13
# Madea - Collection                    12
#                                       ..
# Çakallarla Dans [Seri]                 1
# Pizza                                  1
# 美景之屋（系列）                               1
# Bloodbath at Pinky High Collection     1
# Twin Dragon Encounter Collection       1
# Name: collection, Length: 1943, dtype: int64

# %% [markdown]
# #### Explode & Separate

# %%
df['collection']
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 78392    None
# 78393    None
# 78394    None
# 78395    None
# 78396    None
# Name: collection, Length: 78397, dtype: object

# %%
# df_explode = df.explode('collecti')
# df_explode

# %%
## save unique genres
unique_collections = sorted(df['collection'].dropna().unique())
len(unique_collections)
# Out:
# 1943

# %%
collection_map = dict(zip(unique_collections, range(len(unique_collections))))
collection_map
# Out:
# {'#TemanTapiMenikah': 0,
#  '... Cameras Collection': 1,
#  '.hack Collection': 2,
#  '10 giorni... - Collezione': 3,
#  '100 Girls Collection': 4,
#  '100% Coco Collection': 5,
#  '101 Dalmatians (Live-Action) Collection': 6,
#  '12 Dogs of Christmas Collection': 7,
#  '12 Rounds Collection': 8,
#  '12 Westerns in 12 Months Collection': 9,
#  '14+ (Коллекция)': 10,
#  '1920 Collection': 11,
#  '1981 Collection': 12,
#  '2 Days In... Collection': 13,
#  '2001 Maniacs Collection': 14,
#  '20th Century Boys Collection': 15,
#  '28 Days/Weeks Later Collection': 16,
#  '3 A.M. Collection': 17,
#  '3 Braves Universe': 18,
#  '3 Little Pigs collection': 19,
#  '30 Days of Night Collection': 20,
#  '300 Collection': 21,
#  '365 Days Collection': 22,
#  '47 Meters Down Collection': 23,
#  '47 Ronin Collection': 24,
#  '64 Collection': 25,
#  '666 Collection': 26,
#  '8 свиданий (Коллекция)': 27,
#  'A California Christmas Collection': 28,
#  'A Chinese Odyssey Collection': 29,
#  'A Christmas Prince Collection': 30,
#  'A Doggone Collection': 31,
#  'A Dogs Purpose Collection': 32,
#  'A Few Best Men Collection': 33,
#  'A Frozen Christmas Collection': 34,
#  'A Haunted House Collection': 35,
#  'A Man and a Woman Collection': 36,
#  'A Menina que Matou os Pais': 37,
#  'A Meowy Collection': 38,
#  'A Monkeys Tale': 39,
#  'A Quiet Place Collection': 40,
#  'A Second Chance Collection': 41,
#  'A Simple Favor Collection': 42,
#  'A Very Special Love Collection': 43,
#  'ABCD Collection': 44,
#  'AMV Hell': 45,
#  'ARCHIE Collection': 46,
#  'AVP Collection': 47,
#  'Aadu Collection': 48,
#  'Aashiqui Collection': 49,
#  'Ab Tak Chhappan Collection': 50,
#  'About Love Collection': 51,
#  'Accident Man Collection': 52,
#  'Achtung, fertig Filmreihe': 53,
#  'Action Figures Collection': 54,
#  'Ada Apa Dengan Cinta? Collection': 55,
#  'Admiral Yi': 56,
#  'Adventures of Bailey Collection': 57,
#  'After Collection': 58,
#  'After Porn Ends Collection': 59,
#  'Against the Wild Collection': 60,
#  'Agent Cody Banks Collection': 61,
#  'Ah Boys to Men Collection': 62,
#  'Aileen Wuornos Collection': 63,
#  'Aileen Wuornos: Broomfield Collection': 64,
#  'Ajin Collection': 65,
#  'Akihabara Trilogy': 66,
#  'Aladdin (Live-Action) Collection': 67,
#  'Aldo Giovanni e Giacomo Collection': 68,
#  'Alex Cross Collection': 69,
#  'Algjör Sveppi': 70,
#  'Alice in Wonderland Collection': 71,
#  'Alien Factor Collection': 72,
#  'Alien Sex Files': 73,
#  'Aliens Ate My Homework Collection': 74,
#  'All Hallows Eve Collection': 75,
#  'All for ...': 76,
#  'Alligator Ladies Collection': 77,
#  'Alls Well, Ends Well': 78,
#  'Almighty Collection': 79,
#  'Alone in the Dark Collection': 80,
#  'Along Came the Devil Collection': 81,
#  'Along with the Gods Collection': 82,
#  'Alpha and Omega Collection': 83,
#  'Alvin and the Chipmunks Collection': 84,
#  'Always: Sunset on Third Street Collection': 85,
#  'Amateur Porn Star Killer Collection': 86,
#  'Ambra Collection': 87,
#  'American Addict Collection': 88,
#  'American Civil War Collection': 89,
#  'American Gospel Collection': 90,
#  'American Guinea Pig Collection': 91,
#  'American Pie Collection': 92,
#  'American Poltergeist': 93,
#  'American Psycho Collection': 94,
#  'Amityville Scarecrow Collection': 95,
#  'An American Girl Collection': 96,
#  'An Inconvenient Collection': 97,
#  'Anaconda Collection': 98,
#  'Analyze Collection': 99,
#  'Anatomy Collection': 100,
#  'Anatomy of an Antihero Collection': 101,
#  'Anchorman Collection': 102,
#  'Android Kunjappan Collection': 103,
#  'Anděl Páně (kolekce)': 104,
#  'Ang Tanging Ina Collection': 105,
#  'Angelas Christmas Collection': 106,
#  'Animal Collection': 107,
#  'Anja & Viktor Collection': 108,
#  'Annabelle Collection': 109,
#  'Annika Bengtzon Collection': 110,
#  'Annika Bengtzon Collection (Helena Bergström)': 111,
#  'Another Gay Movie Collection': 112,
#  'Ant-Man Collection': 113,
#  'Antboy Collection': 114,
#  'Antelope Valley Collection': 115,
#  'Antisocial Collection': 116,
#  'Ants in the Pants Collection': 117,
#  'Apocalypse Collection': 118,
#  'Appleseed Collection': 119,
#  'Aqua Teen Hunger Force Colon Movie Film for Theaters Collection': 120,
#  'Aquaman Collection': 121,
#  'Arabian Nights Collection': 122,
#  'Aranmanai Collection': 123,
#  'Ardaas Collection': 124,
#  'Argo Collection': 125,
#  'Armored Trooper VOTOMS Collection': 126,
#  'Armour of God Collection': 127,
#  'Arn Collection': 128,
#  'Arpeggio of blue steel': 129,
#  'Art of the Devil Collection': 130,
#  'Arthur and the Invisibles Collection': 131,
#  'Ash Lad Collection': 132,
#  'Ashens Collection': 133,
#  'Ask Me Anything Collection': 134,
#  'Assassination Classroom Collection': 135,
#  'Asterix & Obelix Collection': 136,
#  'Asterix and Obelix (Animation) Collection': 137,
#  'Atlantic Rim Collection': 138,
#  'Atlantis Collection': 139,
#  'Atlas Shrugged Collection': 140,
#  'Atomic Blonde Collection': 141,
#  'Attack on Titan (Anime) Collection': 142,
#  'Attack on Titan Collection': 143,
#  'Attack the Block Collection': 144,
#  'Attack the Gas Station Collection': 145,
#  'Attraction Collection': 146,
#  'Austin Powers Collection': 147,
#  'Avatar Collection': 148,
#  'Avenger Dogs': 149,
#  'Avengers Grimm Collection': 150,
#  'Avunu Collection': 151,
#  'Aşk Tesadüfleri Sever [Seri]': 152,
#  'Baaghi Collection': 153,
#  'Baby Driver Collection': 154,
#  'Baby Geniuses Collection': 155,
#  'Babysitting Collection': 156,
#  'Bad Ass Collection': 157,
#  'Bad Ben Collection': 158,
#  'Bad Boys Collection': 159,
#  'Bad Kids Collection': 160,
#  'Bad Moms Collection': 161,
#  'Bad Santa Collection': 162,
#  'Baishe Srabon and Dwitiyo Purush Collection': 163,
#  'Balala the Fairies series': 164,
#  'Ballon sur bitume': 165,
#  'Bamse Collection': 166,
#  'BanG Dream! Episode of Roselia Collection': 167,
#  'Bananas!* Collection': 168,
#  'Bang Rajan Collection': 169,
#  'Bangarraju Collection': 170,
#  'Barbershop Collection': 171,
#  'Barbie & Kendra Collection': 172,
#  'Barbie Mariposa Collection': 173,
#  'Basic Instinct Collection': 174,
#  'Batman (DC Universe Animated) Collection': 175,
#  'Batman Animation Collection (Adam West)': 176,
#  'Batman: The Long Halloween Collection': 177,
#  'Battle Royale Collection': 178,
#  'Battle of the Brides': 179,
#  'Bayside Shakedown Collection': 180,
#  'Baztan Trilogy': 181,
#  'Be My Slave Collection': 182,
#  'Bearcity Collection': 183,
#  'Bedroom to Billions': 184,
#  'Beef Collection': 185,
#  'Before... Collection': 186,
#  'Beginnings of the Space Age': 187,
#  'Behind Enemy Lines Collection': 188,
#  'Belle & Sebastian': 189,
#  'Benvenuti al... Collection': 190,
#  'Benvenuto Presidente - Collezione': 191,
#  'Benyamin The Troublemaker': 192,
#  'Bernie the Dolphin Collection': 193,
#  'Berserk: Golden Age Arc Collection': 194,
#  'Best Exotic Marigold Hotel Collection': 195,
#  'Best F(r)iends Collection': 196,
#  'Beverly Hills Chihuahua Collection': 197,
#  'Bhai - Vyakti ki Valli': 198,
#  'Bheja Fry Collection': 199,
#  'Bhool Bhulaiyaa Collection': 200,
#  'Bhoothnath Collection': 201,
#  'Bibi & Tina Collection': 202,
#  'Bibi Blocksberg Collection': 203,
#  'Big Brother Collection': 204,
#  'Big Fat Liar Collection': 205,
#  'Big Mommas House Collection': 206,
#  'Bigfoot Collection': 207,
#  'Bill & Teds Most Excellent Collection': 208,
#  'Bird Box Collection': 209,
#  'Birdemic Collection': 210,
#  'Bishorjan and Bijoya Collection': 211,
#  'Black & White Collection': 212,
#  'Black Panther Collection': 213,
#  'Black Water Collection': 214,
#  'Blade Collection': 215,
#  'Blade Runner Collection': 216,
#  'Blair Witch Collection': 217,
#  'Bleach Collection': 218,
#  'Blood Feast Collection': 219,
#  'BloodRayne Collection': 220,
#  'Bloodbath at Pinky High Collection': 221,
#  'Bloodshot Collection': 222,
#  'Bloody Chainsaw Girl Collection': 223,
#  'Blue Collar Comedy Tour Collection': 224,
#  'Blue Crush Collection': 225,
#  'BoBoiBoy Collection': 226,
#  'Bob The Cat Collection': 227,
#  'Bon Bini Holland Collectie': 228,
#  'Bon Cop Bad Cop Collection': 229,
#  'Bonded by Blood Collection': 230,
#  'Boon Collection': 231,
#  'Boonie Bears Collection': 232,
#  'Borat Moviefilms Collection': 233,
#  'Borgríki Collection': 234,
#  'Boule & Bill': 235,
#  'Bound Heat': 236,
#  'Boys Life (Collection)': 237,
#  'Bratz Collection': 238,
#  'Brice Collection': 239,
#  'Bridget Jones Collection': 240,
#  'Brigada Z Collection': 241,
#  'Bright Collection': 242,
#  'Bring It On Collection': 243,
#  'Broken Blade Collection': 244,
#  'Broken Silence': 245,
#  'Brother Bear Collection': 246,
#  'Brother Collection': 247,
#  'Brotherhood of Blades Collection': 248,
#  'Bulletproof Collection': 249,
#  'Bunker of Blood Collection': 250,
#  'Bunnyman Collection': 251,
#  'Bunty Aur Babli': 252,
#  'Buppah Ratree Collection': 253,
#  'Burg Schreckenstein Filmreihe': 254,
#  'Burnout Collection': 255,
#  'Burnt by the Sun Trilogy': 256,
#  'Bāhubali Collection': 257,
#  'Cabin Fever Collection': 258,
#  'Caesar and Otto Collection': 259,
#  'Cal Collection': 260,
#  'California Trilogy': 261,
#  'Camp Blood Collection': 262,
#  'Campaign Collection': 263,
#  'Camping Collection': 264,
#  'Candyman Collection': 265,
#  'Captain America Collection': 266,
#  'Captain Marvel Collection': 267,
#  'Captain Underpants Collection': 268,
#  'Cardcaptor Sakura Collection': 269,
#  'Carmina - Colección': 270,
#  'CarousHELL Collection': 271,
#  'Carpenter Andersen Collection': 272,
#  'Carry on Jatta Collection': 273,
#  'Cars Collection': 274,
#  'Carters Collection': 275,
#  'Carved Collection': 276,
#  'Casper and Emma Collection': 277,
#  'Cat Run Collection': 278,
#  'Cats & Dogs Collection': 279,
#  'Cattle Hill Collection': 280,
#  'Cementerio General Collection': 281,
#  'Center Stage Collection': 282,
#  'Charlies Angels Collection': 283,
#  'Charter Trips': 284,
#  'Chasing The Dragon Collection': 285,
#  'Che Collection': 286,
#  'Cheaper by the Dozen (2003) Collection': 287,
#  'Cheech & Chong Collection': 288,
#  'Cherry Blossoms': 289,
#  'Chhakka Panja Collection': 290,
#  'Chicken Run Collection': 291,
#  'Chief Daddy Collection': 292,
#  'Chihayafuru Collection': 293,
#  'Children of the Corn Collection': 294,
#  'Childs Play Collection': 295,
#  'Chili Palmer Collection': 296,
#  'Chocolate City Collection': 297,
#  'Christmas Thieves (Collection)': 298,
#  'Christmas with a Prince Collection': 299,
#  'Chronicle Collection': 300,
#  'Cinderella Story Collection': 301,
#  'Cities of Love Collection': 302,
#  'Clash of the Titans Collection': 303,
#  'Class Reunion Collection': 304,
#  'Clerks Collection': 305,
#  'Clint Eastwoods Iwo Jima Collection': 306,
#  'Cloudy with a Chance of Meatballs Collection': 307,
#  'Clubhouse Detectives Collection': 308,
#  'Cocaine Cowboys': 309,
#  'Coconut The Little Dragon Collection': 310,
#  'Code Geass: Akito the Exiled': 311,
#  'Code Geass: Lelouch of the Rebellion Recap Film Trilogy': 312,
#  'Cold Prey Collection': 313,
#  'Cold Pursuit Collection': 314,
#  'Cold War Collection': 315,
#  'Coletânea Nada a Perder': 316,
#  'Come un gatto in tangenziale - Collezione': 317,
#  'Coming to America Collection': 318,
#  'Commander Kellie & the Superkids Collection': 319,
#  'Commando Collection': 320,
#  'Confession Executive Committee (Series)': 321,
#  'Confidential Assignment': 322,
#  'Contracted Collection': 323,
#  'Corky St. Clair Collection': 324,
#  'Corpse Party Collection': 325,
#  'Corpse Prison Collection': 326,
#  'Corto Maltese Collection': 327,
#  'Cowboy Filmreihe': 328,
#  'Crackerjack Collection': 329,
#  'Crank Collection': 330,
#  'Crayon Shin-chan Collection': 331,
#  'Crazy Rich Asians Collection': 332,
#  'Crazy Wedding Collection': 333,
#  'Creed Collection': 334,
#  'Creep Collection': 335,
#  'Crimes of Passion: The Maria Lang Collection': 336,
#  'Crocodile Collection': 337,
#  'Crocodile Dundee Collection': 338,
#  'Cross Collection': 339,
#  'Crouching Tiger, Hidden Dragon Collection': 340,
#  'Crows Collection': 341,
#  'Cruella Collection': 342,
#  'Cube Collection': 343,
#  'Cuccioli - Collezione': 344,
#  'Curious George Collection': 345,
#  'Cyborg 009 Collection': 346,
#  'DAU Cinema': 347,
#  'Dabangg Collection': 348,
#  'Dabbe [Seri]': 349,
#  'Daddy Day Camp Collection': 350,
#  'Daddys Home Collection': 351,
#  'Danur Collection': 352,
#  'Dark Girls Collection': 353,
#  'Dark Night of the Scarecrow Collection': 354,
#  'Dark Planet Collection': 355,
#  'Dark Web Collection': 356,
#  'Dark Woods Collection': 357,
#  'Dark World Collection': 358,
#  'Darko Collection': 359,
#  'Darling Collection': 360,
#  'Darna Hai Collection': 361,
#  'Dawn of the Dragonslayer Collection': 362,
#  'De Club van Sinterklaas': 363,
#  'De Pernas Pro Ar - Coleção': 364,
#  'De forbandede år (samling)': 365,
#  'Dead Rising Collection': 366,
#  'Dead River Collection': 367,
#  'Dead Snow Collection': 368,
#  'Dead or Alive Collection': 369,
#  'Deadlands Collection': 370,
#  'Deadly Prey Collection': 371,
#  'Deadpool Collection': 372,
#  'Deadtime Stories': 373,
#  'Dear God No!': 374,
#  'Dear Nathan': 375,
#  'Death Bell Collection': 376,
#  'Death Forest Collection': 377,
#  'Death Note Collection': 378,
#  'Death Race Collection': 379,
#  'Deco Truck Gal Nami': 380,
#  'Decoys Collection': 381,
#  'Deep Blue Sea Collection': 382,
#  'Deep Sea Monster Raiga Collection': 383,
#  'Demon Slayer': 384,
#  'Den of Thieves Collection': 385,
#  'Den som dræber': 386,
#  'Department Q Collection': 387,
#  'Der kleine Rabe Socke Filmreihe': 388,
#  'Despicable Me Collection': 389,
#  'Detective Chinatown Collection': 390,
#  'Detective Conan Collection': 391,
#  'Detective Dee Collection': 392,
#  'Detective K Collection': 393,
#  'Detective bureau nr. 2': 394,
#  'Detective in the Bar': 395,
#  'Deuce Bigalow Collection': 396,
#  'Devi Collection': 397,
#  'Devil in the Flesh': 398,
#  'Dhamaal Collection': 399,
#  'Dhoom Collection': 400,
#  'Diabolik - Collezione': 401,
#  'Diary of a Wimpy Kid (Animated) Collection': 402,
#  'Diary of a Wimpy Kid Collection': 403,
#  'Die Hard Collection': 404,
#  'Die Vampirschwestern Collection': 405,
#  'Digimon Adventure tri. Collection': 406,
#  'Digimon Collection': 407,
#  'Dilan': 408,
#  'Diplomat Kosaku Kuroda': 409,
#  'Dirty Dancing Collection': 410,
#  'District 13 Collection': 411,
#  'Divergent Collection': 412,
#  'Divã: Coleção': 413,
#  'Doctor Strange Collection': 414,
#  'Dolemite Collection': 415,
#  'Dolphin Tale Collection': 416,
#  'Don Collection': 417,
#  'Doom Collection': 418,
#  'Doraemon Collection': 419,
#  'Dorm Daze Collection': 420,
#  'Dostana Collection': 421,
#  'Downton Abbey Collection': 422,
#  'Dr. Dolittle Collection': 423,
#  'Dracula 2000 Collection': 424,
#  'Dragon Ball Super Collection': 425,
#  'Dragon Inn': 426,
#  'Dragon Loaded Collection': 427,
#  'Dragon Nest Collection': 428,
#  'DragonHeart Collection': 429,
#  'Drishya Collection': 430,
#  'Drishyam Collection': 431,
#  'Drumline - Collection': 432,
#  'Drushyam Collection': 433,
#  'Ducobu Collection': 434,
#  'Dulhania Collection': 435,
#  'Dumb and Dumber Collection': 436,
#  'Dummie the Mummy Collection': 437,
#  'Dune Collection': 438,
#  'Dungeons & Dragons Collection': 439,
#  'Dynamic Pro Super Robot Collection': 440,
#  'Eagle Talon Collection': 441,
#  'Easy Money Collection': 442,
#  'Easy Rider Collection': 443,
#  'Eating Out Collection': 444,
#  'Eberhofer': 445,
#  'Eden of the East Collection': 446,
#  'Eight Ranger Collection': 447,
#  'El Bosque Animado': 448,
#  'El Crack Collection': 449,
#  'El Gezira Collection': 450,
#  'Election Collection': 451,
#  'Elektra Luxx Collection': 452,
#  'Elias the Little Rescue Boat Collection': 453,
#  'Elite Squad Collection': 454,
#  'Elizabeth Collection': 455,
#  'Ella and Friends Collection': 456,
#  'Ellembi Series': 457,
#  'Elling Collection': 458,
#  'Elvira Collection': 459,
#  'Emmanuelle Through Time Collection': 460,
#  'Enchanted Collection': 461,
#  'Enola Holmes Collection': 462,
#  'Erkan & Stefan Collection': 463,
#  'Escape Plan Collection': 464,
#  'Escape Room Collection': 465,
#  'Essex Boys': 466,
#  'Eureka Seven Hi-Evolution Collection': 467,
#  'Euthanizer Collection': 468,
#  'Evil Bong Collection': 469,
#  'Evil Dead Collection': 470,
#  'Ex Collection': 471,
#  'Ex-Files': 472,
#  'Extraction Collection': 473,
#  'Eye of the Dolphin Collection': 474,
#  'F*ck You, Goethe Collection': 475,
#  'Faces of Dying Collection': 476,
#  'Fairy Tail Collection': 477,
#  'Fallen': 478,
#  'Familien Jul (Samling)': 479,
#  'Famous Five Collection': 480,
#  'Fantastic Beasts Collection': 481,
#  'Fantastic Four Collection': 482,
#  'Fantastic Journey To Oz': 483,
#  'Fat Pizza Collection': 484,
#  'Fat, Sick & Nearly Dead': 485,
#  'Fate/Stay Night: Heavens Feel Collection': 486,
#  'Fate/kaleid liner Prisma☆Illya': 487,
#  'Father and Guns Collection': 488,
#  'Father of Four Collection': 489,
#  'Fear PHarm Collection': 490,
#  'Fear Street Collection': 491,
#  'Feast Collection': 492,
#  'Felix the Rabbit Collection': 493,
#  'Feluda Collection': 494,
#  'Female Ninjas Magic Chronicles Collection': 495,
#  'Femalien Collection': 496,
#  'Fifty Shades Collection': 497,
#  'Filosofi Kopi - Collection': 498,
#  'Filthy McNasty Collection': 499,
#  'Fimfárum': 500,
#  'Final Destination Collection': 501,
#  'Final Fantasy VII Collection': 502,
#  'Finding Jesus Collection': 503,
#  'Finding Mr. Right Collection': 504,
#  'Finding Nemo Collection': 505,
#  'Finger of God': 506,
#  'Firefly Collection': 507,
#  'First Lady Collection': 508,
#  'Fishermans Friends Collection': 509,
#  'Fishtales Collection': 510,
#  'Fist of the North Star: The Legends of the True Savior': 511,
#  'Flicka Collection': 512,
#  'Flower and Snake (Remake) Collection': 513,
#  'Fool for Love': 514,
#  'Forbidden Fruit Collection': 515,
#  'Force Collection': 516,
#  'Forgotten Transports Collection': 517,
#  'Fortress Collection': 518,
#  'Four Sisters and a Wedding Collection': 519,
#  'Four Taxidrivers and a Dog Collection': 520,
#  'Franklin Collection': 521,
#  'Free Guy Collection': 522,
#  'Free!': 523,
#  'Freedom Trilogy': 524,
#  'Freier Fall Collection': 525,
#  'French Fried Vacation': 526,
#  'Friday Collection': 527,
#  'Friday the 13th Collection': 528,
#  'Friend Collection': 529,
#  'Fright Night (Reboot) Collection': 530,
#  'From Vegas to Macau Collection': 531,
#  'Frozen Collection': 532,
#  'Fubar Collection': 533,
#  'Fuerzas Especiales Collection': 534,
#  'Fuga de cerebros - Collection': 535,
#  'Fukrey Collection': 536,
#  'Full Out Collection': 537,
#  'Fullmetal Alchemist Collection': 538,
#  'G.I. Joe (Live-Action) Collection': 539,
#  'G.O.R.A. Collection': 540,
#  'GALILEO collection': 541,
#  'Gabriels Inferno Collection': 542,
#  'Gamera (Heisei) Collection': 543,
#  'Gang of Roses Collection': 544,
#  'Gangs of Wasseypur Collection': 545,
#  'Gantz Collection': 546,
#  'Garfield Collection': 547,
#  'Gasland Collection': 548,
#  'Gatao Collection': 549,
#  'Gautas Iškvietimas Collection': 550,
#  'Gen-X Cops Collections': 551,
#  'Generation Iron Collection': 552,
#  'Geniş Aile [Seri]': 553,
#  'Gett Collection': 554,
#  'Ghayal Collection': 555,
#  'Ghost In The Shell: Arise Collection': 556,
#  'Ghost Rider Collection': 557,
#  'Ghost Shark Collection': 558,
#  'Ghost in the Shell (Animated) Collection': 559,
#  'Ghostbusters Collection': 560,
#  'Ginger Snaps Collection': 561,
#  'Gintama Collection': 562,
#  'Gintama Movie Collection': 563,
#  'Girls & Panzer Filmreihe': 564,
#  'Girls on Top Collection': 565,
#  'Glass Tiger collection': 566,
#  'Gloria Duque - Colección': 567,
#  'Gnomeo & Juliet Collection': 568,
#  'Go For Broke Collection': 569,
#  'Go Goa Gone Collection': 570,
#  'Go Lala Go Collection': 571,
#  'Go! Go! Cory Carson Collection': 572,
#  'Goal! Collection': 573,
#  'Goat Story Collection': 574,
#  'God of Gamblers Collection': 575,
#  'Gods Not Dead Collection': 576,
#  'Godzilla (Millennium) Collection': 577,
#  'Godzilla Anime Trilogy': 578,
#  'Godzilla Collection': 579,
#  'Goenda Shabor Collection': 580,
#  'Gogol Collection': 581,
#  'Golden Chicken Collection': 582,
#  'Golden Winter Collection': 583,
#  'Golmaal Collection': 584,
#  'Gomez & Tavarès Collection': 585,
#  'Gonin Collection': 586,
#  'Good Take Collection': 587,
#  'Gooische Vrouwen Collection': 588,
#  'Goon Collection': 589,
#  'Goosebumps Collection': 590,
#  'Grave Encounters Collection': 591,
#  'Green Street Hooligans Collection': 592,
#  'Greenland Collection': 593,
#  'Grey Gardens Collection': 594,
#  'Grindsploitation Collection': 595,
#  'Grizzly Collection': 596,
#  'Groundhog Dave Collection': 597,
#  'Grown Ups Collection': 598,
#  'Guardians of the Galaxy Collection': 599,
#  'Gukga daepyo Collection': 600,
#  'Gumball 3000 Collection': 601,
#  'Gundala': 602,
#  'Gundam Reconguista in G Collection': 603,
#  'Gunnar Goes Collection': 604,
#  'Gunpowder Milkshake Collection': 605,
#  'Gwendolyn Shepherd Collection': 606,
#  'HIT: Cases Collection': 607,
#  'Hababam Sınıfı [Seri]': 608,
#  'Habibie & Ainun Collection': 609,
#  'Haikyu!! - Movie Collection': 610,
#  'Hakuouki Movie Collection': 611,
#  'Half Past Dead Collection': 612,
#  'Halloween (Rob Zombie Series) Collection': 613,
#  'Halloween Collection': 614,
#  'Hamilton Collection': 615,
#  'Hana and Alice Collection': 616,
#  'Hana-Dama Collection': 617,
#  'Hanni & Nanni Filmreihe': 618,
#  'Happiness Collection': 619,
#  'Happy Bhag Jayegi Collection': 620,
#  'Happy Death Day Collection': 621,
#  'Happy Feet Collection': 622,
#  'Harihar Nagar  Collection': 623,
#  'Harold & Kumar Collection': 624,
#  'Harry Potter Collection': 625,
#  'Has Fallen Collection': 626,
#  'Hatchet Collection': 627,
#  'Hate Story Collection': 628,
#  'Haunted Road Collection': 629,
#  'Haunted School Collection': 630,
#  'Haunted Transylvania Collection': 631,
#  'Havoc Collection': 632,
#  'Hayflower and Quiltshoe Collection': 633,
#  'Hayride Collection': 634,
#  'He Who Dares Collection': 635,
#  'Head Cases': 636,
#  'Headless Hero Collection': 637,
#  'Healed by Grace Collection': 638,
#  'Heaven, Hell and Purgatory Collection': 639,
#  'Heavens Lost Property': 640,
#  'Heavy Metal Collection': 641,
#  'Hell House LLC Collection': 642,
#  'Hellboy Collection': 643,
#  'Hellcats Revenge Collection': 644,
#  'Hellraiser Collection': 645,
#  'Help, I Shrunk My...': 646,
#  'Henry Fool Collection': 647,
#  'Hentai Kamen Collection': 648,
#  'Hera Pheri Collection': 649,
#  'Herbie Collection': 650,
#  'Hercule Poirot Collection': 651,
#  'Herr Lehmann Filmreihe': 652,
#  'Hey Arnold Movie Collection': 653,
#  'Hidden Colors Collection': 654,
#  'Hideshi Hinos Theater of Horror': 655,
#  'High School Musical Collection': 656,
#  'High Strung Collection': 657,
#  'High&Low The Movie Collection': 658,
#  'Highlander Collection': 659,
#  'Hitman Collection': 660,
#  'Hobbs & Shaw Collection': 661,
#  'Hollow Man Collection': 662,
#  'Home Alone Collection': 663,
#  'Honest Candidate Collection': 664,
#  'Honey Collection': 665,
#  'Hoodwinked! Collection': 666,
#  'Hooked Collection': 667,
#  'Horrible Bosses Collection': 668,
#  'Horror Stories Collection': 669,
#  'Hostel Collection': 670,
#  'Hot Tub Time Machine Collection': 671,
#  'Hotel Inferno Collection': 672,
#  'Hotel Transylvania Collection': 673,
#  'House of the Dead Collection': 674,
#  'Housefull Collection': 675,
#  'How High Collection': 676,
#  'How to Train Your Dragon Collection': 677,
#  'Howard Lovecraft Collection': 678,
#  'Huevos - Collection': 679,
#  'Hunter x Hunter Collection': 680,
#  'Hurricane Bianca Collection': 681,
#  'I Am Legend Collection': 682,
#  'I Am Vengeance Collection': 683,
#  'I Can Quit Whenever I Want Collection': 684,
#  'I Give You My Word Collection': 685,
#  'I Got Five on It Collection': 686,
#  'I Got the Hook Up Collection': 687,
#  'I Love Hong Kong Collection': 688,
#  'I Spit on Your Grave (Original) Collection': 689,
#  'I Spit on Your Grave Collection': 690,
#  'Ice Age Collection': 691,
#  'Ice Collection': 692,
#  'Iceman Collection': 693,
#  'If You Are the One (Collection)': 694,
#  'Il peggio della mia vita': 695,
#  'Immaturi Collection': 696,
#  'Impy Collection': 697,
#  'In Search of Darkness Collection': 698,
#  'In Search of Walt Whitman Collection': 699,
#  'In the Name of the King Collection': 700,
#  'Inadequate People Collection': 701,
#  'Independence Day Collection': 702,
#  'Indian Gangster Trilogy': 703,
#  'Indiana Jones Collection': 704,
#  'Infernal Affairs Collection': 705,
#  'Initial D': 706,
#  'Inmu': 707,
#  'Inside Man Collection': 708,
#  'Insidious Collection': 709,
#  'Into the Blue Collection': 710,
#  'Inuyasha Collection': 711,
#  'Ip Man Collection': 712,
#  'Iqbal (Samling)': 713,
#  'Iris Collection': 714,
#  'Iron Girl Collection': 715,
#  'Iron Man Collection': 716,
#  'Iron Sky Collection': 717,
#  'Ironclad Collection': 718,
#  'It Collection': 719,
#  'Ivan Tsarevich & the Grey Wolf Collection': 720,
#  'Jack Reacher Collection': 721,
#  'Jack in the Box Collection': 722,
#  'Jack vs. Collection': 723,
#  'Jackass Collection': 724,
#  'Jacqueline Mazerin Collection': 725,
#  'James Bond Collection': 726,
#  'Jan Dara': 727,
#  'Jannat Collection': 728,
#  'Jarhead Collection': 729,
#  'Jarle Klepp-trilogien': 730,
#  'Jay and Silent Bob Collection': 731,
#  'Jeepers Creepers Collection': 732,
#  'Jeremy Jones Trilogy': 733,
#  'Jet Set - Saga': 734,
#  'Jiivi Collection': 735,
#  'Jim Button Collection': 736,
#  'Jism Collection': 737,
#  'Joan of Arc Collection': 738,
#  'Jodorowskys film autobiography': 739,
#  'Joe Dirt Collection': 740,
#  'John Wick Collection': 741,
#  'Johnny 100 Pesos Collection': 742,
#  'Johnny English Collection': 743,
#  'Joséphine - Saga': 744,
#  'Journey Collection': 745,
#  'Journey to the West Collection': 746,
#  'Joy Ride Collection': 747,
#  'Ju-on Collection': 748,
#  'Judwaa Collection': 749,
#  'Julemandens Datter (Samling)': 750,
#  'Jumanji Collection': 751,
#  'Jump Street Collection': 752,
#  'Jungle Cruise Collection': 753,
#  'Jungle Jack Collection': 754,
#  'Jurassic Park Collection': 755,
#  'Jurassic Shark Collection': 756,
#  'Justice League (DC Universe Animated) Collection': 757,
#  'K-9 Adventures Collection': 758,
#  'K.G.F Collection': 759,
#  'KAIJI Collection': 760,
#  'Kaguya-sama: Love is War - Collection': 761,
#  'Kahaani Collection': 762,
#  'Kaithi Collection': 763,
#  'Kakegurui: The Movie': 764,
#  'Kamen Rider (1971) Collection': 765,
#  'Kamen Rider Agito Collection': 766,
#  'Kamen Rider Amazons Collection': 767,
#  'Kamen Rider Decade Collection': 768,
#  'Kamen Rider OOO Collection': 769,
#  'Kamen Rider The First Collection': 770,
#  'Kamen Rider W Collection': 771,
#  'Kandasamys Collection': 772,
#  'Kangaroo Jack Collection': 773,
#  'Karla Collection': 774,
#  'Kartoffelsalat Filmreihe': 775,
#  'Kazuo Umezus Horror Theater Collection': 776,
#  'Keinohrhasen Filmreihe': 777,
#  'Kekko Kamen Collection': 778,
#  'Keluarga Cemara Collection': 779,
#  'Kibakichi Collection': 780,
#  'Kick-Ass Collection': 781,
#  'Kickboxer (Reboot) Collection': 782,
#  'Kidulthood Collection': 783,
#  'Kill Bill Collection': 784,
#  'Kill Buljo Collection': 785,
#  'Killer Shrews Collection': 786,
#  'Killing Cabos Collection': 787,
#  'Killjoy Collection': 788,
#  'Kindergarten Cop Collection': 789,
#  'King Naresuan Collection': 790,
#  'King of Guns Collection': 791,
#  'Kingsman Collection': 792,
#  'Kirikou Collection': 793,
#  'Kizumonogatari': 794,
#  'Klovn (filmene)': 795,
#  'Knerten Collection': 796,
#  'Knights of the Damned Collection': 797,
#  'Knives Out Collection': 798,
#  'Knocked Up Collection': 799,
#  'Knutsen & Ludvigsen Collection': 800,
#  'Kocan Kadar Konuş [Seri]': 801,
#  'Koko Collection': 802,
#  'Kolah Ghermezi': 803,
#  'Krampus Collection': 804,
#  'Krrish Collection': 805,
#  'Kung Fu Masters Collection': 806,
#  'Kung Fu Panda Collection': 807,
#  'Kung Fu Traveler Collection': 808,
#  'Kuntilanak Collection': 809,
#  'Kuroko no Basket: Winter Cup Soushuuhen Collection': 810,
#  'Kuroshithuji Collection': 811,
#  'Kutsal Damacana [Seri]': 812,
#  'Kvartet I Collection': 813,
#  'Köstebekgiller [Seri]': 814,
#  'L.O.R.D Collection': 815,
#  'LEGO DC Comics Super Heroes Collection': 816,
#  'LEGO DC Super Hero Girls Collection': 817,
#  'LEGO: Hero Factory - Saga': 818,
#  'LUPIN THE IIIRD Collection': 819,
#  'La Abuela Collection': 820,
#  'La Soga Collection': 821,
#  'La befana vien di notte': 822,
#  'La niña de tus ojos - Colección': 823,
#  'Lady Ninja Kasumi Series': 824,
#  'Laid To Rest Collection': 825,
#  'Laissez-faire': 826,
#  'Lake Fear Collection': 827,
#  'Lan Kwai Fong Collection': 828,
#  'Lapland Odyssey Collection': 829,
#  'Largo Winch Collection': 830,
#  'Las Leyendas Collection': 831,
#  'LasseMajas Detektivbyrå (samling)': 832,
#  'Laughing Gor（系列）': 833,
#  'Lauras Stern Filmreihe': 834,
#  'Lazer Team Collection': 835,
#  'League of Gods': 836,
#  'Leap collection': 837,
#  'Left Behind Collection': 838,
#  'Legally Blonde Collection': 839,
#  'Legend of a Rabbit Collection': 840,
#  'Lemon Popsicle Collection': 841,
#  'Leprechaun Collection': 842,
#  'Les Crevettes pailletées - Saga': 843,
#  'Les Petits Mouchoirs - Saga': 844,
#  'Lesní trilogie (kolekce)': 845,
#  'Lesson of the Evil Collection': 846,
#  'Let Him Be a Basketball Player Collection': 847,
#  'Lethal Kittens Collection': 848,
#  'Letters to Santa Collection': 849,
#  'Lezioni di Cioccolato Collection': 850,
#  'Liar Game Collection': 851,
#  'Library Wars Collection': 852,
#  'Life in a Day Collection': 853,
#  'Life of Crime Collection': 854,
#  'Lights Out Collection': 855,
#  'Like Mike Collection': 856,
#  'Like a Dragon Collection': 857,
#  'Lilly the Witch Collection': 858,
#  'Lilo & Stitch Collection': 859,
#  'Line Walker Collection': 860,
#  'Little Bear': 861,
#  'Little Book of Love Collection': 862,
#  'Little Forest Collection': 863,
#  'Little Nicholas Trilogy': 864,
#  'Little Witch Academia Collection': 865,
#  'Live. Die. Repeat Collection': 866,
#  'Living Dead Collection': 867,
#  'Long Long Time Ago': 868,
#  'Loro Collection': 869,
#  'Los crímenes del sur': 870,
#  'Lost Collection': 871,
#  'Lotte Collection': 872,
#  'Louis & Luca Collection': 873,
#  'Louis Theroux & The Most Hated Family In America': 874,
#  'Love Comes Softly Collection': 875,
#  'Love For Sale Collection': 876,
#  'Love Stories 2 Series': 877,
#  'Love Stories Series': 878,
#  'Love Undercover Collection': 879,
#  'Love in a... Collection': 880,
#  'Love in the City Collection': 881,
#  'Lovey-Dovey Collection': 882,
#  'Lucifer Collection': 883,
#  'Lucy Collection': 884,
#  'L♥DK': 885,
#  'MVP': 886,
#  'Maari Collection': 887,
#  'Machete Collection': 888,
#  'Machine Girl Collection': 889,
#  'Macross Frontier Collection': 890,
#  'Mad Max Collection': 891,
#  'Madagascar Collection': 892,
#  'Made in Abyss Collection': 893,
#  'Madea - Collection': 894,
#  'Magic Carpet Ride Collection': 895,
#  'Magic Mike Collection': 896,
#  'Magic Silver Collection': 897,
#  'Magical Girl Lyrical Nanoha Collection': 898,
#  'Major Korenev Trilogy': 899,
#  'Major Mahadevan Collection': 900,
#  'Make Me Shudder': 901,
#  'Maleficent Collection': 902,
#  'Malevolence Collection': 903,
#  'Malibu Rescue Collection': 904,
#  'Mall Cop Collection': 905,
#  'Mamma Mia! Collection': 906,
#  'Man and a Baby Collection': 907,
#  'Man of Steel Collection': 908,
#  'Mandie Movies Collection': 909,
#  'Mang Kepweng Collection': 910,
#  'Mann Filmreihe': 911,
#  'Manos Collection': 912,
#  'Manual of Love Collection': 913,
#  'Mapado Collection': 914,
#  'March Comes in Like a Lion Collection': 915,
#  'March of the Penguins Collection': 916,
#  'Mardaani Collection': 917,
#  'Mardock Scramble Collection': 918,
#  'Marfa Girl Collection': 919,
#  'Maria, ihm schmeckts nicht! Filmreihe': 920,
#  'Mariachi Collection': 921,
#  'Marley & Me Collection': 922,
#  'Marrying the Mafia Collection': 923,
#  'Mary Poppins Collection': 924,
#  'Maskeli Beşler [Seri]': 925,
#  'Masquerade Hotel Collection': 926,
#  'Masti Collection': 927,
#  'Mata Batin Collection': 928,
#  'Max Collection': 929,
#  'Max Havoc Collection': 930,
#  'Max Pinlig Collection': 931,
#  'May the Devil Take You': 932,
#  'Maya the Bee Collection': 933,
#  'McDull Collection': 934,
#  'Mean Girls Collection': 935,
#  'Meat pie collection': 936,
#  'Meatball Machine Collection': 937,
#  'Mechanic Collection': 938,
#  'Meet the Blacks Collection': 939,
#  'Meet the In-Laws': 940,
#  'Meet the Parents Collection': 941,
#  'Mega Shark Collection': 942,
#  'Megalodon Collection': 943,
#  'Mektoub is Mektoub': 944,
#  'Memoirs of a Lady Ninja Series': 945,
#  'Men & Women Dilogy': 946,
#  'Men In Black Collection': 947,
#  'Men Suddenly in Black Collections': 948,
#  'Men in the City Collection': 949,
#  'Methagu Collection': 950,
#  'Mexico Barbaro Filmreihe': 951,
#  'Mi Nismo Anđeli Collection': 952,
#  'Midnight Diner Collection': 953,
#  'Mince Alors ! - Saga': 954,
#  'Minions Collection': 955,
#  'Minuscule Collection': 956,
#  'Mirror Mirror Collection': 957,
#  'Mirrors Collection': 958,
#  'Mischievous Kiss The Movie': 959,
#  'Miss Congeniality Collection': 960,
#  'Miss Modern Collection': 961,
#  'Missing 411 Collection': 962,
#  'Mission: Impossible Collection': 963,
#  'Mister Twister Collection': 964,
#  'Mobile Suit Gundam Thunderbolt Collection': 965,
#  'Mobile Suit Gundam: The Origin Collection': 966,
#  'Mobile Suit Zeta Gundam A New Translation': 967,
#  'Mojin Collection': 968,
#  'Molly Hartley Collection': 969,
#  'Monica and Friends': 970,
#  'Monster Family Collection': 971,
#  'Monster High Collection': 972,
#  'Monster Hunt Collection': 973,
#  'Monsters Collection': 974,
#  'Monsters, Inc. Collection': 975,
#  'Moontrap Collection': 976,
#  'Morava, krásná zem (kolekce)': 977,
#  'Mortadelo y Filemón - Colección': 978,
#  'Mortal Kombat Collection': 979,
#  'Mortal Kombat Legends Collection': 980,
#  'Moschettieri del Re - Collezione': 981,
#  'Mountain Collection': 982,
#  'Mr. Bean Collection': 983,
#  'Mr. Bones Collection': 984,
#  'Mr. Ripley Collection': 985,
#  'Mucize [Seri]': 986,
#  'Mummys Kiss Collection': 987,
#  'Munafik Trilogy': 988,
#  'Muni Collection': 989,
#  'Munna Bhai Collection': 990,
#  'Murder Collection': 991,
#  'Murder Mystery Collection': 992,
#  'Mushishi Collection': 993,
#  'My Alien Girlfriend Collection': 994,
#  'My Big Fat Greek Wedding Collection': 995,
#  'My Boss, My Collection': 996,
#  'My Brother Series': 997,
#  'My Friends Sister Series': 998,
#  'My Hero Academia Movie Collection': 999,
#  ...}

# %% [markdown]
# #### ~~WAIT!~~ Nevermind

# %%
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#          budget  \
# 0        100000
# 1             0
# 2             0
# 3      76000000
# 4             0
# ...         ...
# 78392         0
# 78393         0
# 78394         0
# 78395         0
# 78396       400
#
#                                                                                                                                                                       genres  \
# 0                                                                                                                                                                         []
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                            [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 4                                                                                                                [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
# ...                                                                                                                                                                      ...
# 78392                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78393                                                                           [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}, {'id': 18, 'name': 'Drama'}]
# 78394                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78395                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78396                                                                                                         [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
#
#                                                                         homepage  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                  http://www.universalstudiosentertainment.com/children-of-men/
# 4                                                                            NaN
# ...                                                                          ...
# 78392                                              http://icarusfilms.com/if-cli
# 78393                                                                        NaN
# 78394  https://www.michaelraeburn.com/site/web/mr/zimbabwe-countdown_documentary
# 78395                                                                        NaN
# 78396                                                                        NaN
#
#            id    imdb_id original_language                 original_title  \
# 0       30356  tt0144280                en  Whispers from a Shallow Grave
# 1       58520  tt0197633                en         Live Freaky Die Freaky
# 2      459563  tt0204250                en          Death of a Saleswoman
# 3        9693  tt0206634                en                Children of Men
# 4        9925  tt0244521                en                    Funny Money
# ...       ...        ...               ...                            ...
# 78392  387250  tt7098636                fr   Le Clitoris, ce cher inconnu
# 78393  640680  tt7246872                en         Tokyo Bedoone Tavaghof
# 78394  515137  tt7637550                en             Zimbabwe Countdown
# 78395  713681  tt9414698                en                   The Hot Shoe
# 78396  253999  tt9641790                en                     Clearwater
#
#                                                                                                                                                                                                                                                                                                           overview  \
# 0                                                                                                                                                            When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                            It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2      Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                                   In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 4      Henry Perkins, a mild-mannered accountant, accidentally trades briefcases with another man, to find out that there's a million dollars inside. Henry tells his unsuspecting wife of their new-found fortune, but she doesn't embrace it as well as he does. Soon they're joined by their best friends, a...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  Topics about female sexuality are growing in popularity. Magazines and talk shows all discuss it. Yet a fair percentage of women are said to suffer from female sexual dysfunction. While male sexual problems have traditionally received the most publicity, only recently has research begun into the...
# 78393                                                                                                                                                                                                                                                                                                          NaN
# 78394                                                                                                                                                                       Once touted as Zimbabwe's saviour, Robert Mugabe has become synonymous with bad government and misrule. But where did it all go wrong?
# 78395                                                                                                                          A Documentary Movie About Card Counting In The Casino Game of 21. The director used $5,000 of the movie's budget to learn the counting methods, and put them to the test on screen.
# 78396                                                                                                                                                                                   A woman has been abducted by the Clearwater killer, and it's down to one man to solve the murderer's clues and rescue her.
#
#        popularity                       poster_path  \
# 0           0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1           1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2           0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4           4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...           ...                               ...
# 78392       1.400  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393       0.600  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394       0.711  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395       0.600                               NaN
# 78396       2.744  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                                                                                                                                                                                                                                                                               production_companies  \
# 0                                                                                                                                                                                                                                                                                                               []
# 1                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                   [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3               [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FWE Picture Company', 'origin_country': ''}, {'id': 30584, 'logo_path': '/7s0nJTTztkOVeIgavfOwx36EBtj.png', 'name': 'Thinkfactory Media', 'origin_country': 'US'}, {'id': 110623, 'logo_path': None, 'name': 'Tobebo Filmproduktions', 'origin_country': ''}...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cats & Dogs Films', 'origin_country': 'FR'}, {'id': 7106, 'logo_path': None, 'name': 'Sylicone', 'origin_country': 'FR'}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 639, 'logo_path': '/fN...
# 78393                                                                                                                                                                                                                                                                                                           []
# 78394                                                                                                                                                                                          [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}]
# 78395                                                                                                                                                                                                                                                                                                           []
# 78396                                                                                                                                                                                                                   [{'id': 174685, 'logo_path': None, 'name': 'Little Buster Studios', 'origin_country': ''}]
#
#                                                                                                                                production_countries  \
# 0                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3                                        [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# ...                                                                                                                                             ...
# 78392                                                                                                      [{'iso_3166_1': 'FR', 'name': 'France'}]
# 78393                                                                                                        [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 78394                                                            [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'ZW', 'name': 'Zimbabwe'}]
# 78395                                                                                                                                            []
# 78396                                                                                                                                            []
#
#       release_date   revenue  runtime  \
# 0       1997-01-01         0     90.0
# 1       2006-01-31         0     75.0
# 2       2006-09-18         0     77.0
# 3       2006-09-22  70595464    109.0
# 4       2006-01-01         0     98.0
# ...            ...       ...      ...
# 78392   2004-01-16         0     60.0
# 78393   2003-09-10         0     98.0
# 78394   2003-08-28         0     55.0
# 78395   2003-01-01         0     96.0
# 78396   2003-06-10         0     60.0
#
#                                                           spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 4      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                    ...
# 78392  [{'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}]
# 78393    [{'english_name': 'Persian', 'iso_639_1': 'fa', 'name': 'فارسی'}]
# 78394  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78395  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78396  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#          status  \
# 0      Released
# 1      Released
# 2      Released
# 3      Released
# 4      Released
# ...         ...
# 78392  Released
# 78393  Released
# 78394  Released
# 78395  Released
# 78396  Released
#
#                                                                                                                       tagline  \
# 0                                                                                                                         NaN
# 1                                                                                                                         NaN
# 2                                                            6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                                                                           The future's a thing of the past.
# 4      Henry Perkins accidentally trades briefcases with another man, to find out that there's five million dollars inside...
# ...                                                                                                                       ...
# 78392                                                                                                                     NaN
# 78393                                                                                                                     NaN
# 78394                                                                                                                     NaN
# 78395                                                                                                                     NaN
# 78396                                                                                                                     NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification  \
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 78392           NaN
# 78393           NaN
# 78394           NaN
# 78395           NaN
# 78396           NaN
#
#                                                                          production_company_list  \
# 0                                                                                             []
# 1                                                                                             []
# 2                                                                   [Girl Next Door Productions]
# 3                              [Universal Pictures, Strike Entertainment, Hit & Run Productions]
# 4                 [FWE Picture Company, Thinkfactory Media, Tobebo Filmproduktions, Castel Film]
# ...                                                                                          ...
# 78392  [Cats & Dogs Films, Sylicone, ARTE, DR TV, Planète+, SBS TV, CNC, PROCIREP, Angoa-Agicoa]
# 78393                                                                                         []
# 78394                                                                       [ARTE France Cinéma]
# 78395                                                                                         []
# 78396                                                                    [Little Buster Studios]
#
#       collection
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 78392       None
# 78393       None
# 78394       None
# 78395       None
# 78396       None
#
# [78397 rows x 28 columns]

# %%
df_title_collection = df[['imdb_id','collection']]
df_title_collection
# Out:
#          imdb_id collection
# 0      tt0144280       None
# 1      tt0197633       None
# 2      tt0204250       None
# 3      tt0206634       None
# 4      tt0244521       None
# ...          ...        ...
# 78392  tt7098636       None
# 78393  tt7246872       None
# 78394  tt7637550       None
# 78395  tt9414698       None
# 78396  tt9641790       None
#
# [78397 rows x 2 columns]

# %%
df_title_collection.isna().sum()
# Out:
# imdb_id           0
# collection    74480
# dtype: int64

# %%
df_title_collection = df_title_collection.dropna()
df_title_collection.isna().sum()
# Out:
# imdb_id       0
# collection    0
# dtype: int64

# %%
df_title_collection['collection_id'] = df_title_collection['collection'].map(collection_map)
df_title_collection
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_10067/4096060843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_collection['collection_id'] = df_title_collection['collection'].map(collection_map)
#          imdb_id                            collection  collection_id
# 18     tt0317219                       Cars Collection            274
# 19     tt0317919        Mission: Impossible Collection            963
# 34     tt0344854  Arthur and the Invisibles Collection            131
# 36     tt0348150                   Superman Collection           1389
# 49     tt0362120                Scary Movie Collection           1256
# ...          ...                                   ...            ...
# 78301  tt1133935            Detective Conan Collection            391
# 78349  tt2243192            Ultraman Cosmos Collection           1778
# 78374  tt3533690          Raped by an Angel Collection           1187
# 78376  tt3679304      Twin Dragon Encounter Collection           1773
# 78390  tt6352612               Police State Collection           1142
#
# [3917 rows x 3 columns]

# %%
df_collection = pd.DataFrame({'collection_id':collection_map.values(), 'collection_name':collection_map.keys()})
df_collection
# Out:
#       collection_id            collection_name
# 0                 0          #TemanTapiMenikah
# 1                 1     ... Cameras Collection
# 2                 2           .hack Collection
# 3                 3  10 giorni... - Collezione
# 4                 4       100 Girls Collection
# ...             ...                        ...
# 1938           1938                    달마야 시리즈
# 1939           1939                     독전 시리즈
# 1940           1940              동갑내기 과외하기 시리즈
# 1941           1941                반드시 크게 들을 것
# 1942           1942                     식객 시리즈
#
# [1943 rows x 2 columns]

# %% [markdown]
# # LOAD

# %% [markdown]
# ## Connect to MySQL

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *

# %%
## Getting mysql server password
import json
with open('/Users/codingdojo/.secret/mysql.json') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['user', 'password'])

# %%
## create a new movies database
# connect_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies"
connect_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/movies-viz"

# %%
## Check if database exists, if not, create it
if database_exists(connect_str) == False:
    print("Creating the database.")
    create_database(connect_str)
else:
    print('The database already exists.')
# Out:
# The database already exists.

# %%
## create engine
engine = create_engine(connect_str)

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
tables = pd.read_sql(q, engine)
tables
# Out:
#        Tables_in_movies-viz
# 0                    genres
# 1      production_companies
# 2              title_basics
# 3              title_genres
# 4  title_production_company
# 5             title_ratings
# 6                      tmdb

# %% [markdown]
# ### Saving`title_basics` to db

# %%
def get_schema(table,debug=False):
    ## save pandas dtypes in list, make empty dict
    dtypes = table.dtypes
    schema = {}
    
    # for each column
    for col in dtypes.index:
        ## print info if in debug mode
        if debug:
            print(f"{col} = {dtypes.loc[col]}")

        ## if its a string column (object)
        if dtypes.loc[col]=='object':
            
            ## Fill null values and make sure whole column is str
            data = table[col].fillna('').astype(str)
            
            ## get len first
            len_str = data.map(len).max()
            
            ## if the string is shorter than 21845 use String
            # (forget how i knew it was max size)
            if len_str < 21845:
                schema[col] = String( len_str + 1)
                
            ## If longer use Text
            else:
                schema[col] = Text(len_str+1)
        
        # if float make Float
        elif dtypes.loc[col] == 'float':
            schema[col] = Float()

        ## if int make Integer
        elif dtypes.loc[col] == 'int':
            schema[col] = Integer()#Float()#
            
        ## if bool make Boolean
        elif dtypes.loc[col] == 'bool':
            schema[col] = Boolean()
            
    return schema

# %%
basics_schema = get_schema(basics)
basics_schema
# Out:
# {'tconst': String(length=11),
#  'primaryTitle': String(length=243),
#  'startYear': Float(),
#  'runtimeMinutes': Integer()}

# %%
# ## saving text length
# key_len = basics['tconst'].map(len).max()
# title_len = basics['primaryTitle'].map(len).max()
# key_len, title_len

# %%
# basics_schema = {
#     "tconst": String(key_len+1), 
#     "primaryTitle": Text(title_len+1),
#     'startYear':Float(),
#     'runtimeMinutes':Integer()
#     }
# basics_schema

# %%
## Saving basics as table with schema,
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)

## setting title basics as the primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
## query first rows 
q = """SELECT * FROM title_basics LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst                                        primaryTitle  startYear  \
# 0  tt0035423                                      Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mirror     2020.0
# 2  tt0067683            Workers '71: Nothing About Us Without Us     2006.0
# 3  tt0069049                          The Other Side of the Wind     2018.0
# 4  tt0088751                                   The Naked Monster     2005.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2              47
# 3             122
# 4             100

# %% [markdown]
# ### Saving Genre Tables

# %% [markdown]
# #### Saving genre_lookup

# %%
genre_schema = get_schema(genre_lookup)
genre_schema
# Out:
# {'Genre_Name': String(length=12), 'Genre_ID': Integer()}

# %%
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Primary key is Genre_ID
genre_lookup.to_sql('genres',engine,index=False,  if_exists='replace')

engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`Genre_ID`);')

# %%
q = """SELECT * FROM genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Saving `title_genres` table

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
title_genres.to_sql('title_genres',engine,index=False,
                    if_exists='replace' )

# engine.execute('ALTER TABLE title_genres ADD PRIMARY KEY (`tconst`);')
# Out:
# 207423

# %%
q = """SELECT * FROM title_genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  Genre_ID
# 0  tt0035423         5
# 1  tt0035423        10
# 2  tt0035423        19
# 3  tt0062336         8
# 4  tt0067683         7

# %% [markdown]
# ### Saving `title_ratings`

# %%
# ratings_schema = {'tconst':String(key_len+1), 
#                  'averageRating':Float(),
#                  'numVotes':Integer()}#get_schema(ratings)
ratings_schema = get_schema(ratings)
ratings_schema
# Out:
# {'tconst': String(length=11), 'averageRating': Float(), 'numVotes': Integer()}

# %%
ratings.to_sql('title_ratings',engine,if_exists='replace',index=False,
              dtype=ratings_schema)
engine.execute("ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`)")

# %%
q = """SELECT * FROM title_ratings LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     85245
# 1  tt0062336            6.4       163
# 2  tt0067683            6.4        90
# 3  tt0069049            6.7      7435
# 4  tt0088751            5.2       327

# %% [markdown]
# ### Saving TMDB API Data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78397 entries, 0 to 78396
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    78397 non-null  bool
#  1   backdrop_path            43654 non-null  object
#  2   belongs_to_collection    3943 non-null   object
#  3   budget                   78397 non-null  int64
#  4   genres                   78397 non-null  object
#  5   homepage                 21370 non-null  object
#  6   id                       78397 non-null  int64
#  7   imdb_id                  78397 non-null  object
#  8   original_language        78397 non-null  object
#  9   original_title           78397 non-null  object
#  10  overview                 76518 non-null  object
#  11  popularity               78397 non-null  float64
#  12  poster_path              68663 non-null  object
#  13  production_companies     78397 non-null  object
#  14  production_countries     78397 non-null  object
#  15  release_date             76442 non-null  object
#  16  revenue                  78397 non-null  int64
#  17  runtime                  76952 non-null  float64
#  18  spoken_languages         78397 non-null  object
#  19  status                   78397 non-null  object
#  20  tagline                  26818 non-null  object
#  21  title                    78397 non-null  object
#  22  video                    78397 non-null  bool
#  23  vote_average             78397 non-null  float64
#  24  vote_count               78397 non-null  int64
#  25  certification            16961 non-null  object
#  26  production_company_list  77906 non-null  object
#  27  collection               3917 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(19)
# memory usage: 15.7+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False                               NaN                   NaN    100000
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0
#
#                                                                                                                                                                   genres  \
# 0                                                                                                                                                                     []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                        [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                    [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 4                                                                                                            [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
#
#                                                         homepage      id  \
# 0                                                            NaN   30356
# 1                                                            NaN   58520
# 2                                                            NaN  459563
# 3  http://www.universalstudiosentertainment.com/children-of-men/    9693
# 4                                                            NaN    9925
#
#      imdb_id original_language                 original_title  \
# 0  tt0144280                en  Whispers from a Shallow Grave
# 1  tt0197633                en         Live Freaky Die Freaky
# 2  tt0204250                en          Death of a Saleswoman
# 3  tt0206634                en                Children of Men
# 4  tt0244521                en                    Funny Money
#
#                                                                                                                                                                                                                                                                                                       overview  \
# 0                                                                                                                                                        When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                        It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2  Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                               In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 4  Henry Perkins, a mild-mannered accountant, accidentally trades briefcases with another man, to find out that there's a million dollars inside. Henry tells his unsuspecting wife of their new-found fortune, but she doesn't embrace it as well as he does. Soon they're joined by their best friends, a...
#
#    popularity                       poster_path  \
# 0       0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1       1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2       0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3      18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4       4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                                                                                                                                                                                                                                                                           production_companies  \
# 0                                                                                                                                                                                                                                                                                                           []
# 1                                                                                                                                                                                                                                                                                                           []
# 2                                                                                                                                                                                                               [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3           [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FWE Picture Company', 'origin_country': ''}, {'id': 30584, 'logo_path': '/7s0nJTTztkOVeIgavfOwx36EBtj.png', 'name': 'Thinkfactory Media', 'origin_country': 'US'}, {'id': 110623, 'logo_path': None, 'name': 'Tobebo Filmproduktions', 'origin_country': ''}...
#
#                                                                                                                            production_countries  \
# 0                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3                                    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
#
#   release_date   revenue  runtime  \
# 0   1997-01-01         0     90.0
# 1   2006-01-31         0     75.0
# 2   2006-09-18         0     77.0
# 3   2006-09-22  70595464    109.0
# 4   2006-01-01         0     98.0
#
#                                                       spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 4  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#      status  \
# 0  Released
# 1  Released
# 2  Released
# 3  Released
# 4  Released
#
#                                                                                                                   tagline  \
# 0                                                                                                                     NaN
# 1                                                                                                                     NaN
# 2                                                        6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                                                                       The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases with another man, to find out that there's five million dollars inside...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification  \
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R
#
#                                                           production_company_list  \
# 0                                                                              []
# 1                                                                              []
# 2                                                    [Girl Next Door Productions]
# 3               [Universal Pictures, Strike Entertainment, Hit & Run Productions]
# 4  [FWE Picture Company, Thinkfactory Media, Tobebo Filmproduktions, Castel Film]
#
#   collection
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None

# %% [markdown]
# ### Saving Production Companies

# %%
df_title_companies
# Out:
#          imdb_id     production_company_list  company_id
# 0      tt0144280                         NaN         NaN
# 1      tt0197633                         NaN         NaN
# 2      tt0204250  Girl Next Door Productions     14402.0
# 3      tt0206634          Universal Pictures     36827.0
# 3      tt0206634        Strike Entertainment     33356.0
# ...          ...                         ...         ...
# 78392  tt7098636                Angoa-Agicoa      2167.0
# 78393  tt7246872                         NaN         NaN
# 78394  tt7637550          ARTE France Cinéma       961.0
# 78395  tt9414698                         NaN         NaN
# 78396  tt9641790       Little Buster Studios     20583.0
#
# [138213 rows x 3 columns]

# %% [markdown]
# #### `title_company`

# %%
table_title_company = df_title_companies.drop(columns=['production_company_list']) 
table_title_company.isna().sum()
# Out:
# imdb_id           0
# company_id    31660
# dtype: int64

# %%
table_title_company = table_title_company.dropna()
table_title_company['company_id'] = table_title_company['company_id'].astype(int)
table_title_company
# Out:
#          imdb_id  company_id
# 2      tt0204250       14402
# 3      tt0206634       36827
# 3      tt0206634       33356
# 3      tt0206634       16040
# 4      tt0244521       11845
# ...          ...         ...
# 78392  tt7098636        6068
# 78392  tt7098636       26073
# 78392  tt7098636        2167
# 78394  tt7637550         961
# 78396  tt9641790       20583
#
# [106553 rows x 2 columns]

# %%
## saving text length
key_len = table_title_company['imdb_id'].map(len).max()

## saving schema
api_data_schema = {'imdb_id':String(key_len+1)}
api_data_schema
# Out:
# {'imdb_id': String(length=11)}

# %%
# saving mvp version
## Primary key is Genre_ID
table_title_company.to_sql('title_production_company',engine, 
                           index=False,dtype=api_data_schema, if_exists='replace')
# Out:
# 106553

# %% [markdown]
# ### `companies`

# %%
table_companies = df_company.copy()
table_companies
# Out:
#        company_id                   company_name
# 0               0  # Andrea Sperling Productions
# 1               1              #Beardforce Films
# 2               2                 #Sinning Works
# 3               3              #littlesecretfilm
# 4               4                        (주)라인필름
# ...           ...                            ...
# 39867       39867                        타임스토리그룹
# 39868       39868                          파파스필름
# 39869       39869                         플랫폼픽쳐스
# 39870       39870                           한맥문화
# 39871       39871                      환타지엔터테인먼트
#
# [39872 rows x 2 columns]

# %%
# saving mvp version
## Primary key is Genre_ID
table_companies.to_sql('production_companies',engine, index=False,dtype=api_data_schema, if_exists='replace')
# Out:
# 39872

# %% [markdown]
# ### `title_collections`

# %%
df_title_collection
# Out:
#          imdb_id                            collection  collection_id
# 18     tt0317219                       Cars Collection            274
# 19     tt0317919        Mission: Impossible Collection            963
# 34     tt0344854  Arthur and the Invisibles Collection            131
# 36     tt0348150                   Superman Collection           1389
# 49     tt0362120                Scary Movie Collection           1256
# ...          ...                                   ...            ...
# 78301  tt1133935            Detective Conan Collection            391
# 78349  tt2243192            Ultraman Cosmos Collection           1778
# 78374  tt3533690          Raped by an Angel Collection           1187
# 78376  tt3679304      Twin Dragon Encounter Collection           1773
# 78390  tt6352612               Police State Collection           1142
#
# [3917 rows x 3 columns]

# %%
table_title_collection = df_title_collection.drop(columns=['collection']) 
table_title_collection.isna().sum()
# Out:
# imdb_id          0
# collection_id    0
# dtype: int64

# %%
table_title_collection = table_title_collection.dropna()
table_title_collection['collection_id'] = table_title_collection['collection_id'].astype(int)
table_title_collection
# Out:
#          imdb_id  collection_id
# 18     tt0317219            274
# 19     tt0317919            963
# 34     tt0344854            131
# 36     tt0348150           1389
# 49     tt0362120           1256
# ...          ...            ...
# 78301  tt1133935            391
# 78349  tt2243192           1778
# 78374  tt3533690           1187
# 78376  tt3679304           1773
# 78390  tt6352612           1142
#
# [3917 rows x 2 columns]

# %%
# ## saving text length
# key_len = table_title_collection['imdb_id'].map(len).max()
# ## saving schema
# api_data_schema = {'imdb_id':String(key_len+1)}
# api_data_schema
schema = get_schema(table_title_collection)
schema
# Out:
# {'imdb_id': String(length=11), 'collection_id': Integer()}

# %%
# saving mvp version
## Primary key is Genre_ID
table_title_collection.to_sql('title_collection',engine, index=False,dtype=schema, if_exists='replace')
# Out:
# 3917

# %% [markdown]
# ### `collections`

# %%
table_collections = df_collection
table_collections
# Out:
#       collection_id            collection_name
# 0                 0          #TemanTapiMenikah
# 1                 1     ... Cameras Collection
# 2                 2           .hack Collection
# 3                 3  10 giorni... - Collezione
# 4                 4       100 Girls Collection
# ...             ...                        ...
# 1938           1938                    달마야 시리즈
# 1939           1939                     독전 시리즈
# 1940           1940              동갑내기 과외하기 시리즈
# 1941           1941                반드시 크게 들을 것
# 1942           1942                     식객 시리즈
#
# [1943 rows x 2 columns]

# %%
# saving mvp version
table_collections.to_sql('collections',engine, index=False,
                         dtype=get_schema(table_collections),
                         if_exists='replace')
# Out:
# 1943

# %% [markdown]
# ### TMDB API Data

# %% [markdown]
# ~~Instructor Note: Saving 2 versions of API data: MVP and AAB~~

# %%
## Convert financial cols to float (error?)
df['revenue'] = df['revenue'].astype(float)
df['budget'] = df['budget'].astype(float)

# %%
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False                               NaN                   NaN
# 1      False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
# 2      False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN
# 3      False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN
# 4      False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN
# ...      ...                               ...                   ...
# 78392  False  /8AiCju3Guhxiq9Sznj8f7aJZofS.jpg                   NaN
# 78393  False                               NaN                   NaN
# 78394  False                               NaN                   NaN
# 78395  False                               NaN                   NaN
# 78396  False                               NaN                   NaN
#
#            budget  \
# 0        100000.0
# 1             0.0
# 2             0.0
# 3      76000000.0
# 4             0.0
# ...           ...
# 78392         0.0
# 78393         0.0
# 78394         0.0
# 78395         0.0
# 78396       400.0
#
#                                                                                                                                                                       genres  \
# 0                                                                                                                                                                         []
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                            [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 4                                                                                                                [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
# ...                                                                                                                                                                      ...
# 78392                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78393                                                                           [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}, {'id': 18, 'name': 'Drama'}]
# 78394                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78395                                                                                                                                    [{'id': 99, 'name': 'Documentary'}]
# 78396                                                                                                         [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
#
#                                                                         homepage  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                  http://www.universalstudiosentertainment.com/children-of-men/
# 4                                                                            NaN
# ...                                                                          ...
# 78392                                              http://icarusfilms.com/if-cli
# 78393                                                                        NaN
# 78394  https://www.michaelraeburn.com/site/web/mr/zimbabwe-countdown_documentary
# 78395                                                                        NaN
# 78396                                                                        NaN
#
#            id    imdb_id original_language                 original_title  \
# 0       30356  tt0144280                en  Whispers from a Shallow Grave
# 1       58520  tt0197633                en         Live Freaky Die Freaky
# 2      459563  tt0204250                en          Death of a Saleswoman
# 3        9693  tt0206634                en                Children of Men
# 4        9925  tt0244521                en                    Funny Money
# ...       ...        ...               ...                            ...
# 78392  387250  tt7098636                fr   Le Clitoris, ce cher inconnu
# 78393  640680  tt7246872                en         Tokyo Bedoone Tavaghof
# 78394  515137  tt7637550                en             Zimbabwe Countdown
# 78395  713681  tt9414698                en                   The Hot Shoe
# 78396  253999  tt9641790                en                     Clearwater
#
#                                                                                                                                                                                                                                                                                                           overview  \
# 0                                                                                                                                                            When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                            It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2      Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                                   In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 4      Henry Perkins, a mild-mannered accountant, accidentally trades briefcases with another man, to find out that there's a million dollars inside. Henry tells his unsuspecting wife of their new-found fortune, but she doesn't embrace it as well as he does. Soon they're joined by their best friends, a...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  Topics about female sexuality are growing in popularity. Magazines and talk shows all discuss it. Yet a fair percentage of women are said to suffer from female sexual dysfunction. While male sexual problems have traditionally received the most publicity, only recently has research begun into the...
# 78393                                                                                                                                                                                                                                                                                                          NaN
# 78394                                                                                                                                                                       Once touted as Zimbabwe's saviour, Robert Mugabe has become synonymous with bad government and misrule. But where did it all go wrong?
# 78395                                                                                                                          A Documentary Movie About Card Counting In The Casino Game of 21. The director used $5,000 of the movie's budget to learn the counting methods, and put them to the test on screen.
# 78396                                                                                                                                                                                   A woman has been abducted by the Clearwater killer, and it's down to one man to solve the murderer's clues and rescue her.
#
#        popularity                       poster_path  \
# 0           0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1           1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2           0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3          18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4           4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...           ...                               ...
# 78392       1.400  /aWHfVqrTlEkTjUmyiMWYjyd9gsW.jpg
# 78393       0.600  /764JbpPIGeApSheIj0v5WvAUpuk.jpg
# 78394       0.711  /vnpAEhWBDhf7I6m4XZqj3Vf27px.jpg
# 78395       0.600                               NaN
# 78396       2.744  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
#
#                                                                                                                                                                                                                                                                                               production_companies  \
# 0                                                                                                                                                                                                                                                                                                               []
# 1                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                   [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3               [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 4      [{'id': 110622, 'logo_path': None, 'name': 'FWE Picture Company', 'origin_country': ''}, {'id': 30584, 'logo_path': '/7s0nJTTztkOVeIgavfOwx36EBtj.png', 'name': 'Thinkfactory Media', 'origin_country': 'US'}, {'id': 110623, 'logo_path': None, 'name': 'Tobebo Filmproduktions', 'origin_country': ''}...
# ...                                                                                                                                                                                                                                                                                                            ...
# 78392  [{'id': 92745, 'logo_path': None, 'name': 'Cats & Dogs Films', 'origin_country': 'FR'}, {'id': 7106, 'logo_path': None, 'name': 'Sylicone', 'origin_country': 'FR'}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 639, 'logo_path': '/fN...
# 78393                                                                                                                                                                                                                                                                                                           []
# 78394                                                                                                                                                                                          [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}]
# 78395                                                                                                                                                                                                                                                                                                           []
# 78396                                                                                                                                                                                                                   [{'id': 174685, 'logo_path': None, 'name': 'Little Buster Studios', 'origin_country': ''}]
#
#                                                                                                                                production_countries  \
# 0                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                                                        [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3                                        [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4      [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# ...                                                                                                                                             ...
# 78392                                                                                                      [{'iso_3166_1': 'FR', 'name': 'France'}]
# 78393                                                                                                        [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 78394                                                            [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'ZW', 'name': 'Zimbabwe'}]
# 78395                                                                                                                                            []
# 78396                                                                                                                                            []
#
#       release_date     revenue  runtime  \
# 0       1997-01-01         0.0     90.0
# 1       2006-01-31         0.0     75.0
# 2       2006-09-18         0.0     77.0
# 3       2006-09-22  70595464.0    109.0
# 4       2006-01-01         0.0     98.0
# ...            ...         ...      ...
# 78392   2004-01-16         0.0     60.0
# 78393   2003-09-10         0.0     98.0
# 78394   2003-08-28         0.0     55.0
# 78395   2003-01-01         0.0     96.0
# 78396   2003-06-10         0.0     60.0
#
#                                                           spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 4      [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                    ...
# 78392  [{'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}]
# 78393    [{'english_name': 'Persian', 'iso_639_1': 'fa', 'name': 'فارسی'}]
# 78394  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78395  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 78396  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#          status  \
# 0      Released
# 1      Released
# 2      Released
# 3      Released
# 4      Released
# ...         ...
# 78392  Released
# 78393  Released
# 78394  Released
# 78395  Released
# 78396  Released
#
#                                                                                                                       tagline  \
# 0                                                                                                                         NaN
# 1                                                                                                                         NaN
# 2                                                            6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                                                                           The future's a thing of the past.
# 4      Henry Perkins accidentally trades briefcases with another man, to find out that there's five million dollars inside...
# ...                                                                                                                       ...
# 78392                                                                                                                     NaN
# 78393                                                                                                                     NaN
# 78394                                                                                                                     NaN
# 78395                                                                                                                     NaN
# 78396                                                                                                                     NaN
#
#                                   title  video  vote_average  vote_count  \
# 0         Whispers from a Shallow Grave  False           2.0           2
# 1                Live Freaky Die Freaky  False           3.8           8
# 2                 Death of a Saleswoman  False           3.0           1
# 3                       Children of Men  False           7.6        5794
# 4                           Funny Money  False           5.4          39
# ...                                 ...    ...           ...         ...
# 78392  The Clitoris: Forbidden Pleasure  False           8.0           2
# 78393                   Tokyo, Non-Stop  False           0.0           0
# 78394                Zimbabwe Countdown  False           5.0           4
# 78395                      The Hot Shoe  False           0.0           0
# 78396                        Clearwater  False           0.0           0
#
#       certification  \
# 0               NaN
# 1                NR
# 2               NaN
# 3                 R
# 4                 R
# ...             ...
# 78392           NaN
# 78393           NaN
# 78394           NaN
# 78395           NaN
# 78396           NaN
#
#                                                                          production_company_list  \
# 0                                                                                             []
# 1                                                                                             []
# 2                                                                   [Girl Next Door Productions]
# 3                              [Universal Pictures, Strike Entertainment, Hit & Run Productions]
# 4                 [FWE Picture Company, Thinkfactory Media, Tobebo Filmproduktions, Castel Film]
# ...                                                                                          ...
# 78392  [Cats & Dogs Films, Sylicone, ARTE, DR TV, Planète+, SBS TV, CNC, PROCIREP, Angoa-Agicoa]
# 78393                                                                                         []
# 78394                                                                       [ARTE France Cinéma]
# 78395                                                                                         []
# 78396                                                                    [Little Buster Studios]
#
#       collection
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 78392       None
# 78393       None
# 78394       None
# 78395       None
# 78396       None
#
# [78397 rows x 28 columns]

# %%
## Keeping some columns
cols_to_keep = ['imdb_id','budget','revenue','certification',
                'original_language','release_date','popularity','vote_average',
               'vote_count']
mvp = df[cols_to_keep]
mvp
# Out:
#          imdb_id      budget     revenue certification original_language  \
# 0      tt0144280    100000.0         0.0           NaN                en
# 1      tt0197633         0.0         0.0            NR                en
# 2      tt0204250         0.0         0.0           NaN                en
# 3      tt0206634  76000000.0  70595464.0             R                en
# 4      tt0244521         0.0         0.0             R                en
# ...          ...         ...         ...           ...               ...
# 78392  tt7098636         0.0         0.0           NaN                fr
# 78393  tt7246872         0.0         0.0           NaN                en
# 78394  tt7637550         0.0         0.0           NaN                en
# 78395  tt9414698         0.0         0.0           NaN                en
# 78396  tt9641790       400.0         0.0           NaN                en
#
#       release_date  popularity  vote_average  vote_count
# 0       1997-01-01       0.714           2.0           2
# 1       2006-01-31       1.957           3.8           8
# 2       2006-09-18       0.676           3.0           1
# 3       2006-09-22      18.314           7.6        5794
# 4       2006-01-01       4.218           5.4          39
# ...            ...         ...           ...         ...
# 78392   2004-01-16       1.400           8.0           2
# 78393   2003-09-10       0.600           0.0           0
# 78394   2003-08-28       0.711           5.0           4
# 78395   2003-01-01       0.600           0.0           0
# 78396   2003-06-10       2.744           0.0           0
#
# [78397 rows x 9 columns]

# %%
# table_production_companies = df_companies

# %%
mvp.isna().sum()
# Out:
# imdb_id                  0
# budget                   0
# revenue                  0
# certification        61436
# original_language        0
# release_date          1955
# popularity               0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
mvp
# Out:
#          imdb_id      budget     revenue certification original_language  \
# 0      tt0144280    100000.0         0.0           NaN                en
# 1      tt0197633         0.0         0.0            NR                en
# 2      tt0204250         0.0         0.0           NaN                en
# 3      tt0206634  76000000.0  70595464.0             R                en
# 4      tt0244521         0.0         0.0             R                en
# ...          ...         ...         ...           ...               ...
# 78392  tt7098636         0.0         0.0           NaN                fr
# 78393  tt7246872         0.0         0.0           NaN                en
# 78394  tt7637550         0.0         0.0           NaN                en
# 78395  tt9414698         0.0         0.0           NaN                en
# 78396  tt9641790       400.0         0.0           NaN                en
#
#       release_date  popularity  vote_average  vote_count
# 0       1997-01-01       0.714           2.0           2
# 1       2006-01-31       1.957           3.8           8
# 2       2006-09-18       0.676           3.0           1
# 3       2006-09-22      18.314           7.6        5794
# 4       2006-01-01       4.218           5.4          39
# ...            ...         ...           ...         ...
# 78392   2004-01-16       1.400           8.0           2
# 78393   2003-09-10       0.600           0.0           0
# 78394   2003-08-28       0.711           5.0           4
# 78395   2003-01-01       0.600           0.0           0
# 78396   2003-06-10       2.744           0.0           0
#
# [78397 rows x 9 columns]

# %%
# ## saving text length
# key_len = mvp['imdb_id'].map(len).max()
# cert_len = mvp['certification'].fillna('').map(len).max()
# lang_len = mvp['original_language'].map(len).max()

# key_len, cert_len,lang_len

# %%
# ## saving schema
# api_data_schema = {'imdb_id':String(key_len+1), 
#                  'budget':Float(),
#                    'revenue':Float(),
#                  'certification':Text(cert_len+1),
#                   'original_language':Text(lang_len+1)}
api_data_schema = get_schema(mvp.fillna('MISSING'))
api_data_schema
# Out:
# {'imdb_id': String(length=11),
#  'budget': Float(),
#  'revenue': Float(),
#  'certification': String(length=32),
#  'original_language': String(length=3),
#  'release_date': String(length=11),
#  'popularity': Float(),
#  'vote_average': Float(),
#  'vote_count': Integer()}

# %%
mvp = mvp.drop_duplicates()
mvp
# Out:
#          imdb_id      budget     revenue certification original_language  \
# 0      tt0144280    100000.0         0.0           NaN                en
# 1      tt0197633         0.0         0.0            NR                en
# 2      tt0204250         0.0         0.0           NaN                en
# 3      tt0206634  76000000.0  70595464.0             R                en
# 4      tt0244521         0.0         0.0             R                en
# ...          ...         ...         ...           ...               ...
# 78392  tt7098636         0.0         0.0           NaN                fr
# 78393  tt7246872         0.0         0.0           NaN                en
# 78394  tt7637550         0.0         0.0           NaN                en
# 78395  tt9414698         0.0         0.0           NaN                en
# 78396  tt9641790       400.0         0.0           NaN                en
#
#       release_date  popularity  vote_average  vote_count
# 0       1997-01-01       0.714           2.0           2
# 1       2006-01-31       1.957           3.8           8
# 2       2006-09-18       0.676           3.0           1
# 3       2006-09-22      18.314           7.6        5794
# 4       2006-01-01       4.218           5.4          39
# ...            ...         ...           ...         ...
# 78392   2004-01-16       1.400           8.0           2
# 78393   2003-09-10       0.600           0.0           0
# 78394   2003-08-28       0.711           5.0           4
# 78395   2003-01-01       0.600           0.0           0
# 78396   2003-06-10       2.744           0.0           0
#
# [78397 rows x 9 columns]

# %%
mvp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78397 entries, 0 to 78396
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   imdb_id            78397 non-null  object
#  1   budget             78397 non-null  float64
#  2   revenue            78397 non-null  float64
#  3   certification      16961 non-null  object
#  4   original_language  78397 non-null  object
#  5   release_date       76442 non-null  object
#  6   popularity         78397 non-null  float64
#  7   vote_average       78397 non-null  float64
#  8   vote_count         78397 non-null  int64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# saving mvp version
## Primary key is Genre_ID
mvp.to_sql('tmdb',engine, index=False,dtype=api_data_schema, if_exists='replace')
engine.execute('ALTER TABLE tmdb ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#      imdb_id      budget     revenue certification original_language  \
# 0  tt0035423  48000000.0  76019000.0         PG-13                en
# 1  tt0062336         0.0         0.0          None                es
# 2  tt0069049  12000000.0         0.0             R                en
# 3  tt0088751    350000.0         0.0          None                en
# 4  tt0093119   7500000.0         0.0          None                en
#
#   release_date  popularity  vote_average  vote_count
# 0   2001-12-25       9.183           6.3        1112
# 1   2020-02-21       1.400           5.3           3
# 2   2018-11-02       5.155           6.7         155
# 3   2005-04-22       2.190           3.4           5
# 4   2020-02-17       9.226           4.4          14

# %%
df.head()
# Out:
#    adult                     backdrop_path belongs_to_collection      budget  \
# 0  False                               NaN                   NaN    100000.0
# 1  False  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN         0.0
# 2  False  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg                   NaN         0.0
# 3  False  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg                   NaN  76000000.0
# 4  False  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg                   NaN         0.0
#
#                                                                                                                                                                   genres  \
# 0                                                                                                                                                                     []
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}]
# 2                                                                                                        [{'id': 9648, 'name': 'Mystery'}, {'id': 35, 'name': 'Comedy'}]
# 3                                    [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]
# 4                                                                                                            [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
#
#                                                         homepage      id  \
# 0                                                            NaN   30356
# 1                                                            NaN   58520
# 2                                                            NaN  459563
# 3  http://www.universalstudiosentertainment.com/children-of-men/    9693
# 4                                                            NaN    9925
#
#      imdb_id original_language                 original_title  \
# 0  tt0144280                en  Whispers from a Shallow Grave
# 1  tt0197633                en         Live Freaky Die Freaky
# 2  tt0204250                en          Death of a Saleswoman
# 3  tt0206634                en                Children of Men
# 4  tt0244521                en                    Funny Money
#
#                                                                                                                                                                                                                                                                                                       overview  \
# 0                                                                                                                                                        When a beautiful photo model disappears, police track the photographer who last saw her. At his trial, the model herself tells her side of the story.
# 1                                                                                                                                                                                        It is the year 3069 and the Earth has been robbed of all its natural resources, destroyed by war and ozone depletion.
# 2  Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her pers...
# 3                                                               In 2027, in a chaotic world in which humans can no longer procreate, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea, where her child's birth may help scientists save the future of humankind.
# 4  Henry Perkins, a mild-mannered accountant, accidentally trades briefcases with another man, to find out that there's a million dollars inside. Henry tells his unsuspecting wife of their new-found fortune, but she doesn't embrace it as well as he does. Soon they're joined by their best friends, a...
#
#    popularity                       poster_path  \
# 0       0.714  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 1       1.957  /qt7IVXzGca5wS68WZ6PBWHkTcMz.jpg
# 2       0.676  /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 3      18.314  /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 4       4.218  /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
#
#                                                                                                                                                                                                                                                                                           production_companies  \
# 0                                                                                                                                                                                                                                                                                                           []
# 1                                                                                                                                                                                                                                                                                                           []
# 2                                                                                                                                                                                                               [{'id': 90905, 'logo_path': None, 'name': 'Girl Next Door Productions', 'origin_country': ''}]
# 3           [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 655, 'logo_path': None, 'name': 'Strike Entertainment', 'origin_country': ''}, {'id': 11429, 'logo_path': None, 'name': 'Hit & Run Productions', 'origin_country': ''}]
# 4  [{'id': 110622, 'logo_path': None, 'name': 'FWE Picture Company', 'origin_country': ''}, {'id': 30584, 'logo_path': '/7s0nJTTztkOVeIgavfOwx36EBtj.png', 'name': 'Thinkfactory Media', 'origin_country': 'US'}, {'id': 110623, 'logo_path': None, 'name': 'Tobebo Filmproduktions', 'origin_country': ''}...
#
#                                                                                                                            production_countries  \
# 0                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2                                                                                    [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3                                    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
#
#   release_date     revenue  runtime  \
# 0   1997-01-01         0.0     90.0
# 1   2006-01-31         0.0     75.0
# 2   2006-09-18         0.0     77.0
# 3   2006-09-22  70595464.0    109.0
# 4   2006-01-01         0.0     98.0
#
#                                                       spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 2  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 3  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
# 4  [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]
#
#      status  \
# 0  Released
# 1  Released
# 2  Released
# 3  Released
# 4  Released
#
#                                                                                                                   tagline  \
# 0                                                                                                                     NaN
# 1                                                                                                                     NaN
# 2                                                        6 housewives. 1 dead body. A trunk full of plastic storage wear.
# 3                                                                                       The future's a thing of the past.
# 4  Henry Perkins accidentally trades briefcases with another man, to find out that there's five million dollars inside...
#
#                            title  video  vote_average  vote_count  \
# 0  Whispers from a Shallow Grave  False           2.0           2
# 1         Live Freaky Die Freaky  False           3.8           8
# 2          Death of a Saleswoman  False           3.0           1
# 3                Children of Men  False           7.6        5794
# 4                    Funny Money  False           5.4          39
#
#   certification  \
# 0           NaN
# 1            NR
# 2           NaN
# 3             R
# 4             R
#
#                                                           production_company_list  \
# 0                                                                              []
# 1                                                                              []
# 2                                                    [Girl Next Door Productions]
# 3               [Universal Pictures, Strike Entertainment, Hit & Run Productions]
# 4  [FWE Picture Company, Thinkfactory Media, Tobebo Filmproduktions, Castel Film]
#
#   collection
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None

# %%
# # saving AAB version
# ## Primary key is Genre_ID
# df.to_sql('tmdb_data_aab',engine, index=False,dtype=api_data_schema, if_exists='replace')
# engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %% [markdown]
# ### Troubleshoot: Error with AAB Version

# %% [markdown]
# - Error when trying to save AAB version.
# - Built a recursive feature addition loop to try adding more and more columns before running command that error'd.
# - Used function to programmatically make new schema each time (thinking the schema was part of the issue - but it may have been fine).

# %% [markdown]
# ## Bookmark: Need to Fix Title/Original Title

# %% [markdown]
# - Asian characters seem to be the issue. Need to identify and remove rows with incompatible characters.

# %%
len(df)
# Out:
# 78397

# %%
# # identifying incomaptible rows
# bad_titles = (df['original_title']!=df['title']) &\
#                 (df['original_language']!='en') &\
#                ~df['spoken_languages'].str.contains('english',case=False)
# df[bad_titles]

# %%
# df = df[~bad_titles]
# df

# %%
# df['revenue'] = df['revenue'].astype(float)

# %%
# df = df.reset_index(drop=True)
# df

# %%
# schema = get_schema(df)
# schema['title'] = Text()
# schema['original_title'] = Text()

# %%
# schema

# %% [markdown]
# ### Dropping Titles, since these should be joinable with title basics table anyway

# %%
# df_for_db = df.drop(columns=['title','original_title'])
# df_for_db

# %%
# df_for_db.to_sql('tmdb_data_aab',engine, index=False, 
#                             if_exists='replace',dtype=get_schema(df_for_db))
# #                           method='multi')

# %%
# ## loop through adding more columns and remove what errors
# good_cols = [*cols_to_keep]
# bad_cols = []
# all_cols = df.drop(columns=cols_to_keep).columns

# for col in all_cols:
#     print(f"- Adding {col}")
#     try: 
#         cols_to_try = [*good_cols, col]
#         df_filtered = df[ cols_to_try]
#         schema= get_schema(df_filtered)
#         ## Primary key is Genre_ID
#         df_filtered.to_sql('tmdb_data_aab',engine, index=False,
#                             if_exists='replace',#dtype=schema,
#                           method='multi')
        
#         # append col name to good_cols if no error
#         good_cols.append(col)
#     except Exception as e:
#         print("   - ERROR")
#         bad_cols.append({col:e})
# bad_cols

# %%
# engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %%
# q = """SELECT * FROM tmdb_data_aab LIMIT 5"""
# pd.read_sql(q,engine)

# %% [markdown]
# # Final Tables Check

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#        Tables_in_movies-viz
# 0               collections
# 1                    genres
# 2      production_companies
# 3              title_basics
# 4          title_collection
# 5              title_genres
# 6  title_production_company
# 7             title_ratings
# 8                      tmdb
